# %% [markdown]
# ## Tasks:
# Extract invoice number, invoice date, line items from invoice images. Also, the model
# structure should be scalable where we can train a model for any field and extract the
# key-value pair. Find sample data from the kaggle, huggingface, github. you can convert
# pdf files to image files.

# %% [markdown]
# # Install Required Python Packages

# %%
pip install pytesseract pillow opencv-python
# Out:
# Requirement already satisfied: pytesseract in c:\users\gouthum\.conda\envs\myenv\lib\site-packages (0.3.13)
# Requirement already satisfied: pillow in c:\users\gouthum\.conda\envs\myenv\lib\site-packages (11.2.1)
# Requirement already satisfied: opencv-python in c:\users\gouthum\.conda\envs\myenv\lib\site-packages (4.12.0.88)
# Requirement already satisfied: packaging>=21.3 in c:\users\gouthum\.conda\envs\myenv\lib\site-packages (from pytesseract) (25.0)
# Requirement already satisfied: numpy<2.3.0,>=2 in c:\users\gouthum\.conda\envs\myenv\lib\site-packages (from opencv-python) (2.2.6)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ## Confirm Tesseract Path in Python

# %%
import pytesseract

# Set this to where Tesseract is installed on your machine
pytesseract.pytesseract.tesseract_cmd = r'C:\Program Files\Tesseract-OCR\tesseract.exe'

# Test version call
print(pytesseract.get_tesseract_version())
# Out:
# 5.5.0.20241111

# %% [markdown]
# # Extract Text from Invoice Images

# %% [markdown]
# #### What it will do :
#                       Read invoice images from My dataset folder
#
#                       Extract text using Tesseract OCR
#
#                       Save the extracted text as .txt files in my output folder

# %% [markdown]
# ## Extract text from one image(Testing)

# %%
import os
from PIL import Image
import pytesseract

# Set the Tesseract executable path (adjust if needed)
pytesseract.pytesseract.tesseract_cmd = r'C:\Program Files\Tesseract-OCR\tesseract.exe'

def extract_text_from_image(image_path, output_text_path):
    """
    Extract text from a single image and save it to a text file.
    """
    try:
        img = Image.open(image_path)
        text = pytesseract.image_to_string(img)
        
        with open(output_text_path, 'w', encoding='utf-8') as f:
            f.write(text)
        
        print(f"[SUCCESS] Extracted text saved to: {output_text_path}")
    except Exception as e:
        print(f"[ERROR] Could not process {image_path}: {e}")

if __name__ == "__main__":
    # Replace these paths with your actual file paths
    input_image_path = r'C:\Users\Gouthum\Downloads\Project\batch_3\batch_1\batch1_1\batch1-0479.jpg'
    output_text_path = r'C:\Users\Gouthum\Downloads\Project\output\ocr_text\batch1-0479.txt'

    
    extract_text_from_image(input_image_path, output_text_path)
# Out:
# [SUCCESS] Extracted text saved to: C:\Users\Gouthum\Downloads\Project\output\ocr_text\batch1-0479.txt

# %% [markdown]
# ## Image2

# %%
import os
from PIL import Image
import pytesseract

# Set the Tesseract executable path (adjust if needed)
pytesseract.pytesseract.tesseract_cmd = r'C:\Program Files\Tesseract-OCR\tesseract.exe'

def extract_text_from_image(image_path, output_text_path):
    """
    Extract text from a single image and save it to a text file.
    """
    try:
        img = Image.open(image_path)
        text = pytesseract.image_to_string(img)
        
        with open(output_text_path, 'w', encoding='utf-8') as f:
            f.write(text)
        
        print(f"[SUCCESS] Extracted text saved to: {output_text_path}")
    except Exception as e:
        print(f"[ERROR] Could not process {image_path}: {e}")

if __name__ == "__main__":
    # Replace these paths with your actual file paths
    input_image_path = r'C:\Users\Gouthum\Downloads\Project\batch_3\batch_1\batch1_1\batch1-0477.jpg'
    output_text_path = r'C:\Users\Gouthum\Downloads\Project\output\ocr_text\batch1-0477.txt'

    
    extract_text_from_image(input_image_path, output_text_path)
# Out:
# [SUCCESS] Extracted text saved to: C:\Users\Gouthum\Downloads\Project\output\ocr_text\batch1-0477.txt

# %% [markdown]
# #### OCR is working perfectly and Im  already extracting real invoice text from the image

# %% [markdown]
# # Extract Key Fields from OCR Text File

# %% [markdown]
# ##### Invoice Number
#
#       Invoice Date
#
#       Line Items (products, quantity, price, etc.)

# %% [markdown]
# ##### Im using  regular expressions (regex) or other text parsing methods

# %%
import re

def extract_invoice_number(text):
    
    match = re.search(r'Invoice\s*no[:\s]*([A-Za-z0-9\-]+)', text, re.IGNORECASE)
    if match:
        return match.group(1)
    return None

# %%
def extract_invoice_date(text):
    # Match dates like 05/07/2019, 05-07-2019, 2019/07/05, 2019-07-05
    date_patterns = [
        r'(\b\d{2}[/-]\d{2}[/-]\d{4}\b)',  # DD/MM/YYYY or MM/DD/YYYY
        r'(\b\d{4}[/-]\d{2}[/-]\d{2}\b)'   # YYYY/MM/DD or YYYY-MM-DD
    ]
    for pattern in date_patterns:
        match = re.search(pattern, text)
        if match:
            return match.group(1)
    return None

# %%
def extract_line_items(text):
    # Very basic example: extract lines under "ITEMS" section until "SUMMARY"
    items = []
    try:
        # Extract text between ITEMS and SUMMARY sections
        items_section = re.search(r'ITEMS(.*)SUMMARY', text, re.DOTALL | re.IGNORECASE)
        if items_section:
            lines = items_section.group(1).strip().split('\n')
            # Clean empty lines and strip spaces
            lines = [line.strip() for line in lines if line.strip()]
            # For simplicity, return the lines directly (you can parse further)
            return lines
    except Exception as e:
        print(f"Error extracting line items: {e}")
    return items

# %%
def extract_fields_from_file(file_path):
    with open(file_path, 'r', encoding='utf-8') as f:
        text = f.read()
    
    invoice_no = extract_invoice_number(text)
    invoice_date = extract_invoice_date(text)
    line_items = extract_line_items(text)

    return {
        'invoice_number': invoice_no,
        'invoice_date': invoice_date,
        'line_items': line_items
    }

# %%
if __name__ == "__main__":
    file_path = r'C:\Users\Gouthum\Downloads\Project\output\ocr_text\batch1-0479.txt'

    fields = extract_fields_from_file(file_path)
    print("Extracted Fields:")
    print(f"Invoice Number: {fields['invoice_number']}")
    print(f"Invoice Date: {fields['invoice_date']}")
    print(f"Line Items:\n")
    for item in fields['line_items']:
        print(item)
# Out:
# Extracted Fields:
# Invoice Number: 69721323
# Invoice Date: 05/07/2019
# Line Items:
#
# No. Description Qty UM Net price Net worth VAT [%] Gross
# worth
# ils Tie Dyeing Fluffy Rugs Anti-Skid 4,00 each 25,48 101,92 10% 112,11
# Area Rug Dining Room Carpet
# Floor Bedroom Mat
# 2. Galaxy Butterfly Area Rugs 2,00 each 13,69 27,38 10% 30,12
# Children Bedroom Non-Slip
# Doormat Floor Mat Carpet
# oo Colorful Marble Printed Living 2,00 each 12,49 24,98 10% 27,48
# Room and Bedroom Area Rugs
# Carpet CNK2413
# 4. Red Traditional Oriental 4,00 each 39,98 159,92 10% 175,91
# Medallion 8x10 Area Rug Carpet
# 2x3 Mat 5x7 Rugs
# Dy YILONG 2.5'x4' Small Hand 4,00 each 2 000,00 8 000,00 10% 8 800,00
# Knotted Silk Carpets Antistatic
# Floor Area Rug 844B

# %% [markdown]
# ## Image2

# %%
if __name__ == "__main__":
    file_path = r'C:\Users\Gouthum\Downloads\Project\output\ocr_text\batch1-0477.txt'

    fields = extract_fields_from_file(file_path)
    print("Extracted Fields:")
    print(f"Invoice Number: {fields['invoice_number']}")
    print(f"Invoice Date: {fields['invoice_date']}")
    print(f"Line Items:\n")
    for item in fields['line_items']:
        print(item)
# Out:
# Extracted Fields:
# Invoice Number: 65981953
# Invoice Date: 05/14/2020
# Line Items:
#
# No. Description Qty UM Net price Net worth VAT [%] Gross
# worth
# ils iBUYPOWER Gaming Computer 1,00 each 509,95 509,95 10% 560,95
# AMD Ryzen 3 3100, Radeon RX
# 550, 240GB SSD, WiFi Ready
# 2. Dell Desktop Computer PC Core 1,00 each 124,95 124,95 10% 137,45
# i5 3.1GHz 8GB RAM 500GB HD
# Wifi DVD Windows 10
# 2 HP 8300 Slim Desktop Small 3,00 each 99,99 299,97 10% 329,97
# Computer PC i5 3.2GHz 4GB
# 500GB Windows 10 Pro WiFi

# %% [markdown]
# ### Invoice Number and Invoice Date are now extracted correctly

# %% [markdown]
# # parsing the Line Items in a structured way

# %% [markdown]
# ### Item number & description (sometimes multiline)
#
#     Quantity (Qty)
#
#     Unit of measure (UM)
#
#     Net price
#
#     Net worth
#
#     VAT %
#
#     Gross worth

# %%
import re

def extract_line_items(text):
    # Extract text between ITEMS and SUMMARY (as before)
    items = []
    try:
        items_section = re.search(r'ITEMS(.*)SUMMARY', text, re.DOTALL | re.IGNORECASE)
        if items_section:
            lines = items_section.group(1).strip().split('\n')
            lines = [line.strip() for line in lines if line.strip()]
            return lines
    except Exception as e:
        print(f"Error extracting line items: {e}")
    return items

def parse_line_items(lines):
    items = []
    current_item_lines = []
    
    for line in lines:
        if re.match(r'^\d+\.', line.strip()):
            if current_item_lines:
                items.append(' '.join(current_item_lines))
                current_item_lines = []
            current_item_lines.append(line.strip())
        else:
            current_item_lines.append(line.strip())
    if current_item_lines:
        items.append(' '.join(current_item_lines))
    return items

# Read the OCR text file first
file_path = r'C:\Users\Gouthum\Downloads\Project\output\ocr_text\batch1-0479.txt'
with open(file_path, 'r', encoding='utf-8') as f:
    text = f.read()

# Extract and parse line items
line_items = extract_line_items(text)
parsed_items = parse_line_items(line_items)

for i, item in enumerate(parsed_items, 1):
    print(f"Item {i}: {item}\n")
# Out:
# Item 1: No. Description Qty UM Net price Net worth VAT [%] Gross worth ils Tie Dyeing Fluffy Rugs Anti-Skid 4,00 each 25,48 101,92 10% 112,11 Area Rug Dining Room Carpet Floor Bedroom Mat
#
# Item 2: 2. Galaxy Butterfly Area Rugs 2,00 each 13,69 27,38 10% 30,12 Children Bedroom Non-Slip Doormat Floor Mat Carpet oo Colorful Marble Printed Living 2,00 each 12,49 24,98 10% 27,48 Room and Bedroom Area Rugs Carpet CNK2413
#
# Item 3: 4. Red Traditional Oriental 4,00 each 39,98 159,92 10% 175,91 Medallion 8x10 Area Rug Carpet 2x3 Mat 5x7 Rugs Dy YILONG 2.5'x4' Small Hand 4,00 each 2 000,00 8 000,00 10% 8 800,00 Knotted Silk Carpets Antistatic Floor Area Rug 844B

# %% [markdown]
# ## Image2

# %%
import re

def extract_line_items(text):
    # Extract text between ITEMS and SUMMARY (as before)
    items = []
    try:
        items_section = re.search(r'ITEMS(.*)SUMMARY', text, re.DOTALL | re.IGNORECASE)
        if items_section:
            lines = items_section.group(1).strip().split('\n')
            lines = [line.strip() for line in lines if line.strip()]
            return lines
    except Exception as e:
        print(f"Error extracting line items: {e}")
    return items

def parse_line_items(lines):
    items = []
    current_item_lines = []
    
    for line in lines:
        if re.match(r'^\d+\.', line.strip()):
            if current_item_lines:
                items.append(' '.join(current_item_lines))
                current_item_lines = []
            current_item_lines.append(line.strip())
        else:
            current_item_lines.append(line.strip())
    if current_item_lines:
        items.append(' '.join(current_item_lines))
    return items

# Read the OCR text file first
file_path = r'C:\Users\Gouthum\Downloads\Project\output\ocr_text\batch1-0477.txt'
with open(file_path, 'r', encoding='utf-8') as f:
    text = f.read()

# Extract and parse line items
line_items = extract_line_items(text)
parsed_items = parse_line_items(line_items)

for i, item in enumerate(parsed_items, 1):
    print(f"Item {i}: {item}\n")
# Out:
# Item 1: No. Description Qty UM Net price Net worth VAT [%] Gross worth ils iBUYPOWER Gaming Computer 1,00 each 509,95 509,95 10% 560,95 AMD Ryzen 3 3100, Radeon RX 550, 240GB SSD, WiFi Ready
#
# Item 2: 2. Dell Desktop Computer PC Core 1,00 each 124,95 124,95 10% 137,45 i5 3.1GHz 8GB RAM 500GB HD Wifi DVD Windows 10 2 HP 8300 Slim Desktop Small 3,00 each 99,99 299,97 10% 329,97 Computer PC i5 3.2GHz 4GB 500GB Windows 10 Pro WiFi

# %% [markdown]
# # Parsing Based on Line Item Structure

# %%
import re

def extract_invoice_fields(text):
    fields = {
        "invoice_number": None,
        "invoice_date": None,
        "seller": {},
        "client": {},
        "iban": None,
    }

    # Extract Invoice Number
    invoice_no_match = re.search(r"Invoice\s+no[:\-]?\s*(\d+)", text, re.IGNORECASE)
    if invoice_no_match:
        fields["invoice_number"] = invoice_no_match.group(1)

    # Extract Invoice Date
    date_match = re.search(r"\b(\d{2}/\d{2}/\d{4})\b", text)
    if date_match:
        fields["invoice_date"] = date_match.group(1)

    # Extract Seller Info (multiline between 'Seller:' and 'Tax Id')
    seller_match = re.search(r"Seller:\s*(.*?)\s*Tax Id:\s*([\d\-]+)", text, re.IGNORECASE | re.DOTALL)
    if seller_match:
        seller_info = seller_match.group(1).strip().replace("\n", " ")
        fields["seller"]["name_address"] = ' '.join(seller_info.split())
        fields["seller"]["tax_id"] = seller_match.group(2).strip()

    # Extract Client Info (multiline between 'Client:' and 'Tax Id')
    client_match = re.search(r"Client:\s*(.*?)\s*Tax Id:\s*([\d\-]+)", text, re.IGNORECASE | re.DOTALL)
    if client_match:
        client_info = client_match.group(1).strip().replace("\n", " ")
        fields["client"]["name_address"] = ' '.join(client_info.split())
        fields["client"]["tax_id"] = client_match.group(2).strip()

    # Extract IBAN
    iban_match = re.search(r"IBAN:\s*([A-Z0-9]+)", text, re.IGNORECASE)
    if iban_match:
        fields["iban"] = iban_match.group(1).strip()

    return fields


# Sample input
text_line = """
Invoice no: 69721323

Date of issue:

Seller:

Murray-Eaton
773 Joseph Plains
West Nicoleville, AZ 46136

Tax Id: 936-71-8228

05/07/2019

Client:

Cuevas, Reid and Hurst
98071 Daniel Heights
Careyside, MS 59400

Tax Id: 949-88-4885

IBAN: GB22XZGA27411153163644

ITEMS
...
"""

# Extracted fields
fields = extract_invoice_fields(text_line)

# Print results
print("Extracted Fields:\n")
print(f"Invoice Number: {fields['invoice_number']}")
print(f"Invoice Date: {fields['invoice_date']}")
print(f"Seller Info:\n  Name & Address: {fields['seller'].get('name_address')}\n  Tax ID: {fields['seller'].get('tax_id')}")
print(f"Client Info:\n  Name & Address: {fields['client'].get('name_address')}\n  Tax ID: {fields['client'].get('tax_id')}")
print(f"IBAN: {fields['iban']}")
# Out:
# Extracted Fields:
#
# Invoice Number: 69721323
# Invoice Date: 05/07/2019
# Seller Info:
#   Name & Address: Murray-Eaton 773 Joseph Plains West Nicoleville, AZ 46136
#   Tax ID: 936-71-8228
# Client Info:
#   Name & Address: Cuevas, Reid and Hurst 98071 Daniel Heights Careyside, MS 59400
#   Tax ID: 949-88-4885
# IBAN: GB22XZGA27411153163644

# %% [markdown]
# ## Example2

# %%
import re

def extract_invoice_fields(text):
    fields = {
        "invoice_number": None,
        "invoice_date": None,
        "seller": {},
        "client": {},
        "iban": None,
    }

    # Extract Invoice Number
    invoice_no_match = re.search(r"Invoice\s+no[:\-]?\s*(\d+)", text, re.IGNORECASE)
    if invoice_no_match:
        fields["invoice_number"] = invoice_no_match.group(1)

    # Extract Invoice Date
    date_match = re.search(r"\b(\d{2}/\d{2}/\d{4})\b", text)
    if date_match:
        fields["invoice_date"] = date_match.group(1)

    # Extract Seller Info (multiline between 'Seller:' and 'Tax Id')
    seller_match = re.search(r"Seller:\s*(.*?)\s*Tax Id:\s*([\d\-]+)", text, re.IGNORECASE | re.DOTALL)
    if seller_match:
        seller_info = seller_match.group(1).strip().replace("\n", " ")
        fields["seller"]["name_address"] = ' '.join(seller_info.split())
        fields["seller"]["tax_id"] = seller_match.group(2).strip()

    # Extract Client Info (multiline between 'Client:' and 'Tax Id')
    client_match = re.search(r"Client:\s*(.*?)\s*Tax Id:\s*([\d\-]+)", text, re.IGNORECASE | re.DOTALL)
    if client_match:
        client_info = client_match.group(1).strip().replace("\n", " ")
        fields["client"]["name_address"] = ' '.join(client_info.split())
        fields["client"]["tax_id"] = client_match.group(2).strip()

    # Extract IBAN
    iban_match = re.search(r"IBAN:\s*([A-Z0-9]+)", text, re.IGNORECASE)
    if iban_match:
        fields["iban"] = iban_match.group(1).strip()

    return fields


# Sample input
text_line = """
Invoice no: 65981953

Date of issue:

Seller:

Horton LLC
44374 Watkins Points
Norriston, IL 77707

05/14/2020

Client:

Jackson-Holland
167 Howard Place Suite 420
Gordonville, NM 91832

Tax Id: 932-86-9428
IBAN: GB9OSKPB52785824368203

Tax Id: 978-99-3941

ITEMS

...
"""

# Extracted fields
fields = extract_invoice_fields(text_line)

# Print results
print("Extracted Fields:\n")
print(f"Invoice Number: {fields['invoice_number']}")
print(f"Invoice Date: {fields['invoice_date']}")
print(f"Seller Info:\n  Name & Address: {fields['seller'].get('name_address')}\n  Tax ID: {fields['seller'].get('tax_id')}")
print(f"Client Info:\n  Name & Address: {fields['client'].get('name_address')}\n  Tax ID: {fields['client'].get('tax_id')}")
print(f"IBAN: {fields['iban']}")
# Out:
# Extracted Fields:
#
# Invoice Number: 65981953
# Invoice Date: 05/14/2020
# Seller Info:
#   Name & Address: Horton LLC 44374 Watkins Points Norriston, IL 77707 05/14/2020 Client: Jackson-Holland 167 Howard Place Suite 420 Gordonville, NM 91832
#   Tax ID: 932-86-9428
# Client Info:
#   Name & Address: Jackson-Holland 167 Howard Place Suite 420 Gordonville, NM 91832
#   Tax ID: 932-86-9428
# IBAN: GB9OSKPB52785824368203

# %% [markdown]
# # Extracting line items from Invoice Number, Invoice Date, Seller Info, Client Info, IBAN  From Image

# %%
import pytesseract
from PIL import Image
import re

# Path to tesseract executable (update path if needed)
# Example for Windows:
# pytesseract.pytesseract.tesseract_cmd = r'C:\Program Files\Tesseract-OCR\tesseract.exe'

def extract_invoice_fields(text):
    fields = {
        "invoice_number": None,
        "invoice_date": None,
        "seller": {"name": None, "address": None, "tax_id": None},
        "client": {"name": None, "address": None, "tax_id": None},
        "iban": None,
    }

    # Invoice Number
    invoice_no_match = re.search(r"Invoice\s+no[:\-]?\s*(\d+)", text, re.IGNORECASE)
    if invoice_no_match:
        fields["invoice_number"] = invoice_no_match.group(1)

    # Invoice Date
    date_match = re.search(r"\b(\d{2}/\d{2}/\d{4})\b", text)
    if date_match:
        fields["invoice_date"] = date_match.group(1)

    # Seller
    seller_match = re.search(r"Seller:\s*(.*?)\s*Tax Id:\s*([\d\-]+)", text, re.IGNORECASE | re.DOTALL)
    if seller_match:
        seller_block = seller_match.group(1).strip().split("\n", 1)
        if len(seller_block) == 2:
            fields["seller"]["name"] = seller_block[0].strip()
            fields["seller"]["address"] = ' '.join(seller_block[1].strip().split())
        else:
            fields["seller"]["name"] = seller_block[0].strip()
        fields["seller"]["tax_id"] = seller_match.group(2).strip()

    # Client
    client_match = re.search(r"Client:\s*(.*?)\s*Tax Id:\s*([\d\-]+)", text, re.IGNORECASE | re.DOTALL)
    if client_match:
        client_block = client_match.group(1).strip().split("\n", 1)
        if len(client_block) == 2:
            fields["client"]["name"] = client_block[0].strip()
            fields["client"]["address"] = ' '.join(client_block[1].strip().split())
        else:
            fields["client"]["name"] = client_block[0].strip()
        fields["client"]["tax_id"] = client_match.group(2).strip()

    # IBAN
    iban_match = re.search(r"IBAN:\s*([A-Z0-9]+)", text, re.IGNORECASE)
    if iban_match:
        fields["iban"] = iban_match.group(1).strip()

    return fields

# ----------- MAIN IMAGE PROCESSING -----------

# Load image file
image_path = "C:/Users/Gouthum/Downloads/Project/batch_3/batch_1/batch1_1/batch1-0479.jpg"  # ← Replace with my invoice image path
image = Image.open(image_path)

# Extract text from image using OCR
ocr_text = pytesseract.image_to_string(image)

# Apply extraction logic
invoice_data = extract_invoice_fields(ocr_text)

# Print extracted data
print("Extracted Fields:\n")
print(f"Invoice Number: {invoice_data['invoice_number']}")
print(f"Invoice Date: {invoice_data['invoice_date']}")
print("Seller Info:")
print(f"  Name: {invoice_data['seller'].get('name')}")
print(f"  Address: {invoice_data['seller'].get('address')}")
print(f"  Tax ID: {invoice_data['seller'].get('tax_id')}")
print("Client Info:")
print(f"  Name: {invoice_data['client'].get('name')}")
print(f"  Address: {invoice_data['client'].get('address')}")
print(f"  Tax ID: {invoice_data['client'].get('tax_id')}")
print(f"IBAN: {invoice_data['iban']}")
# Out:
# Extracted Fields:
#
# Invoice Number: 69721323
# Invoice Date: 05/07/2019
# Seller Info:
#   Name: Murray-Eaton
#   Address: 773 Joseph Plains West Nicoleville, AZ 46136
#   Tax ID: 936-71-8228
# Client Info:
#   Name: Cuevas, Reid and Hurst
#   Address: 98071 Daniel Heights Careyside, MS 59400
#   Tax ID: 949-88-4885
# IBAN: GB22XZGA27411153163644

# %% [markdown]
# ## image3

# %%
import pytesseract
from PIL import Image
import re

# Path to tesseract executable (update path if needed)
# Example for Windows:
# pytesseract.pytesseract.tesseract_cmd = r'C:\Program Files\Tesseract-OCR\tesseract.exe'

def extract_invoice_fields(text):
    fields = {
        "invoice_number": None,
        "invoice_date": None,
        "seller": {"name": None, "address": None, "tax_id": None},
        "client": {"name": None, "address": None, "tax_id": None},
        "iban": None,
    }

    # Invoice Number
    invoice_no_match = re.search(r"Invoice\s+no[:\-]?\s*(\d+)", text, re.IGNORECASE)
    if invoice_no_match:
        fields["invoice_number"] = invoice_no_match.group(1)

    # Invoice Date
    date_match = re.search(r"\b(\d{2}/\d{2}/\d{4})\b", text)
    if date_match:
        fields["invoice_date"] = date_match.group(1)

    # Seller
    seller_match = re.search(r"Seller:\s*(.*?)\s*Tax Id:\s*([\d\-]+)", text, re.IGNORECASE | re.DOTALL)
    if seller_match:
        seller_block = seller_match.group(1).strip().split("\n", 1)
        if len(seller_block) == 2:
            fields["seller"]["name"] = seller_block[0].strip()
            fields["seller"]["address"] = ' '.join(seller_block[1].strip().split())
        else:
            fields["seller"]["name"] = seller_block[0].strip()
        fields["seller"]["tax_id"] = seller_match.group(2).strip()

    # Client
    client_match = re.search(r"Client:\s*(.*?)\s*Tax Id:\s*([\d\-]+)", text, re.IGNORECASE | re.DOTALL)
    if client_match:
        client_block = client_match.group(1).strip().split("\n", 1)
        if len(client_block) == 2:
            fields["client"]["name"] = client_block[0].strip()
            fields["client"]["address"] = ' '.join(client_block[1].strip().split())
        else:
            fields["client"]["name"] = client_block[0].strip()
        fields["client"]["tax_id"] = client_match.group(2).strip()

    # IBAN
    iban_match = re.search(r"IBAN:\s*([A-Z0-9]+)", text, re.IGNORECASE)
    if iban_match:
        fields["iban"] = iban_match.group(1).strip()

    return fields

# ----------- MAIN IMAGE PROCESSING -----------

# Load image file
image_path = "C:/Users/Gouthum/Downloads/Project/batch_3/batch_1/batch1_1/batch1-0477.jpg"  # ← Replace with my invoice image path
image = Image.open(image_path)

# Extract text from image using OCR
ocr_text = pytesseract.image_to_string(image)

# Apply extraction logic
invoice_data = extract_invoice_fields(ocr_text)

# Print extracted data
print("Extracted Fields:\n")
print(f"Invoice Number: {invoice_data['invoice_number']}")
print(f"Invoice Date: {invoice_data['invoice_date']}")
print("Seller Info:")
print(f"  Name: {invoice_data['seller'].get('name')}")
print(f"  Address: {invoice_data['seller'].get('address')}")
print(f"  Tax ID: {invoice_data['seller'].get('tax_id')}")
print("Client Info:")
print(f"  Name: {invoice_data['client'].get('name')}")
print(f"  Address: {invoice_data['client'].get('address')}")
print(f"  Tax ID: {invoice_data['client'].get('tax_id')}")
print(f"IBAN: {invoice_data['iban']}")
# Out:
# Extracted Fields:
#
# Invoice Number: 65981953
# Invoice Date: 05/14/2020
# Seller Info:
#   Name: Horton LLC
#   Address: 44374 Watkins Points Norriston, IL 77707 05/14/2020 Client: Jackson-Holland 167 Howard Place Suite 420 Gordonville, NM 91832
#   Tax ID: 932-86-9428
# Client Info:
#   Name: Jackson-Holland
#   Address: 167 Howard Place Suite 420 Gordonville, NM 91832
#   Tax ID: 932-86-9428
# IBAN: GB9OSKPB52785824368203

# %% [markdown]
# # Image2

# %%
import pytesseract
from PIL import Image
import re

# Path to tesseract executable (update path if needed)
# Example for Windows:
# pytesseract.pytesseract.tesseract_cmd = r'C:\Program Files\Tesseract-OCR\tesseract.exe'

def extract_invoice_fields(text):
    fields = {
        "invoice_number": None,
        "invoice_date": None,
        "seller": {"name": None, "address": None, "tax_id": None},
        "client": {"name": None, "address": None, "tax_id": None},
        "iban": None,
    }

    # Invoice Number
    invoice_no_match = re.search(r"Invoice\s+no[:\-]?\s*(\d+)", text, re.IGNORECASE)
    if invoice_no_match:
        fields["invoice_number"] = invoice_no_match.group(1)

    # Invoice Date
    date_match = re.search(r"\b(\d{2}/\d{2}/\d{4})\b", text)
    if date_match:
        fields["invoice_date"] = date_match.group(1)

    # Seller
    seller_match = re.search(r"Seller:\s*(.*?)\s*Tax Id:\s*([\d\-]+)", text, re.IGNORECASE | re.DOTALL)
    if seller_match:
        seller_block = seller_match.group(1).strip().split("\n", 1)
        if len(seller_block) == 2:
            fields["seller"]["name"] = seller_block[0].strip()
            fields["seller"]["address"] = ' '.join(seller_block[1].strip().split())
        else:
            fields["seller"]["name"] = seller_block[0].strip()
        fields["seller"]["tax_id"] = seller_match.group(2).strip()

    # Client
    client_match = re.search(r"Client:\s*(.*?)\s*Tax Id:\s*([\d\-]+)", text, re.IGNORECASE | re.DOTALL)
    if client_match:
        client_block = client_match.group(1).strip().split("\n", 1)
        if len(client_block) == 2:
            fields["client"]["name"] = client_block[0].strip()
            fields["client"]["address"] = ' '.join(client_block[1].strip().split())
        else:
            fields["client"]["name"] = client_block[0].strip()
        fields["client"]["tax_id"] = client_match.group(2).strip()

    # IBAN
    iban_match = re.search(r"IBAN:\s*([A-Z0-9]+)", text, re.IGNORECASE)
    if iban_match:
        fields["iban"] = iban_match.group(1).strip()

    return fields

# ----------- MAIN IMAGE PROCESSING -----------

# Load image file
image_path = "C:/Users/Gouthum/Downloads/Project/batch_3/batch_1/batch1_1/batch1-0021.jpg"
image = Image.open(image_path)

# Extract text from image using OCR
ocr_text = pytesseract.image_to_string(image)

# Apply extraction logic
invoice_data = extract_invoice_fields(ocr_text)

# Print extracted data
print("Extracted Fields:\n")
print(f"Invoice Number: {invoice_data['invoice_number']}")
print(f"Invoice Date: {invoice_data['invoice_date']}")
print("Seller Info:")
print(f"  Name: {invoice_data['seller'].get('name')}")
print(f"  Address: {invoice_data['seller'].get('address')}")
print(f"  Tax ID: {invoice_data['seller'].get('tax_id')}")
print("Client Info:")
print(f"  Name: {invoice_data['client'].get('name')}")
print(f"  Address: {invoice_data['client'].get('address')}")
print(f"  Tax ID: {invoice_data['client'].get('tax_id')}")
print(f"IBAN: {invoice_data['iban']}")
# Out:
# Extracted Fields:
#
# Invoice Number: 96430839
# Invoice Date: 01/13/2019
# Seller Info:
#   Name: Bennett, Chavez and Vazquez
#   Address: Unit 8361 Box 7078 DPO AE 69202
#   Tax ID: 971-80-5191
# Client Info:
#   Name: Alexander-Petersen
#   Address: 647 Joyce Ville Waltonfort, IA 57670
#   Tax ID: 934-91-7455
# IBAN: GB9ORYME18980824175499

# %% [markdown]
# # Parsing Based on Line Item Structure(More Organised way)

# %%
import re

def extract_invoice_fields(text):
    fields = {
        "invoice_number": None,
        "invoice_date": None,
        "seller": {"name": None, "address": None, "tax_id": None},
        "client": {"name": None, "address": None, "tax_id": None},
        "iban": None,
    }
  
    # Extract Invoice Number
    invoice_no_match = re.search(r"Invoice\s+no[:\-]?\s*(\d+)", text, re.IGNORECASE)
    if invoice_no_match:
        fields["invoice_number"] = invoice_no_match.group(1)


    # Extract Invoice Date (accepts common formats like dd/mm/yyyy)
    date_match = re.search(r"\b(\d{2}/\d{2}/\d{4})\b", text)
    if date_match:
        fields["invoice_date"] = date_match.group(1)


    # Extract Seller Info
    seller_match = re.search(r"Seller:\s*(.*?)\s*Tax Id:\s*([\d\-]+)", text, re.IGNORECASE | re.DOTALL)
    if seller_match:
        seller_block = seller_match.group(1).strip().split("\n", 1)
        if len(seller_block) == 2:
            fields["seller"]["name"] = seller_block[0].strip()
            fields["seller"]["address"] = ' '.join(seller_block[1].strip().split())
        else:
            fields["seller"]["name"] = seller_block[0].strip()
        fields["seller"]["tax_id"] = seller_match.group(2).strip()

    
    # Extract Client Info
    client_match = re.search(r"Client:\s*(.*?)\s*Tax Id:\s*([\d\-]+)", text, re.IGNORECASE | re.DOTALL)
    if client_match:
        client_block = client_match.group(1).strip().split("\n", 1)
        if len(client_block) == 2:
            fields["client"]["name"] = client_block[0].strip()
            fields["client"]["address"] = ' '.join(client_block[1].strip().split())
        else:
            fields["client"]["name"] = client_block[0].strip()
        fields["client"]["tax_id"] = client_match.group(2).strip()


    # Extract IBAN
    iban_match = re.search(r"IBAN:\s*([A-Z0-9]+)", text, re.IGNORECASE)
    if iban_match:
        fields["iban"] = iban_match.group(1).strip()

    return fields

# Sample input text
text_line = """
Invoice no: 69721323

Date of issue:

Seller:

Murray-Eaton
773 Joseph Plains
West Nicoleville, AZ 46136

Tax Id: 936-71-8228

05/07/2019

Client:

Cuevas, Reid and Hurst
98071 Daniel Heights
Careyside, MS 59400

Tax Id: 949-88-4885

IBAN: GB22XZGA27411153163644

ITEMS
...
"""

# Extract and print fields
fields = extract_invoice_fields(text_line)

print("Extracted Fields:\n")
print(f"Invoice Number: {fields['invoice_number']}")
print(f"Invoice Date: {fields['invoice_date']}")
print("Seller Info:")
print(f"  Name: {fields['seller'].get('name')}")
print(f"  Address: {fields['seller'].get('address')}")
print(f"  Tax ID: {fields['seller'].get('tax_id')}")
print("Client Info:")
print(f"  Name: {fields['client'].get('name')}")
print(f"  Address: {fields['client'].get('address')}")
print(f"  Tax ID: {fields['client'].get('tax_id')}")
print(f"IBAN: {fields['iban']}")
# Out:
# Extracted Fields:
#
# Invoice Number: 69721323
# Invoice Date: 05/07/2019
# Seller Info:
#   Name: Murray-Eaton
#   Address: 773 Joseph Plains West Nicoleville, AZ 46136
#   Tax ID: 936-71-8228
# Client Info:
#   Name: Cuevas, Reid and Hurst
#   Address: 98071 Daniel Heights Careyside, MS 59400
#   Tax ID: 949-88-4885
# IBAN: GB22XZGA27411153163644

# %% [markdown]
# # Extracting line items from invoice OCR text

# %%
import re
import pandas as pd

# Example OCR text lines for items (replace with your actual OCR text)
ocr_text = """
1. Tie Dyeing Fluffy Rugs Anti-Skid 4,00 each 25,48 101,92 10% 112,11
2. Galaxy Butterfly Area Rugs 2,00 each 13,69 27,38 10% 30,12
3. Colorful Marble Printed Living 2,00 each 12,49 24,98 10% 27,48
4. Red Traditional Oriental 4,00 each 39,98 159,92 10% 175,91
5. YILONG 2.5'x4' Small Hand 4,00 each 2 000,00 8 000,00 10% 8 800,00
"""

# Extract lines (assuming each item is one line)
lines = ocr_text.strip().split('\n')

items = []

# Regex pattern to extract fields except description:
pattern = re.compile(
    r"^(?P<No>\d+)[\.:]?\s.*?\s"               # Item No and skip description (non-greedy)
    r"(?P<Qty>\d+,\d+)\s"                      # Quantity (e.g. 4,00)
    r"(?P<UM>\w+)\s"                           # Unit of Measure (e.g. each)
    r"(?P<NetPrice>[\d\s,]+)\s"                # Net price (e.g. 25,48 or 2 000,00)
    r"(?P<NetWorth>[\d\s,]+)\s"                # Net worth
    r"(?P<VAT>\d+)%\s"                         # VAT %
    r"(?P<Gross>[\d\s,]+)$"                    # Gross worth
)

for line in lines:
    match = pattern.match(line)
    if match:
        data = match.groupdict()
        # Normalize numbers: remove spaces, replace commas with dots
        for key in ['Qty', 'NetPrice', 'NetWorth', 'Gross']:
            data[key] = data[key].replace(" ", "").replace(",", ".")
        items.append(data)
    else:
        print(f"Skipped line (no match): {line}")

# Create DataFrame
df = pd.DataFrame(items)

print(df)
# Out:
#   No   Qty    UM  NetPrice NetWorth VAT    Gross
# 0  1  4.00  each     25.48   101.92  10   112.11
# 1  2  2.00  each     13.69    27.38  10    30.12
# 2  3  2.00  each     12.49    24.98  10    27.48
# 3  4  4.00  each     39.98   159.92  10   175.91
# 4  5  4.00  each  2000.008   000.00  10  8800.00

# %%
df
# Out:
#   No   Qty    UM  NetPrice NetWorth VAT    Gross
# 0  1  4.00  each     25.48   101.92  10   112.11
# 1  2  2.00  each     13.69    27.38  10    30.12
# 2  3  2.00  each     12.49    24.98  10    27.48
# 3  4  4.00  each     39.98   159.92  10   175.91
# 4  5  4.00  each  2000.008   000.00  10  8800.00

# %% [markdown]
# # Extracting line items from invoice images

# %%
import cv2
import pytesseract
import re
import pandas as pd

# Path to Tesseract executable (update if needed)
pytesseract.pytesseract.tesseract_cmd = r'C:\Program Files\Tesseract-OCR\tesseract.exe'

def extract_line_items_from_text(text):
    lines = text.strip().split('\n')
    items = []

    pattern = re.compile(
        r"^(?P<No>\d+)[\.:]?\s.*?\s"               # Item No and skip description (non-greedy)
        r"(?P<Qty>\d+,\d+)\s"                      # Quantity (e.g. 4,00)
        r"(?P<UM>\w+)\s"                           # Unit of Measure (e.g. each)
        r"(?P<NetPrice>[\d\s,]+)\s"                # Net price (e.g. 25,48 or 2 000,00)
        r"(?P<NetWorth>[\d\s,]+)\s"                # Net worth
        r"(?P<VAT>\d+)%\s"                         # VAT %
        r"(?P<Gross>[\d\s,]+)$"                    # Gross worth
    )

    for line in lines:
        match = pattern.match(line)
        if match:
            data = match.groupdict()
            # Normalize numbers: remove spaces, replace commas with dots
            for key in ['Qty', 'NetPrice', 'NetWorth', 'Gross']:
                data[key] = data[key].replace(" ", "").replace(",", ".")
            items.append(data)
        else:
            # Uncomment to debug lines skipped:
            # print(f"Skipped line (no match): {line}")
            pass

    return pd.DataFrame(items)

def extract_line_items_from_image(image_path):
    # Load image
    img = cv2.imread(image_path)

    if img is None:
        raise FileNotFoundError(f"Image not found: {image_path}")

    # Convert to grayscale (better OCR results)
    gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

    # Run OCR
    ocr_text = pytesseract.image_to_string(gray)

    # Extract line items from OCR text
    df_items = extract_line_items_from_text(ocr_text)

    return df_items

# Example usage
if __name__ == "__main__":
    image_path = "C:/Users/Gouthum/Downloads/Project/batch_3/batch_1/batch1_1/batch1-0479.jpg"


    try:
        df = extract_line_items_from_image(image_path)
        if not df.empty:
            print("Extracted Line Items from Image:")
            print(df)
        else:
            print("No line items found in the image OCR.")
    except Exception as e:
        print(f"Error: {e}")
# Out:
# Extracted Line Items from Image:
#   No   Qty    UM  NetPrice NetWorth VAT    Gross
# 0  2  2.00  each     13.69    27.38  10    30.12
# 1  4  4.00  each     39.98   159.92  10   175.91
# 2  5  4.00  each  2000.008   000.00  10  8800.00

# %%
df
# Out:
#   No   Qty    UM  NetPrice NetWorth VAT    Gross
# 0  2  2.00  each     13.69    27.38  10    30.12
# 1  4  4.00  each     39.98   159.92  10   175.91
# 2  5  4.00  each  2000.008   000.00  10  8800.00

# %%
import os
import cv2
import pytesseract
import re
import pandas as pd

# Configure Tesseract path (update if needed)
pytesseract.pytesseract.tesseract_cmd = r'C:\Program Files\Tesseract-OCR\tesseract.exe'

# Regex pattern for line items
pattern = re.compile(
    r"^(?P<No>\d+)[\.:]?\s.*?\s"
    r"(?P<Qty>\d+,\d+)\s"
    r"(?P<UM>\w+)\s"
    r"(?P<NetPrice>[\d\s,]+)\s"
    r"(?P<NetWorth>[\d\s,]+)\s"
    r"(?P<VAT>\d+)%\s"
    r"(?P<Gross>[\d\s,]+)$"
)

def extract_line_items_from_text(text, filename):
    lines = text.strip().split('\n')
    items = []

    for line in lines:
        match = pattern.match(line)
        if match:
            data = match.groupdict()
            for key in ['Qty', 'NetPrice', 'NetWorth', 'Gross']:
                data[key] = data[key].replace(" ", "").replace(",", ".")
            data["Filename"] = filename
            items.append(data)

    return items

def process_image(image_path):
    img = cv2.imread(image_path)
    if img is None:
        raise FileNotFoundError(f"Image not found: {image_path}")
    gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    text = pytesseract.image_to_string(gray)
    return text

def collect_all_invoice_data(directories):
    all_items = []

    for folder in directories:
        for root, _, files in os.walk(folder):
            for file in files:
                if file.lower().endswith(('.jpg', '.jpeg', '.png', '.tiff')):
                    full_path = os.path.join(root, file)
                    try:
                        print(f"Processing: {full_path}")
                        text = process_image(full_path)
                        items = extract_line_items_from_text(text, file)
                        all_items.extend(items)
                    except Exception as e:
                        print(f"Error processing {full_path}: {e}")

    return pd.DataFrame(all_items)

# Your image directories
directories = [
    r"C:\Users\Gouthum\Downloads\Project\batch_1\batch_1",
    r"C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_2",
    r"C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_1",
    r"C:\Users\Gouthum\Downloads\Project\batch_2\batch_2\batch2_3",
    r"C:\Users\Gouthum\Downloads\Project\batch_2\batch_2\batch2_2",
    r"C:\Users\Gouthum\Downloads\Project\batch_2\batch_2\batch2_1",
    r"C:\Users\Gouthum\Downloads\Project\batch_3\batch_3\batch3_5",
    r"C:\Users\Gouthum\Downloads\Project\batch_3\batch_3\batch3_4",
    r"C:\Users\Gouthum\Downloads\Project\batch_3\batch_3\batch3_3",
    r"C:\Users\Gouthum\Downloads\Project\batch_3\batch_3\batch3_2",
    r"C:\Users\Gouthum\Downloads\Project\batch_3\batch_3\batch3_1",
    r"C:\Users\Gouthum\Downloads\Project\batch_3\batch_2\batch2_3",
    r"C:\Users\Gouthum\Downloads\Project\batch_3\batch_2\batch2_2",
    r"C:\Users\Gouthum\Downloads\Project\batch_3\batch_2\batch2_1",
    r"C:\Users\Gouthum\Downloads\Project\batch_3\batch_1\batch1_3",
    r"C:\Users\Gouthum\Downloads\Project\batch_3\batch_1\batch1_2",
    r"C:\Users\Gouthum\Downloads\Project\batch_3\batch_1\batch1_1"
]

# Run the extraction
df_all = collect_all_invoice_data(directories)

# Show or save results
print(df_all)

# Optional: Save to CSV/JSON
df_all.to_csv(r"C:\Users\Gouthum\Downloads\Project\output\all_invoiceee_items.csv", index=False)
df_all.to_json(r"C:\Users\Gouthum\Downloads\Project\output\all_invoiceee_items.json", orient='records', indent=2)
# Out:
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_1\batch1-0001.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_1\batch1-0002.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_1\batch1-0003.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_1\batch1-0004.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_1\batch1-0005.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_1\batch1-0006.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_1\batch1-0007.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_1\batch1-0008.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_1\batch1-0009.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_1\batch1-0010.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_1\batch1-0011.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_1\batch1-0012.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_1\batch1-0013.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_1\batch1-0014.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_1\batch1-0015.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_1\batch1-0016.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_1\batch1-0017.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_1\batch1-0018.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_1\batch1-0019.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_1\batch1-0020.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_1\batch1-0021.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_1\batch1-0022.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_1\batch1-0023.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_1\batch1-0024.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_1\batch1-0025.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_1\batch1-0026.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_1\batch1-0027.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_1\batch1-0028.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_1\batch1-0029.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_1\batch1-0030.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_1\batch1-0031.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_1\batch1-0032.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_1\batch1-0033.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_1\batch1-0034.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_1\batch1-0035.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_1\batch1-0036.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_1\batch1-0037.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_1\batch1-0038.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_1\batch1-0039.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_1\batch1-0040.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_1\batch1-0041.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_1\batch1-0042.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_1\batch1-0043.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_1\batch1-0044.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_1\batch1-0045.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_1\batch1-0046.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_1\batch1-0047.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_1\batch1-0048.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_1\batch1-0049.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_1\batch1-0050.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_1\batch1-0051.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_1\batch1-0052.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_1\batch1-0053.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_1\batch1-0054.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_1\batch1-0055.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_1\batch1-0056.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_1\batch1-0057.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_1\batch1-0058.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_1\batch1-0059.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_1\batch1-0060.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_1\batch1-0061.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_1\batch1-0062.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_1\batch1-0063.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_1\batch1-0064.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_1\batch1-0065.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_1\batch1-0066.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_1\batch1-0067.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_1\batch1-0068.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_1\batch1-0069.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_1\batch1-0070.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_1\batch1-0071.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_1\batch1-0072.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_1\batch1-0073.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_1\batch1-0074.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_1\batch1-0075.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_1\batch1-0076.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_1\batch1-0077.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_1\batch1-0078.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_1\batch1-0079.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_1\batch1-0080.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_1\batch1-0081.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_1\batch1-0082.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_1\batch1-0083.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_1\batch1-0084.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_1\batch1-0085.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_1\batch1-0086.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_1\batch1-0087.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_1\batch1-0088.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_1\batch1-0089.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_1\batch1-0090.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_1\batch1-0091.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_1\batch1-0092.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_1\batch1-0093.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_1\batch1-0094.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_1\batch1-0095.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_1\batch1-0096.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_1\batch1-0097.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_1\batch1-0098.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_1\batch1-0099.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_1\batch1-0100.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_1\batch1-0101.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_1\batch1-0102.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_1\batch1-0103.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_1\batch1-0104.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_1\batch1-0105.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_1\batch1-0106.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_1\batch1-0107.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_1\batch1-0108.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_1\batch1-0109.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_1\batch1-0110.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_1\batch1-0111.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_1\batch1-0112.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_1\batch1-0113.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_1\batch1-0114.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_1\batch1-0115.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_1\batch1-0116.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_1\batch1-0117.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_1\batch1-0118.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_1\batch1-0119.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_1\batch1-0120.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_1\batch1-0121.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_1\batch1-0122.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_1\batch1-0123.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_1\batch1-0124.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_1\batch1-0125.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_1\batch1-0126.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_1\batch1-0127.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_1\batch1-0128.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_1\batch1-0129.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_1\batch1-0130.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_1\batch1-0131.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_1\batch1-0132.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_1\batch1-0133.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_1\batch1-0134.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_1\batch1-0135.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_1\batch1-0136.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_1\batch1-0137.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_1\batch1-0138.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_1\batch1-0139.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_1\batch1-0140.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_1\batch1-0141.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_1\batch1-0142.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_1\batch1-0143.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_1\batch1-0144.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_1\batch1-0145.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_1\batch1-0146.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_1\batch1-0147.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_1\batch1-0148.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_1\batch1-0149.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_1\batch1-0150.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_1\batch1-0151.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_1\batch1-0152.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_1\batch1-0153.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_1\batch1-0154.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_1\batch1-0155.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_1\batch1-0156.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_1\batch1-0157.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_1\batch1-0158.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_1\batch1-0159.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_1\batch1-0160.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_1\batch1-0161.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_1\batch1-0162.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_1\batch1-0163.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_1\batch1-0164.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_1\batch1-0165.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_1\batch1-0166.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_1\batch1-0167.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_1\batch1-0168.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_1\batch1-0169.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_1\batch1-0170.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_1\batch1-0171.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_1\batch1-0172.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_1\batch1-0173.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_1\batch1-0174.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_1\batch1-0175.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_1\batch1-0176.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_1\batch1-0177.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_1\batch1-0178.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_1\batch1-0179.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_1\batch1-0180.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_1\batch1-0181.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_1\batch1-0182.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_1\batch1-0183.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_1\batch1-0184.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_1\batch1-0185.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_1\batch1-0186.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_1\batch1-0187.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_1\batch1-0188.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_1\batch1-0189.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_1\batch1-0190.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_1\batch1-0191.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_1\batch1-0192.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_1\batch1-0193.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_1\batch1-0194.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_1\batch1-0195.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_1\batch1-0196.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_1\batch1-0197.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_1\batch1-0198.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_1\batch1-0199.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_1\batch1-0200.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_1\batch1-0201.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_1\batch1-0202.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_1\batch1-0203.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_1\batch1-0204.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_1\batch1-0205.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_1\batch1-0206.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_1\batch1-0207.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_1\batch1-0208.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_1\batch1-0209.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_1\batch1-0210.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_1\batch1-0211.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_1\batch1-0212.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_1\batch1-0213.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_1\batch1-0214.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_1\batch1-0215.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_1\batch1-0216.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_1\batch1-0217.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_1\batch1-0218.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_1\batch1-0219.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_1\batch1-0220.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_1\batch1-0221.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_1\batch1-0222.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_1\batch1-0223.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_1\batch1-0224.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_1\batch1-0225.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_1\batch1-0226.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_1\batch1-0227.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_1\batch1-0228.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_1\batch1-0229.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_1\batch1-0230.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_1\batch1-0231.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_1\batch1-0232.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_1\batch1-0233.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_1\batch1-0234.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_1\batch1-0235.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_1\batch1-0236.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_1\batch1-0237.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_1\batch1-0238.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_1\batch1-0239.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_1\batch1-0240.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_1\batch1-0241.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_1\batch1-0242.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_1\batch1-0243.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_1\batch1-0244.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_1\batch1-0245.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_1\batch1-0246.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_1\batch1-0247.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_1\batch1-0248.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_1\batch1-0249.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_1\batch1-0250.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_1\batch1-0251.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_1\batch1-0252.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_1\batch1-0253.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_1\batch1-0254.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_1\batch1-0255.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_1\batch1-0256.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_1\batch1-0257.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_1\batch1-0258.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_1\batch1-0259.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_1\batch1-0260.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_1\batch1-0261.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_1\batch1-0262.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_1\batch1-0263.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_1\batch1-0264.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_1\batch1-0265.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_1\batch1-0266.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_1\batch1-0267.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_1\batch1-0268.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_1\batch1-0269.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_1\batch1-0270.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_1\batch1-0271.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_1\batch1-0272.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_1\batch1-0273.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_1\batch1-0274.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_1\batch1-0275.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_1\batch1-0276.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_1\batch1-0277.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_1\batch1-0278.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_1\batch1-0279.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_1\batch1-0280.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_1\batch1-0281.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_1\batch1-0282.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_1\batch1-0283.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_1\batch1-0284.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_1\batch1-0285.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_1\batch1-0286.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_1\batch1-0287.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_1\batch1-0288.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_1\batch1-0289.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_1\batch1-0290.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_1\batch1-0291.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_1\batch1-0292.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_1\batch1-0293.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_1\batch1-0294.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_1\batch1-0295.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_1\batch1-0296.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_1\batch1-0297.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_1\batch1-0298.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_1\batch1-0299.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_1\batch1-0300.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_1\batch1-0301.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_1\batch1-0302.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_1\batch1-0303.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_1\batch1-0304.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_1\batch1-0305.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_1\batch1-0306.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_1\batch1-0307.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_1\batch1-0308.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_1\batch1-0309.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_1\batch1-0310.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_1\batch1-0311.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_1\batch1-0312.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_1\batch1-0313.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_1\batch1-0314.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_1\batch1-0315.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_1\batch1-0316.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_1\batch1-0317.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_1\batch1-0318.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_1\batch1-0319.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_1\batch1-0320.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_1\batch1-0321.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_1\batch1-0322.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_1\batch1-0323.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_1\batch1-0324.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_1\batch1-0325.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_1\batch1-0326.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_1\batch1-0327.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_1\batch1-0328.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_1\batch1-0329.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_1\batch1-0330.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_1\batch1-0331.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_1\batch1-0332.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_1\batch1-0333.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_1\batch1-0334.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_1\batch1-0335.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_1\batch1-0336.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_1\batch1-0337.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_1\batch1-0338.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_1\batch1-0339.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_1\batch1-0340.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_1\batch1-0341.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_1\batch1-0342.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_1\batch1-0343.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_1\batch1-0344.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_1\batch1-0345.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_1\batch1-0346.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_1\batch1-0347.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_1\batch1-0348.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_1\batch1-0349.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_1\batch1-0350.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_1\batch1-0351.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_1\batch1-0352.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_1\batch1-0353.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_1\batch1-0354.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_1\batch1-0355.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_1\batch1-0356.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_1\batch1-0357.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_1\batch1-0358.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_1\batch1-0359.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_1\batch1-0360.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_1\batch1-0361.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_1\batch1-0362.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_1\batch1-0363.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_1\batch1-0364.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_1\batch1-0365.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_1\batch1-0366.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_1\batch1-0367.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_1\batch1-0368.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_1\batch1-0369.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_1\batch1-0370.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_1\batch1-0371.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_1\batch1-0372.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_1\batch1-0373.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_1\batch1-0374.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_1\batch1-0375.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_1\batch1-0376.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_1\batch1-0377.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_1\batch1-0378.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_1\batch1-0379.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_1\batch1-0380.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_1\batch1-0381.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_1\batch1-0382.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_1\batch1-0383.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_1\batch1-0384.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_1\batch1-0385.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_1\batch1-0386.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_1\batch1-0387.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_1\batch1-0388.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_1\batch1-0389.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_1\batch1-0390.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_1\batch1-0391.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_1\batch1-0392.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_1\batch1-0393.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_1\batch1-0394.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_1\batch1-0395.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_1\batch1-0396.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_1\batch1-0397.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_1\batch1-0398.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_1\batch1-0399.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_1\batch1-0400.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_1\batch1-0401.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_1\batch1-0402.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_1\batch1-0403.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_1\batch1-0404.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_1\batch1-0405.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_1\batch1-0406.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_1\batch1-0407.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_1\batch1-0408.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_1\batch1-0409.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_1\batch1-0410.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_1\batch1-0411.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_1\batch1-0412.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_1\batch1-0413.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_1\batch1-0414.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_1\batch1-0415.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_1\batch1-0416.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_1\batch1-0417.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_1\batch1-0418.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_1\batch1-0419.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_1\batch1-0420.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_1\batch1-0421.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_1\batch1-0422.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_1\batch1-0423.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_1\batch1-0424.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_1\batch1-0425.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_1\batch1-0426.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_1\batch1-0427.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_1\batch1-0428.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_1\batch1-0429.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_1\batch1-0430.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_1\batch1-0431.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_1\batch1-0432.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_1\batch1-0433.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_1\batch1-0434.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_1\batch1-0435.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_1\batch1-0436.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_1\batch1-0437.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_1\batch1-0438.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_1\batch1-0439.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_1\batch1-0440.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_1\batch1-0441.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_1\batch1-0442.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_1\batch1-0443.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_1\batch1-0444.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_1\batch1-0445.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_1\batch1-0446.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_1\batch1-0447.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_1\batch1-0448.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_1\batch1-0449.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_1\batch1-0450.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_1\batch1-0451.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_1\batch1-0452.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_1\batch1-0453.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_1\batch1-0454.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_1\batch1-0455.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_1\batch1-0456.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_1\batch1-0457.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_1\batch1-0458.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_1\batch1-0459.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_1\batch1-0460.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_1\batch1-0461.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_1\batch1-0462.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_1\batch1-0463.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_1\batch1-0464.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_1\batch1-0465.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_1\batch1-0466.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_1\batch1-0467.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_1\batch1-0468.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_1\batch1-0469.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_1\batch1-0470.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_1\batch1-0471.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_1\batch1-0472.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_1\batch1-0473.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_1\batch1-0474.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_1\batch1-0475.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_1\batch1-0476.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_1\batch1-0477.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_1\batch1-0478.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_1\batch1-0479.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_1\batch1-0480.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_1\batch1-0481.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_1\batch1-0482.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_1\batch1-0483.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_1\batch1-0484.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_1\batch1-0485.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_1\batch1-0486.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_1\batch1-0487.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_1\batch1-0488.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_1\batch1-0489.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_1\batch1-0490.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_1\batch1-0491.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_1\batch1-0492.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_1\batch1-0493.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_1\batch1-0494.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_1\batch1-0495.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_1\batch1-0496.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_1\batch1-0497.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_1\batch1-0498.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_1\batch1-0499.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_2\batch1-0500.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_2\batch1-0501.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_2\batch1-0502.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_2\batch1-0503.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_2\batch1-0504.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_2\batch1-0505.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_2\batch1-0506.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_2\batch1-0507.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_2\batch1-0508.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_2\batch1-0509.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_2\batch1-0510.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_2\batch1-0511.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_2\batch1-0512.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_2\batch1-0513.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_2\batch1-0514.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_2\batch1-0515.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_2\batch1-0516.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_2\batch1-0517.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_2\batch1-0518.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_2\batch1-0519.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_2\batch1-0520.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_2\batch1-0521.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_2\batch1-0522.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_2\batch1-0523.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_2\batch1-0524.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_2\batch1-0525.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_2\batch1-0526.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_2\batch1-0527.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_2\batch1-0528.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_2\batch1-0529.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_2\batch1-0530.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_2\batch1-0531.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_2\batch1-0532.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_2\batch1-0533.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_2\batch1-0534.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_2\batch1-0535.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_2\batch1-0536.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_2\batch1-0537.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_2\batch1-0538.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_2\batch1-0539.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_2\batch1-0540.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_2\batch1-0541.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_2\batch1-0542.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_2\batch1-0543.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_2\batch1-0544.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_2\batch1-0545.jpg
# ...
# Processing: C:\Users\Gouthum\Downloads\Project\batch_3\batch_1\batch1_1\batch1-0328.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_3\batch_1\batch1_1\batch1-0329.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_3\batch_1\batch1_1\batch1-0330.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_3\batch_1\batch1_1\batch1-0331.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_3\batch_1\batch1_1\batch1-0332.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_3\batch_1\batch1_1\batch1-0333.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_3\batch_1\batch1_1\batch1-0334.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_3\batch_1\batch1_1\batch1-0335.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_3\batch_1\batch1_1\batch1-0336.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_3\batch_1\batch1_1\batch1-0337.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_3\batch_1\batch1_1\batch1-0338.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_3\batch_1\batch1_1\batch1-0339.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_3\batch_1\batch1_1\batch1-0340.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_3\batch_1\batch1_1\batch1-0341.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_3\batch_1\batch1_1\batch1-0342.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_3\batch_1\batch1_1\batch1-0343.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_3\batch_1\batch1_1\batch1-0344.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_3\batch_1\batch1_1\batch1-0345.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_3\batch_1\batch1_1\batch1-0346.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_3\batch_1\batch1_1\batch1-0347.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_3\batch_1\batch1_1\batch1-0348.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_3\batch_1\batch1_1\batch1-0349.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_3\batch_1\batch1_1\batch1-0350.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_3\batch_1\batch1_1\batch1-0351.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_3\batch_1\batch1_1\batch1-0352.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_3\batch_1\batch1_1\batch1-0353.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_3\batch_1\batch1_1\batch1-0354.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_3\batch_1\batch1_1\batch1-0355.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_3\batch_1\batch1_1\batch1-0356.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_3\batch_1\batch1_1\batch1-0357.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_3\batch_1\batch1_1\batch1-0358.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_3\batch_1\batch1_1\batch1-0359.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_3\batch_1\batch1_1\batch1-0360.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_3\batch_1\batch1_1\batch1-0361.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_3\batch_1\batch1_1\batch1-0362.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_3\batch_1\batch1_1\batch1-0363.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_3\batch_1\batch1_1\batch1-0364.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_3\batch_1\batch1_1\batch1-0365.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_3\batch_1\batch1_1\batch1-0366.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_3\batch_1\batch1_1\batch1-0367.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_3\batch_1\batch1_1\batch1-0368.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_3\batch_1\batch1_1\batch1-0369.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_3\batch_1\batch1_1\batch1-0370.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_3\batch_1\batch1_1\batch1-0371.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_3\batch_1\batch1_1\batch1-0372.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_3\batch_1\batch1_1\batch1-0373.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_3\batch_1\batch1_1\batch1-0374.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_3\batch_1\batch1_1\batch1-0375.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_3\batch_1\batch1_1\batch1-0376.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_3\batch_1\batch1_1\batch1-0377.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_3\batch_1\batch1_1\batch1-0378.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_3\batch_1\batch1_1\batch1-0379.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_3\batch_1\batch1_1\batch1-0380.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_3\batch_1\batch1_1\batch1-0381.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_3\batch_1\batch1_1\batch1-0382.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_3\batch_1\batch1_1\batch1-0383.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_3\batch_1\batch1_1\batch1-0384.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_3\batch_1\batch1_1\batch1-0385.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_3\batch_1\batch1_1\batch1-0386.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_3\batch_1\batch1_1\batch1-0387.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_3\batch_1\batch1_1\batch1-0388.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_3\batch_1\batch1_1\batch1-0389.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_3\batch_1\batch1_1\batch1-0390.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_3\batch_1\batch1_1\batch1-0391.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_3\batch_1\batch1_1\batch1-0392.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_3\batch_1\batch1_1\batch1-0393.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_3\batch_1\batch1_1\batch1-0394.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_3\batch_1\batch1_1\batch1-0395.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_3\batch_1\batch1_1\batch1-0396.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_3\batch_1\batch1_1\batch1-0397.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_3\batch_1\batch1_1\batch1-0398.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_3\batch_1\batch1_1\batch1-0399.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_3\batch_1\batch1_1\batch1-0400.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_3\batch_1\batch1_1\batch1-0401.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_3\batch_1\batch1_1\batch1-0402.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_3\batch_1\batch1_1\batch1-0403.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_3\batch_1\batch1_1\batch1-0404.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_3\batch_1\batch1_1\batch1-0405.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_3\batch_1\batch1_1\batch1-0406.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_3\batch_1\batch1_1\batch1-0407.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_3\batch_1\batch1_1\batch1-0408.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_3\batch_1\batch1_1\batch1-0409.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_3\batch_1\batch1_1\batch1-0410.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_3\batch_1\batch1_1\batch1-0411.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_3\batch_1\batch1_1\batch1-0412.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_3\batch_1\batch1_1\batch1-0413.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_3\batch_1\batch1_1\batch1-0414.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_3\batch_1\batch1_1\batch1-0415.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_3\batch_1\batch1_1\batch1-0416.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_3\batch_1\batch1_1\batch1-0417.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_3\batch_1\batch1_1\batch1-0418.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_3\batch_1\batch1_1\batch1-0419.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_3\batch_1\batch1_1\batch1-0420.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_3\batch_1\batch1_1\batch1-0421.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_3\batch_1\batch1_1\batch1-0422.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_3\batch_1\batch1_1\batch1-0423.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_3\batch_1\batch1_1\batch1-0424.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_3\batch_1\batch1_1\batch1-0425.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_3\batch_1\batch1_1\batch1-0426.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_3\batch_1\batch1_1\batch1-0427.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_3\batch_1\batch1_1\batch1-0428.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_3\batch_1\batch1_1\batch1-0429.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_3\batch_1\batch1_1\batch1-0430.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_3\batch_1\batch1_1\batch1-0431.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_3\batch_1\batch1_1\batch1-0432.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_3\batch_1\batch1_1\batch1-0433.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_3\batch_1\batch1_1\batch1-0434.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_3\batch_1\batch1_1\batch1-0435.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_3\batch_1\batch1_1\batch1-0436.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_3\batch_1\batch1_1\batch1-0437.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_3\batch_1\batch1_1\batch1-0438.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_3\batch_1\batch1_1\batch1-0439.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_3\batch_1\batch1_1\batch1-0440.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_3\batch_1\batch1_1\batch1-0441.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_3\batch_1\batch1_1\batch1-0442.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_3\batch_1\batch1_1\batch1-0443.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_3\batch_1\batch1_1\batch1-0444.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_3\batch_1\batch1_1\batch1-0445.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_3\batch_1\batch1_1\batch1-0446.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_3\batch_1\batch1_1\batch1-0447.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_3\batch_1\batch1_1\batch1-0448.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_3\batch_1\batch1_1\batch1-0449.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_3\batch_1\batch1_1\batch1-0450.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_3\batch_1\batch1_1\batch1-0451.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_3\batch_1\batch1_1\batch1-0452.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_3\batch_1\batch1_1\batch1-0453.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_3\batch_1\batch1_1\batch1-0454.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_3\batch_1\batch1_1\batch1-0455.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_3\batch_1\batch1_1\batch1-0456.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_3\batch_1\batch1_1\batch1-0457.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_3\batch_1\batch1_1\batch1-0458.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_3\batch_1\batch1_1\batch1-0459.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_3\batch_1\batch1_1\batch1-0460.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_3\batch_1\batch1_1\batch1-0461.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_3\batch_1\batch1_1\batch1-0462.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_3\batch_1\batch1_1\batch1-0463.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_3\batch_1\batch1_1\batch1-0464.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_3\batch_1\batch1_1\batch1-0465.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_3\batch_1\batch1_1\batch1-0466.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_3\batch_1\batch1_1\batch1-0467.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_3\batch_1\batch1_1\batch1-0468.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_3\batch_1\batch1_1\batch1-0469.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_3\batch_1\batch1_1\batch1-0470.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_3\batch_1\batch1_1\batch1-0471.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_3\batch_1\batch1_1\batch1-0472.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_3\batch_1\batch1_1\batch1-0473.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_3\batch_1\batch1_1\batch1-0474.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_3\batch_1\batch1_1\batch1-0475.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_3\batch_1\batch1_1\batch1-0476.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_3\batch_1\batch1_1\batch1-0477.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_3\batch_1\batch1_1\batch1-0478.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_3\batch_1\batch1_1\batch1-0479.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_3\batch_1\batch1_1\batch1-0480.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_3\batch_1\batch1_1\batch1-0481.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_3\batch_1\batch1_1\batch1-0482.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_3\batch_1\batch1_1\batch1-0483.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_3\batch_1\batch1_1\batch1-0484.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_3\batch_1\batch1_1\batch1-0485.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_3\batch_1\batch1_1\batch1-0486.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_3\batch_1\batch1_1\batch1-0487.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_3\batch_1\batch1_1\batch1-0488.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_3\batch_1\batch1_1\batch1-0489.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_3\batch_1\batch1_1\batch1-0490.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_3\batch_1\batch1_1\batch1-0491.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_3\batch_1\batch1_1\batch1-0492.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_3\batch_1\batch1_1\batch1-0493.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_3\batch_1\batch1_1\batch1-0494.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_3\batch_1\batch1_1\batch1-0495.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_3\batch_1\batch1_1\batch1-0496.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_3\batch_1\batch1_1\batch1-0497.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_3\batch_1\batch1_1\batch1-0498.jpg
# Processing: C:\Users\Gouthum\Downloads\Project\batch_3\batch_1\batch1_1\batch1-0499.jpg
#      No   Qty    UM NetPrice NetWorth VAT    Gross         Filename
# 0     2  5.00  each    37.75   188.75  10   207.63  batch1-0001.jpg
# 1     3  1.00  each   400.00   400.00  10   440.00  batch1-0001.jpg
# 2     4  3.00  each  464.891   394.67  10  1534.14  batch1-0001.jpg
# 3     5  5.00  each  221.991   109.95  10  1220.95  batch1-0001.jpg
# 4     6  4.00  each  269.951   079.80  10  1187.78  batch1-0001.jpg
# ...  ..   ...   ...      ...      ...  ..      ...              ...
# 1356  2  5.00  each    10.99    54.95  10    60.45  batch1-0497.jpg
# 1357  3  1.00  each   295.00   295.00  10   324.50  batch1-0497.jpg
# 1358  4  5.00  each     8.00    40.00  10    44.00  batch1-0497.jpg
# 1359  6  5.00  each     5.99    29.95  10    32.95  batch1-0497.jpg
# 1360  2  3.00  each     0.99     2.97  10     3.27  batch1-0499.jpg
#
# [1361 rows x 8 columns]

# %%
import cv2
import pytesseract
import re
import pandas as pd

# Path to Tesseract executable (update if needed)
pytesseract.pytesseract.tesseract_cmd = r'C:\Program Files\Tesseract-OCR\tesseract.exe'

def extract_line_items_from_text(text):
    lines = text.strip().split('\n')
    items = []

    # Updated regex to capture description
    pattern = re.compile(
        r"^(?P<No>\d+)[\.:]?\s+"                          # Item No
        r"(?P<Description>.+?)\s+"                         # Description (non-greedy)
        r"(?P<Qty>\d+,\d+)\s+"                             # Quantity
        r"(?P<UM>\w+)\s+"                                  # Unit of Measure
        r"(?P<NetPrice>[\d\s,]+)\s+"                       # Net price
        r"(?P<NetWorth>[\d\s,]+)\s+"                       # Net worth
        r"(?P<VAT>\d+)(?:%?)\s+"                           # VAT (optional % sign)
        r"(?P<Gross>[\d\s,]+)$"                            # Gross
    )

    for line in lines:
        match = pattern.match(line)
        if match:
            data = match.groupdict()
            # Normalize numbers
            for key in ['Qty', 'NetPrice', 'NetWorth', 'Gross']:
                data[key] = data[key].replace(" ", "").replace(",", ".")
            items.append(data)

    return pd.DataFrame(items)

def extract_line_items_from_image(image_path):
    # Load image
    img = cv2.imread(image_path)

    if img is None:
        raise FileNotFoundError(f"Image not found: {image_path}")

    # Convert to grayscale
    gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

    # Run OCR
    ocr_text = pytesseract.image_to_string(gray)

    # Extract line items
    df_items = extract_line_items_from_text(ocr_text)

    return df_items

# Example usage
if __name__ == "__main__":
    image_path = "C:/Users/Gouthum/Downloads/Project/batch_3/batch_1/batch1_1/batch1-0479.jpg"

    try:
        df = extract_line_items_from_image(image_path)
        if not df.empty:
            print("Extracted Line Items from Image:")
            print(df)
        else:
            print("No line items found in the image OCR.")
    except Exception as e:
        print(f"Error: {e}")
# Out:
# Extracted Line Items from Image:
#   No                 Description   Qty    UM  NetPrice NetWorth VAT    Gross
# 0  2  Galaxy Butterfly Area Rugs  2.00  each     13.69    27.38  10    30.12
# 1  4    Red Traditional Oriental  4.00  each     39.98   159.92  10   175.91
# 2  5   YILONG 2.5'x4' Small Hand  4.00  each  2000.008   000.00  10  8800.00

# %%
C:/Users/Gouthum/Downloads/Project/batch_3/batch_1/batch1_1/batch1-0479.jpg

# %% [markdown]
# # image2

# %% [markdown]
# # Key Value

# %%
import os
import cv2
import pytesseract
from PIL import Image
from tqdm import tqdm

# Set up tesseract path (update if needed)
pytesseract.pytesseract.tesseract_cmd = r"C:\Program Files\Tesseract-OCR\tesseract.exe"

# Define all image folder paths
image_dirs = [
    r"C:\Users\Gouthum\Downloads\Project\batch_1\batch_1",
    r"C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_2",
    r"C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_1",

    r"C:\Users\Gouthum\Downloads\Project\batch_2\batch_2\batch2_3",
    r"C:\Users\Gouthum\Downloads\Project\batch_2\batch_2\batch2_2",
    r"C:\Users\Gouthum\Downloads\Project\batch_2\batch_2\batch2_1",

    r"C:\Users\Gouthum\Downloads\Project\batch_3\batch_3\batch3_5",
    r"C:\Users\Gouthum\Downloads\Project\batch_3\batch_3\batch3_4",
    r"C:\Users\Gouthum\Downloads\Project\batch_3\batch_3\batch3_3",
    r"C:\Users\Gouthum\Downloads\Project\batch_3\batch_3\batch3_2",
    r"C:\Users\Gouthum\Downloads\Project\batch_3\batch_3\batch3_1",

    r"C:\Users\Gouthum\Downloads\Project\batch_3\batch_2\batch2_3",
    r"C:\Users\Gouthum\Downloads\Project\batch_3\batch_2\batch2_2",
    r"C:\Users\Gouthum\Downloads\Project\batch_3\batch_2\batch2_1",

    r"C:\Users\Gouthum\Downloads\Project\batch_3\batch_1\batch1_3",
    r"C:\Users\Gouthum\Downloads\Project\batch_3\batch_1\batch1_2",
    r"C:\Users\Gouthum\Downloads\Project\batch_3\batch_1\batch1_1",
]

# Supported image extensions
image_extensions = ['.jpg', '.jpeg', '.png', '.tiff', '.bmp']

# Extract key-value pairs from OCR text (basic example, customize this later)
def extract_key_value_pairs(text):
    key_values = {}
    for line in text.split('\n'):
        if ':' in line:
            parts = line.split(':', 1)
            key = parts[0].strip()
            value = parts[1].strip()
            if key and value:
                key_values[key] = value
    return key_values

# Process all images in the given folders
all_results = []

for image_dir in image_dirs:
    if not os.path.exists(image_dir):
        print(f"Folder not found: {image_dir}")
        continue

    for filename in tqdm(os.listdir(image_dir), desc=f"Processing {image_dir}"):
        ext = os.path.splitext(filename)[-1].lower()
        if ext in image_extensions:
            image_path = os.path.join(image_dir, filename)
            try:
                image = Image.open(image_path)
                ocr_text = pytesseract.image_to_string(image)

                key_values = extract_key_value_pairs(ocr_text)

                all_results.append({
                    'image_path': image_path,
                    'ocr_text': ocr_text,
                    'key_values': key_values
                })

            except Exception as e:
                print(f"Failed to process {image_path}: {e}")

# Example: Print result summary
print("\n--- Extracted Key-Values Summary ---")
for result in all_results:
    print(f"\nImage: {os.path.basename(result['image_path'])}")
    for k, v in result['key_values'].items():
        print(f"{k}: {v}")
# Out:
# Processing C:\Users\Gouthum\Downloads\Project\batch_1\batch_1: 100%|█████████████████████████████| 6/6 [00:00<?, ?it/s]
# Processing C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_2: 100%|████████| 501/501 [18:40<00:00,  2.24s/it]
# Processing C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_1: 100%|████████| 499/499 [19:02<00:00,  2.29s/it]
# Processing C:\Users\Gouthum\Downloads\Project\batch_2\batch_2\batch2_3: 100%|████████| 490/490 [13:11<00:00,  1.62s/it]
# Processing C:\Users\Gouthum\Downloads\Project\batch_2\batch_2\batch2_2: 100%|████████| 501/501 [14:29<00:00,  1.74s/it]
# Processing C:\Users\Gouthum\Downloads\Project\batch_2\batch_2\batch2_1: 100%|████████| 500/500 [19:31<00:00,  2.34s/it]
# Processing C:\Users\Gouthum\Downloads\Project\batch_3\batch_3\batch3_5: 100%|████████| 222/222 [07:07<00:00,  1.93s/it]
# Processing C:\Users\Gouthum\Downloads\Project\batch_3\batch_3\batch3_4: 100%|████████| 500/500 [25:12<00:00,  3.02s/it]
# Processing C:\Users\Gouthum\Downloads\Project\batch_3\batch_3\batch3_3: 100%|████████| 501/501 [17:18<00:00,  2.07s/it]
# Processing C:\Users\Gouthum\Downloads\Project\batch_3\batch_3\batch3_2: 100%|████████| 499/499 [16:54<00:00,  2.03s/it]
# Processing C:\Users\Gouthum\Downloads\Project\batch_3\batch_3\batch3_1: 100%|████████| 499/499 [15:22<00:00,  1.85s/it]
# Processing C:\Users\Gouthum\Downloads\Project\batch_3\batch_2\batch2_3: 100%|████████| 490/490 [14:16<00:00,  1.75s/it]
# Processing C:\Users\Gouthum\Downloads\Project\batch_3\batch_2\batch2_2: 100%|████████| 501/501 [15:57<00:00,  1.91s/it]
# Processing C:\Users\Gouthum\Downloads\Project\batch_3\batch_2\batch2_1: 100%|████████| 500/500 [20:19<00:00,  2.44s/it]
# Processing C:\Users\Gouthum\Downloads\Project\batch_3\batch_1\batch1_3: 100%|████████| 489/489 [13:50<00:00,  1.70s/it]
# Processing C:\Users\Gouthum\Downloads\Project\batch_3\batch_1\batch1_2: 100%|████████| 501/501 [14:21<00:00,  1.72s/it]
# Processing C:\Users\Gouthum\Downloads\Project\batch_3\batch_1\batch1_1: 100%|████████| 499/499 [14:09<00:00,  1.70s/it]
# --- Extracted Key-Values Summary ---
#
# Image: batch1-0500.jpg
# Invoice no: 34476404
# Date of issue: 07/24/2018
# Seller: Client:
# Tax Id: 975-86-1582 Tax Id: 902-92-1120
# IBAN: GB14UTZB20101973421914
#
# Image: batch1-0501.jpg
# Invoice no: 18999056
# Tax Id: 934-91-7704
# IBAN: GB96KZTB85221072973831
#
# Image: batch1-0502.jpg
# Invoice no: 33289699
# Tax Id: 953-82-2864
# IBAN: GB32HGAS20083011657056
#
# Image: batch1-0503.jpg
# Invoice no: 22758345
# Tax Id: 942-74-5002
# IBAN: GB36KYWK10385657483744
#
# Image: batch1-0504.jpg
# Invoice no: 79036267
# Date of issue: 09/16/2016
# Seller: Client:
# Tax Id: 940-81-6212 Tax Id: 903-76-2071
# IBAN: GBO6EYSH87132118408113
#
# Image: batch1-0505.jpg
# Invoice no: 11556735
# Tax Id: 939-73-8621
# IBAN: GB82SVCE08751937948089
#
# Image: batch1-0506.jpg
# Invoice no: 35382296
# Tax Id: 982-92-4270
# IBAN: GB97SVBJ13467617537698
#
# Image: batch1-0507.jpg
# Invoice no: 64661204
# Tax Id: 917-70-4830
# IBAN: GB60AMAZ11977251874745
#
# Image: batch1-0508.jpg
# Invoice no: 95545504
# Tax Id: 998-79-7169
# IBAN: GB87IPTJ05582977551180
#
# Image: batch1-0509.jpg
# Invoice no: 66919860
# Tax Id: 912-81-4088
# IBAN: GB96NPWF24313123989624
#
# Image: batch1-0510.jpg
# Invoice no: 51033885
# Date of issue: 10/20/2020
# Seller: Client:
# Tax Id: 924-85-0
# IBAN: GB72WXZQ30602505765427
#
# Image: batch1-0511.jpg
# Invoice no: 17014325
# Tax Id: 961-75-8721
# IBAN: GB63VYKU25151548792645
#
# Image: batch1-0512.jpg
# Invoice no: 81040846
# Tax Id: 960-94-6644
# IBAN: GB36FNBG72685497690343
# Cars McQueen 1: 55 Diecast Lot
# 3: 4 pcs Kids Size Cartoon Peppa 1,00
#
# Image: batch1-0513.jpg
# Invoice no: 86883880
# Tax Id: 988-72-4811
# IBAN: GB63WGSI95835863625969
# 3: 3D Starry sky Carpet Child Play
#
# Image: batch1-0514.jpg
# Invoice no: 63042822
# Tax Id: 909-82-6817
# IBAN: GB72EJSX53160989293657
#
# Image: batch1-0515.jpg
# Invoice no: 41287213
# Tax Id: 958-92-0941
# IBAN: GB59NUQS46594706243199
#
# Image: batch1-0516.jpg
# Invoice no: 74093352
# Tax Id: 961-91-8761
# IBAN: GB29YJZA36672521634669
#
# Image: batch1-0517.jpg
# Invoice no: 80673242
# Date of issue: 06/12/2012
# Seller: Client:
# Tax Id: 909-90-7529 Tax Id: 976-71-1285
# IBAN: GB78XUNJ66821661162634
#
# Image: batch1-0518.jpg
# Invoice no: 94052403
# Tax Id: 928-97-9700
# IBAN: GB37TYVM02581764425566
# S: 6'x3' Black Marble Large Dining 3,00
#
# Image: batch1-0519.jpg
# Invoice no: 61249473
# Tax Id: 949-88-5332
# IBAN: GB71QDKV18239296168053
# 3: Original Nintendo Gaming 5,00
#
# Image: batch1-0520.jpg
# Invoice no: 91858806
# Date of issue: 03/05/2012
# Tax Id: 962-99-4335
# IBAN: GBO2KZOK44962043610197
#
# Image: batch1-0521.jpg
# Invoice no: 70471446
# Tax Id: 952-83-2026
# IBAN: GB81REGA90697374514551
# 3: Magnavox Odyssey 2 5,00
#
# Image: batch1-0522.jpg
# Invoice no: 80921168
# Tax Id: 999-90-0468
# IBAN: GB39CRDS82853845004678
#
# Image: batch1-0523.jpg
# Invoice no: 12947568
# Date of issue: 11/10/2018
# Seller: Client:
# Tax Id: 970-92-9578
# IBAN: GB24IHWR23389490452402
# a Black House: A Novel by 3,00 each
#
# Image: batch1-0524.jpg
# Invoice no: 76059860
# Date of issue: 03/04/2020
# Seller: Client:
# Tax Id: 921-76-4334 Tax Id: 966-75-4792
# IBAN: GB28QXWP57776134050198
#
# Image: batch1-0525.jpg
# Invoice no: 83087619
# Tax Id: 917-94-9139
# IBAN: GB60VBTM64941117655704
# Battlestations! (Star Trek: The
#
# Image: batch1-0526.jpg
# Invoice no: 61987058
# Tax Id: 999-80-6296
# IBAN: GB36KTDL23862064037578
# 3: Enough By Helen Roseveare 3,00
# 5: Harry Potter and the Chamber 4,00
#
# Image: batch1-0527.jpg
# Invoice no: 85992771
# Tax Id: 998-99-5998
# IBAN: GB90SXRI43551309635242
# 3: Sketchers Energy Lights Boys 3,00
#
# Image: batch1-0528.jpg
# Invoice no: 10503434
# Tax Id: 922-86-9460
# IBAN: GB68WUQJ50293517775877
#
# Image: batch1-0529.jpg
# Invoice no: 16455494
# Tax Id: 913-91-8468
# IBAN: GB6OWRAU97719147995766
#
# Image: batch1-0530.jpg
# Invoice no: 89528165
# Tax Id: 989-72-7105
# IBAN: GB85CYU074289270955300
#
# Image: batch1-0531.jpg
# Invoice no: 79622223
# Date of issue: 08/30/2011
# Seller: Client:
# Tax Id: 939-81-4755
# IBAN: GB87ESHD81490169427717
#
# Image: batch1-0532.jpg
# Invoice no: 72499229
# Tax Id: 949-87-4339
# IBAN: GB78SCQU65928970675216
#
# Image: batch1-0533.jpg
# Invoice no: 98424808
# Tax Id: 984-74-4819
# IBAN: GB13CSTL25020849255302
# 3: Muted Vegetable Dye Khootan 1,00
#
# Image: batch1-0534.jpg
# Invoice no: 61382297
# Tax Id: 988-72-7408
# IBAN: GB68XJXF92740762485025
#
# Image: batch1-0535.jpg
# Invoice no: 93281048
# Tax Id: 912-87-0223
# IBAN: GB81DFMJ63938748923911
#
# Image: batch1-0536.jpg
# Invoice no: 11101593
# Date of issue: 05/18/2015
# Tax Id: 932-94-8276
# IBAN: GB42BADT92735948077407
#
# Image: batch1-0537.jpg
# Invoice no: 90670432
# Tax Id: 906-75-9849
# IBAN: GB35VMQQ33475201075568
#
# Image: batch1-0538.jpg
# Invoice no: 93008460
# Tax Id: 969-86-5535
# IBAN: GB30IMHC92330290216388
# 3: hp all in one desktop computer 5,00
#
# Image: batch1-0539.jpg
# Invoice no: 11898657
# Tax Id: 997-900-5621
# IBAN: GB45ACOZ95865781715902
# 5: Caslon Blue White Sleeveless 1,00
#
# Image: batch1-0540.jpg
# Invoice no: 84991865
# Tax Id: 969-94-4351
# IBAN: GBO9BZLP67123213143488
#
# Image: batch1-0541.jpg
# Invoice no: 34521296
# Tax Id: 958-75-9101
# IBAN: GB96UEZN13686726209998
#
# Image: batch1-0542.jpg
# Invoice no: 82038366
# Tax Id: 932-78-3610
# IBAN: GB23HKLU13068276011034
# 3: HUGE Sony PlayStation 3 2,00
# 5: Sony PlayStation 2 Black Home 3,00
#
# Image: batch1-0543.jpg
# Invoice no: 53831875
# Date of issue: 02/12/2017
# Seller: Client:
# Tax Id: 940-90-1785 Tax Id: 992-85-8387
# IBAN: GB84RTRO97212468719728
#
# Image: batch1-0544.jpg
# Invoice no: 68743594
# Date of issue: 11/14/2015
# Tax Id: 908-96-5050
# IBAN: GB82DTZZ62127862271001
#
# Image: batch1-0545.jpg
# Invoice no: 89499883
# Date of issue: 11/23/2013
# Seller: Client:
# Tax Id: 920-71-6603 Tax Id: 975-99-1790
# IBAN: GB48KPDM89266099797577
# 3. The Trapper's Bible: The Most 1,00 each 13,49 13,49 10% 14,84
# 5: Steam Yacht Varuna, Brand 3,00 each 8,45 25,35) 10% 27,89
#
# Image: batch1-0546.jpg
# Invoice no: 66789639
# Tax Id: 942-75-5647
# IBAN: GB18TVDL00942136316502
# 3: Sing My Way Home: Voices of 5,00
# a Haida: Their Art and Culture 1,00
#
# Image: batch1-0547.jpg
# Invoice no: 66043700
# Date of issue: 09/08/2014
# Tax Id: 915-76-5267
# IBAN: GB530RZG62716043803709
#
# Image: batch1-0548.jpg
# Invoice no: 89174655
# Tax Id: 970-77-2494
# IBAN: GB89JRLS95828897014080
# ils The Great One: The Complete 2,00
# Country: Seeing America
#
# Image: batch1-0549.jpg
# Invoice no: 76654515
# Date of issue: 04/09/2012
# Seller: Client:
# Tax Id: 985-92-1
# IBAN: GB57ENRV41456145345087
# ils Unleashed: The Story of Tool, 3,00 each
#
# Image: batch1-0550.jpg
# Invoice no: 58097062
# Tax Id: 964-84-7884
# IBAN: GB79CMCC33561352409593
#
# Image: batch1-0551.jpg
# Invoice no: 19078061
# Tax Id: 993-97-1984
# IBAN: GB84ZRNY19629363252302
#
# Image: batch1-0552.jpg
# Invoice no: 65524700
# Tax Id: 952-84-7160
# IBAN: GB66DSV030328253726805
# 3: Dell Desktop Computer Optiplex 5,00
# 5: Gaming PC Desktop Computer 5,00
#
# Image: batch1-0553.jpg
# Invoice no: 16798931
# Tax Id: 977-88-7324
# IBAN: GB87ZVVB88258027299757
# 3: Reebok Boys Furylite Graphic 2,00
# 5: PUMA Pre-School Scuderia 4,00
#
# Image: batch1-0554.jpg
# Invoice no: 18884359
# Tax Id: 930-71-5450
# IBAN: GB93EQFF54734324377583
#
# Image: batch1-0555.jpg
# Invoice no: 97286997
# Tax Id: 988-77-5829
# IBAN: GB30JRHD27608005658757
# 2: Arnold Ehret RATIONAL FASTING 5,00
# S: Cell: A Novel by Stephen King 4,00
# 6. The Last Victim: A True-Life 2,00
#
# Image: batch1-0556.jpg
# Invoice no: 60050779
# Tax Id: 941-83-5191
# IBAN: GB46UUZU91627212711325
# 3: Joma Boys Youth Super Copa 5,00
#
# Image: batch1-0557.jpg
# Invoice no: 11187242
# Tax Id: 957-98-4430
# IBAN: GB29UQLX40638540279313
# 1. The Trapper's Bible: The Most 3,00
# 2. The Fountainhead: 50th 3,00
# 5: Motorcycle Journeys Through 4,00
# North America: A Guide for
# 7. Seashells of North America: A 4,00
#
# Image: batch1-0558.jpg
# Invoice no: 57381840
# Tax Id: 979-99-9419
# IBAN: GB36HCHW59184056744767
# 3: Blue Shiny Stone Floral Art
#
# Image: batch1-0559.jpg
# Invoice no: 38631441
# Date of issue: 02/08/2016
# Seller: Client:
# Tax Id: 976-83-6078
# IBAN: GB91LPFH85182474328082
#
# Image: batch1-0560.jpg
# Invoice no: 37481348
# Tax Id: 941-70-3813
# IBAN: GB58ANEJ71053300912958
# 3: Pond Scenery Fish Area Rugs 4,00
#
# Image: batch1-0561.jpg
# Invoice no: 34977445
# Tax Id: 996-96-3571
# IBAN: GB42YFFK02087870795108
#
# Image: batch1-0562.jpg
# Invoice no: 60795755
# Date of issue: 11/30/2011
# Seller: Client:
# Tax Id: 952-80-9499
# IBAN: GBO2HNQV04236902061077
#
# Image: batch1-0563.jpg
# Invoice no: 61026262
# Tax Id: 948-83-3330
# IBAN: GB34PSSJ26140269131425
# 5: Microsoft Xbox 360 S 4GB Black 4,00
#
# Image: batch1-0564.jpg
# Invoice no: 77307465
# Date of issue: 08/12/2014
# Seller: Client:
# Tax Id: 900-82-2663
# IBAN: GB950GSV36555708398085
#
# Image: batch1-0565.jpg
# Invoice no: 45767415
# Date of issue: 05/28/2015
# Tax Id: 982-92-1951
# IBAN: GB85GJMU32440067680287
# 3: HOME ESSENTIALS GRADIENT 1,00 each
#
# Image: batch1-0566.jpg
# Invoice no: 74898182
# Tax Id: 924-88-9771
# IBAN: GB14MWCV18105652308620
#
# Image: batch1-0567.jpg
# Invoice no: 77545252
# Tax Id: 986-70-1517
# IBAN: GB71CENJ79347815059655
#
# Image: batch1-0568.jpg
# Invoice no: 91125915
# Tax Id: 995-83-4095
# IBAN: GB44JSZW18347929758233
# 5: Sony Playstation 3 PS3 Slim 5,00
#
# Image: batch1-0569.jpg
# Invoice no: 66525131
# Date of issue: 07/26/2014
# Seller: Client:
# Tax Id: 922-97-1027 Tax Id: 985-90-2461
# IBAN: GB42YUKZ76503407905762
#
# Image: batch1-0570.jpg
# Invoice no: 69934544
# Tax Id: 937-77-3183
# IBAN: GB22MTVU06245364076494
#
# Image: batch1-0571.jpg
# Invoice no: 57443354
# Tax Id: 953-78-0173
# IBAN: GB96JJCP41911692988371
#
# Image: batch1-0572.jpg
# Invoice no: 25596256
# Tax Id: 989-92-4630
# IBAN: GB95UXLL05973666430772
#
# Image: batch1-0573.jpg
# Invoice no: 64197871
# Tax Id: 951-77-7205
# IBAN: GB98ZAPN48275814518696
# 3: Under Armour KIDS' LOCKDOWN
# Youth Sneakers: Sz 12k
#
# Image: batch1-0574.jpg
# Invoice no: 34916768
# Tax Id: 963-90-3201
# IBAN: GB86NSGM23877414691090
# 5: Microsoft Xbox One S 1TB 3,00
#
# Image: batch1-0575.jpg
# Invoice no: 48223084
# Tax Id: 983-91-8412
# IBAN: GB72JCTX43802931858904
#
# Image: batch1-0576.jpg
# Invoice no: 87388122
# Tax Id: 987-99-8918
# IBAN: GB59QMDG83315739161960
# 5: An Hour With Jesus 1,00
#
# Image: batch1-0577.jpg
# Invoice no: 73316184
# Tax Id: 975-85-8194
# IBAN: GB77XBMO043486566444443
# 3: Blueteeth LED Galaxy Projector 5,00
#
# Image: batch1-0578.jpg
# Invoice no: 48385116
# Tax Id: 915-83-9153
# IBAN: GB73XIOR22875156650471
# 5: Nintendo Wii New Super Mario 4,00
#
# Image: batch1-0579.jpg
# Invoice no: 79493856
# Tax Id: 984-88-2434
# IBAN: GB95WFCZ64941429535230
#
# Image: batch1-0580.jpg
# Invoice no: 47089332
# Tax Id: 912-86-6428
# IBAN: GB82VPWL04121428059686
# 3: Egg Shape Area Rugs Soft 1,00
#
# Image: batch1-0581.jpg
# Invoice no: 57338979
# Tax Id: 939-81-4695
# IBAN: GB9OALYU92362601688809
#
# Image: batch1-0582.jpg
# Invoice no: 89681299
# Tax Id: 997-84-1067
# IBAN: GB84CHOH80689043313192
#
# Image: batch1-0583.jpg
# Invoice no: 46916101
# Tax Id: 927-79-0644
# IBAN: GB50FHRJ76828594410969
#
# Image: batch1-0584.jpg
# Invoice no: 35603644
# Tax Id: 912-76-4111
# IBAN: GB86STWL97507319357665
#
# Image: batch1-0585.jpg
# Invoice no: 57905164
# Tax Id: 940-74-5920
# IBAN: GBO2QBHZ70184097596719
#
# Image: batch1-0586.jpg
# Invoice no: 53551787
# Tax Id: 945-88-6074
# IBAN: GB19VTIT10977146092856
# 3: Guccl Area Rugs Living Room 1,00
# 15: 56 10%
#
# Image: batch1-0587.jpg
# Invoice no: 65809258
# Tax Id: 921-84-9861
# IBAN: GB43UBZY01685476660728
#
# Image: batch1-0588.jpg
# Invoice no: 71999960
# Date of issue: 10/13/2017
# Tax Id: 998-95-3381
# IBAN: GB86AXKW20154111839935
#
# Image: batch1-0589.jpg
# Invoice no: 19608758
# Tax Id: 974-84-9228
# IBAN: GB85RBGA54342067350859
#
# Image: batch1-0590.jpg
# Invoice no: 91817064
# Tax Id: 997-78-2441
# IBAN: GB67IEHI18809591004895
#
# Image: batch1-0591.jpg
# Invoice no: 56557802
# Tax Id: 992-98-8054
# IBAN: GB74WFFD17300213526018
# 3: Refinery Wine Opener
#
# Image: batch1-0592.jpg
# Invoice no: 74576933
# Tax Id: 969-91-1034
# IBAN: GB92BAIN95242302828660
# 3: BLACK Butterfly Winged
# S: Sitting Deer Wine Bottle Holder
#
# Image: batch1-0593.jpg
# Invoice no: 43066287
# Date of issue: 12/03/2011
# Seller: Client:
# Tax Id: 960-86-6054 Tax Id: 937-78-2740
# IBAN: GB80ACCM39187551419549
# ils A New Earth: Awakening to Your 5,00 each 4,49 22,45 10% 24,70
# 4. Unleashed: The Story of Tool, 5,00 each 16,88 84,40 10% 92,84
# 5: return to virgin river by robyn 4,00 each 2,99 11,96 10% 13,16
# 6. The Fountainhead: 50th 3,00 each 4,49 13,47 10% 14,82
#
# Image: batch1-0594.jpg
# Invoice no: 56967329
# Tax Id: 921-85-8757
# IBAN: GB52ZLFI42670277307496
# 2: Stemware Rack Display Kitchen
#
# Image: batch1-0595.jpg
# Invoice no: 70184923
# Tax Id: 953-90-1251
# IBAN: GB73KFQB00443594087080
# 6. Shaping the World: Sculpture 5,00
#
# Image: batch1-0596.jpg
# Invoice no: 62801471
# Tax Id: 987-95-0607
# IBAN: GB43YPPM63429317026651
#
# Image: batch1-0597.jpg
# Invoice no: 16021510
# Date of issue: 12/21/2014
# Seller: Client:
# Tax Id: 920-98-9142 Tax Id: 998-81-6833
# IBAN: GBOS5MKKL50400612864650
#
# Image: batch1-0598.jpg
# Invoice no: 54299574
# Tax Id: 968-80-8718
# IBAN: GB60APZH41378958559864
# 3: 40 Inches Marble Utility Table
#
# Image: batch1-0599.jpg
# Invoice no: 59090855
# Tax Id: 926-97-9476
# IBAN: GB86ITNO81527698989075
#
# Image: batch1-0600.jpg
# Invoice no: 28248186
# Tax Id: 971-95-7428
# IBAN: GB85CZLF00079861232359
#
# Image: batch1-0601.jpg
# Invoice no: 88351693
# Date of issue: 09/01/2014
# Tax Id: 906-78-1558
# IBAN: GB12OVRF48783325801365
#
# Image: batch1-0602.jpg
# Invoice no: 27968677
# Tax Id: 971-81-4928
# IBAN: GB19LZFP85008407866864
#
# Image: batch1-0603.jpg
# Invoice no: 98224499
# Tax Id: 974-94-2078
# IBAN: GB22SEEN14690845180279
# 3: Nike 747998-401 Team Hustle
#
# Image: batch1-0604.jpg
# Invoice no: 65345089
# Tax Id: 958-90-2468
# IBAN: GB41CYBY20444587829017
#
# Image: batch1-0605.jpg
# Invoice no: 83091868
# Tax Id: 941-97-8554
# IBAN: GB86XGQG99639899146980
# 3: Ryzen Gaming Computer
#
# Image: batch1-0606.jpg
# Invoice no: 44337721
# Tax Id: 962-82-1600
# IBAN: GB30QDAV47663465507009
# Country: Seeing America
# North America: A Guide for
# S: Enough By Helen Roseveare 2,00
#
# Image: batch1-0607.jpg
# Invoice no: 36268429
# Tax Id: 969-96-4798
# IBAN: GB38UKIJ21665136045658
# 2: Custom Built Gaming Computer 5,00
# 5: NEW RGB Quad Core Gaming PC 2,00
#
# Image: batch1-0608.jpg
# Invoice no: 30885203
# Tax Id: 937-72-6142
# IBAN: GBO2ZONNL63005814637467
# 2: Stemware Rack Display Kitchen 3,00
# S: Wine Things Unlimited - Tipsy 5,00
#
# Image: batch1-0609.jpg
# Invoice no: 29864689
# Tax Id: 913-71-3837
# IBAN: GB55MMEF60869801450930
#
# Image: batch1-0610.jpg
# Invoice no: 69167020
# Tax Id: 936-95-7995
# IBAN: GB76RLVG97497779065189
# 3: Happy Christmas Home
#
# Image: batch1-0611.jpg
# Invoice no: 31045620
# Tax Id: 970-92-7216
# IBAN: GB20AYFN06122510374802
#
# Image: batch1-0612.jpg
# Invoice no: 87695069
# Tax Id: 983-70-8237
# IBAN: GB71SOMY41554092839099
#
# Image: batch1-0613.jpg
# Invoice no: 12198664
# Tax Id: 952-97-9295
# IBAN: GB96PSKP77934880550335
# 3: Roper Boys' American Patriot 3,00
# S: Sperry Infant Size 6 Boat Shoes 2,00
#
# Image: batch1-0614.jpg
# Invoice no: 46964541
# Tax Id: 932-98-0843
# IBAN: GB52GEEM17057064270366
# 3: Coinmine One Intel or AMD with
#
# Image: batch1-0615.jpg
# Invoice no: 81384146
# Tax Id: 975-88-0557
# IBAN: GB85FXWI03764269520259
# Cars McQueen 1: 55 Diecast Lot
# 3: Skechers Shoes Kids Size 2
# 5: Lakai Select Skate Shoe - Little
#
# Image: batch1-0616.jpg
# Invoice no: 36854240
# Date of issue: 02/12/2016
# Seller: Client:
# Tax Id: 917-75-1041 Tax Id: 992-96-4567
# IBAN: GB97RFMT08440774445575
#
# Image: batch1-0617.jpg
# Invoice no: 42760323
# Tax Id: 979-98-4396
# IBAN: GB490KCD66731511692442
# 3: Fluffy Rugs Anti-slip Area Rug 4,00
#
# Image: batch1-0618.jpg
# Invoice no: 28428192
# Date of issue: 07/16/2015
# Seller: Client:
# Tax Id: 947-81-0049
# IBAN: GB580RZH78424092129558
#
# Image: batch1-0619.jpg
# Invoice no: 40703416
# Tax Id: 993-85-1912
# IBAN: GB87VHVY25464138065566
#
# Image: batch1-0620.jpg
# Invoice no: 42321277
# Date of issue: 03/04/2015
# Seller: Client:
# Tax Id: 931-91-1835
# IBAN: GB71TRSB38658790977230
#
# Image: batch1-0621.jpg
# Invoice no: 83876203
# Tax Id: 909-75-0228
# IBAN: GB11TSGI11085522221932
# oo Christmas Cupcake Murder: A 5,00
# 4. Sing My Way Home: Voices of 5,00
# 5: Rebecca and Ana (American Girl 1,00
# 6. Unleashed: The Story of Tool, 2,00
#
# Image: batch1-0622.jpg
# Invoice no: 30933703
# Date of issue: 03/08/2019
# Tax Id: 961-95-6215
# IBAN: GB630SSA96049791516981
#
# Image: batch1-0623.jpg
# Invoice no: 87655538
# Date of issue: 12/16/2018
# Tax Id: 970-96-1494
# IBAN: GB59MCIJ70715558745631
#
# Image: batch1-0624.jpg
# Invoice no: 18212068
# Tax Id: 920-91-3763
# IBAN: GB79UXUI32711407896844
#
# Image: batch1-0625.jpg
# Invoice no: 62962397
# Tax Id: 956-81-4111
# IBAN: GB91QN0Q58484580654871
#
# Image: batch1-0626.jpg
# Invoice no: 37959814
# Tax Id: 970-94-8001
# IBAN: GBO5XBMF67798318915337
# 3: Custom Gaming Computer 2,00
# 5: Dell Desktop Computer PC 5,00
#
# Image: batch1-0627.jpg
# Invoice no: 20369343
# Tax Id: 934-82-2398
# IBAN: GB10WQSV20535335597484
#
# Image: batch1-0628.jpg
# Invoice no: 37995856
# Seller: Client:
# Tax Id: 941-97-9484
# IBAN: GB15WYGM00923783631136
#
# Image: batch1-0629.jpg
# Invoice no: 98914713
# Date of issue: 01/13/2012
# Seller: Client:
# Tax Id: 965-99-5985 Tax Id: 990-92-6635
# IBAN: GB69X0CZ99259366064912
#
# Image: batch1-0630.jpg
# Invoice no: 93128666
# Tax Id: 994-82-3949
# IBAN: GB18TZJU54496600379641
#
# Image: batch1-0631.jpg
# Invoice no: 17945455
# Tax Id: 952-73-0856
# IBAN: GBO3IPYG30839908981013
#
# Image: batch1-0632.jpg
# Invoice no: 74330913
# Tax Id: 981-91-2493
# IBAN: GB47LSJU21543168763067
# $3: 772,52
#
# Image: batch1-0633.jpg
# Invoice no: 68456767
# Tax Id: 968-83-6957
# IBAN: GBO5VWTP21153093587644
#
# Image: batch1-0634.jpg
# Invoice no: 94006791
# Tax Id: 954-73-5688
# IBAN: GB62BPCY62278484325750
#
# Image: batch1-0635.jpg
# Invoice no: 22809328
# Seller: Client:
# Tax Id: 927-87-9509
# IBAN: GB67YBXG82461526820050
#
# Image: batch1-0636.jpg
# Invoice no: 87101999
# Tax Id: 992-83-6219
# IBAN: GB40FJUB94063154688274
#
# Image: batch1-0637.jpg
# Invoice no: 15883673
# Date of issue: 05/20/2012
# Seller: Client:
# Tax Id: 954-76-7192
# IBAN: GB98RREZ76578007955961
#
# Image: batch1-0638.jpg
# Invoice no: 44909511
# Tax Id: 931-76-2067
# IBAN: GB91JBAX90178165186815
#
# Image: batch1-0639.jpg
# Invoice no: 29378439
# Tax Id: 913-71-4613
# IBAN: GB79DVQP67594826429760
# 3: Saucony Boys' Ride ISO 1,00
# S: boys bogs waterproof boots 1,00
#
# Image: batch1-0640.jpg
# Invoice no: 72120624
# Tax Id: 933-99-0088
# IBAN: GB65FOQP67430087783490
#
# Image: batch1-0641.jpg
# Invoice no: 32075407
# Date of issue: 04/16/2017
# Tax Id: 944-85-5331
# IBAN: GB500DWZ90242536175287
#
# Image: batch1-0642.jpg
# Invoice no: 37984067
# Tax Id: 958-74-0701
# IBAN: GB11ZMKK30115854451979
#
# Image: batch1-0643.jpg
# Invoice no: 69642118
# Tax Id: 978-80-5348
# IBAN: GB85GJBG73762850564540
# ils Q&A a Day: 5-Year Journal 2,00
#
# Image: batch1-0644.jpg
# Invoice no: 70710512
# Tax Id: 987-81-5356
# IBAN: GB28TRTH90859067641033
# 5: Threshold Quality Strafford 2,00
#
# Image: batch1-0645.jpg
# Invoice no: 29907458
# Tax Id: 975-83-0226
# IBAN: GB191UDU68156963058807
# 3: Women Sexy Lingerie Lace 4,00
# S: Women Spaghetti Strap 2,00
#
# Image: batch1-0646.jpg
# Invoice no: 10357282
# Date of issue: 11/08/2016
# Seller: Client:
# Tax Id: 998-95-4942 Tax Id: 921-84-0980
# IBAN: GB17LRHJ86121974993232
# and Its All Small Stuff: Simple
#
# Image: batch1-0647.jpg
# Invoice no: 60703296
# Tax Id: 944-90-0667
# IBAN: GB59NDBQ47330290079375
# 3: Chindi Rugs Carpet New Design 3,00
# 5: Round Indian Braided Jute 5,00
#
# Image: batch1-0648.jpg
# Invoice no: 39714865
# Date of issue: 09/08/2018
# Seller: Client:
# Tax Id: 930-95-8020 Tax Id: 920-99-0537
# IBAN: GBO2TMTC25755610558773
#
# Image: batch1-0649.jpg
# Invoice no: 57478727
# Tax Id: 949-74-8404
# IBAN: GB42HKRE69161206722083
# S: 6'x3' Black Marble Top Dining 4,00
#
# Image: batch1-0650.jpg
# Invoice no: 49416245
# Tax Id: 965-84-6891
# IBAN: GB80DKDE30435328433412
#
# Image: batch1-0651.jpg
# Invoice no: 87456388
# Tax Id: 964-98-8357
# IBAN: GB65LOLY47932229833502
#
# Image: batch1-0652.jpg
# Invoice no: 40949664
# Tax Id: 998-75-7020
# IBAN: GB78APAP25463699014706
# S: 14 Colors Women Spaghetti 4,00
#
# Image: batch1-0653.jpg
# Invoice no: 96192536
# Date of issue: 06/12/2011
# Seller: Client:
# Tax Id: 932-96-0983 Tax Id: 954-87-4129
# IBAN: GB43WFNW20455585011126
#
# Image: batch1-0654.jpg
# Invoice no: 44868919
# Tax Id: 981-85-7748
# IBAN: GB23A0VU49182844482123
# 3: Liza Byrd Dress Sz L- Coral
#
# Image: batch1-0655.jpg
# Invoice no: 45072803
# Date of issue: 08/05/2017
# Seller: Client:
# Tax Id: 956-91-5905 Tax Id: 925-70-9586
# IBAN: GB62DIUF98412628425096
#
# Image: batch1-0656.jpg
# Invoice no: 86780085
# Tax Id: 984-91-8529
# IBAN: GB30ZZZM66374557209013
# 5: Nintendo Switch Lite Yellow 1,00
#
# Image: batch1-0657.jpg
# Invoice no: 23048796
# Tax Id: 941-95-4158
# IBAN: GB26BQKP56187033878756
# 3: Birthday Girl Wine Glass by 4,00
#
# Image: batch1-0658.jpg
# Invoice no: 11036543
# Date of issue: 06/25/2017
# Seller: Client:
# Tax Id: 983-95-9524 Tax Id: 944-95-9239
# IBAN: GB51JYPA41706484714659
#
# Image: batch1-0659.jpg
# Invoice no: 75050384
# Tax Id: 964-88-6010
# IBAN: GB23YBLD73900334583339
# 3: YILONG 5.6'x8.2' Handknotted
# 5: Moroccan Handmade Amazigh 2,00
#
# Image: batch1-0660.jpg
# Invoice no: 29712721
# Date of issue: 05/04/2021
# Seller: Client:
# Tax Id: 904-95-9
# IBAN: GB15QZKA88830741837409
#
# Image: batch1-0661.jpg
# Invoice no: 71748307
# Tax Id: 996-86-8087
# IBAN: GB48EAPQ46997886926034
# 5: miley cyrus Bubble Dress 2,00
#
# Image: batch1-0662.jpg
# Invoice no: 93132815
# Date of issue: 09/07/2019
# Seller: Client:
# Tax Id: 994-76-2516 Tax Id: 965-88-2883
# IBAN: GB86ZU0D03559216642476
#
# Image: batch1-0663.jpg
# Invoice no: 17619666
# Tax Id: 937-79-7558
# IBAN: GB40JKGK45011938135603
#
# Image: batch1-0664.jpg
# Invoice no: 16759248
# Tax Id: 956-99-7330
# IBAN: GB93TWXT35430625888348
#
# Image: batch1-0665.jpg
# Invoice no: 86792000
# Tax Id: 958-74-4412
# IBAN: GB46SUWL10604451928084
# Q&A a Day: 5-Year Journal 3,00
# Banjo: Revised and Enhanced
# Beverley Nichols: A Life by 5,00
#
# Image: batch1-0666.jpg
# Invoice no: 71561544
# Tax Id: 997-75-5313
# IBAN: GB44GUVN59172661985184
#
# Image: batch1-0667.jpg
# Invoice no: 47981077
# Tax Id: 934-77-3140
# IBAN: GB81KHDY06695208511692
#
# Image: batch1-0668.jpg
# Invoice no: 67802841
# Tax Id: 935-80-2158
# IBAN: GBOSEFWL28589579077613
# 3: PocketGo Bittboy v2 White
#
# Image: batch1-0669.jpg
# Invoice no: 35293120
# Date of issue: 08/09/2018
# Seller: Client:
# Tax Id: 963-85-4755 Tax Id: 983-85-2498
# IBAN: GB13JVIU78410116496939
#
# Image: batch1-0670.jpg
# Invoice no: 24734743
# Tax Id: 929-91-8169
# IBAN: GB27FMNA07632139513602
# 5: Lilly Pulitzer XS Spike the Punch 3,00
#
# Image: batch1-0671.jpg
# Invoice no: 88223203
# Date of issue: 01/14/2014
# Seller: Client:
# Tax Id: 910-85-4727 Tax Id: 973-94-2332
# IBAN: GB14CVST21243189310101
#
# Image: batch1-0672.jpg
# Invoice no: 68338115
# Tax Id: 939-99-9502
# IBAN: GB510EMX60944820724863
#
# Image: batch1-0673.jpg
# Invoice no: 22442124
# Tax Id: 937-95-4564
# IBAN: GB15HDTW85461664416478
#
# Image: batch1-0674.jpg
# Invoice no: 19570656
# Tax Id: 911-88-4203
# IBAN: GBO8UMMI198094755494368
#
# Image: batch1-0675.jpg
# Invoice no: 37306845
# Date of issue: 04/29/2015
# Tax Id: 902-77-3474
# IBAN: GB28EWHK11859621089321
#
# Image: batch1-0676.jpg
# Invoice no: 18650156
# Tax Id: 964-75-4735
# IBAN: GB19FFCY83556688389779
# 3: Joma Boys Youth Gol-102 3,00
#
# Image: batch1-0677.jpg
# Invoice no: 90292361
# Tax Id: 964-79-3530
# IBAN: GB94KJJC66350392403995
# 5: Chindi Rugs Carpet New Design 2,00
#
# Image: batch1-0678.jpg
# Invoice no: 32009066
# Tax Id: 966-82-9
# IBAN: GB22DO0W059772132319337
#
# Image: batch1-0679.jpg
# Invoice no: 66825384
# Tax Id: 901-82-4343
# IBAN: GB46ABQB31058264411257
#
# Image: batch1-0680.jpg
# Invoice no: 47602389
# Tax Id: 905-96-0130
# IBAN: GB59GUGQ50026153371793
#
# Image: batch1-0681.jpg
# Invoice no: 23287155
# Tax Id: 978-77-0277
# IBAN: GB42MHLP74483354987589
# 3: Black Shaggy Rug 5,00
# 5: YILONG 4'x6' Yellow Handmade 3,00
#
# Image: batch1-0682.jpg
# Invoice no: 38392535
# Tax Id: 942-73-8289
# IBAN: GB53DPTP69022229570706
#
# Image: batch1-0683.jpg
# Invoice no: 85395957
# Tax Id: 979-72-4769
# IBAN: GB79EJAI89365481232876
# 3: Unicorn Wine Bottle Display
#
# Image: batch1-0684.jpg
# Invoice no: 91445086
# Tax Id: 929-88-1421
# IBAN: GB26WQKM14989983341952
#
# Image: batch1-0685.jpg
# Invoice no: 95076029
# Tax Id: 918-91-8490
# IBAN: GB66JBMG14825780092382
#
# Image: batch1-0686.jpg
# Invoice no: 41659958
# Tax Id: 942-75-6971
# IBAN: GB93ZZCL46242237825953
#
# Image: batch1-0687.jpg
# Invoice no: 43813549
# Tax Id: 911-74-2492
# IBAN: GB39SASL91799987560348
# 2: Xhilaration Womens L Burgandy 1,00
# 3: Betsey Johnson Black Solid 2,00
# 5: Adult Kids Pokemon Pikachu 4,00
#
# Image: batch1-0688.jpg
# Invoice no: 56943461
# Tax Id: 970-82-8763
# IBAN: GB31AJPJ35776683143765
#
# Image: batch1-0689.jpg
# Invoice no: 92944130
# Tax Id: 989-78-8644
# IBAN: GBO9VHPH54755658499923
# 3: Fast Dell Optiplex Windows 10 1,00
#
# Image: batch1-0690.jpg
# Invoice no: 94666143
# Tax Id: 974-94-5262
# IBAN: GB83YNKY81872681261020
# 5: SONY Playstation2 Console 4,00
#
# Image: batch1-0691.jpg
# Invoice no: 77164038
# Date of issue: 04/15/2021
# Seller: Client:
# Tax Id: 915-81-7284
# IBAN: GB34PODL50120591029883
#
# Image: batch1-0692.jpg
# Invoice no: 15902016
# Tax Id: 905-70-3376
# IBAN: GB62TDNY91893152860446
# 3: Dell Optiplex 790 Computer i7 4,00
# 5: GAMING PC Desktop Computer 3,00
#
# Image: batch1-0693.jpg
# Invoice no: 74227045
# Tax Id: 952-81-3407
# IBAN: GB37YKTF0O1501025767922
#
# Image: batch1-0694.jpg
# Invoice no: 22434910
# Date of issue: 12/30/2015
# Seller: Client:
# Tax Id: 932-74-5299 Tax Id: 993-87-4206
# IBAN: GB97SYXK21154194731792
#
# Image: batch1-0695.jpg
# Invoice no: 98497640
# Tax Id: 943-98-2108
# IBAN: GB26SOCQ30024658377186
#
# Image: batch1-0696.jpg
# Invoice no: 64291160
# Tax Id: 964-91-6604
# IBAN: GB16CKZJ66620560829546
#
# Image: batch1-0697.jpg
# Invoice no: 98824587
# Tax Id: 945-83-4600
# IBAN: GB20SJZU55484922035378
#
# Image: batch1-0698.jpg
# Invoice no: 12681565
# Tax Id: 971-96-6933
# IBAN: GB20IFBT89821062114124
#
# Image: batch1-0699.jpg
# Invoice no: 14103295
# Tax Id: 956-79-3831
# IBAN: GB89DIVP72977735643876
# 2: Lilly Pulitzer Lillywood California 1,00
#
# Image: batch1-0700.jpg
# Invoice no: 78785504
# Tax Id: 924-80-6154
# IBAN: GB93HXLD30308952272868
# 3: Lolita "Wine Bouquet" Hand
#
# Image: batch1-0701.jpg
# Invoice no: 83158540
# Date of issue: 02/28/2015
# Tax Id: 935-94-9398
# IBAN: GB76MRMM02871555180809
#
# Image: batch1-0702.jpg
# Invoice no: 63960251
# Tax Id: 955-82-6268
# IBAN: GB51FIYG83099845917805
#
# Image: batch1-0703.jpg
# Invoice no: 66430808
# Date of issue: 06/18/2020
# Seller: Client:
# Tax Id: 952-73-6413 Tax Id: 951-94-4314
# IBAN: GB45FFLW23217428528260
#
# Image: batch1-0704.jpg
# Invoice no: 59628193
# Tax Id: 926-72-8884
# IBAN: GB78YBLA80809585603986
#
# Image: batch1-0705.jpg
# Invoice no: 94914402
# Tax Id: 979-72-1317
# IBAN: GB17VCKB95228636038037
# 3: adidas Youth Boys Soccer Cleats
#
# Image: batch1-0706.jpg
# Invoice no: 14467965
# Tax Id: 938-77-1642
# IBAN: GB25EKKT58751383043984
# 3: Rug for living room-Minion And
#
# Image: batch1-0707.jpg
# Invoice no: 95611677
# Date of issue: 07/19/2016
# Seller: Client:
# Tax Id: 973-97-5084 Tax Id: 952-81-0165
# IBAN: GB95MPFV88552069556163
#
# Image: batch1-0708.jpg
# Invoice no: 49822251
# Tax Id: 992-98-6676
# IBAN: GB32BSVJ18563928156491
#
# Image: batch1-0709.jpg
# Invoice no: 26020078
# Tax Id: 942-86-9388
# IBAN: GB93YUAY48784201603098
# Cars McQueen 1: 55 Diecast Lot
#
# Image: batch1-0710.jpg
# Invoice no: 34069390
# Tax Id: 949-73-3279
# IBAN: GB49JHMV37488350534063
# 3: Dell Desktop Computer PC Intel 5,00
#
# Image: batch1-0711.jpg
# Invoice no: 42485588
# Tax Id: 970-99-7937
# IBAN: GB47NOKI45420514797164
#
# Image: batch1-0712.jpg
# Invoice no: 72794429
# Date of issue: 03/15/2021
# Seller: Client:
# Tax Id: 932-82-1959 Tax Id: 945-97-3734
# IBAN: GB97ZAJJ81744871749453
#
# Image: batch1-0713.jpg
# Invoice no: 50222999
# Tax Id: 913-85-2985
# IBAN: GB20JMEM34079477867974
#
# Image: batch1-0714.jpg
# Invoice no: 78697882
# Tax Id: 976-97-2203
# IBAN: GB87WHWH85430916517133
#
# Image: batch1-0715.jpg
# Invoice no: 94689364
# Tax Id: 963-73-0110
# IBAN: GB67GYBL21403855924419
# S: Egg Bathroom Rug Carpet Area 2,00
#
# Image: batch1-0716.jpg
# Invoice no: 62416513
# Date of issue: 05/05/2013
# Seller: Client:
# Tax Id: 975-83-3
# IBAN: GBO2PADT01686568494870
#
# Image: batch1-0717.jpg
# Invoice no: 48402876
# Tax Id: 930-79-2809
# IBAN: GB80ESDN56327720432862
#
# Image: batch1-0718.jpg
# Invoice no: 55043266
# Tax Id: 982-76-3791
# IBAN: GB36UQPH09586322205377
# 3: Stemware Rack Display Kitchen 4,00
#
# Image: batch1-0719.jpg
# Invoice no: 11158119
# Tax Id: 943-88-6756
# IBAN: GB83FTEF94522626404124
#
# Image: batch1-0720.jpg
# Invoice no: 48142412
# Tax Id: 925-97-4219
# IBAN: GBO4DASF93147348040373
#
# Image: batch1-0721.jpg
# Invoice no: 65321852
# Tax Id: 957-82-7504
# IBAN: GB85XPMM58300597200061
# 3: Joma Boys Youth Gol-102
#
# Image: batch1-0722.jpg
# Invoice no: 53695084
# Tax Id: 950-83-8341
# IBAN: GB23EWWJ02101517027257
# 3: STUDENT/WORK COMPUTER
#
# Image: batch1-0723.jpg
# Invoice no: 86268868
# Tax Id: 951-73-7519
# IBAN: GB90KGZY90567874189494
#
# Image: batch1-0724.jpg
# Invoice no: 65851875
# Tax Id: 939-76-1432
# IBAN: GB10CDOB89879026186527
# 3: Vintage MIKASA Crystal Glass 2,00
#
# Image: batch1-0725.jpg
# Invoice no: 77006579
# Tax Id: 935-99-6545
# IBAN: GB38LDMS35426816092509
# 5: GUESS dress size 2 5,00
#
# Image: batch1-0726.jpg
# Invoice no: 39280409
# Tax Id: 965-83-8071
# IBAN: GB39WJUU70698169375316
# 3: Bohemian Rag Rug- Woven 2,00
#
# Image: batch1-0727.jpg
# Invoice no: 57262990
# Tax Id: 901-95-1569
# IBAN: GB37JTAK84616292458592
# 3: Tea with Jane Austen
#
# Image: batch1-0728.jpg
# Invoice no: 87278875
# Tax Id: 938-94-3648
# IBAN: GB96ONEJ77402455114924
# 3: Joma Boys Youth Gol-102
#
# Image: batch1-0729.jpg
# Invoice no: 49089384
# Tax Id: 971-99-5388
# IBAN: GB24TUWZ29828090312120
#
# Image: batch1-0730.jpg
# Invoice no: 16220332
# Tax Id: 988-78-0364
# IBAN: GB30RUVA78076817247388
# 3: YILONG 5'x7.5' Handknotted
#
# Image: batch1-0731.jpg
# Invoice no: 10080932
# Tax Id: 983-86-8494
# IBAN: GB15MBGH75492488995651
# 5: War Horse Series Small Large 3,00
#
# Image: batch1-0732.jpg
# Invoice no: 76999802
# Tax Id: 953-71-2727
# IBAN: GB64FEHQ32175908346356
# 3: 36" Agate Center Dining Table 4,00
# 5: 34"x34" Marble Round Top 3,00
#
# Image: batch1-0733.jpg
# Invoice no: 88659425
# Tax Id: 941-70-8992
# IBAN: GB16YTDN72987233002849
# 2: Forever 21 Blue A-Line Dress
# 5: Women's black cocktail dress,
#
# Image: batch1-0734.jpg
# Invoice no: 61619303
# Date of issue: 09/20/2013
# Seller: Client:
# Tax Id: 971-86-1778
# IBAN: GB89PBXV06755096377275
#
# Image: batch1-0735.jpg
# Invoice no: 83326872
# Tax Id: 957-88-6629
# IBAN: GB93DZWE23982846561488
#
# Image: batch1-0736.jpg
# Invoice no: 92608297
# Seller: Client:
# Tax Id: 967-85-5825
# IBAN: GB47PUXE23952807013906
#
# Image: batch1-0737.jpg
# Invoice no: 56514066
# Tax Id: 955-86-3035
# IBAN: GB76WTTH68902414885248
#
# Image: batch1-0738.jpg
# Invoice no: 47743201
# Tax Id: 912-96-7434
# IBAN: GB7OWHXD28723919267896
# 2: Sperry Top Sider Billfish Boys 5,00
#
# Image: batch1-0739.jpg
# Invoice no: 74322107
# Tax Id: 915-98-4870
# IBAN: GB31YDUN56799610017131
#
# Image: batch1-0740.jpg
# Invoice no: 45072501
# Tax Id: 994-98-7413
# IBAN: GB65BSDX18427409737993
# 3: Sonic Wind The Story of John 5,00
# 5: How to Win Friends & Influence 4,00
#
# Image: batch1-0741.jpg
# Invoice no: 33931957
# Tax Id: 903-94-1332
# IBAN: GB17YMKF08477262646620
#
# Image: batch1-0742.jpg
# Invoice no: 74474655
# Date of issue: 01/03/2015
# Seller: Client:
# Tax Id: 979-73-8511
# IBAN: GB78LJX136348036441752
#
# Image: batch1-0743.jpg
# Invoice no: 70372519
# Tax Id: 933-82-8453
# IBAN: GB19KZPB65453134501012
# 3: Sony PlayStation 5 Console - 5,00
#
# Image: batch1-0744.jpg
# Invoice no: 95592218
# Date of issue: 03/09/2017
# Seller: Client:
# Tax Id: 938-85-3914
# IBAN: GB94JRJU72702823539905
# 2. Astronomy: A Visual Guide 1,00 each 5,02 5,02 10% 5,52
#
# Image: batch1-0745.jpg
# Invoice no: 94133236
# Tax Id: 937-75-3172
# IBAN: GB72GHYW09265342345456
#
# Image: batch1-0746.jpg
# Invoice no: 33652903
# Tax Id: 916-71-6735
# IBAN: GB821EIC92575317339836
# Bh Rod: The Autobiography by Rod 3,00
# 5: Catechism of the Catholic 4,00
#
# Image: batch1-0747.jpg
# Invoice no: 25353322
# Tax Id: 948-76-4638
# IBAN: GB68JTXX82406535564656
# 2: Beach Lunch Lounge Striped
# 3: Banana Republic Maroon
# 5: Boden black blue floral short
#
# Image: batch1-0748.jpg
# Invoice no: 51686132
# Tax Id: 990-87-4012
# IBAN: GB67DSXM44548665165041
#
# Image: batch1-0749.jpg
# Invoice no: 99988020
# Tax Id: 933-90-7591
# IBAN: GB87LIST13922496116710
#
# Image: batch1-0750.jpg
# Invoice no: 38829380
# Tax Id: 979-96-0266
# IBAN: GB77WZUW03936127773887
#
# Image: batch1-0751.jpg
# Invoice no: 68868961
# Tax Id: 921-90-5767
# IBAN: GB16YOXG40499445558384
#
# Image: batch1-0752.jpg
# Invoice no: 78566408
# Tax Id: 906-74-9305
# IBAN: GB76QCXU43762789246312
# S: Joma Boys Youth Gol-102 3,00
#
# Image: batch1-0753.jpg
# Invoice no: 97802815
# Tax Id: 970-76-9057
# IBAN: GB24VX0C22859556183057
#
# Image: batch1-0754.jpg
# Invoice no: 95707254
# Tax Id: 923-94-2802
# IBAN: GBO7AGJU73318785668495
# 3: TODDLER SHAQ HIGH TOP 3,00
# 5: Lotto Soccer Turf Shoes 6 Black 4,00
#
# Image: batch1-0755.jpg
# Invoice no: 67182330
# Date of issue: 06/05/2014
# Seller: Client:
# Tax Id: 954-99-7182 Tax Id: 955-98-4068
# IBAN: GB28JALD66709047561002
# 5: Old Navy Womens Sleeveless 2,00 each 12,00 24,00 10% 26,40
#
# Image: batch1-0756.jpg
# Invoice no: 72346654
# Tax Id: 927-90-3514
# IBAN: GB98THYE24829931003032
#
# Image: batch1-0757.jpg
# Invoice no: 89538216
# Tax Id: 927-95-6832
# IBAN: GB40ESWD08979767150482
#
# Image: batch1-0758.jpg
# Invoice no: 29180375
# Tax Id: 917-95-6854
# IBAN: GB85AQWU82065233427036
#
# Image: batch1-0759.jpg
# Invoice no: 60178633
# Tax Id: 939-81-7319
# IBAN: GB36JYKL45599075785785
#
# Image: batch1-0760.jpg
# Invoice no: 65744802
# Tax Id: 927-76-9862
# IBAN: GB33PSJG02482992709528
#
# Image: batch1-0761.jpg
# Invoice no: 76671573
# Tax Id: 912-85-0464
# IBAN: GBO3VHUR92534869762657
#
# Image: batch1-0762.jpg
# Invoice no: 49656852
# Tax Id: 983-85-6334
# IBAN: GB83DUWH39995300044767
# 2: 6'x3' Black Marble Top Dining 1,00
#
# Image: batch1-0763.jpg
# Invoice no: 46775557
# Date of issue: 04/05/2019
# Seller: Client:
# Tax Id: 908-71-4639 Tax Id: 972-82-7727
# IBAN: GB30LTFL22480789312543
#
# Image: batch1-0764.jpg
# Invoice no: 23876575
# Tax Id: 945-79-5352
# IBAN: GB19SDIC93772652135580
# S: Gaming PC Computer RX 580 5,00
#
# Image: batch1-0765.jpg
# Invoice no: 97159829
# Tax Id: 994-72-1270
# IBAN: GB81LZW0O32519172531418
#
# Image: batch1-0766.jpg
# Invoice no: 89379798
# Tax Id: 904-79-4529
# IBAN: GB48HIIL39320241247330
# 3: Striped Contemporary Gabbeh 3,00
#
# Image: batch1-0767.jpg
# Invoice no: 12456262
# Tax Id: 924-94-5998
# IBAN: GB44WCRF64229286775104
#
# Image: batch1-0768.jpg
# Invoice no: 20297202
# Tax Id: 924-81-2403
# IBAN: GB48WHYT08186585509931
#
# Image: batch1-0769.jpg
# Invoice no: 70370075
# Tax Id: 945-85-4697
# IBAN: GB78SHRV44480784377121
#
# Image: batch1-0770.jpg
# Invoice no: 40703934
# Tax Id: 995-90-7291
# IBAN: GB76QYI056599829861096
#
# Image: batch1-0771.jpg
# Invoice no: 12877828
# Date of issue: 01/28/2017
# Seller: Client:
# Tax Id: 975-72-2584 Tax Id: 985-96-1315
# IBAN: GB82VYVG17099999462642
#
# Image: batch1-0772.jpg
# Invoice no: 20850516
# Date of issue: 07/10/2017
# Tax Id: 908-70-1405
# IBAN: GB48NZE029152051083956
#
# Image: batch1-0773.jpg
# Invoice no: 24467788
# Tax Id: 954-83-2992
# IBAN: GB49LQQL11710394710747
#
# Image: batch1-0774.jpg
# Invoice no: 13194726
# Tax Id: 995-88-9495
# IBAN: GB31LZXS20242755934691
#
# Image: batch1-0775.jpg
# Invoice no: 75703845
# Tax Id: 983-87-6459
# IBAN: GB25EDMB29208774348993
# 5: Rectangle Faux Fur Sheepskin 4,00
#
# Image: batch1-0776.jpg
# Invoice no: 33137636
# Tax Id: 993-86-5833
# IBAN: GBO5ZUCN48071007458396
# ils The Fountainhead: 50th 4,00
# 5: Evolutionary Analysis 5,00
#
# Image: batch1-0777.jpg
# Invoice no: 65937088
# Tax Id: 980-94-9375
# IBAN: GB63KRJL69460294656260
# US: 2'5
#
# Image: batch1-0778.jpg
# Invoice no: 93411242
# Tax Id: 974-85-7776
# IBAN: GB42RRTT66211676813047
#
# Image: batch1-0779.jpg
# Invoice no: 78985014
# Date of issue: 10/21/2020
# Seller: Client:
# Tax Id: 903-84-2561
# IBAN: GB95QWSR26857909060365
#
# Image: batch1-0780.jpg
# Invoice no: 53575326
# Date of issue: 11/18/2018
# Seller: Client:
# Tax Id: 988-98-5378 Tax Id: 902-88-3745
# IBAN: GB90SDJS70653737426517
#
# Image: batch1-0781.jpg
# Invoice no: 25342867
# Tax Id: 943-78-4216
# IBAN: GB48GPKP09511878652700
# 5: Brand new Cuisinart CWO-25 1,00
#
# Image: batch1-0782.jpg
# Invoice no: 96856159
# Tax Id: 961-83-1800
# IBAN: GB71ASRS13473133281482
#
# Image: batch1-0783.jpg
# Invoice no: 26248685
# Date of issue: 05/26/2018
# Seller: Client:
# Tax Id: 966-72-6
# IBAN: GB97DXYE25395425116910
# 2: Leopard Print Large Dress With 4,00 each
#
# Image: batch1-0784.jpg
# Invoice no: 41887406
# Tax Id: 917-77-9225
# IBAN: GB25ZKNR97624698669256
# 2: Dell Desktop Computers [J 1,00
# 3: AMD Dual Core 3.9Ghz 4GB 5,00
#
# Image: batch1-0785.jpg
# Invoice no: 24344887
# Tax Id: 951-75-2882
# IBAN: GB54XIPK87973282182425
# ils Endurance: Shackleton's 4,00
# 4. A History of Christianity Vol. 1: 5,00
#
# Image: batch1-0786.jpg
# Invoice no: 24902792
# Tax Id: 985-77-9408
# IBAN: GB39KVWC74758597496697
# 3: Philadelphia Eagles Anti-Skid 5,00
# S: Watercolor Butterfly Carpets 4,00
#
# Image: batch1-0787.jpg
# Invoice no: 37292788
# Tax Id: 973-73-9497
# IBAN: GB60YHSD00503639265086
# 3: Carton Tiger Print Area Rug
#
# Image: batch1-0788.jpg
# Invoice no: 68357221
# Tax Id: 907-78-5377
# IBAN: GB930EJFO7529100824109
#
# Image: batch1-0789.jpg
# Invoice no: 84422507
# Tax Id: 961-79-5330
# IBAN: GB9OLFJV64626371402095
#
# Image: batch1-0790.jpg
# Invoice no: 14964142
# Tax Id: 997-75-8847
# IBAN: GB0O5IBQM91202997209705
# and Its All Small Stuff: Simple
#
# Image: batch1-0791.jpg
# Invoice no: 39463508
# Date of issue: 09/17/2013
# Seller: Client:
# Tax Id: 957-83-5556
# IBAN: GB55GUPQ13123489885460
#
# Image: batch1-0792.jpg
# Invoice no: 12830936
# Tax Id: 914-78-1124
# IBAN: GB30QDVO20178698471358
# 3: HP ProDesk G1 Desktop
# 5: personal computer
#
# Image: batch1-0793.jpg
# Invoice no: 56323869
# Tax Id: 945-75-6433
# IBAN: GB28YQLQ88894983812058
#
# Image: batch1-0794.jpg
# Invoice no: 68043569
# Tax Id: 960-87-0985
# IBAN: GB94RSWA52694096609663
#
# Image: batch1-0795.jpg
# Invoice no: 88408888
# Tax Id: 941-94-1167
# IBAN: GB56RKWK49595633158002
#
# Image: batch1-0796.jpg
# Invoice no: 32656405
# Tax Id: 931-98-1810
# IBAN: GB32NFYI33796812641240
# 3: Newborn Infant Baby Girl Boy
#
# Image: batch1-0797.jpg
# Invoice no: 52557179
# Tax Id: 910-74-8692
# IBAN: GB92BFOY90525696154731
#
# Image: batch1-0798.jpg
# Invoice no: 80150256
# Date of issue: 07/24/2017
# Seller: Client:
# Tax Id: 907-73-8970 Tax Id: 970-76-7515
# IBAN: GB70TBBJ52427765625418
#
# Image: batch1-0799.jpg
# Invoice no: 59540671
# Date of issue: 09/23/2012
# Tax Id: 926-70-0253
# IBAN: GB97NUCF18280907270412
# 1. Beverley Nichols: A Life by 3,00 each
# 35,95: 107,85
#
# Image: batch1-0800.jpg
# Invoice no: 80930562
# Tax Id: 918-83-5577
# IBAN: GB64HCMB38220199023910
# 5: Nintendo Wii U Console 5,00
#
# Image: batch1-0801.jpg
# Invoice no: 85817513
# Tax Id: 988-94-6829
# IBAN: GB56GJQS22788684254685
# ils Book: The Lee-Enfield by lan 1,00
#
# Image: batch1-0802.jpg
# Invoice no: 55954287
# Tax Id: 947-83-7475
# IBAN: GB23EGBD42189646185853
#
# Image: batch1-0803.jpg
# Invoice no: 26675003
# Tax Id: 966-87-8299
# IBAN: GB92UKUV22836497179015
# 3: The Graphic Design Reference 2,00
# 5: American Zoos 4,00
#
# Image: batch1-0804.jpg
# Invoice no: 79616362
# Tax Id: 909-95-3097
# IBAN: GB53HQXX53220596594552
# 3: Dell OptiPlex 9020 SFF 3,00
#
# Image: batch1-0805.jpg
# Invoice no: 92651511
# Tax Id: 989-90-6230
# IBAN: GB20PPSV40476334461682
#
# Image: batch1-0806.jpg
# Invoice no: 92751876
# Date of issue: 02/14/2013
# Seller: Client:
# Tax Id: 920-78-8007 Tax Id: 935-77-6543
# IBAN: GB15FNPA88057402257291
#
# Image: batch1-0807.jpg
# Invoice no: 87970852
# Tax Id: 903-83-8188
# IBAN: GB80JAPJ33404818900485
# 2: Lolita Happy Retirement Wine
# 3: VINTAGE ANTIQUE BRASS
#
# Image: batch1-0808.jpg
# Invoice no: 53489259
# Tax Id: 968-84-5612
# IBAN: GBO7YXBE30378903392383
# 3: THE ORIGINAL NIB WINE-DOWN 5,00
# S: Wine Openers.Heavy Duty 5,00
#
# Image: batch1-0809.jpg
# Invoice no: 94885760
# Tax Id: 974-99-3914
# IBAN: GB36ENEJ21422561399911
#
# Image: batch1-0810.jpg
# Invoice no: 17695664
# Tax Id: 936-73-8697
# IBAN: GB47SDLI92738962954333
# 3: Buffy the Vampire Slayer
#
# Image: batch1-0811.jpg
# Invoice no: 90446683
# Tax Id: 911-96-7248
# IBAN: GB19LAZW37358375097586
#
# Image: batch1-0812.jpg
# Invoice no: 52013651
# Tax Id: 921-98-4356
# IBAN: GB55PODK19198401150277
# 3: 25"x25" White Marble Top
# 5: Clear Acrylic Table, Breakfast
#
# Image: batch1-0813.jpg
# Invoice no: 26213346
# Date of issue: 10/05/2020
# Tax Id: 958-70-4603
# IBAN: GBO9CPQL79185028042898
# 3: Sony PlayStation 3 150GB 2,00 each
#
# Image: batch1-0814.jpg
# Invoice no: 29470022
# Tax Id: 965-70-2868
# IBAN: GB50JVRS02423611510258
#
# Image: batch1-0815.jpg
# Invoice no: 21722776
# Tax Id: 946-72-1313
# IBAN: GB18KUOF34054232333666
# 3: Fast i7 RGB Gaming Desktop PC
#
# Image: batch1-0816.jpg
# Invoice no: 28610769
# Date of issue: 06/19/2017
# Seller: Client:
# Tax Id: 963-94-0
# IBAN: GB11PTYT82637652514320
#
# Image: batch1-0817.jpg
# Invoice no: 79637771
# Tax Id: 960-90-2892
# IBAN: GB39NPVM35523882007872
# 3: Nordic Style Round Carpet Blue 4,00
#
# Image: batch1-0818.jpg
# Invoice no: 33691533
# Tax Id: 963-95-6326
# IBAN: GB79HWNL47420369669125
#
# Image: batch1-0819.jpg
# Invoice no: 52574707
# Tax Id: 910-77-3086
# IBAN: GB56JDHT14291079780637
#
# Image: batch1-0820.jpg
# Invoice no: 53339803
# Tax Id: 991-83-1943
# IBAN: GB94JWPV41308802932072
#
# Image: batch1-0821.jpg
# Invoice no: 23128566
# Tax Id: 925-80-6189
# IBAN: GB97DYPW34270098642863
# 2: Experience by Martin Amis 2,00
# 3: Language and Woman's Place 5,00
# North America: A Guide for
#
# Image: batch1-0822.jpg
# Invoice no: 13110923
# Date of issue: 12/21/2013
# Seller: Client:
# Tax Id: 907-76-8703
# IBAN: GB32AMZY31340900461145
#
# Image: batch1-0823.jpg
# Invoice no: 66045137
# Tax Id: 981-80-7113
# IBAN: GB41ZNEN10731547653308
# S: Unicorn Wine Bottle Display 5,00
#
# Image: batch1-0824.jpg
# Invoice no: 10963794
# Tax Id: 991-81-4918
# IBAN: GB32YFGN69663327761865
#
# Image: batch1-0825.jpg
# Invoice no: 72005605
# Tax Id: 909-98-4977
# IBAN: GB80)XBS98611986795347
# 3: 48" Beautiful Marble Dining Top
#
# Image: batch1-0826.jpg
# Invoice no: 86561552
# Date of issue: 03/09/2018
# Seller: Client:
# Tax Id: 952-79-5757
# IBAN: GB63VZHN76142928623566
#
# Image: batch1-0827.jpg
# Invoice no: 40725651
# Tax Id: 994-84-7469
# IBAN: GB40CAEA99729747090871
# 3: Yilong 2'x3' Traditional
#
# Image: batch1-0828.jpg
# Invoice no: 66537515
# Date of issue: 11/25/2018
# Seller: Client:
# Tax Id: 991-75-0436
# IBAN: GB36GFUF93342035354916
#
# Image: batch1-0829.jpg
# Invoice no: 28661957
# Tax Id: 962-85-4820
# IBAN: GBO6ODPK69551914162205
#
# Image: batch1-0830.jpg
# Invoice no: 17548173
# Tax Id: 904-86-6711
# IBAN: GB93UZRN61415520236090
# 3: New without boxes heavy duty
# 5D: Pier 1 Multi-color Cordial
#
# Image: batch1-0831.jpg
# Invoice no: 48239873
# Date of issue: 09/19/2016
# Tax Id: 985-88-6753
# IBAN: GB88SIVN15952505043461
#
# Image: batch1-0832.jpg
# Invoice no: 16581981
# Date of issue: 07/26/2016
# Seller: Client:
# Tax Id: 921-84-3388
# IBAN: GB67JWCS29906137954735
#
# Image: batch1-0833.jpg
# Invoice no: 22323078
# Date of issue: 05/11/2016
# Seller: Client:
# Tax Id: 941-90-7
# IBAN: GB27FEMM49504830524204
#
# Image: batch1-0834.jpg
# Invoice no: 27188556
# Tax Id: 936-98-2132
# IBAN: GB14GIRC85339920238877
#
# Image: batch1-0835.jpg
# Invoice no: 71963176
# Tax Id: 960-90-7638
# IBAN: GB71GEES63663942802962
# 5: Nutcracker Christmas Tales New 1,00
#
# Image: batch1-0836.jpg
# Invoice no: 72026666
# Tax Id: 903-97-0777
# IBAN: GB18JLXJ48452714880570
# 3: 48 Inches Marble Dinning Table
# S: Hardwood Insect Pinning Block
#
# Image: batch1-0837.jpg
# Invoice no: 22537855
# Tax Id: 961-85-8571
# IBAN: GB98FOPY29496953726939
# 5: Carton Tiger Print Area Rug 2,00
#
# Image: batch1-0838.jpg
# Invoice no: 41997527
# Tax Id: 936-77-3988
# IBAN: GB95XJQZ22238493620481
#
# Image: batch1-0839.jpg
# Invoice no: 99053443
# Tax Id: 911-94-2974
# IBAN: GB78QSZR27259773261475
# By Game of Thrones: The Poster 5,00
#
# Image: batch1-0840.jpg
# Invoice no: 87433420
# Date of issue: 04/26/2015
# Seller: Client:
# Tax Id: 904-91-3589 Tax Id: 992-81-4882
# IBAN: GB61ISRR62084785140637
# ils Forgotten Fantasy: Sunday..., 5,00 each 107,09 535,45 10% 589,00
# 2. Against All Odds: The Untold 4,00 each 4,41 17,64 10% 19,40
# oo Astronomy: A Visual Guide 4,00 each 5,02 20,08 10% 22,09
#
# Image: batch1-0841.jpg
# Invoice no: 64218159
# Tax Id: 980-74-4827
# IBAN: GB84IGSP08278890356055
# 2: The Picture of Dorian Gray by 1,00
#
# Image: batch1-0842.jpg
# Invoice no: 78190005
# Tax Id: 903-74-1935
# IBAN: GB79ZQIE46612682783689
# S: Dell Optiplex Windows 10 Pro 5,00
#
# Image: batch1-0843.jpg
# Invoice no: 29333870
# Tax Id: 981-84-1838
# IBAN: GB82DJFU82273146210425
#
# Image: batch1-0844.jpg
# Invoice no: 48757480
# Tax Id: 966-97-0354
# IBAN: GB24RZOY69539046154544
#
# Image: batch1-0845.jpg
# Invoice no: 19832522
# Date of issue: 09/27/2016
# Tax Id: 904-78-5257
# IBAN: GB76IRQX71544776249289
#
# Image: batch1-0846.jpg
# Invoice no: 70646996
# Tax Id: 967-83-0312
# IBAN: GB85DATC50901204220301
# 3: Coolibar Sun Protection Tunic
#
# Image: batch1-0847.jpg
# Invoice no: 77097467
# Date of issue: 05/03/2019
# Seller: Client:
# Tax Id: 916-73-6436 Tax Id: 961-70-5365
# IBAN: GB610UMV71214128210897
#
# Image: batch1-0848.jpg
# Invoice no: 78984257
# Tax Id: 938-81-5983
# IBAN: GB40ZQFP78280907734742
#
# Image: batch1-0849.jpg
# Invoice no: 84408619
# Tax Id: 931-83-1908
# IBAN: GB77CUHU67202355617607
# 3: Sentry Gaming Computer | 2,00
#
# Image: batch1-0850.jpg
# Invoice no: 93769983
# Tax Id: 900-85-9685
# IBAN: GB55CCPV37554454518615
# 3: 18" Marble Coffee Table Top
#
# Image: batch1-0851.jpg
# Invoice no: 52721574
# Tax Id: 990-92-2412
# IBAN: GB74ZCME87766646211207
#
# Image: batch1-0852.jpg
# Invoice no: 65428348
# Tax Id: 914-77-7181
# IBAN: GB34FPYD88234862125581
# 2: Liza Byrd Dress Sz L- Coral
#
# Image: batch1-0853.jpg
# Invoice no: 20527132
# Tax Id: 935-78-9111
# IBAN: GB81QVVI10829940279192
#
# Image: batch1-0854.jpg
# Invoice no: 57114004
# Tax Id: 956-83-1183
# IBAN: GB73KBWT75185699279775
# ils Seashells of North America: A 3,00
#
# Image: batch1-0855.jpg
# Invoice no: 35494837
# Date of issue: 04/02/2019
# Seller: Client:
# Tax Id: 931-94-3068 Tax Id: 992-85-8131
# IBAN: GB56QACY43932160774116
# and Its All Small Stuff: Simple
# 2. House of Earth: A Novel by 3,00 each 4,49 13,47 10% 14,82
# Se Rod: The Autobiography by Rod 4,00 each 4,49 17,96 10% 19,76
#
# Image: batch1-0856.jpg
# Invoice no: 76588527
# Tax Id: 982-95-3864
# IBAN: GB27XROJ22702939702011
# 2: Sony PlayStation 3 150GB 4,00
#
# Image: batch1-0857.jpg
# Invoice no: 85736423
# Tax Id: 982-73-3467
# IBAN: GB67VUSS69448922023728
# 3: Sega V Saturn Victor Console
# 5: Sega Genesis System Console
#
# Image: batch1-0858.jpg
# Invoice no: 59506452
# Tax Id: 928-99-1510
# IBAN: GBO5DOTF47260279973284
# 3: 6'x3' Oval Marble White Top
# S: Marble Top Side Table Tiger Eye 2,00
#
# Image: batch1-0859.jpg
# Invoice no: 50368630
# Tax Id: 980-96-4855
# IBAN: GB68RGWY69259946979217
# 3: 36" Round Marble Dining Table
#
# Image: batch1-0860.jpg
# Invoice no: 16575103
# Tax Id: 946-95-3110
# IBAN: GB89DLGE94252454144602
#
# Image: batch1-0861.jpg
# Invoice no: 84404809
# Tax Id: 922-72-7545
# IBAN: GB26SVMT24500832022977
# Country: Seeing America
# 3: Walleye wisdom
#
# Image: batch1-0862.jpg
# Invoice no: 14941401
# Tax Id: 950-70-7916
# IBAN: GB20XIFA80751355330570
#
# Image: batch1-0863.jpg
# Invoice no: 40345107
# Tax Id: 933-91-1306
# IBAN: GB87WTNX68187420702306
#
# Image: batch1-0864.jpg
# Invoice no: 77725914
# Tax Id: 901-99-8186
# IBAN: GB95WMPC16489175429181
#
# Image: batch1-0865.jpg
# Invoice no: 56014042
# Date of issue: 10/01/2014
# Seller: Client:
# Tax Id: 953-87-6813 Tax Id: 965-90-8517
# IBAN: GBO8KXQT19711661357354
# 2: Sketchers Energy Lights Boys 4,00 each 12,00 48,00 10% 52,80
#
# Image: batch1-0866.jpg
# ...
#
# Image: batch1-0377.jpg
# Invoice no: 35259356
# Date of issue: 01/20/2018
# Seller: Client:
# Tax Id: 928-96-4400 Tax Id: 939-96-7563
# IBAN: GB8ONLWF79872037169129
# 5: LuLaRoe Nicole Dress Size 5,00 each 1,99 9,95 10% 10,94
#
# Image: batch1-0378.jpg
# Invoice no: 74263194
# Date of issue: 03/28/2020
# Seller: Client:
# Tax Id: 954-81-3
# IBAN: GB97UADP91298552977140
#
# Image: batch1-0379.jpg
# Invoice no: 59051048
# Tax Id: 948-94-1459
# IBAN: GB20VEMN29130859876706
#
# Image: batch1-0380.jpg
# Invoice no: 13310164
# Date of issue: 01/16/2020
# Seller: Client:
# Tax Id: 924-83-8802 Tax Id: 999-80-5625
# IBAN: GB13LKIT26418644296553
#
# Image: batch1-0381.jpg
# Invoice no: 76272465
# Tax Id: 930-74-1829
# IBAN: GB81HYMN60082229755269
#
# Image: batch1-0382.jpg
# Invoice no: 38680884
# Date of issue: 12/22/2015
# Seller: Client:
# Tax Id: 947-71-5317 Tax Id: 987-84-5701
# IBAN: GB68ZQPE16473995044513
# Cars McQueen 1: 55 Diecast Lot
#
# Image: batch1-0383.jpg
# Invoice no: 23908850
# Tax Id: 996-91-5459
# IBAN: GB56AMOT20381791595194
# 5: Jordan 10 Retro Fusion Red Size 3,00
#
# Image: batch1-0384.jpg
# Invoice no: 20295549
# Tax Id: 999-79-0463
# IBAN: GB28FVFP72557385738524
# 3: Fast Dell Optiplex Desktop PC 2,00
#
# Image: batch1-0385.jpg
# Invoice no: 45141161
# Tax Id: 929-73-2229
# IBAN: GBO4QTVN37160669532304
#
# Image: batch1-0386.jpg
# Invoice no: 42910151
# Tax Id: 960-86-6276
# IBAN: GB35THGM38607815672207
#
# Image: batch1-0387.jpg
# Invoice no: 11640046
# Tax Id: 921-95-1514
# IBAN: GB87GZYG77483939908425
# 3: Fast i7 RGB Gaming Desktop PC 3,00
# S: Desktop Computer Gaming PC 4,00
#
# Image: batch1-0388.jpg
# Invoice no: 57600191
# Tax Id: 932-80-7476
# IBAN: GB30PKEZ32220639658830
# 2: sega cdx console with original
# 3: Nintendo Gameboy Pocket
#
# Image: batch1-0389.jpg
# Invoice no: 69652053
# Date of issue: 11/19/2014
# Seller: Client:
# Tax Id: 935-70-5137 Tax Id: 916-96-7231
# IBAN: GB56AUZA53021548063132
#
# Image: batch1-0390.jpg
# Invoice no: 59119338
# Tax Id: 992-94-4657
# IBAN: GB83XPFJ48452898851860
# 3: boys bogs waterproof boots 3,00
#
# Image: batch1-0391.jpg
# Invoice no: 84423800
# Tax Id: 945-98-2210
# IBAN: GBO6YQKI12270767261206
#
# Image: batch1-0392.jpg
# Invoice no: 97830664
# Tax Id: 928-94-5073
# IBAN: GB68LIAD19258633278631
# 3: Sheepskin Shaggy Faux Fur 5,00
# 5: Leopard Printed Rug Skin Mat 2,00
#
# Image: batch1-0393.jpg
# Invoice no: 69614664
# Tax Id: 990-900-7832
# IBAN: GB83QGEB05834764688813
#
# Image: batch1-0394.jpg
# Invoice no: 76880869
# Tax Id: 956-82-0802
# IBAN: GB65EJKF06885403664048
# 5: Nintendo 64 N64 Console Black 5,00
#
# Image: batch1-0395.jpg
# Invoice no: 81858677
# Tax Id: 905-96-5697
# IBAN: GBO6WJVA31682243580522
# S: Victorian European Country 5,00
#
# Image: batch1-0396.jpg
# Invoice no: 39489564
# Tax Id: 911-70-0995
# IBAN: GB46VKBJ69005019397807
# 3: Joma Youth Boys Gol 205 Piso 3,00
#
# Image: batch1-0397.jpg
# Invoice no: 35963820
# Tax Id: 917-87-3727
# IBAN: GBO4XRCE48098994768909
# Bh The Great One: The Complete
# 7. Against All Odds: The Untold
#
# Image: batch1-0398.jpg
# Invoice no: 19091235
# Tax Id: 953-92-1255
# IBAN: GB28ORJP86525054351152
# 2: Dell Desktop Computers [J 4,00
# 3: custom gaming computer 3,00
#
# Image: batch1-0399.jpg
# Invoice no: 66053252
# Tax Id: 922-84-8254
# IBAN: GB12TLAI20866357513573
#
# Image: batch1-0400.jpg
# Invoice no: 51508002
# Tax Id: 909-73-2209
# IBAN: GB12GWQL51284465994769
#
# Image: batch1-0401.jpg
# Invoice no: 63131640
# Tax Id: 937-75-0747
# IBAN: GB97EEGV74815787185844
# 3: Vintage Set of 3 Cobalt Blue
#
# Image: batch1-0402.jpg
# Invoice no: 58805260
# Date of issue: 03/07/2019
# Seller: Client:
# Tax Id: 932-94-1632 Tax Id: 967-90-8360
# IBAN: GB85ETVV11072777524235
#
# Image: batch1-0403.jpg
# Invoice no: 33696326
# Tax Id: 972-76-5490
# IBAN: GB12ZMFD99861668554659
# S: 2 Industrial Live edge Legs 16" 1,00
#
# Image: batch1-0404.jpg
# Invoice no: 99116837
# Tax Id: 925-92-9139
# IBAN: GB16PVWU12036876749289
# 3: Dell OptiPlex 390 SFF Computer 4,00
# 5: Dell Optiplex 790 Computer i7 2,00
#
# Image: batch1-0405.jpg
# Invoice no: 52230192
# Tax Id: 979-94-7617
# IBAN: GB57FLQY83891707664947
#
# Image: batch1-0406.jpg
# Invoice no: 59334099
# Tax Id: 948-83-5320
# IBAN: GB70MKIO11579991870319
#
# Image: batch1-0407.jpg
# Invoice no: 46915335
# Tax Id: 978-84-3101
# IBAN: GB14U0FC23209846088600
#
# Image: batch1-0408.jpg
# Invoice no: 28618390
# Date of issue: 08/09/2014
# Seller: Client:
# Tax Id: 948-84-5768 Tax Id: 938-95-2146
# IBAN: GBO5TNVQ52119718006120
# Survival: Skills, Tactics, and
#
# Image: batch1-0409.jpg
# Invoice no: 77931288
# Tax Id: 963-90-3628
# IBAN: GB91XBBY85035471802843
# 3: 38/40/42/44mm Silicone Sport
#
# Image: batch1-0410.jpg
# Invoice no: 83337807
# Tax Id: 906-75-0428
# IBAN: GBO6HADJ15318738890358
#
# Image: batch1-0411.jpg
# Invoice no: 48844293
# Tax Id: 992-74-2444
# IBAN: GB47NBVF94295045071181
# 5: Sony PlayStation 3 PS3 5,00
#
# Image: batch1-0412.jpg
# Invoice no: 60866416
# Date of issue: 02/17/2021
# Tax Id: 942-90-5696
# IBAN: GB94WSHN30369012384367
#
# Image: batch1-0413.jpg
# Invoice no: 77513425
# Tax Id: 916-87-1502
# IBAN: GB69CYRJ12393499976192
#
# Image: batch1-0414.jpg
# Invoice no: 16543713
# Tax Id: 943-74-5746
# IBAN: GB91LZ1IZ44005662333118
#
# Image: batch1-0415.jpg
# Invoice no: 78796145
# Tax Id: 939-79-0082
# IBAN: GB20ISZD02077927293024
#
# Image: batch1-0416.jpg
# Invoice no: 62005229
# Tax Id: 983-97-4249
# IBAN: GB27GKAK37654921959034
#
# Image: batch1-0417.jpg
# Invoice no: 88628178
# Date of issue: 07/18/2012
# Seller: Client:
# Tax Id: 975-71-4059 Tax Id: 973-86-8876
# IBAN: GB64UBLI38769744685141
#
# Image: batch1-0418.jpg
# Invoice no: 98964062
# Tax Id: 923-92-8409
# IBAN: GB96GQJZ03988921998435
# 3: Under Armour UA Curry 3 4,00
#
# Image: batch1-0419.jpg
# Invoice no: 93300746
# Tax Id: 953-84-1487
# IBAN: GB28KLRK56290237567077
# S: Round Rug Carpet For Living 2,00
#
# Image: batch1-0420.jpg
# Invoice no: 35014787
# Date of issue: 01/17/2012
# Seller: Client:
# Tax Id: 976-73-4628 Tax Id: 934-81-8590
# IBAN: GB40HHVJ53610108173643
#
# Image: batch1-0421.jpg
# Invoice no: 52335893
# Tax Id: 986-75-5185
# IBAN: GB67VRGE08714906088983
# 3: Cartoon Rabbit Printed Round
#
# Image: batch1-0422.jpg
# Invoice no: 54557938
# Tax Id: 920-88-3036
# IBAN: GB610HLG05005223844074
# 3: Dell Desktop Computer Intel
#
# Image: batch1-0423.jpg
# Invoice no: 32530432
# Tax Id: 915-91-7687
# IBAN: GB37HJCH03964179060142
# 3: Super Nintendo SNES System 2,00
# 5: New Sony Playstation 4 Slim 5,00
#
# Image: batch1-0424.jpg
# Invoice no: 18531177
# Tax Id: 910-92-9312
# IBAN: GB66GZAK5 7253283036257
# 3: Skechers Blue Athletic Shoes
#
# Image: batch1-0425.jpg
# Invoice no: 30083114
# Tax Id: 926-74-1022
# IBAN: GB29LSQD94062786526203
# Cars McQueen 1: 55 Diecast Lot
# 5: Reebok Boys Furylite Graphic 4,00
#
# Image: batch1-0426.jpg
# Invoice no: 31386585
# Tax Id: 917-98-0997
# IBAN: GB84ZVVN32534578508768
#
# Image: batch1-0427.jpg
# Invoice no: 17811597
# Tax Id: 926-83-4037
# IBAN: GB75RJCO26246800396107
#
# Image: batch1-0428.jpg
# Invoice no: 94215570
# Date of issue: 11/05/2017
# Seller: Client:
# Tax Id: 951-77-3930 Tax Id: 970-87-1723
# IBAN: GB74VIGS00454458523860
#
# Image: batch1-0429.jpg
# Invoice no: 24060857
# Date of issue: 07/09/2015
# Seller: Client:
# Tax Id: 949-76-4848 Tax Id: 934-76-3266
# IBAN: GB34IDVP93151630757847
#
# Image: batch1-0430.jpg
# Invoice no: 37763406
# Date of issue: 08/17/2015
# Seller: Client:
# Tax Id: 944-84-6954 Tax Id: 999-84-6006
# IBAN: GB29UQGL80485248896431
#
# Image: batch1-0431.jpg
# Invoice no: 69607855
# Tax Id: 901-97-4500
# IBAN: GB81JOBH59020356401789
#
# Image: batch1-0432.jpg
# Invoice no: 74337375
# Tax Id: 946-90-5500
# IBAN: GBO9ARDN04052597984359
# 1. Nightmares in the Sky: 5,00
# By The Great One: The Complete 2,00
# 5: Q&A a Day: 5-Year Journal 1,00
#
# Image: batch1-0433.jpg
# Invoice no: 25604558
# Tax Id: 968-91-4447
# IBAN: GB80TMJI44741478905305
# 3: Boden Size 8 US Green & Navy
#
# Image: batch1-0434.jpg
# Invoice no: 86504530
# Tax Id: 928-95-8430
# IBAN: GB51XYWRO02122483867316
# 3: 4Pcs Adjustable Stainless Steel
#
# Image: batch1-0435.jpg
# Invoice no: 61819195
# Tax Id: 902-99-3657
# IBAN: GB33ARJE04963501593840
# 1. Sing My Way Home: Voices of
# 2: Goodnight from London: A
# 3: The WORLD of ART Time Life
#
# Image: batch1-0436.jpg
# Invoice no: 56427222
# Date of issue: 11/26/2018
# Seller: Client:
# Tax Id: 922-88-8140 Tax Id: 908-98-1151
# IBAN: GB31DWKI61814192089300
#
# Image: batch1-0437.jpg
# Invoice no: 67851927
# Tax Id: 999-82-7228
# IBAN: GB21XGYT64179960030012
# 3: Round Rug Carpets for Living
#
# Image: batch1-0438.jpg
# Invoice no: 32483210
# Date of issue: 11/29/2011
# Seller: Client:
# Tax Id: 967-78-7107 Tax Id: 931-82-1890
# IBAN: GB94JGHK11862734625747
#
# Image: batch1-0439.jpg
# Invoice no: 42498094
# Tax Id: 937-72-6545
# IBAN: GBO8RWVA59280101041053
# 3: Nike 7y Black
#
# Image: batch1-0440.jpg
# Invoice no: 64603610
# Tax Id: 947-77-8708
# IBAN: GB8OWHFE54430411137024
#
# Image: batch1-0441.jpg
# Invoice no: 81149702
# Tax Id: 942-70-8561
# IBAN: GB91ZZUL44895073330541
# 5: 5 YOUTH Boys Big Kids Nike 3,00
#
# Image: batch1-0442.jpg
# Invoice no: 39193381
# Date of issue: 06/19/2015
# Seller: Client:
# Tax Id: 903-92-0926
# IBAN: GB98STHZ78196586386978
#
# Image: batch1-0443.jpg
# Invoice no: 21024792
# Date of issue: 02/23/2013
# Seller: Client:
# Tax Id: 989-95-0263 Tax Id: 935-75-5706
# IBAN: GB30XWFZ08377802938801
#
# Image: batch1-0444.jpg
# Invoice no: 44048791
# Tax Id: 931-94-0010
# IBAN: GB76TFWV61243574137339
# 3: Nintendo Switch Lite Yellow
#
# Image: batch1-0445.jpg
# Invoice no: 67123367
# Tax Id: 936-77-0304
# IBAN: GB57PLEFO2128879147146
#
# Image: batch1-0446.jpg
# Invoice no: 13865937
# Tax Id: 980-78-0305
# IBAN: GB47CQIL18836858037017
#
# Image: batch1-0447.jpg
# Invoice no: 81432357
# Tax Id: 979-72-2010
# IBAN: GB20WXDS17725959227934
#
# Image: batch1-0448.jpg
# Invoice no: 40217081
# Tax Id: 963-86-6472
# IBAN: GBO3TGNC26577214111531
# S: Burent Orange Long Dress With 4,00
#
# Image: batch1-0449.jpg
# Invoice no: 95296819
# Tax Id: 942-95-3041
# IBAN: GB36)JTV38848248598936
# 3: Geometry Hippie Non-slip Area
# S: Imitation Wool Carpet Rugs 2,00
#
# Image: batch1-0450.jpg
# Invoice no: 14139811
# Tax Id: 950-99-8783
# IBAN: GB1700TB76377431255815
#
# Image: batch1-0451.jpg
# Invoice no: 72256079
# Tax Id: 940-92-2484
# IBAN: GB10FQAZ25907258049975
#
# Image: batch1-0452.jpg
# Invoice no: 77715322
# Date of issue: 08/23/2013
# Seller: Client:
# Tax Id: 917-96-4735
# IBAN: GB98HWVS80522515394628
#
# Image: batch1-0453.jpg
# Invoice no: 20802870
# Tax Id: 980-78-0734
# IBAN: GB52UKGE99002499068410
# 3: Galaxy Butterfly Area Rugs 1,00
#
# Image: batch1-0454.jpg
# Invoice no: 73019594
# Seller: Client:
# Tax Id: 983-74-6801
# IBAN: GB22WYEY75076082414028
#
# Image: batch1-0455.jpg
# Invoice no: 74494433
# Date of issue: 09/12/2017
# Seller: Client:
# Tax Id: 961-72-2355 Tax Id: 970-82-4039
# IBAN: GB10TPUA77994091934658
#
# Image: batch1-0456.jpg
# Invoice no: 36985569
# Tax Id: 909-72-1634
# IBAN: GB26PKDS72578826688808
#
# Image: batch1-0457.jpg
# Invoice no: 18670724
# Tax Id: 946-70-7914
# IBAN: GBO6LENG97987218683219
# 5: Nintendo Gameboy Original 1,00
#
# Image: batch1-0458.jpg
# Invoice no: 31311902
# Tax Id: 998-95-7322
# IBAN: GB85GKTK69985416223788
#
# Image: batch1-0459.jpg
# Invoice no: 29998351
# Date of issue: 12/21/2012
# Seller: Client:
# Tax Id: 985-97-0354 Tax Id: 960-92-5776
# IBAN: GBO3WLPW04938114706004
#
# Image: batch1-0460.jpg
# Invoice no: 45743873
# Tax Id: 934-76-2225
# IBAN: GB63UUKW88923169438377
#
# Image: batch1-0461.jpg
# Invoice no: 95216794
# Date of issue: 08/10/2017
# Seller: Client:
# Tax Id: 946-79-3835 Tax Id: 939-82-6159
# IBAN: GB94Z0CS29335948893013
# By A History of Christianity Vol. 1: 1,00 each 4,09 4,09 10% 4,50
#
# Image: batch1-0462.jpg
# Invoice no: 85432283
# Date of issue: 12/13/2014
# Seller: Client:
# Tax Id: 950-92-7100 Tax Id: 993-99-7022
# IBAN: GB25XTZN61207419513391
# 2. Endurance: Shackleton's 3,00 each 4,09 12,27 10% 13,50
# oo Christmas Cupcake Murder: A 1,00 each 2,99 2,99 10% 3,29
#
# Image: batch1-0463.jpg
# Invoice no: 40044178
# Date of issue: 04/05/2019
# Seller: Client:
# Tax Id: 993-73-5866 Tax Id: 908-91-0888
# IBAN: GB74IFZP51395809591442
#
# Image: batch1-0464.jpg
# Invoice no: 45904441
# Tax Id: 996-79-5687
# IBAN: GB26PYSB20884519683362
# 3: RICOSTA BGE boys everyday 1,00
#
# Image: batch1-0465.jpg
# Invoice no: 85765662
# Tax Id: 971-83-2985
# IBAN: GB93BKA083939015460445
#
# Image: batch1-0466.jpg
# Invoice no: 72492750
# Date of issue: 02/03/2013
# Seller: Client:
# Tax Id: 964-86-3709 Tax Id: 983-70-9730
# IBAN: GB95DUBT22656942604217
#
# Image: batch1-0467.jpg
# Invoice no: 85303612
# Tax Id: 973-80-7172
# IBAN: GB13QCQB12342217088974
#
# Image: batch1-0468.jpg
# Invoice no: 45562249
# Tax Id: 977-98-0264
# IBAN: GB22BXDG54057978757726
# 2. Seashells of North America: A 5,00
#
# Image: batch1-0469.jpg
# Invoice no: 29870205
# Tax Id: 997-85-8631
# IBAN: GB27CNMR41415802215005
# 3: RICOSTA BGE boys everyday 5,00
# 5: 5 YOUTH Boys Big Kids Nike 1,00
#
# Image: batch1-0470.jpg
# Invoice no: 39772830
# Tax Id: 969-90-5658
# IBAN: GB65JSUB40056859416979
#
# Image: batch1-0471.jpg
# Invoice no: 99173131
# Tax Id: 967-95-3242
# IBAN: GB12JVSB37709032390713
#
# Image: batch1-0472.jpg
# Invoice no: 76322049
# Date of issue: 05/21/2021
# Seller: Client:
# Tax Id: 932-98-4214 Tax Id: 950-91-2299
# IBAN: GB73AHPS77365053663190
# ils Straw Dogs: Thoughts on 4,00 each 13,99 55,96 10% 61,56
#
# Image: batch1-0473.jpg
# Invoice no: 63246591
# Tax Id: 959-94-8870
# IBAN: GB87FIAL58030346735047
#
# Image: batch1-0474.jpg
# Invoice no: 30208398
# Tax Id: 936-91-7429
# IBAN: GB66EKEI36897474997889
#
# Image: batch1-0475.jpg
# Invoice no: 97776691
# Tax Id: 946-98-5103
# IBAN: GB52RVGM63349413875126
#
# Image: batch1-0476.jpg
# Invoice no: 29515593
# Tax Id: 973-82-3932
# IBAN: GB54QNHU33327112150795
# 3: Waterford Elegance Chardonnay 4,00
#
# Image: batch1-0477.jpg
# Invoice no: 65981953
# Tax Id: 978-99-3941
# IBAN: GB9OSKPB52785824368203
#
# Image: batch1-0478.jpg
# Invoice no: 50357965
# Tax Id: 964-75-1002
# IBAN: GB49KRRH09651427977294
# oo The Four Agreements: A 1,00
# a Astronomy: A Visual Guide 2,00
#
# Image: batch1-0479.jpg
# Invoice no: 69721323
# Tax Id: 949-88-4885
# IBAN: GB22XZGA27411153163644
#
# Image: batch1-0480.jpg
# Invoice no: 99214533
# Date of issue: 05/25/2017
# Tax Id: 959-83-1471
# IBAN: GBO50DWQ99672274091269
#
# Image: batch1-0481.jpg
# Invoice no: 40631256
# Tax Id: 944-73-9850
# IBAN: GB81YFBP61884065352583
#
# Image: batch1-0482.jpg
# Invoice no: 60595703
# Date of issue: 08/13/2019
# Seller: Client:
# Tax Id: 975-72-9657 Tax Id: 998-87-5040
# IBAN: GB36CCER60185835874040
# 5: Nintendo Wii Console With 2,00 each 29,99 59,98 10% 65,98
#
# Image: batch1-0483.jpg
# Invoice no: 37575831
# Tax Id: 901-80-6675
# IBAN: GB24QKLA17088933212020
# Country: Seeing America
# Bh A History of Christianity Vol. 1: 5,00
# S: How to Repair Home Laundry 3,00
#
# Image: batch1-0484.jpg
# Invoice no: 69638281
# Tax Id: 968-92-6539
# IBAN: GB88ABQW68230357564176
#
# Image: batch1-0485.jpg
# Invoice no: 71388340
# Tax Id: 928-83-9846
# IBAN: GB9OESX186669085473554
#
# Image: batch1-0486.jpg
# Invoice no: 28807915
# Tax Id: 904-95-4664
# IBAN: GBO6ANRX72033981145652
#
# Image: batch1-0487.jpg
# Invoice no: 63279909
# Date of issue: 01/27/2012
# Tax Id: 988-98-5445
# IBAN: GB43PBLX16667607456773
#
# Image: batch1-0488.jpg
# Invoice no: 11829549
# Date of issue: 05/13/2017
# Seller: Client:
# Tax Id: 910-99-4402
# IBAN: GB42GRFE12828986459550
# 3: Waterford Elegance Chardonnay 4,00 each
#
# Image: batch1-0489.jpg
# Invoice no: 37451664
# Tax Id: 916-94-8739
# IBAN: GB31KIAV64209378666800
#
# Image: batch1-0490.jpg
# Invoice no: 32135544
# Tax Id: 997-85-1616
# IBAN: GB21VGUQ93040788957754
#
# Image: batch1-0491.jpg
# Invoice no: 10372826
# Date of issue: 05/15/2019
# Seller: Client:
# Tax Id: 975-98-4861 Tax Id: 978-80-2701
# IBAN: GB56SDLA43798626107179
#
# Image: batch1-0492.jpg
# Invoice no: 45175273
# Date of issue: 03/30/2020
# Seller: Client:
# Tax Id: 901-73-3277 Tax Id: 920-80-9993
# IBAN: GB100BAM24928408675285
#
# Image: batch1-0493.jpg
# Invoice no: 22529030
# Tax Id: 938-83-8149
# IBAN: GB480ZWQ30024053292452
#
# Image: batch1-0494.jpg
# Invoice no: 84652373
# Tax Id: 937-70-8530
# IBAN: GB911YX005542456978150
# 3: Vintage Crystal Red Wine
# S: Lolita "Wine Bouquet" Hand
#
# Image: batch1-0495.jpg
# Invoice no: 45302561
# Tax Id: 950-70-5811
# IBAN: GB51GQGK03722855880684
#
# Image: batch1-0496.jpg
# Invoice no: 75399670
# Tax Id: 998-79-3566
# IBAN: GB740ALW12437007562033
#
# Image: batch1-0497.jpg
# Invoice no: 73285932
# Date of issue: 07/25/2017
# Seller: Client:
# Tax Id: 963-86-7453 Tax Id: 901-73-0142
# IBAN: GB16HUWQ31434229260013
#
# Image: batch1-0498.jpg
# Invoice no: 33310882
# Tax Id: 917-78-6794
# IBAN: GB92THKG55938218455949
# 3: Super Nintendo SNES System 4,00
# 5: Magnavox Odyssey 2 2,00
#
# Image: batch1-0499.jpg
# Invoice no: 40108666
# Date of issue: 02/07/2020
# Seller: Client:
# Tax Id: 993-75-3149 Tax Id: 998-98-6887
# IBAN: GB80MTNI52501633185191

# %% [markdown]
# ## Option 1: Save as JSON (recommended for structured key-value pairs)

# %%
import json

output_file_path = r"C:\Users\Gouthum\Downloads\Project\ocr_results.json"

with open(output_file_path, 'w', encoding='utf-8') as f:
    json.dump(all_results, f, indent=4, ensure_ascii=False)

print(f"\n✅ OCR results saved to: {output_file_path}")
# Out:
# ✅ OCR results saved to: C:\Users\Gouthum\Downloads\Project\ocr_results.json

# %% [markdown]
# ## Save My  structured OCR results

# %%
import json

try:
    with open(r'C:\Users\Gouthum\Downloads\Project\ocr_results.json', 'r', encoding='utf-8') as f:
        ocr_data = json.load(f)
    print("✅ Successfully loaded OCR data.")
except json.JSONDecodeError as e:
    print(f"❌ JSON decode error: {e}")
except Exception as e:
    print(f"❌ Other error: {e}")
# Out:
# ✅ Successfully loaded OCR data.

# %%
import os
import json

json_path = r"C:\Users\Gouthum\Downloads\Project\ocr_results.json"

if os.path.exists(json_path):
    with open(json_path, 'r', encoding='utf-8') as f:
        ocr_data = json.load(f)
    print("✅ Loaded existing OCR results.")
else:
    # your OCR code here
    ocr_data = run_ocr_and_collect_results()  # hypothetical function
    with open(json_path, 'w', encoding='utf-8') as f:
        json.dump(ocr_data, f, indent=4, ensure_ascii=False)
    print("✅ OCR results saved.")
# Out:
# ✅ Loaded existing OCR results.

# %%
with open('ocr_results.json', 'r', encoding='utf-8') as f:
    ocr_data = json.load(f)

# %%
ocr_data
# Out:
# [{'image_path': 'C:\\Users\\Gouthum\\Downloads\\Project\\batch_1\\batch_1\\batch1_2\\batch1-0500.jpg',
#   'ocr_text': "Invoice no: 34476404\n\nDate of issue: 07/24/2018\n\nSeller: Client:\n\nCarrillo, Lara and Hooper Ellis and Sons\n\nUSNV Jones 85942 Tucker Plains Apt. 982\nFPO AE 13513 Hernandezchester, SC 88596\nTax Id: 975-86-1582 Tax Id: 902-92-1120\n\nIBAN: GB14UTZB20101973421914\n\nITEMS\nNo. Description Qty UM Net price Net worth VAT [%] Gross\nworth\nils Pack 3 Artificial Sheepskin Seat 1,00 each 14,22 14,22 10% 15,64\nPads 30cm Round Pad Floor\nArea Carpets\n2. Soft Sheepskin Mat Faux Fur 2,00 each 8,40 16,80 10% 18,48\nRug Small Shaggy Non Slip\nFloor Carpet Yellow\noo Chindi Rugs Carpet New Design 4,00 each 29,99 119,96 10% 131,96\nBohemian Garden Yoga Mat\nIndian Kilim Coverlet\n4. YILONG 9'x12' Oversize 4,00 each 7 800,00 31 200,00 10% 34 320,00\nHandmade Silk Carpet Antistatic\nLuxurious Area Rug TJ107A\nSUMMARY\nVAT [%] Net worth VAT Gross worth\n10% 31 350,98 3 135,10 34 486,08\n\nTotal $ 31 350,98 $ 3 135,10 $ 34 486,08\n",
#   'key_values': {'Invoice no': '34476404',
#    'Date of issue': '07/24/2018',
#    'Seller': 'Client:',
#    'Tax Id': '975-86-1582 Tax Id: 902-92-1120',
#    'IBAN': 'GB14UTZB20101973421914'}},
#  {'image_path': 'C:\\Users\\Gouthum\\Downloads\\Project\\batch_1\\batch_1\\batch1_2\\batch1-0501.jpg',
#   'ocr_text': 'Invoice no: 18999056\n\nDate of issue:\n\nSeller:\n\nWood-Kim\n8881 Nicholas Grove\nWest Andrewshire, WA 71685\n\nTax Id: 900-76-1437\nIBAN: GB96KZTB85221072973831\n\nITEMS\nNo. Description Qty\n1. NINTENDO 64 CONSOLE Plus 2 3,00\nGAMES Barely Played With in\nPARTIAL ORIGINAL BOX\nSUMMARY\nVAT [%]\n\n10%\n\nTotal\n\nUM\n\neach\n\n07/29/2011\n\nClient:\n\nThompson PLC\n\n810 Adkins Canyon\nKristinton, ND 66973\n\nTax Id: 934-91-7704\n\nNet price\n\nNet worth VAT [%]\n49,99 149,97 10%\nNet worth VAT\n149,97 15,00\n$ 149,97 $ 15,00\n\nGross\nworth\n\n164,97\n\nGross worth\n164,97\n\n$ 164,97\n',
#   'key_values': {'Invoice no': '18999056',
#    'Tax Id': '934-91-7704',
#    'IBAN': 'GB96KZTB85221072973831'}},
#  {'image_path': 'C:\\Users\\Gouthum\\Downloads\\Project\\batch_1\\batch_1\\batch1_2\\batch1-0502.jpg',
#   'ocr_text': 'Invoice no: 33289699\n\nDate of issue:\n\nSeller:\n\nHall-Martinez\n3197 Jillian Forks Suite 115\nKimchester, HI 43821\n\nTax Id: 941-80-9599\n\nIBAN: GB32HGAS20083011657056\n\nITEMS\n\nNo. Description\n\nAe Nintendo GameCube Console\nDOL-001 Black w/ Controller,\nPower, A/V,\nSUMMARY\n\nTotal\n\n12/24/2012\n\nClient:\n\nHaynes-Woods\nUSNV Gilbert\nFPO AP 32645\n\nTax Id: 953-82-2864\n\nQty UM Net price Net worth VAT [%] Gross\nworth\n\n5,00 each 79,99 399,95 10% 439,95\nVAT [%] Net worth VAT Gross worth\n10% 399,95 40,00 439,95\n\n$ 399,95 $ 40,00 $ 439,95\n',
#   'key_values': {'Invoice no': '33289699',
#    'Tax Id': '953-82-2864',
#    'IBAN': 'GB32HGAS20083011657056'}},
#  {'image_path': 'C:\\Users\\Gouthum\\Downloads\\Project\\batch_1\\batch_1\\batch1_2\\batch1-0503.jpg',
#   'ocr_text': 'Invoice no: 22758345\n\nDate of issue:\n\nSeller:\n\nHensley, Harrison and Miller\n9983 Gonzalez Shoal Suite 223\nJeffreyberg, ND 71223\n\nTax Id: 941-70-5402\nIBAN: GB36KYWK10385657483744\n\nITEMS\nNo. Description Qty\nils Selmash Lux Home Alcohol 4,00\nDistiller Kit for wine brewing, 15\n20 301\n2. Rabbit Wine Bottle Opener 1,00\n\nCorkscrew Set With Foil Cutter\n\na Frosted Satin Wine Goblet 2,00\nGlasses Crooked Stem Set Of 3\n\n4. 2 Hand Blown Wine Water 4,00\nGoblet Glass Art Mexico Pulled\nFeather Iridescent Swirl\n\n5, 50L/70L Moonshine Still Home 5,00\nAlcohol Oil Distiller Wine Making\nWater Brew Kit\n\nSUMMARY\n\nVAT [%]\n10%\n\nTotal\n\n12/21/2015\n\nUM\n\neacn\n\neacn\n\neacn\n\neacn\n\neacn\n\nClient:\n\nPeters LLC\n27910 Lindsey Inlet\nPort Martinside, NM 22708\n\nTax Id: 942-74-5002\n\nNet price Net worth VAT [%] Gross\nworth\n\n157,90 631,60 10% 694,76\n12,00 12,00 10% 13,20\n32,00 64,00 10% 70,40\n29,99 119,96 10% 131,96\n324,33 1 621,65 10% 1 783,81\nNet worth VAT Gross worth\n\n2 449,21 244,92 2 694,13\n\n$ 2 449,21 $ 244,92 $ 2 694,13\n',
#   'key_values': {'Invoice no': '22758345',
#    'Tax Id': '942-74-5002',
#    'IBAN': 'GB36KYWK10385657483744'}},
#  {'image_path': 'C:\\Users\\Gouthum\\Downloads\\Project\\batch_1\\batch_1\\batch1_2\\batch1-0504.jpg',
#   'ocr_text': 'Invoice no: 79036267\n\nDate of issue: 09/16/2016\n\nSeller: Client:\n\nAnderson, Gentry and Williams Bradley-Daniel\n\n1469 Theresa Grove 26018 Erica Mission Suite 050\nGarzaberg, NY 16415 New Scottborough, NY 56048\nTax Id: 940-81-6212 Tax Id: 903-76-2071\n\nIBAN: GBO6EYSH87132118408113\n\nITEMS\nNo. Description Qty UM Net price Net worth VAT [%] Gross\nworth\nils HP ProDesk G1 Desktop 4,00 each 119,95 479,80 10% 527,78\nComputer Core i3 3.4GHz 8GB\n500GB HD 19" LCD Windows 10\nPC\n2. Dell Optiplex SFF Desktop 5,00 each 89,99 449,95 10% 494,95\nComputer Windows 10 4GB\n160GB\na Dell Desktop Computer{JIntel 2,00 each 69,95 139,90 10% 153,89\nCore 2 Duo 8GB 1TB HD\nQWindows 10 PC 22" LCD Wifi\nSUMMARY\nVAT [%] Net worth VAT Gross worth\n10% 1 069,65 106,97 1176,62\n\nTotal $ 1 069,65 $ 106,97 $1176,62\n',
#   'key_values': {'Invoice no': '79036267',
#    'Date of issue': '09/16/2016',
#    'Seller': 'Client:',
#    'Tax Id': '940-81-6212 Tax Id: 903-76-2071',
#    'IBAN': 'GBO6EYSH87132118408113'}},
#  {'image_path': 'C:\\Users\\Gouthum\\Downloads\\Project\\batch_1\\batch_1\\batch1_2\\batch1-0505.jpg',
#   'ocr_text': 'Invoice no: 11556735\n\nDate of issue:\n\nSeller:\n\nWeaver-Barber\n60902 Steven Trace\nTylerland, MA 82522\n\nTax Id: 995-97-3608\nIBAN: GB82SVCE08751937948089\n\nITEMS\nNo. Description Qty\n1. Stemware Rack Display Kitchen 5,00\n\nWine Glass Holder Bottle\nCarbon Steel Free Punch\n\n2. Refinery Wine Opener 5,00\nBy Wine Glasses Goblets Pair Clear 5,00\nGlass\n4. Unicorn Wine Bottle Display 2,00\nSUMMARY\nVAT [%]\n10%\nTotal\n\n03/07/2014\n\nUM\n\neach\n\neach\n\neach\n\neach\n\nClient:\nScott Ltd\n\n6958 Ramirez Crest\nMooremouth, NJ 37424\n\nTax Id: 939-73-8621\n\nNet price\n\n42,32\n\n10,00\n\n12,00\n\n15,85\n\nNet worth\n353,30\n\n$ 353,30\n\nNet worth VAT [%]\n\n211,60 10%\n50,00 10%\n60,00 10%\n31,70 10%\n\nVAT\n35,33\n$ 35,33\n\nGross\nworth\n\n232,76\n\n55,00\n\n66,00\n\n34,87\n\nGross worth\n388,63\n\n$ 388,63\n',
#   'key_values': {'Invoice no': '11556735',
#    'Tax Id': '939-73-8621',
#    'IBAN': 'GB82SVCE08751937948089'}},
#  {'image_path': 'C:\\Users\\Gouthum\\Downloads\\Project\\batch_1\\batch_1\\batch1_2\\batch1-0506.jpg',
#   'ocr_text': 'Invoice no: 35382296\n\nDate of issue:\n\nSeller:\n\nNorman-Best\n5217 Morris Mountain Apt. 600\nNorth Danielshire, MI 66538\n\nTax Id: 900-99-6175\nIBAN: GB97SVBJ13467617537698\n\nITEMS\nNo. Description Qty\nils Nintendo Gameboy Pocket 3,00\n\nConsole Clear Purple with Box\nMGB-001 Japan Tested 53\n\n2. HUGE Sony PlayStation 3 5,00\n\nConsole Lot w/ 30 Games!\nSystem Bundle PS3\n\nSUMMARY\n\nVAT [%]\n10%\n\nTotal\n\n09/07/2016\n\nUM\n\neach\n\neach\n\nClient:\n\nGilbert, Spencer and Anderson\nPSC 7207, Box 5750\nAPO AA 48779\n\nTax Id: 982-92-4270\n\nNet price Net worth VAT [%]\n\n85,00 255,00 10%\n\n299,95 1 499,75 10%\nNet worth VAT\n1754,75 175,48\n$1 754,75 $ 175,48\n\nGross\nworth\n\n280,50\n\n1 649,72\n\nGross worth\n1 930,23\n\n$ 1 930,23\n',
#   'key_values': {'Invoice no': '35382296',
#    'Tax Id': '982-92-4270',
#    'IBAN': 'GB97SVBJ13467617537698'}},
#  {'image_path': 'C:\\Users\\Gouthum\\Downloads\\Project\\batch_1\\batch_1\\batch1_2\\batch1-0507.jpg',
#   'ocr_text': 'Invoice no: 64661204\n\nDate of issue:\n\nSeller:\n\nAbbott, Martinez and Nunez\n700 Jennings Shoals Apt. 008\nWoodsborough, DC 14098\n\nTax Id: 911-78-8806\nIBAN: GB60AMAZ11977251874745\n\nITEMS\nNo. Description Qty\n1. Ryzen Gaming Computer 3,00\n2. Dell OptiPlex 7060 SFF 4,00\n\nComputer, 8th Gen Core i5, 8GB\nDDR4, New 240GB SSD, DVD\n\nBy Custom Build HP Desktop 2,00\nComputer 16GB | 2TB | SSD |\nWindows 10 Windows 7 PC WiFi\n\n4. HP T520 Thin Client Computer 5,00\nAMD GX-212JC 1.2GHz 4GB RAM\nTESTED !!READ BELOW!!\n\nSUMMARY\n\nVAT [%]\n10%\n\nTotal\n\n12/19/2016\n\nUM\n\neacn\n\neacn\n\neacn\n\neacn\n\nClient:\n\nWilson PLC\n200 Gregory Junctions\nJamesmouth, NV 63642\n\nNet price\n\n752,00\n\n202,50\n\n329,00\n\n37,75\n\nNet worth\n3 912,75\n\n$3 912,75\n\nTax Id: 917-70-4830\n\nNet worth VAT [%]\n2 256,00 10%\n810,00 10%\n658,00 10%\n188,75 10%\n\nVAT\n\n391,28\n\n$ 391,28\n\nGross\nworth\n\n2 481,60\n\n891,00\n\n723,80\n\n207,63\n\nGross worth\n4 304,03\n\n$ 4 304,03\n',
#   'key_values': {'Invoice no': '64661204',
#    'Tax Id': '917-70-4830',
#    'IBAN': 'GB60AMAZ11977251874745'}},
#  {'image_path': 'C:\\Users\\Gouthum\\Downloads\\Project\\batch_1\\batch_1\\batch1_2\\batch1-0508.jpg',
#   'ocr_text': 'Invoice no: 95545504\n\nDate of issue:\n\nSeller:\n\nAdams, Hess and Davis\n225 Gonzales Crest Apt. 419\nHolmesview, OK 39540\n\nTax Id: 927-95-7389\nIBAN: GB87IPTJ05582977551180\n\nITEMS\nNo. Description Qty\n1. Xhilaration Womens L Burgandy 4,00\nBoho Embroidered Festival Mini\nDress NEW\nSUMMARY\nVAT [%]\n\n10%\n\nTotal\n\nUM\n\neach\n\n04/06/2012\n\nClient:\n\nJohnson Ltd\n\n326 Gonzalez Throughway Suite 496\nLake Johnborough, FL 59208\n\nTax Id: 998-79-7169\n\nNet price Net worth VAT [%]\n14,95 59,80 10%\nNet worth VAT\n59,80 5,98\n$ 59,80 $ 5,98\n\nGross\nworth\n\n65,78\n\nGross worth\n\n65,78\n\n$ 65,78\n',
#   'key_values': {'Invoice no': '95545504',
#    'Tax Id': '998-79-7169',
#    'IBAN': 'GB87IPTJ05582977551180'}},
#  {'image_path': 'C:\\Users\\Gouthum\\Downloads\\Project\\batch_1\\batch_1\\batch1_2\\batch1-0509.jpg',
#   'ocr_text': 'Invoice no: 66919860\n\nDate of issue:\n\nSeller:\n\nKing-Aguilar\n595 Hoffman Prairie\nSouth James, MT 62369\n\nTax Id: 967-76-8099\nIBAN: GB96NPWF24313123989624\n\nITEMS\nNo. Description Qty\nils The Wire in the Blood (Tony Hill 3,00\n\nand Carol Jordan, Book 2) by\nMcDermid New+-\n\nSUMMARY\n\nVAT [%]\n\n10%\n\nTotal\n\n05/11/2021\n\nClient:\n\nChavez, Ortega and Hunt\n466 Laura Hills\nNew Ruth, AK 68704\n\nTax Id: 912-81-4088\n\nUM Net price Net worth VAT [%]\neach TS 45,36 10%\nNet worth VAT\n45,36 4,54\n$ 45,36 $ 4,54\n\nGross\nworth\n\n49,90\n\nGross worth\n\n49,90\n\n$ 49,90\n',
#   'key_values': {'Invoice no': '66919860',
#    'Tax Id': '912-81-4088',
#    'IBAN': 'GB96NPWF24313123989624'}},
#  {'image_path': 'C:\\Users\\Gouthum\\Downloads\\Project\\batch_1\\batch_1\\batch1_2\\batch1-0510.jpg',
#   'ocr_text': 'Invoice no: 51033885\n\nDate of issue: 10/20/2020\nSeller: Client:\nHaney LLC Davis-Olson\n\n299 Lopez Turnpike\nPort Ashleystad, CT 96543\n\nTax Id: 983-71-0760\nIBAN: GB72WXZQ30602505765427\n\nITEMS\nNo. Description Qty UM\nils Nike Shoes Size 7 5,00 each\n2. DC Kids Pixie 3 Sneaker 3,00 each\n\n(Toddler/Little Kid/Big Kid) Color\nWHITE/BATTLESHIP\n\nSUMMARY\nVAT [%]\n10%\n\nTotal\n\n03296 Larry Locks Suite 711\nBoothland, OK 16934\n\nTax Id: 924-85-0\n\nNet price\n\n8,65\n\n55,00\n\nNet worth\n208,25\n\n$ 208,25\n\n788\n\nNet worth VAT [%]\n\n43,25\n\n165,00\n\nVAT\n20,83\n\n$ 20,83\n\n10%\n\n10%\n\nGross\nworth\n\n47,58\n\n181,50\n\nGross worth\n229,08\n\n$ 229,08\n',
#   'key_values': {'Invoice no': '51033885',
#    'Date of issue': '10/20/2020',
#    'Seller': 'Client:',
#    'Tax Id': '924-85-0',
#    'IBAN': 'GB72WXZQ30602505765427'}},
#  {'image_path': 'C:\\Users\\Gouthum\\Downloads\\Project\\batch_1\\batch_1\\batch1_2\\batch1-0511.jpg',
#   'ocr_text': 'Invoice no: 17014325\n\nDate of issue:\n\nSeller:\n\nValdez, Clark and Fischer\n4108 Marissa Ports\n\nNew Andreaborough, MN 20857\n\nTax Id: 981-88-9179\nIBAN: GB63VYKU25151548792645\n\nITEMS\nNo. Description Qty\nils Nintendo Switch Lite Console - 2,00\nGray - with Animal Crossing\nNew Horizons Game\nSUMMARY\nVAT [%]\n\n10%\n\nTotal\n\nUM\n\neach\n\n03/16/2017\n\nClient:\n\nHancock-Shields\n397 Mary Skyway Suite 261\nRochaburgh, SC 53742\n\nTax Id: 961-75-8721\n\nNet price Net worth VAT [%]\n310,00 620,00 10%\nNet worth VAT\n620,00 62,00\n$ 620,00 $ 62,00\n\nGross\nworth\n\n682,00\n\nGross worth\n682,00\n\n$ 682,00\n',
#   'key_values': {'Invoice no': '17014325',
#    'Tax Id': '961-75-8721',
#    'IBAN': 'GB63VYKU25151548792645'}},
#  {'image_path': 'C:\\Users\\Gouthum\\Downloads\\Project\\batch_1\\batch_1\\batch1_2\\batch1-0512.jpg',
#   'ocr_text': "Invoice no: 81040846\n\nDate of issue:\n\nSeller:\n\nGibson-Gonzalez\n89975 Richard Center\nEast Jennifermouth, AK 64173\n\nTax Id: 936-94-7256\nIBAN: GB36FNBG72685497690343\n\nITEMS\nNo. Description Qty\nils All Mattel Disney Pixar Model 3,00\n\nCars McQueen 1:55 Diecast Lot\nChoose Loose Kid Toy\n\n2. Lego Star Wars Minifigures 3,00\nStormtrooper Darth Vader Yoda\nObi Van Mandalorian New\n\n3: 4 pcs Kids Size Cartoon Peppa 1,00\nPink Pig Cotton Face Masks\nMouth Cover Washable\n\n4. Under Armour Kids' Grade 5,00\nSchool Curry 3Zer0 2 Basketball\nShoes\n\na LL Bean Boys Lot Size 1 Athletic 4,00\nSneakers 2 Black Blue Canvas\nBelts SM\n\n6. Minecraft Creative Stuffed Plush 4,00\n\nKids Childrens Gift Cute Toy\nBirthday Christmas\n\nSUMMARY\n\nVAT [%]\n10%\n\nTotal\n\n02/07/2021\n\nUM\n\neacn\n\neacn\n\neacn\n\neacn\n\neacn\n\neacn\n\nClient:\n\nOsborne, Mcdonald and Hamilton\n712 Gonzales Ways\nKnighthaven, GA 32178\n\nTax Id: 960-94-6644\n\nNet price\n\n12,99\n\n2,98\n\n11,88\n\n44,99\n\n6,99\n\n7,25\n\nNet worth\n341,70\n\n$ 341,70\n\nNet worth\n\n38,97\n\n8,94\n\n11,88\n\n224,95\n\n27,96\n\n29,00\n\nVAT [%]\n\n10%\n\n10%\n\n10%\n\n10%\n\n10%\n\n10%\n\nVAT\n\n34,17\n\n$ 34,17\n\nGross\nworth\n\n42,87\n\n9,83\n\n13,07\n\n247,45\n\n30,76\n\n31,90\n\nGross worth\n\n375,87\n\n$ 375,87\n",
#   'key_values': {'Invoice no': '81040846',
#    'Tax Id': '960-94-6644',
#    'IBAN': 'GB36FNBG72685497690343',
#    'Cars McQueen 1': '55 Diecast Lot',
#    '3': '4 pcs Kids Size Cartoon Peppa 1,00'}},
#  {'image_path': 'C:\\Users\\Gouthum\\Downloads\\Project\\batch_1\\batch_1\\batch1_2\\batch1-0513.jpg',
#   'ocr_text': 'Invoice no: 86883880\n\nDate of issue:\n\nSeller:\n\nRhodes, Young and Yoder\n41630 Sanchez Avenue\nLake Nathan, MO 18866\n\nTax Id: 995-92-6109\nIBAN: GB63WGSI95835863625969\n\nITEMS\n\nNo. Description\n\n1. Unicorn Series Small Large Long\nFloor Carpet Area Rugs Various\nSize Soft Rug\n\n2. 2Pack Soft Fluffy Faux Fur Plain\nChair Cover Washable Shaggy\nArea Rugs Carpet\n\n3: 3D Starry sky Carpet Child Play\nArea Rug Kids Room Carpets\nMat for Living Room\n\n4. 3pcs Faux Fur Seat Pads 30cm\n\nRound Cushions Fleece Floor\nCarpets Decorative\n\nSUMMARY\n\nTotal\n\nQty\n\n3,00\n\n2,00\n\n2,00\n\n1,00\n\nVAT [%]\n\n10%\n\n06/16/2018\n\nUM\n\neacn\n\neacn\n\neacn\n\neacn\n\nClient:\nDavis PLC\n\n7257 Chelsea Circle\nNorth Victoria, MI 38860\n\nTax Id: 988-72-4811\n\nNet price\n\n46,50\n\n13,59\n\n11,69\n\n14,66\n\nNet worth\n204,72\n\n$ 204,72\n\nNet worth VAT [%]\n139,50 10%\n27,18 10%\n23,38 10%\n14,66 10%\n\nVAT\n\n20,47\n\n$ 20,47\n\nGross\nworth\n\n153,45\n\n29,90\n\nPLS TPZ\n\n16,13\n\nGross worth\n225,19\n\n$ 225,19\n',
#   'key_values': {'Invoice no': '86883880',
#    'Tax Id': '988-72-4811',
#    'IBAN': 'GB63WGSI95835863625969',
#    '3': '3D Starry sky Carpet Child Play'}},
#  {'image_path': 'C:\\Users\\Gouthum\\Downloads\\Project\\batch_1\\batch_1\\batch1_2\\batch1-0514.jpg',
#   'ocr_text': 'Invoice no: 63042822\n\nDate of issue:\n\nSeller:\n\nRamirez and Sons\n057 Andrews Vista\nJeffreyfort, AR 30246\n\nTax Id: 961-81-3603\nIBAN: GB72EJSX53160989293657\n\nITEMS\nNo. Description Qty\n1. Round Rug Carpets for Living 3,00\n\nRoom Decor Kids Room Long\nPlush Rugs Bedroom Mats*\n\n2. Yilong 6\'x9\' Handknotted Silk 3,00\nRed Carpet Kid Friendly Oriental\nLuxury Rug Z439A\n\noo Cotton Handmade Area Rug 2,00\nHome Decorative Rustic Carpet\nWoven Dhurrie 3X5 Runner\n\n4. Yilong 5\'x8\' Handknotted Silk 5,00\nArea Rug Living Room Black\nClassic Carpet L38B\n\na Faux Fur Animal Print Hide Skin 1,00\n\nRug Cowhide Area Rug Floor\nMat Carpet 33.5"X43"\n\nSUMMARY\n\nVAT [%]\n10%\n\nTotal\n\n06/04/2014\n\nUM\n\neacn\n\neacn\n\neacn\n\neacn\n\neacn\n\nClient:\n\nHarrison LLC\n5446 Miller Rue\n\nLyonsfort, ID 29652\n\nTax Id: 909-82-6817\n\nNet price\n\n4,38\n\n3 800,00\n\n44,40\n\n8 000,00\n\n26,03\n\nNet worth\n51 527,97\n\n$ 51 527,97\n\nNet worth VAT [%]\n13,14 10%\n11 400,00 10%\n88,80 10%\n40 000,00 10%\n26,03 10%\n\nVAT\n\n5 152,80\n\n$5 152,80\n\nGross\nworth\n\n14,45\n\n12 540,00\n\n97,68\n\n44 000,00\n\n28,63\n\nGross worth\n\n56 680,77\n\n$ 56 680,77\n',
#   'key_values': {'Invoice no': '63042822',
#    'Tax Id': '909-82-6817',
#    'IBAN': 'GB72EJSX53160989293657'}},
#  {'image_path': 'C:\\Users\\Gouthum\\Downloads\\Project\\batch_1\\batch_1\\batch1_2\\batch1-0515.jpg',
#   'ocr_text': "Invoice no: 41287213\n\nDate of issue:\n\nSeller:\n\nElliott, Jordan and Watson\n89940 John Forges\nEast Jacobton, MT 74972\n\nTax Id: 972-70-6667\nIBAN: GB59NUQS46594706243199\n\nITEMS\nNo. Description Qty\nils Vintage Wine Basket Holder - 3 3,00\nBottles\n2. Wine Bottle Holder 2,00\n3. Vintage wine 2 bottles holder 2,00\n\nlron & rattan rack\n4. Leed's Wine Companion Bottle 2,00\nCorkscrew Opener Gift Box Set\nwith Foil Cutter\nae Chef Wine Bottle Holder 2,00\n6. New Fully Automatic Red Wine 3,00\n\nBottle Opener Electric Red Wine\nOpener Corkscrew\n\nSUMMARY\n\nVAT [%]\n10%\n\nTotal\n\n12/05/2019\n\nUM\n\neacn\n\neacn\n\neacn\n\neacn\n\neacn\n\neacn\n\nClient:\n\nSanders Group\nUSNV Patterson\nFPO AP 78581\n\nTax Id: 958-92-0941\n\nNet price\n\n32,99\n\n10,75\n\n55,00\n\n7,50\n\n65,95\n\n25,99\n\nNet worth\n455,34\n\n$ 455,34\n\nNet worth\n\n98,97\n\n21,50\n\n110,00\n\n15,00\n\n131,90\n\n7197\n\nVAT [%]\n\n10%\n\n10%\n\n10%\n\n10%\n\n10%\n\n10%\n\nVAT\n\n45,53\n\n$ 45,53\n\nGross\nworth\n\n108,87\n\n23,65\n\n121,00\n\n16,50\n\n145,09\n\n85,77\n\nGross worth\n\n500,87\n\n$ 500,87\n",
#   'key_values': {'Invoice no': '41287213',
#    'Tax Id': '958-92-0941',
#    'IBAN': 'GB59NUQS46594706243199'}},
#  {'image_path': 'C:\\Users\\Gouthum\\Downloads\\Project\\batch_1\\batch_1\\batch1_2\\batch1-0516.jpg',
#   'ocr_text': "Invoice no: 74093352\n\nDate of issue:\n\nSeller:\n\nMatthews-Olson\n5687 Samuel Wall Apt. 125\nDavisberg, CA 50111\n\nTax Id: 971-78-5476\nIBAN: GB29YJZA36672521634669\n\nITEMS\nNo. Description Qty\n1. Kids Jordan 7 Retro Sz 2y 2,00\n2. boys shoes size 5 3,00\nBy Lands' End Kids Boys Snow 4,00\n\nWinter Boots Size 5 Blue Warm\nZip Up Easy On Easy Off\n\n4. Joma Boys Youth Super Copa 3,00\n102 Soccer Cleats 2.5 White\nYellow Blue Futbol NEW\n\nDe Joma Boys Youth Gol-102 5,00\n\nSoccer Cleats Shoes Size 4\nWhite Red Futbol NEW\n\nSUMMARY\n\nVAT [%]\n10%\n\nTotal\n\n10/18/2020\n\nUM\n\neacn\n\neacn\n\neacn\n\neacn\n\neacn\n\nClient:\n\nMiller, Coleman and Rivera\n26057 John Flat Apt. 069\nLake Scott, UT 74808\n\nTax Id: 961-91-8761\n\nNet price Net worth VAT [%]\n\n72,00 144,00 10%\n\n5,80 17,40 10%\n\n9,50 38,00 10%\n\n19,99 59,97 10%\n\n19,99 99,95 10%\nNet worth VAT\n359,32 35,93\n\n$ 359,32 $ 35,93\n\nGross\nworth\n\n158,40\n19,14\n\n41,80\n\n65,97\n\n109,94\n\nGross worth\n\n395,25\n\n$ 395,25\n",
#   'key_values': {'Invoice no': '74093352',
#    'Tax Id': '961-91-8761',
#    'IBAN': 'GB29YJZA36672521634669'}},
#  {'image_path': 'C:\\Users\\Gouthum\\Downloads\\Project\\batch_1\\batch_1\\batch1_2\\batch1-0517.jpg',
#   'ocr_text': "Invoice no: 80673242\n\nDate of issue: 06/12/2012\n\nSeller: Client:\n\nRice, Pitts and Ramos Petersen Group\n\n57143 Derrick Ville Apt. 520 39313 Christopher Islands Suite 035\nGrantview, PA 42829 New Jessicaland, TN 68290\n\nTax Id: 909-90-7529 Tax Id: 976-71-1285\n\nIBAN: GB78XUNJ66821661162634\n\nITEMS\nNo. Description Qty UM Net price Net worth VAT [%] Gross\nworth\nils LuLaRoe Nicole Dress Size Large 2,00 each 1,99 3,98 10% 4,38\n25\n2. Vintage AGB Black Velvet Maxi 3,00 each 69,96 209,88 10% 230,87\nDress L Mandarin Collar\nBy Elisa Cavaletti Daniela 4,00 each 60,00 240,00 10% 264,00\nDallavalle Shift Dress Grey And\nWhite .Size M\n4. Andrea Polizzi Women's 5,00 each 0,99 4,95 10% 5,45\nSleeveless Shift Dress Silver\nSize 8\nSUMMARY\nVAT [%] Net worth VAT Gross worth\n10% 458,81 45,88 504,69\n\nTotal $ 458,81 $ 45,88 $ 504,69\n",
#   'key_values': {'Invoice no': '80673242',
#    'Date of issue': '06/12/2012',
#    'Seller': 'Client:',
#    'Tax Id': '909-90-7529 Tax Id: 976-71-1285',
#    'IBAN': 'GB78XUNJ66821661162634'}},
#  {'image_path': 'C:\\Users\\Gouthum\\Downloads\\Project\\batch_1\\batch_1\\batch1_2\\batch1-0518.jpg',
#   'ocr_text': 'Invoice no: 94052403\n\nDate of issue:\n\nSeller:\n\nWoods, Hubbard and Harris\n6005 Sutton Fort Apt. 363\nShanemouth, MN 22878\n\nTax Id: 902-91-5275\nIBAN: GB37TYVM02581764425566\n\nITEMS\nNo. Description Qty\nils 6\'x3\' Marble Dining Center 5,00\n\nTable Marquetry Inlay Italian\nMosaic Patio Arts H3112\n\n2. Blue Shiny Stone Floral Art 5,00\nDinning Table Top Marble\nKitchen Table Top 48 Inches\n\noo 12" White Marble Coffee Table 1,00\nTop Lapis Turquoise Floral Inlay\nHome Decors W538\n\n4. Marquetry Art Marble Inlay 5,00\nTable Top Octagon Dinning\nTable Home Assent 48 Inches\n\nS: 6\'x3\' Black Marble Large Dining 3,00\nTable Top Very Fine Handmade\nMarquetry Birds Art\n\n6. 60 Inches Marble Dinning Table 5,00\nTop Hand Inlaid Garden Table\nwith Gemstones\n\nde 2 Industrial Live edge Legs 16" 2,00\n\nTall Cast Aluminum Cast Iron\nCoffee Table Bench\n\nSUMMARY\n\nVAT [%]\n10%\n\nTotal\n\n03/30/2021\n\nClient:\n\nHines, Ingram and Fisher\n67543 David Springs\nJenniferhaven, IA 04824\n\nTax Id: 928-97-9700\n\nUM Net price Net worth VAT [%]\neach 6 647,61 33 238,05 10%\neach 3 960,00 19 800,00 10%\neach 295,73 295,73 10%\neach 2 860,00 14 300,00 10%\neach 5 303,66 15 910,98 10%\neach 5 908,00 29 540,00 10%\neach 159,28 318,56 10%\n\nNet worth VAT\n113 403,32 11 340,33\n\n$113 403,32 $11 340,33\n\nGross\nworth\n\n36 561,85\n\n21 780,00\n\n325,30\n\n15 730,00\n\n17 502,08\n\n32 494,00\n\n350,42\n\nGross worth\n124 743,65\n\n$ 124 743,65\n',
#   'key_values': {'Invoice no': '94052403',
#    'Tax Id': '928-97-9700',
#    'IBAN': 'GB37TYVM02581764425566',
#    'S': "6'x3' Black Marble Large Dining 3,00"}},
#  {'image_path': 'C:\\Users\\Gouthum\\Downloads\\Project\\batch_1\\batch_1\\batch1_2\\batch1-0519.jpg',
#   'ocr_text': 'Invoice no: 61249473\n\nDate of issue:\n\nSeller:\n\nOdonnell-Moore\n8244 Gabrielle Prairie\nNew Anthony, IL 79749\n\nTax Id: 972-80-7159\nIBAN: GB71QDKV18239296168053\n\nITEMS\nNo. Description Qty\nils Nintendo Wii Console Mario Kart 4,00\n\nController Wii Fit 2 Board\nRemotes Game BUNDLE\n\n2. SONY Playstation2 Console 1,00\nSCPH-39000 " Aqua Color "/\nTESTED 11180\n\n3: Original Nintendo Gaming 5,00\nConsole with Robot, 9 games &\nextras\n\n4. PS4 PlayStation 4 500 GB 3,00\n\nConsole CUH-1115A Bundle, 1\nController, 8 Games\n\nSUMMARY\n\nVAT [%]\n10%\n\nTotal\n\n12/02/2015\n\nUM\n\neacn\n\neacn\n\neacn\n\neacn\n\nClient:\n\nSloan and Sons\n\n9111 Gregory Turnpike Apt. 860\nWrightfort, MT 27289\n\nTax Id: 949-88-5332\n\nNet price\n\n199,97\n\n60,00\n\n475,00\n\n349,99\n\nNet worth\n4 284,85\n\n$ 4 284,85\n\nNet worth VAT [%]\n\n799,88 10%\n60,00 10%\n2 375,00 10%\n1 049,97 10%\nVAT\n428,49\n$ 428,49\n\nGross\nworth\n\n879,87\n\n66,00\n\n2 612,50\n\n1154,97\n\nGross worth\n4 713,34\n\n$ 4 713,34\n',
#   'key_values': {'Invoice no': '61249473',
#    'Tax Id': '949-88-5332',
#    'IBAN': 'GB71QDKV18239296168053',
#    '3': 'Original Nintendo Gaming 5,00'}},
#  {'image_path': 'C:\\Users\\Gouthum\\Downloads\\Project\\batch_1\\batch_1\\batch1_2\\batch1-0520.jpg',
#   'ocr_text': 'Invoice no: 91858806\n\nDate of issue: 03/05/2012\n\nSeller:\n\nDecker-Martinez\n392 Kristin Camp\nEast Corey, AZ 36537\n\nTax Id: 928-94-8507\nIBAN: GBO2KZOK44962043610197\n\nITEMS\nNo. Description Qty UM\n1. Keep the Boos Coming Stainless 2,00 each\nSteel Stemless Wine Tumbler,\n120z2\n2. Pier 1 Multi-color Cordial 5,00 each\n\nLiqueur Wine Glasses Set of 4\n\nSUMMARY\n\nVAT [%]\n10%\n\nTotal\n\nClient:\n\nSchmidt, Butler and Rodriguez\n25400 Stevens Court Apt. 975\nFullerstad, MT 46358\n\nTax Id: 962-99-4335\n\nNet price Net worth VAT [%]\n\n19,99 39,98 10%\n30,00 150,00 10%\nNet worth VAT\n189,98 19,00\n$ 189,98 $ 19,00\n\nGross\nworth\n\n43,98\n\n165,00\n\nGross worth\n208,98\n\n$ 208,98\n',
#   'key_values': {'Invoice no': '91858806',
#    'Date of issue': '03/05/2012',
#    'Tax Id': '962-99-4335',
#    'IBAN': 'GBO2KZOK44962043610197'}},
#  {'image_path': 'C:\\Users\\Gouthum\\Downloads\\Project\\batch_1\\batch_1\\batch1_2\\batch1-0521.jpg',
#   'ocr_text': 'Invoice no: 70471446\n\nDate of issue:\n\nSeller:\n\nHendrix, Miller and Robertson\n49514 David Islands\nLangfurt, SC 07215\n\nTax Id: 978-77-8875\nIBAN: GB81REGA90697374514551\n\nITEMS\nNo. Description Qty\n1. sega cdx console with original 2,00\n\npower supply (laser info-read\ndescription)\n\n2. Nintendo GameCube System 1,00\nConsole Bundle Mario Sunshine\n+ Genuine controller LOT\n\n3: Magnavox Odyssey 2 5,00\nMicroprocessor Console System\nw Joy Sticks & 15 Games - 1978\n\n4. Nintendo Wii Teal Blue Limited 2,00\nEdition Console with Mario Kart -\nMINT TESTED\nSUMMARY\nVAT [%]\n10%\nTotal\n\n03/16/2019\n\nUM\n\neacn\n\neacn\n\neacn\n\neacn\n\nClient:\n\nGonzalez, Jacobs and Williams\n62658 George Road\n\nPort Jefferyfort, MN 62836\n\nTax Id: 952-83-2026\n\nNet price\n\n194,00\n\n159,99\n\n155,00\n\n114,99\n\nNet worth\n1552,97\n\n$1552,97\n\nNet worth VAT [%]\n388,00 10%\n159,99 10%\n775,00 10%\n229,98 10%\n\nVAT\n155,30\n$ 155,30\n\nGross\nworth\n\n426,80\n\n175,99\n\n852,50\n\n252,98\n\nGross worth\n1 708,27\n\n$ 1 708,27\n',
#   'key_values': {'Invoice no': '70471446',
#    'Tax Id': '952-83-2026',
#    'IBAN': 'GB81REGA90697374514551',
#    '3': 'Magnavox Odyssey 2 5,00'}},
#  {'image_path': 'C:\\Users\\Gouthum\\Downloads\\Project\\batch_1\\batch_1\\batch1_2\\batch1-0522.jpg',
#   'ocr_text': 'Invoice no: 80921168\n\nDate of issue:\n\nSeller:\n\nMatthews, Long and Hutchinson\n347 Alvarez Radial\nEast Jessicaview, NM 60216\n\nTax Id: 990-96-5375\n\nIBAN: GB39CRDS82853845004678\n\nITEMS\n\nNo.\n\nDescription\n\nFAST Dell Windows 10 Desktop\nComputer Core 2 Duo 4GB Ram\n250GB DVD WiFi 22" LCD\n\nDell Precision Workstation\nComputer Intel Xeon Quad Core\n16GB 1TB Windows 10 Pro\n\nDell Optiplex Desktop Computer\n790 Core i7 8GB RAM 1TB HD\nDVD Windows 10 PC Wifi\n\nSAMA RGB Gaming PC Desktop\nComputer i5 3.7GHz Nvidia GTX\n1060 16GB Windows 10\n\nSUMMARY\n\nTotal\n\nQty\n\n5,00\n\n4,00\n\n3,00\n\n4,00\n\nVAT [%]\n\n10%\n\n05/14/2015\n\nUM\n\neacl\n\neac\n\neac\n\neac\n\nh\n\nClient:\n\nPaul, Schneider\n\nand Kim\n\n08152 Chandler Cliff Suite 704\n\nAndersonview, MO 93029\n\nTax Id: 999-90-0468\n\nNet price\n\n169,95\n\n139,00\n\n159,95\n\n400,00\n\nNet worth\n3 485,60\n\n$ 3 485,60\n\nNet worth VAT [%]\n849,75 10%\n556,00 10%\n479,85 10%\n\n1 600,00 10%\nVAT\n348,56\n$ 348,56\n\nGross\nworth\n\n934,73\n\n611,60\n\n527,83\n\n1 760,00\n\nGross worth\n3 834,16\n\n$ 3 834,16\n',
#   'key_values': {'Invoice no': '80921168',
#    'Tax Id': '999-90-0468',
#    'IBAN': 'GB39CRDS82853845004678'}},
#  {'image_path': 'C:\\Users\\Gouthum\\Downloads\\Project\\batch_1\\batch_1\\batch1_2\\batch1-0523.jpg',
#   'ocr_text': 'Invoice no: 12947568\n\nDate of issue: 11/10/2018\nSeller: Client:\nSantos-King\n\n089 Anthony Turnpike Apt. 605\nNorth Melissa, RI 42841\n\nTax Id: 963-71-0206\nIBAN: GB24IHWR23389490452402\n\nITEMS\nNo. Description Qty UM\nils The WORLD of ART Time Life 5,00 each\n\nBooks~CompleteSet of 24 +\nAmerican Modern Art\n\n2. All American History Vol 1 1,00 each\nStudent Reader\n\na Black House: A Novel by 3,00 each\nStephen King, Peter Straub\n\nSUMMARY\n\nVAT [%]\n10%\n\nTotal\n\nNet price\n\n50,00\n\n9,99\n\n4,49\n\nNet worth\n273,46\n\n$ 273,46\n\nStone, Kramer and Diaz\n6249 Black Cliffs Apt. 929\nEast Gary, NY 47586\n\nTax Id: 970-92-9578\n\nNet worth VAT [%]\n\n250,00 10%\n9,99 10%\n13,47 10%\n\nVAT\n\n27739\n\n$ 27,35\n\nGross\nworth\n\n275,00\n\n10,99\n\n14,82\n\nGross worth\n300,81\n\n$ 300,81\n',
#   'key_values': {'Invoice no': '12947568',
#    'Date of issue': '11/10/2018',
#    'Seller': 'Client:',
#    'Tax Id': '970-92-9578',
#    'IBAN': 'GB24IHWR23389490452402',
#    'a Black House': 'A Novel by 3,00 each'}},
#  {'image_path': 'C:\\Users\\Gouthum\\Downloads\\Project\\batch_1\\batch_1\\batch1_2\\batch1-0524.jpg',
#   'ocr_text': 'Invoice no: 76059860\n\nDate of issue: 03/04/2020\nSeller: Client:\nMills, Harrington and Winters Owens-Harrison\n16014 Caitlyn Burg 96708 Tom Streets\nSanchezview, WY 67594 West Timothy, TN 85705\nTax Id: 921-76-4334 Tax Id: 966-75-4792\nIBAN: GB28QXWP57776134050198\nITEMS\nNo. Description Qty UM Net price Net worth VAT [%] Gross\nworth\nils Star Wars Childs Slippers - NWT 3,00 each 2,25) 6,75 10% 7,43\n2. Native Charley White 2,00 each 13,00 26,00 10% 28,60\nSandals~Size Infant/Child\n6~Boys/Girls~Very Good\nCondition\nSUMMARY\nVAT [%] Net worth VAT Gross worth\n10% 32,75 3,28 36,03\n\nTotal $ 32,75 $ 3,28 $ 36,03\n',
#   'key_values': {'Invoice no': '76059860',
#    'Date of issue': '03/04/2020',
#    'Seller': 'Client:',
#    'Tax Id': '921-76-4334 Tax Id: 966-75-4792',
#    'IBAN': 'GB28QXWP57776134050198'}},
#  {'image_path': 'C:\\Users\\Gouthum\\Downloads\\Project\\batch_1\\batch_1\\batch1_2\\batch1-0525.jpg',
#   'ocr_text': 'Invoice no: 83087619\n\nDate of issue:\n\nSeller:\n\nMurray-Blake\n0236 Hayes Turnpike Suite 528\n\nSouth Michaelchester, MD 11205\n\nTax Id: 929-91-8415\n\nIBAN: GB60VBTM64941117655704\n\nITEMS\n\nNo.\n\nDescription\n\nIn the Footsteps of the Russian\nSnowman (Paperback or\nSoftback)\n\nBuffy the Vampire Slayer\nSeason 12 Library Edition,\nHardcover by Gage, Christ...\n\nBattlestations! (Star Trek: The\nOriginal Series)\n\nCambridge Star Atlas 2000.0 by\nTirion, Wil Hardback Book The\nFast Free Shipping\n\nSUMMARY\n\nTotal\n\nQty\n\n3,00\n\n2,00\n\n2,00\n\n1,00\n\nVAT [%]\n\n10%\n\n05/06/2019\n\nUM\n\neacn\n\neacn\n\neacn\n\neacn\n\nClient:\n\nTurner-Wilkins\n\n02804 Higgins Summit\nLake Justin, Rl 81038\n\nTax Id: 917-94-9139\n\nNet price\n\nDsyiaiy/!\n\n24,89\n\n4,49\n\n20,37\n\nNet worth\n156,74\n\n$ 156,74\n\nNet worth VAT [%]\n77,61 10%\n49,78 10%\n\n8,98 10%\n20,37 10%\nVAT\n15,67\n\n$ 15,67\n\nGross\nworth\n\n85,37\n\n54,76\n\n9,88\n\n22,41\n\nGross worth\n\n172,41\n\n$ 172,41\n',
#   'key_values': {'Invoice no': '83087619',
#    'Tax Id': '917-94-9139',
#    'IBAN': 'GB60VBTM64941117655704',
#    'Battlestations! (Star Trek': 'The'}},
#  {'image_path': 'C:\\Users\\Gouthum\\Downloads\\Project\\batch_1\\batch_1\\batch1_2\\batch1-0526.jpg',
#   'ocr_text': 'Invoice no: 61987058\n\nDate of issue:\n\nSeller:\n\nSchneider, Johnston and Aguirre\n99443 Rodriguez Center\nEdwinfurt, MI 35731\n\nTax Id: 962-74-6839\nIBAN: GB36KTDL23862064037578\n\nITEMS\nNo. Description Qty\n1. Cambridge Star Atlas 2000.0 by 3,00\n\nTirion, Wil Hardback Book The\nFast Free Shipping\n\n2. BEVERLY HILLBILLIES 1993 TV 4,00\nShow BOOK Ist Edition\nAUTOGRAPHED Signed\nSTEPHEN COX\n\n3: Enough By Helen Roseveare 3,00\n4. Entertaining 3,00\n5: Harry Potter and the Chamber 4,00\n\nof Secrets (Book 2) by Rowling,\nJ. K. Paperback The\n\n6. Diabetic Dream Desserts 1,00\n\n7. The Nature Notes of an 4,00\nEdwardian Lady (Country Dia...\nby Holden, Edith Paperback\n\nSUMMARY\n\nVAT [%]\n10%\n\nTotal\n\n11/13/2014\n\nUM\n\neacn\n\neacn\n\neacn\n\neacn\n\neacn\n\neacn\n\neacn\n\nClient:\n\nPerry, Elliott and Gray\n3414 Christina Grove\nBrianmouth, CO 49582\n\nTax Id: 999-80-6296\n\nNet price\n\n20,37\n\n24,99\n\n8,86\n4,49\n\n7,62\n\n4,49\n\n26,67\n\nNet worth\n342,77\n\n$ 342,77\n\nNet worth\n\n61,11\n\n99,96\n\n26,58\n13,47\n\n30,48\n\n4,49\n\n106,68\n\nVAT [%]\n\n10%\n\n10%\n\n10%\n10%\n\n10%\n\n10%\n\n10%\n\nVAT\n\n34,28\n\n$ 34,28\n\nGross\nworth\n\n67,22\n\n109,96\n\n29,24\n14,82\n\n33,53\n\n4,94\n\n117,35\n\nGross worth\n\n377,05\n\n$ 377,05\n',
#   'key_values': {'Invoice no': '61987058',
#    'Tax Id': '999-80-6296',
#    'IBAN': 'GB36KTDL23862064037578',
#    '3': 'Enough By Helen Roseveare 3,00',
#    '5': 'Harry Potter and the Chamber 4,00'}},
#  {'image_path': 'C:\\Users\\Gouthum\\Downloads\\Project\\batch_1\\batch_1\\batch1_2\\batch1-0527.jpg',
#   'ocr_text': "Invoice no: 85992771\n\nDate of issue:\n\nSeller:\n\nKing Inc\n6557 Nguyen Knoll\nMatthewstad, CT 16171\n\nTax Id: 912-91-7096\nIBAN: GB90SXRI43551309635242\n\nITEMS\nNo. Description Qty\n1. Joma Boys Youth Gol-102 2,00\n\nSoccer Cleats Shoes Size 1.5\nWhite Red 1.5Y NEW\n\n2. Easy No Tie Rubber Shoe Laces 4,00\nColored Trainers Snickers Kids\n+ Adults Shoelaces\n\n3: Sketchers Energy Lights Boys 3,00\nBlack Canvas Size 4 With\nCharging Cable\n\n4. Beyblade Burst B-163 Superking 1,00\nBrave Valkyrie.Ev' 2A Top\n/Launcher /Grip Kid Toy\n\na boys shoes size 5 4,00\n6. NWT adidas Pulseboost HD (Big 3,00\nKid) Casual Running Shoes Boys\nBLACK SIZE 4\nSUMMARY\nVAT [%]\n10%\nTotal\n\n03/30/2021\n\nUM\n\neacn\n\neacn\n\neacn\n\neacn\n\neacn\n\neacn\n\nClient:\n\nChapman, Koch and Rivera\n206 Noble Walks\nLake James, NY 27700\n\nTax Id: 998-99-5998\n\nNet price Net worth VAT [%]\n19,99 39,98 10%\n1,55 6,20 10%\n12,00 36,00 10%\n11,59 11,59 10%\n5,80 23,20 10%\n84,99 254,97 10%\n\nNet worth VAT\n\n371,94 37,19\n\n$ 371,94 $ 37,19\n\nGross\nworth\n\n43,98\n\n6,82\n\n39,60\n\n12,75\n\n25,52\n\n280,47\n\nGross worth\n\n409,13\n\n$ 409,13\n",
#   'key_values': {'Invoice no': '85992771',
#    'Tax Id': '998-99-5998',
#    'IBAN': 'GB90SXRI43551309635242',
#    '3': 'Sketchers Energy Lights Boys 3,00'}},
#  {'image_path': 'C:\\Users\\Gouthum\\Downloads\\Project\\batch_1\\batch_1\\batch1_2\\batch1-0528.jpg',
#   'ocr_text': 'Invoice no: 10503434\n\nDate of issue:\n\nSeller:\n\nHenry-Fleming\n607 Caitlin Streets\nNorth Garyland, NJ 15865\n\nTax Id: 906-92-5447\nIBAN: GB68WUQJ50293517775877\n\nITEMS\nNo. Description Qty\nils Nintendo Super Famicom 1,00\n\nConsole in box with 2\ncontrollers tested working japan\n\nSUMMARY\n\nVAT [%]\n\n10%\n\nTotal\n\n10/14/2020\n\nClient:\n\nTucker-Castillo\n3391 Sandra Ramp Suite 924\nSouth Roberthaven, WY 46520\n\nTax Id: 922-86-9460\n\nUM Net price Net worth VAT [%]\neach 79,99 79,99 10%\nNet worth VAT\n79,99 8,00\n$ 79,99 $ 8,00\n\nGross\nworth\n\n87,99\n\nGross worth\n87,99\n\n$ 87,99\n',
#   'key_values': {'Invoice no': '10503434',
#    'Tax Id': '922-86-9460',
#    'IBAN': 'GB68WUQJ50293517775877'}},
#  {'image_path': 'C:\\Users\\Gouthum\\Downloads\\Project\\batch_1\\batch_1\\batch1_2\\batch1-0529.jpg',
#   'ocr_text': 'Invoice no: 16455494\n\nDate of issue:\n\nSeller:\n\nShaw-Boyer\n6193 Amy Isle\nLewischester, MS 69249\n\nTax Id: 975-73-1374\nIBAN: GB6OWRAU97719147995766\n\nITEMS\nNo. Description Qty\nils 18"\' Marble Coffee Table Top 5,00\nLapis Collectible Floral Inlay\nKitchen Decors W335\n2. 6\'x3\' White Marble Living Room 4,00\nDining Table Top Marquetry\nInlay Furniture H4743A\noo 2\' Black Marble Coffee Top Side 3,00\nTable Floral Fine Marquetry\nInlay Decors E1068A\n4. Yellow Stone Royal Art Marble 2,00\nDinning Table Top Round\nGarden Table Top 60 Inches\na 16 Inches Marble Corner Table 1,00\nTop Inlay Coffee Table with\nMulti Color Gemstones\n6. 6\'x3\' Marble Dining Center 3,00\nTable Marquetry Inlay Italian\nMosaic Patio Arts H3112\nSUMMARY\nVAT [%]\n10%\n\nTotal\n\n10/08/2014\n\nClient:\n\nStephenson, Edwards and Fowler\n9695 Douglas Curve\nBowmanfort, NM 94038\n\nTax Id: 913-91-8468\n\nUM Net price Net worth VAT [%]\neach 355,68 1 778,40 10%\neach 5 590,21 22 360,84 10%\neach 539,50 1 618,50 10%\neach 6 756,00 13 512,00 10%\neach 238,00 238,00 10%\neach 6 647,61 19 942,83 10%\n\nNet worth VAT\n59 450,57 5 945,06\n$ 59 450,57 $ 5 945,06\n\nGross\nworth\n\n1 956,24\n\n24 596,92\n\n1 780,35\n\n14 863,20\n\n261,80\n\n21 937,11\n\nGross worth\n\n65 395,63\n\n$ 65 395,63\n',
#   'key_values': {'Invoice no': '16455494',
#    'Tax Id': '913-91-8468',
#    'IBAN': 'GB6OWRAU97719147995766'}},
#  {'image_path': 'C:\\Users\\Gouthum\\Downloads\\Project\\batch_1\\batch_1\\batch1_2\\batch1-0530.jpg',
#   'ocr_text': 'Invoice no: 89528165\n\nDate of issue:\n\nSeller:\n\nMendoza and Sons\n32121 Brian Point Suite 140\nNew Josephton, CA 91943\n\nTax Id: 972-99-9622\nIBAN: GB85CYU074289270955300\n\nITEMS\nNo. Description Qty\n1. Cork Wine Bottle Stoppers With 4,00\n\nCandle Wicks Set 4\n\nSUMMARY\n\nVAT [%]\n\n10%\n\nTotal\n\n12/30/2019\n\nClient:\n\nFuller, Martin and Hays\nPSC 4972, Box 5640\nAPO AA 78470\n\nTax Id: 989-72-7105\n\nUM Net price Net worth VAT [%]\neach 8,25 33,00 10%\nNet worth VAT\n33,00 3,30\n$ 33,00 $ 3,30\n\nGross\nworth\n\n36,30\n\nGross worth\n\n36,30\n\n$ 36,30\n',
#   'key_values': {'Invoice no': '89528165',
#    'Tax Id': '989-72-7105',
#    'IBAN': 'GB85CYU074289270955300'}},
#  {'image_path': 'C:\\Users\\Gouthum\\Downloads\\Project\\batch_1\\batch_1\\batch1_2\\batch1-0531.jpg',
#   'ocr_text': 'Invoice no: 79622223\n\nDate of issue: 08/30/2011\n\nSeller: Client:\n\nRamirez, Parker and Perez\n938 Mathews Pine\nNew Alexander, ME 61875\n\nTax Id: 982-98-5624\nIBAN: GB87ESHD81490169427717\n\nITEMS\nNo. Description Qty UM\n1. Hyperkin RetroN 3 HD Console 2,00 each\n\nfor NES SNES Super Famicom\nGenesis/Mega Drive Black\n\n2. Nintendo Super Famicom 3,00 each\n\nConsole in box with 2\ncontrollers tested working japan\n\nSUMMARY\nVAT [%]\n10%\n\nTotal\n\nHaas PLC\n\n9669 Douglas Flats Suite 375\nPort Miguel, MI 10218\n\nTax Id: 939-81-4755\n\nNet price\n\n40,00\n\n79,99\n\nNet worth\n319,97\n\n$ 319,97\n\nNet worth VAT [%]\n\n80,00\n\n239,97\n\nVAT\n32,00\n\n$ 32,00\n\n10%\n\n10%\n\nGross\nworth\n\n88,00\n\n263,97\n\nGross worth\n351,97\n\n$ 351,97\n',
#   'key_values': {'Invoice no': '79622223',
#    'Date of issue': '08/30/2011',
#    'Seller': 'Client:',
#    'Tax Id': '939-81-4755',
#    'IBAN': 'GB87ESHD81490169427717'}},
#  {'image_path': 'C:\\Users\\Gouthum\\Downloads\\Project\\batch_1\\batch_1\\batch1_2\\batch1-0532.jpg',
#   'ocr_text': 'Invoice no: 72499229\n\nDate of issue:\n\nSeller:\n\nGray Ltd\n7142 Donald Road Suite 229\nLake Shelly, MN 32195\n\nTax Id: 957-81-9241\nIBAN: GB78SCQU65928970675216\n\nITEMS\n\nNo. Description Qty\n\n1. 1920s Flapper Gatsby Cocktail 5,00\nDress Chiffon Wedding Party\nEvening Formal Dresses\n\n2. Boden black blue floral short 4,00\nsleeve dress size 6\n\nSUMMARY\nVAT [%]\n\n10%\n\nTotal\n\nUM\n\neach\n\neach\n\n02/15/2012\n\nClient:\n\nCordova, Kennedy and Stevenson\n611 Lynch Hollow Apt. 972\n\nEast Douglashaven, GA 90688\n\nTax Id: 949-87-4339\n\nNet price\n\nNet worth VAT [%]\n\n8,99 44,95 10%\n\n36,99 147,96 10%\nNet worth VAT\n192,91 19,29\n$ 192,91 $ 19,29\n\nGross\nworth\n\n49,45\n\n162,76\n\nGross worth\n212,20\n\n$ 212,20\n',
#   'key_values': {'Invoice no': '72499229',
#    'Tax Id': '949-87-4339',
#    'IBAN': 'GB78SCQU65928970675216'}},
#  {'image_path': 'C:\\Users\\Gouthum\\Downloads\\Project\\batch_1\\batch_1\\batch1_2\\batch1-0533.jpg',
#   'ocr_text': "Invoice no: 98424808\n\nDate of issue:\n\nSeller:\n\nHernandez-Wilson\n13048 Craig Rapid Apt. 602\nLake Brianmouth, MA 18523\n\nTax Id: 979-94-0725\nIBAN: GB13CSTL25020849255302\n\nITEMS\nNo. Description Qty\n1. Bedroom Decor Carpets Living 2,00\n\nRoom Line Pattern Green Rug\nModern Simple Area Rugs\n\n2. YILONG 4'x6' Yellow Handmade 2,00\nCarpet Dining Room Hand\nKnotted Silk Rugs 083B\n\n3: Muted Vegetable Dye Khootan 1,00\nOriental Area Rug Hand-knotted\nFloral 8'x11' Carpet\n\n4. Yilong 2.5'x4' Hand Knotted Silk 3,00\n\nGarden Scene Rug Indoor\nOriental Carpet 352B\n\nSUMMARY\n\nVAT [%]\n10%\n\nTotal\n\n03/26/2019\n\nUM\n\neacn\n\neacn\n\neacn\n\neacn\n\nClient:\nHiggins-Rhodes\n\n731 Jenna Junction Suite 637\n\nStantonville, PA\n\n75207\n\nTax Id: 984-74-4819\n\nNet price\n\n33,86\n\n3 600,00\n\n2 015,64\n\n2 000,00\n\nNet worth\n15 283,36\n\n$ 15 283,36\n\nNet worth VAT [%]\n\n67,72 10%\n7 200,00 10%\n2 015,64 10%\n6 000,00 10%\nVAT\n1 528,34\n$ 1 528,34\n\nGross\nworth\n\n74,49\n\n7 920,00\n\n2217/20\n\n6 600,00\n\nGross worth\n16 811,70\n\n$ 16 811,70\n",
#   'key_values': {'Invoice no': '98424808',
#    'Tax Id': '984-74-4819',
#    'IBAN': 'GB13CSTL25020849255302',
#    '3': 'Muted Vegetable Dye Khootan 1,00'}},
#  {'image_path': 'C:\\Users\\Gouthum\\Downloads\\Project\\batch_1\\batch_1\\batch1_2\\batch1-0534.jpg',
#   'ocr_text': 'Invoice no: 61382297\n\nDate of issue:\n\nSeller:\n\nReyes and Sons\n62517 Archer Lane Apt. 872\nPhilipport, MN 27104\n\nTax Id: 909-90-9161\n\nIBAN: GB68XJXF92740762485025\n\nITEMS\n\nNo.\n\nAe\n\nDescription\n\nB397 Nintendo DSi console Red\nJapan NDS x\n\nNintendo 3DS Handheld Console\nPurple\n\nNintendo 64 Charcoal Grey\nConsole With Original Cables\ncontroller NFL game day\n\nNintendo Wii New Super Mario\nBros Console System Bundle\nGamecube Compatible\n\nPlayStation Vita Minecraft\nSpecial Edition Bundle Console\nSONY JPN import F/S\n\nSUMMARY\n\nTotal\n\nQty\n\n1,00\n\n1,00\n\n2,00\n\n4,00\n\n4,00\n\nVAT [%]\n\n10%\n\n12/23/2015\n\nUM\n\neacn\n\neacn\n\neacn\n\neacn\n\neacn\n\nClient:\n\nWeaver-Hughes\n\n0805 Garcia Well Suite 009\n\nNorth Richardmouth, WY 49376\n\nTax Id: 988-72-7408\n\nNet price\n\n6,99\n\n98,99\n\n85,00\n\n89,99\n\n266,00\n\nNet worth\n1 699,94\n\n$ 1699,94\n\nNet worth VAT [%]\n\n6,99\n\n98,99\n\n170,00\n\n359,96\n\n1 064,00\n\nVAT\n\n169,99\n\n$ 169,99\n\n10%\n\n10%\n\n10%\n\n10%\n\n10%\n\nGross\nworth\n7,69\n\n108,89\n\n187,00\n\n395,96\n\n1170,40\n\nGross worth\n\n1 869,93\n\n$ 1 869,93\n',
#   'key_values': {'Invoice no': '61382297',
#    'Tax Id': '988-72-7408',
#    'IBAN': 'GB68XJXF92740762485025'}},
#  {'image_path': 'C:\\Users\\Gouthum\\Downloads\\Project\\batch_1\\batch_1\\batch1_2\\batch1-0535.jpg',
#   'ocr_text': 'Invoice no: 93281048\n\nDate of issue:\n\nSeller:\n\nReilly, Hicks and Hughes\n0413 Joe Ford\nGoodwinchester, AZ 52058\n\nTax Id: 955-92-1246\n\nIBAN: GB81DFMJ63938748923911\n\nITEMS\n\nNo.\n\nDescription\n\nVintage Art from India Marble\nDinning Table Top Round\nHallway Table 50 Inches\n\n12" Marble Side Coffee Table\nTop Multi Stone Floral Inlay\nOccasional Decor W260\n\n7\'x4\' Buy Marble Dining Table\nWith Black Top Marquetry Inlay\nHallway Decor E944\n\nReal Madrid Inflatable Chair\n(SG16136)\n\nSUMMARY\n\nTotal\n\nQty\n\n3,00\n\n1,00\n\n2,00\n\n2,00\n\nVAT [%]\n\n10%\n\n11/27/2017\n\nUM\n\neacn\n\neacn\n\neacn\n\neacn\n\nClient:\n\nBenson, Medina and Hamilton\n46561 Charles Groves\nBlackmouth, ME 72341\n\nTax Id: 912-87-0223\n\nNet price\n\n3 000,00\n\n259,77\n\n14 721,08\n\n43,95\n\nNet worth\n\n38 789,83\n\n$ 38 789,83\n\nNet worth VAT [%]\n9 000,00 10%\n259,77 10%\n29 442,16 10%\n87,90 10%\n\nVAT\n\n3 878,98\n\n$ 3 878,98\n\nGross\nworth\n\n9 900,00\n\n285,75\n\n32 386,38\n\n96,69\n\nGross worth\n42 668,81\n\n$ 42 668,81\n',
#   'key_values': {'Invoice no': '93281048',
#    'Tax Id': '912-87-0223',
#    'IBAN': 'GB81DFMJ63938748923911'}},
#  {'image_path': 'C:\\Users\\Gouthum\\Downloads\\Project\\batch_1\\batch_1\\batch1_2\\batch1-0536.jpg',
#   'ocr_text': 'Invoice no: 11101593\n\nDate of issue: 05/18/2015\n\nSeller:\n\nHood, Ruiz and Williams\n648 Margaret Inlet Apt. 779\nNew Virginiafort, CO 92810\n\nTax Id: 902-85-7672\nIBAN: GB42BADT92735948077407\n\nITEMS\nNo. Description Qty UM\nils HP Elite 8300 Business USFF 5,00 each\n\nDesktop Computer i3 4GB\n250GB Windows 10\n\n2. Sentry Gaming Computer | 1,00 each\nRyzen 3 3200G | 16 GB Ram |\nBuild-to-Order\n\nSUMMARY\n\nVAT [%]\n10%\n\nTotal\n\nClient:\n\nCarter Ltd\n65534 Campbell Path Suite 163\nNorth Stacy, DC 67000\n\nTax Id: 932-94-8276\n\nNet price Net worth VAT [%]\n\n84,99 424,95 10%\n\n594,99 594,99 10%\nNet worth VAT\n1 019,94 101,99\n$1019,94 $ 101,99\n\nGross\nworth\n\n467,45\n\n654,49\n\nGross worth\n1 121,93\n\n$1121,93\n',
#   'key_values': {'Invoice no': '11101593',
#    'Date of issue': '05/18/2015',
#    'Tax Id': '932-94-8276',
#    'IBAN': 'GB42BADT92735948077407'}},
#  {'image_path': 'C:\\Users\\Gouthum\\Downloads\\Project\\batch_1\\batch_1\\batch1_2\\batch1-0537.jpg',
#   'ocr_text': 'Invoice no: 90670432\n\nDate of issue:\n\nSeller:\n\nKennedy PLC\n33259 David Courts\nPort Michael, VT 18813\n\nTax Id: 963-77-6871\n\n03/13/2018\n\nClient:\n\nStevens Inc\nUSCGC Williams\nFPO AP 05167\n\nTax Id: 906-75-9849\n\nIBAN: GB35VMQQ33475201075568\n\nITEMS\n\nNo. Description\n\n1. Luxury Bedroom Carpet Faux\nFur Area Rugs Shaggy for Floor\nReading Room Gray\n\nSUMMARY\n\nTotal\n\nQty UM\n\nNet price Net worth VAT [%] Gross\n\nworth\n\n5,00 each 14,46 72,30 10% 79,53\nVAT [%] Net worth VAT Gross worth\n10% 72,30 7,23 7/2), 5)\n\n$ 72,30 $ 7,23 $ 79,53\n',
#   'key_values': {'Invoice no': '90670432',
#    'Tax Id': '906-75-9849',
#    'IBAN': 'GB35VMQQ33475201075568'}},
#  {'image_path': 'C:\\Users\\Gouthum\\Downloads\\Project\\batch_1\\batch_1\\batch1_2\\batch1-0538.jpg',
#   'ocr_text': 'Invoice no: 93008460\n\nDate of issue:\n\nSeller:\n\nHuynh, Kim and Jacobs\n2132 Price Forest\nLeemouth, OK 21415\n\nTax Id: 985-72-3955\nIBAN: GB30IMHC92330290216388\n\nITEMS\nNo. Description Qty\n1. Gaming PC Desktop Computer 2,00\n\nHDMI RGB Intel i7 RTX 2060,\nHDD+SSD, Windows 10, Wifi\n\n2. Dell Precision Workstation 5,00\nComputer Intel Xeon Quad Core\n16GB 1TB Windows 10 Pro\n\n3: hp all in one desktop computer 5,00\ntouch screen\n\n4. HP All-in-One Computer 22” 3,00\n\nFull-HD Display Intel 2.90GHz\n4GB 1TB HD Win10 - TEAL\n\nSUMMARY\n\nVAT [%]\n10%\n\nTotal\n\n03/06/2015\n\nUM\n\neacl\n\neac\n\neac\n\neac\n\nh\n\nClient:\n\nDavis, Wilson and Hunt\n773 Freeman Prairie\nPort Julieville, MA 47703\n\nTax Id: 969-86-5535\n\nNet price Net worth VAT [%]\n999,50 1 999,00 10%\n139,00 695,00 10%\n205,00 1 025,00 10%\n449,99 1 349,97 10%\nNet worth VAT\n\n5 068,97 506,90\n\n$ 5 068,97 $ 506,90\n\nGross\nworth\n\n2 198,90\n\n764,50\n\n1 127,50\n\n1 484,97\n\nGross worth\n\n5 575,87\n\n$5 575,87\n',
#   'key_values': {'Invoice no': '93008460',
#    'Tax Id': '969-86-5535',
#    'IBAN': 'GB30IMHC92330290216388',
#    '3': 'hp all in one desktop computer 5,00'}},
#  {'image_path': 'C:\\Users\\Gouthum\\Downloads\\Project\\batch_1\\batch_1\\batch1_2\\batch1-0539.jpg',
#   'ocr_text': 'Invoice no: 11898657\n\nDate of issue:\n\nSeller:\n\nSmith-Elliott\n021 Parrish Trace Suite 648\nWest Kevin, MT 71835\n\nTax Id: 990-79-3361\nIBAN: GB45ACOZ95865781715902\n\nITEMS\nNo. Description Qty\n1. Lilly Pulitzer Lillywood California 1,00\n\n8 Shift Dress\n\n2. Vintage 80s All That Jazz Blue 5,00\nVelvet Dress Small/Medium\n\nBy NWT Modcloth Blue Floral 4,00\nFormal Full Length Maxi Dress\n\n4. Xhilaration Womens L Burgandy 2,00\nBoho Embroidered Festival Mini\nDress NEW\n\n5: Caslon Blue White Sleeveless 1,00\n\nBelted Ruffle Rayon Dress Sz L\n\n6. Free People Lace Dress One 2,00\nShoulder Size L\n\nSUMMARY\n\nVAT [%]\n10%\n\nTotal\n\n07/29/2020\n\nUM\n\neacn\n\neacn\n\neacn\n\neacn\n\neacn\n\neacn\n\nClient:\n\nEvans, Andrade\n\nand Williams\n\n680 Scott Corners\nWest Sarahmouth, GA 85183\n\nTax Id: 997-900-5621\n\nNet price\n\n76,00\n\n10,00\n\n65,00\n\n14,95\n\n4,99\n\n12,00\n\nNet worth\n444,89\n\n$ 444,89\n\nNet worth VAT [%]\n\n76,00\n\n50,00\n\n260,00\n\n29,90\n\n4,99\n\n24,00\n\nVAT\n44,49\n\n$ 44,49\n\n10%\n\n10%\n\n10%\n\n10%\n\n10%\n\n10%\n\nGross\n\nworth\n\n83,60\n\n55,00\n\n286,00\n\n32,89\n\n5,49\n\n26,40\n\nGross worth\n\n489,38\n\n$ 489,38\n',
#   'key_values': {'Invoice no': '11898657',
#    'Tax Id': '997-900-5621',
#    'IBAN': 'GB45ACOZ95865781715902',
#    '5': 'Caslon Blue White Sleeveless 1,00'}},
#  {'image_path': 'C:\\Users\\Gouthum\\Downloads\\Project\\batch_1\\batch_1\\batch1_2\\batch1-0540.jpg',
#   'ocr_text': 'Invoice no: 84991865\n\nDate of issue:\n\nSeller:\n\nCollins Ltd\n4958 Jordan Port\nMatthewchester, NE 08958\n\nTax Id: 970-92-1896\nIBAN: GBO9BZLP67123213143488\n\nITEMS\nNo. Description Qty\n1. Lilly Pulitzer XS Spike the Punch 2,00\nCassie Cotton Dress with\nQuarter Sleeves\nSUMMARY\nVAT [%]\n\n10%\n\nTotal\n\nUM\n\neach\n\n03/18/2012\n\nClient:\n\nSanchez-Bean\n82418 Michael Garden Apt. 873\nNew Cynthia, SD 25266\n\nTax Id: 969-94-4351\n\nNet price Net worth VAT [%]\n44,89 89,78 10%\nNet worth VAT\n89,78 8,98\n$ 89,78 $ 8,98\n\nGross\nworth\n\n98,76\n\nGross worth\n98,76\n\n$ 98,76\n',
#   'key_values': {'Invoice no': '84991865',
#    'Tax Id': '969-94-4351',
#    'IBAN': 'GBO9BZLP67123213143488'}},
#  {'image_path': 'C:\\Users\\Gouthum\\Downloads\\Project\\batch_1\\batch_1\\batch1_2\\batch1-0541.jpg',
# ...
#   'ocr_text': 'Invoice no: 11829549\n\nDate of issue: 05/13/2017\nSeller: Client:\nSmith-Myers\n\n123 Matthew Loaf\nNorth Jessica, WI 60501\n\nTax Id: 955-74-0303\nIBAN: GB42GRFE12828986459550\n\nITEMS\nNo. Description Qty UM\nils Whiskey Glass Mountain 1,00 each\nWooden Bottom Wine\nTransparent\n2. Outdoor Wine Glass Beer Holder 5,00 each\n\nTo Armrest With Attachments\nRed Wine Base _yoxq\n\n3: Waterford Elegance Chardonnay 4,00 each\nWine Glass, Pair - 40001097\nNew In Box\nSUMMARY\nVAT [%]\n10%\nTotal\n\nTapia, Robinson and Miller\n417 Christopher Brook Suite 968\nPort Robertmouth, IL 51885\n\nTax Id: 910-99-4402\n\nNet price\n\n19,48\n\n11,44\n\n19,98\n\nNet worth\n156,60\n\n$ 156,60\n\nNet worth VAT [%] Gross\nworth\n\n19,48 10% 21,43\n57,20 10% 62,92\n79,92 10% 87,91\nVAT Gross worth\n\n15,66 172,26\n\n$ 15,66 $ 172,26\n',
#   'key_values': {'Invoice no': '11829549',
#    'Date of issue': '05/13/2017',
#    'Seller': 'Client:',
#    'Tax Id': '910-99-4402',
#    'IBAN': 'GB42GRFE12828986459550',
#    '3': 'Waterford Elegance Chardonnay 4,00 each'}},
#  {'image_path': 'C:\\Users\\Gouthum\\Downloads\\Project\\batch_1\\batch_1\\batch1_1\\batch1-0489.jpg',
#   'ocr_text': 'Invoice no: 37451664\n\nDate of issue:\n\nSeller:\n\nScott-Howard\n45558 Davis Mountains\nEast Zacharyville, |A 99376\n\nTax Id: 997-75-1112\nIBAN: GB31KIAV64209378666800\n\nITEMS\nNo. Description Qty\nils PUMA Boys Youth Universal FG 2,00\n\nJr Soccer Cleats 2.5 White High\nRed NEW Futbol\n\n2. Lotto Youth Boys Fuerzapura 5,00\nL500 Jr Soccer Cleats Size 2.5\nWhite Blue M6147 2.5Y\n\nSUMMARY\n\nVAT [%]\n10%\n\nTotal\n\nUM\n\neach\n\neach\n\n06/11/2020\n\nClient:\n\nWilliams, Schneider and Gomez\n588 Morales Rapids\n\nEast Katherineton, MT 53545\n\nTax Id: 916-94-8739\n\nNet price Net worth VAT [%]\n\n19,99 39,98 10%\n19,99 99,95 10%\nNet worth VAT\n139,93 13,99\n$ 139,93 $ 13,99\n\nGross\nworth\n\n43,98\n\n109,94\n\nGross worth\n153,92\n\n$ 153,92\n',
#   'key_values': {'Invoice no': '37451664',
#    'Tax Id': '916-94-8739',
#    'IBAN': 'GB31KIAV64209378666800'}},
#  {'image_path': 'C:\\Users\\Gouthum\\Downloads\\Project\\batch_1\\batch_1\\batch1_1\\batch1-0490.jpg',
#   'ocr_text': 'Invoice no: 32135544\n\nDate of issue:\n\nSeller:\n\nReed and Sons\nUnit 5010 Box 0461\nDPO AA 27717\n\nTax Id: 912-95-0493\nIBAN: GB21VGUQ93040788957754\n\nITEMS\nNo. Description Qty\nils Wine Bottle Storage 6 Slots 4,00\n\nModern Countertop Metal Rack\nKitchen Bar Organizer\n\n2. Anthropologie Gold Elegant 4,00\nSwan Decorative Metal Bottle\nStopper Wine Saver\n\noo mDesign Metal Wine Rack 4,00\nStorage Organizer, 12 Bottles -\nDark Gray\n\n4. Tiffany and Co Pair 2 Stemless 2,00\n\nWine Champagne Glasses\nOriginal Stickers NO BOX\n\na Outdoor Wine Glass Beer Holder 3,00\nTo Armrest With Attachments\nRed Wine Base _yoxq\n\n6. Hardwood Wine Rack 12 Bottles 3,00\nVery Nice Eonophiles Delight\n\nSUMMARY\n\nVAT [%]\n10%\n\nTotal\n\n08/16/2014\n\nUM\n\neacn\n\neacn\n\neacn\n\neacn\n\neacn\n\neacn\n\nClient:\n\nLucas-Barnett\nUSNS Scott\nFPO AA 73490\n\nTax Id: 997-85-1616\n\nNet price\n\n30,59\n\n19,98\n\n44,99\n\n74,99\n\n11,44\n\n20,00\n\nNet worth\n626,54\n\n$ 626,54\n\nNet worth\n\n122,36\n\n79,92\n\n179,96\n\n149,98\n\n34,32\n\n60,00\n\nVAT [%]\n\n10%\n\n10%\n\n10%\n\n10%\n\n10%\n\n10%\n\nVAT\n\n62,65\n\n$ 62,65\n\nGross\nworth\n\n134,60\n\n87,91\n\n197,96\n\n164,98\n\n37,75\n\n66,00\n\nGross worth\n\n689,19\n\n$ 689,19\n',
#   'key_values': {'Invoice no': '32135544',
#    'Tax Id': '997-85-1616',
#    'IBAN': 'GB21VGUQ93040788957754'}},
#  {'image_path': 'C:\\Users\\Gouthum\\Downloads\\Project\\batch_1\\batch_1\\batch1_1\\batch1-0491.jpg',
#   'ocr_text': 'Invoice no: 10372826\n\nDate of issue: 05/15/2019\nSeller: Client:\nGraham, Briggs and Anderson Moore Group\n2056 Martin Extensions 89000 Christopher Brook\nPort Christopherton, VA 87978 Port Richardmouth, CA 87376\nTax Id: 975-98-4861 Tax Id: 978-80-2701\nIBAN: GB56SDLA43798626107179\nITEMS\nNo. Description Qty UM Net price Net worth VAT [%] Gross\nworth\n1. NEW TOMMY HILFIGER RED 5,00 each 34,50 172,50 10% 189,75\nWHITE BLUE #5 COLOR BLOCK\nBEACH SANDALS BOYS KIDS 8/9\n2. 10" Cuphead Game Soft Plush 1,00 each 26,99 26,99 10% 29,69\nDoll Cuphead Mugman Mecup\nBrocup kids Gift US Stock\noo 2 Pair-Wonder Nation Childrens 4,00 each 12,99 51,96 10% 57,16\nTucker Boots NEW Size 10 Black\nEasy on/off\nSUMMARY\nVAT [%] Net worth VAT Gross worth\n10% 251,45 25,15 276,60\n\nTotal $ 251,45 $ 25,15 $ 276,60\n',
#   'key_values': {'Invoice no': '10372826',
#    'Date of issue': '05/15/2019',
#    'Seller': 'Client:',
#    'Tax Id': '975-98-4861 Tax Id: 978-80-2701',
#    'IBAN': 'GB56SDLA43798626107179'}},
#  {'image_path': 'C:\\Users\\Gouthum\\Downloads\\Project\\batch_1\\batch_1\\batch1_1\\batch1-0492.jpg',
#   'ocr_text': 'Invoice no: 45175273\n\nDate of issue: 03/30/2020\n\nSeller: Client:\n\nThomas and Sons Smith, Fox and Castaneda\n8762 Matthew Overpass Apt. 126 1827 Byrd Islands\nLewisbury, NC 68186 Martinezstad, DE 49001\nTax Id: 901-73-3277 Tax Id: 920-80-9993\n\nIBAN: GB100BAM24928408675285\n\nITEMS\nNo. Description Qty UM Net price Net worth VAT [%] Gross\nworth\nils Garden Flower Carpet Quilted 5,00 each 45,50 227,50 10% 250,25\nBedroom Floor Princess Tapis\nLace Rug Carpets\n2. Rectangle Faux Fur Sheepskin 2,00 each 29,95 59,90 10% 65,89\nRug Fluffy Area Rug Floor\nCarpets Dark Pink\noo Color Skull Series Small Large 5,00 each 36,30 181,50 10% 199,65\nLong Floor Carpet Area Rugs\nVarious Size Soft Rug\n4. Unicorn Series Small Large Long 5,00 each 46,50 232,50 10% 255,75\nFloor Carpet Area Rugs Various\nSize Soft Rug\nSUMMARY\nVAT [%] Net worth VAT Gross worth\n10% 701,40 70,14 771,54\n\nTotal $ 701,40 $ 70,14 $ 771,54\n',
#   'key_values': {'Invoice no': '45175273',
#    'Date of issue': '03/30/2020',
#    'Seller': 'Client:',
#    'Tax Id': '901-73-3277 Tax Id: 920-80-9993',
#    'IBAN': 'GB100BAM24928408675285'}},
#  {'image_path': 'C:\\Users\\Gouthum\\Downloads\\Project\\batch_1\\batch_1\\batch1_1\\batch1-0493.jpg',
#   'ocr_text': 'Invoice no: 22529030\n\nDate of issue:\n\nSeller:\n\nHogan, Adkins and Rogers\n2917 Young Cape\nSouth James, PA 13959\n\nTax Id: 960-87-3385\nIBAN: GB480ZWQ30024053292452\n\nITEMS\nNo. Description Qty\nils PS2 Slim Console System 4,00\nSCPH-77000 PINK Playstation 2\nTested\n2. Nintendo Wii Console With 5,00\n\nCables And Accessories And\nNew Super Mario Bros Disc!\n\noo Nintendo Switch Gaming 1,00\nConsole W/ Neon Blue & Red\nControllers,Carry Case,Cable\n\n4. Sony PlayStation Gray PS1 2,00\nConsole! CONSOLE ONLY!\nTested Working!\n\na B408 Nintendo Gameboy Color 4,00\nconsole Ice Blue Toysrus\nLimited Japan GBC REAR x\n\n6. Nintendo DS Lite Onyx Black 1,00\nSystem Console & 6 games\nMario Charger Stylus\n\nEe Nintendo 64 N64 Game Console 3,00\nSystem + Controller Cords\nWORKING\nSUMMARY\nVAT [%]\n10%\nTotal\n\n02/02/2018\n\nUM\n\neacn\n\neacn\n\neacn\n\neacn\n\neacn\n\neacn\n\neacn\n\nClient:\n\nJohnson LLC\n\n3913 Frank Inlet\nPort Kathy, GA 28821\n\nTax Id: 938-83-8149\n\nNet price\n\n252,00\n\n29,99\n\n300,00\n\n21,99\n\n74,99\n\n69,99\n\n100,00\n\nNet worth\n2 171,88\n\n$2171,88\n\nNet worth\n\n1 008,00\n\n149,95\n\n300,00\n\n43,98\n\n299,96\n\n69,99\n\n300,00\n\nVAT [%]\n\n10%\n\n10%\n\n10%\n\n10%\n\n10%\n\n10%\n\n10%\n\nVAT\n\n217,19\n\n$ 217,19\n\nGross\nworth\n\n1 108,80\n\n164,94\n\n330,00\n\n48,38\n\n329,96\n\n76,99\n\n330,00\n\nGross worth\n\n2 389,07\n\n$ 2 389,07\n',
#   'key_values': {'Invoice no': '22529030',
#    'Tax Id': '938-83-8149',
#    'IBAN': 'GB480ZWQ30024053292452'}},
#  {'image_path': 'C:\\Users\\Gouthum\\Downloads\\Project\\batch_1\\batch_1\\batch1_1\\batch1-0494.jpg',
#   'ocr_text': 'Invoice no: 84652373\n\nDate of issue:\n\nSeller:\n\nNguyen-Roach\n247 David Highway\nLake John, WV 84178\n\nTax Id: 991-72-5826\nIBAN: GB911YX005542456978150\n\nITEMS\n\nNo. Description\n\n1. Stemware Rack Display Kitchen\nWine Glass Holder Bottle\nCarbon Steel Free Punch\n\n2. VTG (4) 7 Ounce Since 1852\nMilk Bottle Wine Carafe Juice\nGlass with Cork Lids\n\n3: Vintage Crystal Red Wine\nGlasses NOS West Germany\n1983 6 10 ounce elegant stems\n\n4. 3 Ikea Stainless Steel 4-bottle\nWine Rack 300.557.60 - great\ncondition gift it!\n\nS: Lolita "Wine Bouquet" Hand\n\nPainted and Decorated Wine\nGlass NIB\n\nSUMMARY\n\nTotal\n\nQty\n\n1,00\n\n1,00\n\n1,00\n\n4,00\n\n1,00\n\nVAT [%]\n\n10%\n\n02/23/2021\n\nUM\n\neacn\n\neacn\n\neacn\n\neacn\n\neacn\n\nClient:\n\nClark-Foster\n77477 Troy Cliff Apt. 853\nWashingtonbury, MS 78346\n\nTax Id: 937-70-8530\n\nNet price Net worth VAT [%]\n\n42,32 42,32\n14,00 14,00\n35,45 35,45\n25,00 100,00\n20,00 20,00\nNet worth VAT\n211,77 21,18\n\n$ 211,77 $ 21,18\n\n10%\n\n10%\n\n10%\n\n10%\n\n10%\n\nGross\nworth\n\n46,55\n\n15,40\n\n39,00\n\n110,00\n\n22,00\n\nGross worth\n\n232,95\n\n$ 232,95\n',
#   'key_values': {'Invoice no': '84652373',
#    'Tax Id': '937-70-8530',
#    'IBAN': 'GB911YX005542456978150',
#    '3': 'Vintage Crystal Red Wine',
#    'S': 'Lolita "Wine Bouquet" Hand'}},
#  {'image_path': 'C:\\Users\\Gouthum\\Downloads\\Project\\batch_1\\batch_1\\batch1_1\\batch1-0495.jpg',
#   'ocr_text': 'Invoice no: 45302561\n\nDate of issue:\n\nSeller:\n\nWright-Hall\n3641 Sawyer Ridge Suite 572\nRoberttown, MN 62250\n\nTax Id: 953-90-8379\nIBAN: GB51GQGK03722855880684\n\nITEMS\nNo. Description Qty\nils 60 Inches Marble Dinning Table 2,00\n\nTop Inlay Work Lawn Table with\nMulti Color Stones\n\n2. 7\'x4\' Marble Living Room Center 4,00\nTable Top Yellowish Sea Shell\nInlay Decor E863A\n\noo 36 Inches Marble Dinning Table 5,00\nTop Hand Inlaid Office Table\nwith Multi Gemstones\n\n4. 5\'x2\' Marble White Center Table 4,00\nTop With 18" Tall Stand\nPauashell Inlay Art Deco\n\na Yellow Marble Royal Look 3,00\nMarble Inlay Table Top\nHandmade Dinning Table 60\nInches\n\n6. 26"x26" Black Marble Round 3,00\nTop Table Grapes Art Inlay\nFloral Christmas Gift Deco\n\n7. Carnelian Stone Inlay Art Marble 4,00\n\nCoffee Table Top White Corner\nTable 14 Inches\n\nSUMMARY\n\nVAT [%]\n10%\n\nTotal\n\n11/25/2015\n\nUM\n\neacn\n\neacn\n\neacn\n\neacn\n\neacn\n\neacn\n\neacn\n\nClient:\nFinley PLC\n\n71106 Jessica Rapid Suite 235\nNew Margaretburgh, NE 02077\n\nTax Id: 950-70-5811\n\nNet price\n\n5 756,00\n\n16 887,62\n\n1 451,25\n\n3 888,89\n\n6 076,00\n\n1 288,00\n\n225125;\n\nNet worth\n124 867,29\n\n$ 124 867,29\n\nNet worth VAT [%]\n\n11 512,00 10%\n67 550,48 10%\n7 256,25 10%\n15 555,56 10%\n18 228,00 10%\n3 864,00 10%\n901,00 10%\n\nVAT\n\n12 486,73\n\n$ 12 486,73\n\nGross\nworth\n\n12 663,20\n\n74 305,53\n\n7 981,87\n\n17 111,12\n\n20 050,80\n\n4 250,40\n\n991,10\n\nGross worth\n\n137 354,02\n\n$ 137 354,02\n',
#   'key_values': {'Invoice no': '45302561',
#    'Tax Id': '950-70-5811',
#    'IBAN': 'GB51GQGK03722855880684'}},
#  {'image_path': 'C:\\Users\\Gouthum\\Downloads\\Project\\batch_1\\batch_1\\batch1_1\\batch1-0496.jpg',
#   'ocr_text': 'Invoice no: 75399670\n\nDate of issue:\n\nSeller:\n\nRoberts-Larson\n34377 Deborah Cliffs\nPort Tonybury, ME 29427\n\nTax Id: 997-91-5844\nIBAN: GB740ALW12437007562033\n\nITEMS\nNo. Description Qty\nils Rebecca Minkoff Black Polyester 5,00\nFringe and Lambskin Dress Sz\n12\n2. Socialite White Black Striped A 4,00\n\nLine Dress With Pockets Large\n\na womens sparkle dress size 2X 4,00\nHoliday Party RED metallic\n\n4. 1920s Flapper Gatsby Cocktail 2,00\nDress Chiffon Wedding Party\nEvening Formal Dresses\n\na New Wallis black floral midi 2,00\ndress sleeveles, size UK 12\n\nSUMMARY\n\nVAT [%]\n10%\n\nTotal\n\n03/25/2012\n\nUM\n\neacn\n\neacn\n\neacn\n\neacn\n\neacn\n\nClient:\n\nHernandez, Murphy and Saunders\n99581 Raymond Forge Apt. 828\nSouth Brendan, CA 25172\n\nTax Id: 998-79-3566\n\nNet price Net worth VAT [%]\n\n9,99 49,95 10%\n10,00 40,00 10%\n9,99 39,96 10%\n8,99 17,98 10%\n38,00 76,00 10%\nNet worth VAT\n\n223,89 22,39\n\n$ 223,89 $ 22,39\n\nGross\nworth\n\n54,95\n\n44,00\n\n43,96\n\n19,78\n\n83,60\n\nGross worth\n\n246,28\n\n$ 246,28\n',
#   'key_values': {'Invoice no': '75399670',
#    'Tax Id': '998-79-3566',
#    'IBAN': 'GB740ALW12437007562033'}},
#  {'image_path': 'C:\\Users\\Gouthum\\Downloads\\Project\\batch_1\\batch_1\\batch1_1\\batch1-0497.jpg',
#   'ocr_text': "Invoice no: 73285932\n\nDate of issue: 07/25/2017\n\nSeller: Client:\n\nMerritt, Williams and Young Olson, Cisneros and Moore\n6801 Frank Run 80943 Beck Divide\n\nWest Mary, IN 06055 Wadeport, IA 90419\n\nTax Id: 963-86-7453 Tax Id: 901-73-0142\n\nIBAN: GB16HUWQ31434229260013\n\nITEMS\nNo. Description Qty UM Net price Net worth VAT [%] Gross\nworth\nils Bcbgeneration Black Sleeveless 2,00 each 2,99 5,98 10% 6,58\nLace Back Cut Out Dress Sz 2\n2. 2pcs baby boys clothes cotton 5,00 each 10,99 54,95 10% 60,45\nhoodied top+pants baby boys\nOutfits gentleman\n3. NWT $1200 J.Crew Silk Chiffon 1,00 each 295,00 295,00 10% 324,50\nIvory Wedding Dress with\nBeading\n4. Shein Blue And White Striped 5,00 each 8,00 40,00 10% 44,00\nWrap Dress\na Guess Dress Size 6 2,00 each 20,00 40,00 10% 44,00\n6. CLIFFORD & WILLS BLACK 5,00 each 5,99 29,95 10% 32,95\nNET/MESH OVER TAUPE LONG\nDRESS SIZE 4\nEe Matilda Jane Women's Light 3,00 each 50,00 150,00 10% 165,00\nRising High Low Green Floral\nDress Size L Pockets\nSUMMARY\nVAT [%] Net worth VAT Gross worth\n10% 615,88 61,59 677,47\n\nTotal $ 615,88 $ 61,59 $ 677,47\n",
#   'key_values': {'Invoice no': '73285932',
#    'Date of issue': '07/25/2017',
#    'Seller': 'Client:',
#    'Tax Id': '963-86-7453 Tax Id: 901-73-0142',
#    'IBAN': 'GB16HUWQ31434229260013'}},
#  {'image_path': 'C:\\Users\\Gouthum\\Downloads\\Project\\batch_1\\batch_1\\batch1_1\\batch1-0498.jpg',
#   'ocr_text': 'Invoice no: 33310882\n\nDate of issue:\n\nSeller:\n\nBrown Group\n2672 Rodriguez Parks\nLindseyfort, TN 83907\n\nTax Id: 989-79-2897\nIBAN: GB92THKG55938218455949\n\nITEMS\nNo. Description Qty\n1. NEC PC Engine INTERFACE UNIT 5,00\n\nIFU-30 CD ROM Console\nPI-TGOO1 Tested Japan\n\n2. Original xbox console (Works 3,00\nGreat, Tested)\n\n3: Super Nintendo SNES System 4,00\nConsole SNS-001 with 2\nControllers Cleaned And Tested\n\n4. Nintendo BLUE Wii System 4,00\nGame Console Complete with 2\nMotion Remotes Tested Work\n\n5: Magnavox Odyssey 2 2,00\n\nMicroprocessor Console System\nw Joy Sticks & 15 Games - 1978\n\nSUMMARY\n\nVAT [%]\n10%\n\nTotal\n\n01/23/2020\n\nUM\n\neacn\n\neacn\n\neacn\n\neacn\n\neacn\n\nClient:\n\nDavis, Hogan and Hardin\n456 Snyder Crossroad\nNew Erikmouth, IA 43321\n\nTax Id: 917-78-6794\n\nNet price Net worth VAT [%]\n159,99 799,95 10%\n38,00 114,00 10%\n149,99 599,96 10%\n99,98 399,92 10%\n155,00 310,00 10%\n\nNet worth VAT\n\n2 223,83 222,38\n\n$ 2 223,83 $ 222,38\n\nGross\nworth\n\n879,95\n\n125,40\n\n659,96\n\n439,91\n\n341,00\n\nGross worth\n2 446,21\n\n$ 2 446,21\n',
#   'key_values': {'Invoice no': '33310882',
#    'Tax Id': '917-78-6794',
#    'IBAN': 'GB92THKG55938218455949',
#    '3': 'Super Nintendo SNES System 4,00',
#    '5': 'Magnavox Odyssey 2 2,00'}},
#  {'image_path': 'C:\\Users\\Gouthum\\Downloads\\Project\\batch_1\\batch_1\\batch1_1\\batch1-0499.jpg',
#   'ocr_text': 'Invoice no: 40108666\n\nDate of issue: 02/07/2020\n\nSeller: Client:\n\nBailey, Murray and Lewis Hester Inc\n\n33771 Powell Pike Suite 054 4000 Tonya Rapid Suite 963\nEast Lisastad, RI 21938 South Marissaport, MN 39537\nTax Id: 993-75-3149 Tax Id: 998-98-6887\n\nIBAN: GB80MTNI52501633185191\n\nITEMS\nNo. Description Qty UM Net price Net worth VAT [%] Gross\nworth\nils Microsoft Xbox One 1 - 500 GB 1,00 each 175,00 175,00 10% 192,50\nConsole - Black w/ Controller &\nPower Supply GOOD\n2. Nintendo DSOriginal NTR-001 3,00 each 0,99 2,97 10% 3,27\nConsole - Camouflage - Tested\nWorks\noo Nintendo 2DS Console Blue 5,00 each 54,99 274,95 10% 302,45\nJapan model Combine Shipping\navailable 2\nSUMMARY\nVAT [%] Net worth VAT Gross worth\n10% 452,92 45,29 498,21\n\nTotal $ 452,92 $ 45,29 $ 498,21\n',
#   'key_values': {'Invoice no': '40108666',
#    'Date of issue': '02/07/2020',
#    'Seller': 'Client:',
#    'Tax Id': '993-75-3149 Tax Id: 998-98-6887',
#    'IBAN': 'GB80MTNI52501633185191'}},
#  ...]

# %% [markdown]
# # NLP

# %%
pip install nltk
# Out:
# Requirement already satisfied: nltk in c:\users\gouthum\.conda\envs\myenv\lib\site-packages (3.9.1)
# Requirement already satisfied: click in c:\users\gouthum\.conda\envs\myenv\lib\site-packages (from nltk) (8.1.8)
# Requirement already satisfied: joblib in c:\users\gouthum\.conda\envs\myenv\lib\site-packages (from nltk) (1.5.1)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\gouthum\.conda\envs\myenv\lib\site-packages (from nltk) (2024.11.6)
# Requirement already satisfied: tqdm in c:\users\gouthum\.conda\envs\myenv\lib\site-packages (from nltk) (4.67.1)
# Requirement already satisfied: colorama in c:\users\gouthum\.conda\envs\myenv\lib\site-packages (from click->nltk) (0.4.6)
# Note: you may need to restart the kernel to use updated packages.

# %%
import nltk
nltk.download('punkt')
nltk.download('stopwords')
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package punkt to C:\Users\Gouthum/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Gouthum/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Gouthum/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %% [markdown]
# # STEP 1: Load All CSVs

# %% [markdown]
# #### load and combine them into a single DataFrame

# %%
import pandas as pd
import os

# Folder path
folder_path = r'C:\Users\Gouthum\Downloads\Project\batch_1\batch_1'

# File names
csv_files = ['batch1_1.csv', 'batch1_2.csv', 'batch1_3.csv']  

# Load and concatenate all CSVs
dfs = []
for file in csv_files:
    full_path = os.path.join(folder_path, file)
    df = pd.read_csv(full_path)
    dfs.append(df)

# Combine into one DataFrame
full_df = pd.concat(dfs, ignore_index=True)
print("✅ Combined CSV shape:", full_df.shape)

# Save the combined DataFrame
output_path = os.path.join(folder_path, 'combined_batch1.csv')
full_df.to_csv(output_path, index=False, encoding='utf-8-sig')
print(f"✅ Combined CSV saved to: {output_path}")
# Out:
# ✅ Combined CSV shape: (1414, 3)
# ✅ Combined CSV saved to: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\combined_batch1.csv

# %%
import pandas as pd
import os

# Folder path
folder_path = r'C:\Users\Gouthum\Downloads\Project\batch_1\batch_1'

# File names
csv_files = ['batch1_1.csv', 'batch1_2.csv', 'batch1_3.csv']  # Update if different

# Load and concatenate all CSVs
dfs = []
for file in csv_files:
    full_path = os.path.join(folder_path, file)
    df = pd.read_csv(full_path)
    dfs.append(df)

# Combine into one DataFrame
full_df = pd.concat(dfs, ignore_index=True)
print("✅ Combined CSV shape:", full_df.shape)

# Save combined CSV
csv_output_path = os.path.join(folder_path, 'combined_batch1.csv')
full_df.to_csv(csv_output_path, index=False, encoding='utf-8-sig')
print(f"✅ CSV saved to: {csv_output_path}")

# Save as JSON
json_output_path = os.path.join(folder_path, 'combined_batch1.json')
full_df.to_json(json_output_path, orient='records', indent=4, force_ascii=False)
print(f"✅ JSON saved to: {json_output_path}")
# Out:
# ✅ Combined CSV shape: (1414, 3)
# ✅ CSV saved to: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\combined_batch1.csv
# ✅ JSON saved to: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\combined_batch1.json

# %% [markdown]
# # STEP 2: Rename Columns (if needed)

# %%
# Let's rename for consistency
full_df.columns = ['file_name', 'json_data', 'ocr_text']

# %%
full_df.columns
# Out:
# Index(['file_name', 'json_data', 'ocr_text'], dtype='object')

# %%
import pandas as pd
import os

# Folder path
folder_path = r'C:\Users\Gouthum\Downloads\Project\batch_1\batch_1'

# File names
csv_files = ['batch1_1.csv', 'batch1_2.csv', 'batch1_3.csv']  # Update if different

# Load and concatenate all CSVs
dfs = []
for file in csv_files:
    full_path = os.path.join(folder_path, file)
    df = pd.read_csv(full_path)
    dfs.append(df)

# Combine into one DataFrame
full_df = pd.concat(dfs, ignore_index=True)
print("✅ Combined CSV shape:", full_df.shape)

# ✅ Rename columns
full_df.rename(columns={
    'File Name': 'file_name',
    'Json Data': 'json_data',
    'OCRed Text': 'ocr_text'
}, inplace=True)

# ✅ Save as CSV
csv_output_path = os.path.join(folder_path, 'combined_batch1.csv')
full_df.to_csv(csv_output_path, index=False, encoding='utf-8-sig')
print(f"✅ CSV saved to: {csv_output_path}")

# ✅ Save as JSON
json_output_path = os.path.join(folder_path, 'combined_batch1.json')
full_df.to_json(json_output_path, orient='records', indent=4, force_ascii=False)
print(f"✅ JSON saved to: {json_output_path}")
# Out:
# ✅ Combined CSV shape: (1414, 3)
# ✅ CSV saved to: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\combined_batch1.csv
# ✅ JSON saved to: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\combined_batch1.json

# %%
print(full_df.columns.tolist())
# Out:
# ['File Name', 'Json Data', 'OCRed Text']

# %%
import pandas as pd
import os

# Base folder path
base_path = r'C:\Users\Gouthum\Downloads\Project\batch_1\batch_1'

# List of CSV files to combine
csv_files = ['batch1_1.csv', 'batch1_2.csv', 'batch1_3.csv']

# Load and concatenate all CSVs
dfs = []
for file in csv_files:
    full_path = os.path.join(base_path, file)
    df = pd.read_csv(full_path)
    dfs.append(df)

# Combine into one DataFrame
full_df = pd.concat(dfs, ignore_index=True)
print("✅ Combined CSV shape:", full_df.shape)

# ✅ Rename columns for NLP readiness
full_df.rename(columns={
    'File Name': 'file_name',
    'Json Data': 'json_data',
    'OCRed Text': 'ocr_text'
}, inplace=True)

# ✅ Preprocessing output folder
preprocess_folder = os.path.join(base_path, 'pre_process')
os.makedirs(preprocess_folder, exist_ok=True)

# ✅ Save as CSV
csv_output_path = os.path.join(preprocess_folder, 'combined_batch1.csv')
full_df.to_csv(csv_output_path, index=False, encoding='utf-8-sig')
print(f"✅ CSV saved to: {csv_output_path}")

# ✅ Save as JSON
json_output_path = os.path.join(preprocess_folder, 'combined_batch1.json')
full_df.to_json(json_output_path, orient='records', indent=4, force_ascii=False)
print(f"✅ JSON saved to: {json_output_path}")
# Out:
# ✅ Combined CSV shape: (1414, 3)
# ✅ CSV saved to: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\pre_process\combined_batch1.csv
# ✅ JSON saved to: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\pre_process\combined_batch1.json

# %%
print(full_df.columns.tolist())
# Out:
# ['file_name', 'json_data', 'ocr_text']

# %%
preprocess_folder = os.path.join(base_path, 'pre_process')

# %%
preprocess_folder
# Out:
# 'C:\\Users\\Gouthum\\Downloads\\Project\\batch_1\\batch_1\\pre_process'

# %% [markdown]
# # STEP 3: Preprocess OCR Text

# %% [markdown]
# ##### Clean whitespace, remove \n, etc.

# %%
import re

def clean_text(text):
    if pd.isna(text):
        return ''
    text = text.replace('\n', ' ').replace('\r', '')
    text = re.sub(r'\s{2,}', ' ', text)  # collapse extra spaces
    return text.strip()

full_df['cleaned_text'] = full_df['ocr_text'].apply(clean_text)

# %%
full_df['cleaned_text']
# Out:
# 0       Invoice no: 84652373 Date of issue: 02/23/2021...
# 1       Invoice no: 37451664 Date of issue: 06/11/2020...
# 2       Invoice no: 40108666 Date of issue: 02/07/2020...
# 3       Invoice no: 73285932 Date of issue: 07/25/2017...
# 4       Invoice no: 15288019 Date of issue: 09/07/2014...
#                               ...
# 1409    Invoice no: 87519797 Date of issue: 05/13/2013...
# 1410    Invoice no: 94223548 Date of issue: 11/19/2012...
# 1411    Invoice no: 59612541 Date of issue: 08/24/2016...
# 1412    Invoice no: 34630909 Date of issue: 09/14/2011...
# 1413    Invoice no: 14287592 Date of issue: 03/05/2021...
# Name: cleaned_text, Length: 1414, dtype: object

# %% [markdown]
# # STEP 4: OCR Cleaning

# %%
import pandas as pd
import re
import os

# Path to the existing combined CSV
csv_path = r"C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\preprocessing\combined_batch1.csv"
df = pd.read_csv(csv_path)

# Cleaning function
def clean_ocr_text(text):
    if pd.isna(text):
        return ""
    text = text.lower()                                  # lowercase
    text = re.sub(r'[^\w\s/:\-.]', '', text)             # keep only words, spaces, /, :, -, .
    text = re.sub(r'\s+', ' ', text).strip()             # remove extra spaces
    return text

# Apply cleaning
df['clean_text'] = df['ocr_text'].apply(clean_ocr_text)

# Save to new CSV
output_path = r"C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\preprocessing\combined_batch1_cleaned.csv"
df.to_csv(output_path, index=False, encoding='utf-8-sig')

print(f"✅ Cleaned CSV saved to: {output_path}")
print(f"✅ New column added: 'clean_text'")
print(f"✅ Final shape: {df.shape}")
# Out:
# ✅ Cleaned CSV saved to: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\preprocessing\combined_batch1_cleaned.csv
# ✅ New column added: 'clean_text'
# ✅ Final shape: (1414, 4)

# %%
full_df['ocr_text'] = full_df['ocr_text'].apply(clean_ocr_text)

# %%
full_df['ocr_text']
# Out:
# 0       invoice no: 84652373 date of issue: 02/23/2021...
# 1       invoice no: 37451664 date of issue: 06/11/2020...
# 2       invoice no: 40108666 date of issue: 02/07/2020...
# 3       invoice no: 73285932 date of issue: 07/25/2017...
# 4       invoice no: 15288019 date of issue: 09/07/2014...
#                               ...
# 1409    invoice no: 87519797 date of issue: 05/13/2013...
# 1410    invoice no: 94223548 date of issue: 11/19/2012...
# 1411    invoice no: 59612541 date of issue: 08/24/2016...
# 1412    invoice no: 34630909 date of issue: 09/14/2011...
# 1413    invoice no: 14287592 date of issue: 03/05/2021...
# Name: ocr_text, Length: 1414, dtype: object

# %%
Extracted Fields:

Invoice Number: 69721323
Invoice Date: 05/07/2019
Seller Info:
  Name: Murray-Eaton
  Address: 773 Joseph Plains West Nicoleville, AZ 46136
  Tax ID: 936-71-8228
Client Info:
  Name: Cuevas, Reid and Hurst
  Address: 98071 Daniel Heights Careyside, MS 59400
  Tax ID: 949-88-4885
IBAN: GB22XZGA27411153163644

# %%
import os
import re
import json
from PIL import Image
import pytesseract

# Set your Tesseract executable path here (update if different)
pytesseract.pytesseract.tesseract_cmd = r'C:\Program Files\Tesseract-OCR\tesseract.exe'

def extract_invoice_fields(text):
    text = text.replace('\r', '\n').replace('\n\n', '\n')

    invoice_number_match = re.search(r"Invoice (?:no|number)[:\s]*([\w\d\-]+)", text, re.IGNORECASE)
    invoice_number = invoice_number_match.group(1).strip() if invoice_number_match else None

    invoice_date_match = re.search(r"Date of issue[:\s]*([\d/.-]+)", text, re.IGNORECASE)
    invoice_date = invoice_date_match.group(1).strip() if invoice_date_match else None

    iban_match = re.search(r"IBAN[:\s]*([A-Z0-9]+)", text, re.IGNORECASE)
    iban = iban_match.group(1).strip() if iban_match else None

    seller_match = re.search(r"Seller:\s*(.*?)\n(?:Client:|Tax Id:|$)", text, re.DOTALL | re.IGNORECASE)
    seller_text = seller_match.group(1).strip() if seller_match else ''

    seller_name = None
    seller_address = None
    seller_taxid = None
    if seller_text:
        lines = seller_text.split('\n')
        if len(lines) >= 1:
            seller_name = lines[0].strip()
        if len(lines) >= 2:
            seller_address = lines[1].strip()
        taxid_match = re.search(r"Tax Id[:\s]*([\d\-]+)", seller_text, re.IGNORECASE)
        seller_taxid = taxid_match.group(1).strip() if taxid_match else None

    client_match = re.search(r"Client:\s*(.*?)\n(?:Tax Id:|$)", text, re.DOTALL | re.IGNORECASE)
    client_text = client_match.group(1).strip() if client_match else ''

    client_name = None
    client_address = None
    client_taxid = None
    if client_text:
        lines = client_text.split('\n')
        if len(lines) >= 1:
            client_name = lines[0].strip()
        if len(lines) >= 2:
            client_address = lines[1].strip()
        taxid_match = re.search(r"Tax Id[:\s]*([\d\-]+)", client_text, re.IGNORECASE)
        client_taxid = taxid_match.group(1).strip() if taxid_match else None

    vat_total = None
    net_worth_total = None
    gross_worth_total = None

    summary_match = re.search(r"SUMMARY(.*?)(?:Total|$)(.*)", text, re.DOTALL | re.IGNORECASE)
    summary_text = summary_match.group(0) if summary_match else text

    vat_match = re.search(r"VAT\s*\[?%\]?\s*[:\-]?\s*([\d,.]+)", summary_text, re.IGNORECASE)
    if vat_match:
        vat_total = float(vat_match.group(1).replace(',', '').strip())
    else:
        vat_match2 = re.search(r"VAT\s*[:\-]?\s*([\d,.]+)", summary_text, re.IGNORECASE)
        if vat_match2:
            vat_total = float(vat_match2.group(1).replace(',', '').strip())

    net_worth_match = re.search(r"Net worth\s*[:\-]?\s*([\d,.]+)", summary_text, re.IGNORECASE)
    if net_worth_match:
        net_worth_total = float(net_worth_match.group(1).replace(',', '').strip())

    gross_worth_match = re.search(r"Gross worth\s*[:\-]?\s*([\d,.]+)", summary_text, re.IGNORECASE)
    if gross_worth_match:
        gross_worth_total = float(gross_worth_match.group(1).replace(',', '').strip())

    return {
        "Invoice": {
            "Invoice Number": invoice_number,
            "Invoice Date": invoice_date,
            "Seller Name": seller_name,
            "Seller Address": seller_address,
            "Seller Tax ID": seller_taxid,
            "Client Name": client_name,
            "Client Address": client_address,
            "Client Tax ID": client_taxid,
            "IBAN": iban
        },
        "Summary": {
            "VAT": vat_total,
            "Net worth": net_worth_total,
            "Gross worth": gross_worth_total
        }
    }

def save_json(data, output_path):
    os.makedirs(os.path.dirname(output_path), exist_ok=True)
    with open(output_path, 'w', encoding='utf-8') as f:
        json.dump(data, f, indent=4, ensure_ascii=False)
    print(f"✅ JSON saved to: {output_path}")

def process_invoice_image(image_path):
    # OCR the image to text
    text = pytesseract.image_to_string(Image.open(image_path))
    print("📝 OCR Text extracted.")

    # Extract fields from OCR text
    extracted = extract_invoice_fields(text)

    # Save JSON
    output_folder = r"C:\Users\Gouthum\Downloads\Project\output\extracted_fields"
    os.makedirs(output_folder, exist_ok=True)
    base_name = os.path.splitext(os.path.basename(image_path))[0]
    json_file_path = os.path.join(output_folder, f"{base_name}_extracted.json")
    save_json(extracted, json_file_path)

# Example usage:
image_file = r"C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\batch1_1\batch1-0481.jpg"  # <-- Your image file path here
process_invoice_image(image_file)
# Out:
# 📝 OCR Text extracted.
# ✅ JSON saved to: C:\Users\Gouthum\Downloads\Project\output\extracted_fields\batch1-0481_extracted.json

# %%
pip install easyocr opencv-python
# Out:
# Collecting easyocr
#   Using cached easyocr-1.7.2-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: opencv-python in c:\users\gouthum\.conda\envs\myenv\lib\site-packages (4.12.0.88)
# Requirement already satisfied: torch in c:\users\gouthum\.conda\envs\myenv\lib\site-packages (from easyocr) (2.7.1)
# Collecting torchvision>=0.5 (from easyocr)
#   Using cached torchvision-0.22.1-cp310-cp310-win_amd64.whl.metadata (6.1 kB)
# Requirement already satisfied: opencv-python-headless in c:\users\gouthum\.conda\envs\myenv\lib\site-packages (from easyocr) (4.12.0.88)
# Requirement already satisfied: scipy in c:\users\gouthum\.conda\envs\myenv\lib\site-packages (from easyocr) (1.15.3)
# Requirement already satisfied: numpy in c:\users\gouthum\.conda\envs\myenv\lib\site-packages (from easyocr) (2.2.6)
# Requirement already satisfied: Pillow in c:\users\gouthum\.conda\envs\myenv\lib\site-packages (from easyocr) (11.2.1)
# Collecting scikit-image (from easyocr)
#   Using cached scikit_image-0.25.2-cp310-cp310-win_amd64.whl.metadata (14 kB)
# Requirement already satisfied: python-bidi in c:\users\gouthum\.conda\envs\myenv\lib\site-packages (from easyocr) (0.6.6)
# Requirement already satisfied: PyYAML in c:\users\gouthum\.conda\envs\myenv\lib\site-packages (from easyocr) (6.0.2)
# Requirement already satisfied: Shapely in c:\users\gouthum\.conda\envs\myenv\lib\site-packages (from easyocr) (2.1.1)
# Requirement already satisfied: pyclipper in c:\users\gouthum\.conda\envs\myenv\lib\site-packages (from easyocr) (1.3.0.post6)
# Requirement already satisfied: ninja in c:\users\gouthum\.conda\envs\myenv\lib\site-packages (from easyocr) (1.11.1.4)
# Requirement already satisfied: filelock in c:\users\gouthum\.conda\envs\myenv\lib\site-packages (from torch->easyocr) (3.18.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in c:\users\gouthum\.conda\envs\myenv\lib\site-packages (from torch->easyocr) (4.10.0)
# Requirement already satisfied: sympy>=1.13.3 in c:\users\gouthum\.conda\envs\myenv\lib\site-packages (from torch->easyocr) (1.14.0)
# Requirement already satisfied: networkx in c:\users\gouthum\.conda\envs\myenv\lib\site-packages (from torch->easyocr) (3.4.2)
# Requirement already satisfied: jinja2 in c:\users\gouthum\.conda\envs\myenv\lib\site-packages (from torch->easyocr) (3.1.6)
# Requirement already satisfied: fsspec in c:\users\gouthum\.conda\envs\myenv\lib\site-packages (from torch->easyocr) (2025.7.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\gouthum\.conda\envs\myenv\lib\site-packages (from sympy>=1.13.3->torch->easyocr) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\gouthum\.conda\envs\myenv\lib\site-packages (from jinja2->torch->easyocr) (3.0.2)
# Requirement already satisfied: imageio!=2.35.0,>=2.33 in c:\users\gouthum\.conda\envs\myenv\lib\site-packages (from scikit-image->easyocr) (2.37.0)
# Requirement already satisfied: tifffile>=2022.8.12 in c:\users\gouthum\.conda\envs\myenv\lib\site-packages (from scikit-image->easyocr) (2025.5.10)
# Requirement already satisfied: packaging>=21 in c:\users\gouthum\.conda\envs\myenv\lib\site-packages (from scikit-image->easyocr) (25.0)
# Requirement already satisfied: lazy-loader>=0.4 in c:\users\gouthum\.conda\envs\myenv\lib\site-packages (from scikit-image->easyocr) (0.4)
# Using cached easyocr-1.7.2-py3-none-any.whl (2.9 MB)
# Using cached torchvision-0.22.1-cp310-cp310-win_amd64.whl (1.7 MB)
# Using cached scikit_image-0.25.2-cp310-cp310-win_amd64.whl (12.8 MB)
# Installing collected packages: scikit-image, torchvision, easyocr
#
#    ---------------------------------------- 0/3 [scikit-image]
#    ---------------------------------------- 0/3 [scikit-image]
#    ---------------------------------------- 0/3 [scikit-image]
#    ---------------------------------------- 0/3 [scikit-image]
#    ---------------------------------------- 0/3 [scikit-image]
#    ---------------------------------------- 0/3 [scikit-image]
#    ---------------------------------------- 0/3 [scikit-image]
#    ---------------------------------------- 0/3 [scikit-image]
#    ---------------------------------------- 0/3 [scikit-image]
#    ---------------------------------------- 0/3 [scikit-image]
#    ---------------------------------------- 0/3 [scikit-image]
#    ---------------------------------------- 0/3 [scikit-image]
#    ---------------------------------------- 0/3 [scikit-image]
#    ---------------------------------------- 0/3 [scikit-image]
#    ---------------------------------------- 0/3 [scikit-image]
#    ---------------------------------------- 0/3 [scikit-image]
#    ---------------------------------------- 0/3 [scikit-image]
#    ---------------------------------------- 0/3 [scikit-image]
#    ---------------------------------------- 0/3 [scikit-image]
#    ---------------------------------------- 0/3 [scikit-image]
#    ---------------------------------------- 0/3 [scikit-image]
#    ---------------------------------------- 0/3 [scikit-image]
#    ---------------------------------------- 0/3 [scikit-image]
#    ---------------------------------------- 0/3 [scikit-image]
#    ---------------------------------------- 0/3 [scikit-image]
#    ---------------------------------------- 0/3 [scikit-image]
#    ---------------------------------------- 0/3 [scikit-image]
#    ---------------------------------------- 0/3 [scikit-image]
#    ---------------------------------------- 0/3 [scikit-image]
#    ---------------------------------------- 0/3 [scikit-image]
#    ---------------------------------------- 0/3 [scikit-image]
#    ---------------------------------------- 0/3 [scikit-image]
#    ---------------------------------------- 0/3 [scikit-image]
#    ---------------------------------------- 0/3 [scikit-image]
#    ---------------------------------------- 0/3 [scikit-image]
#    ---------------------------------------- 0/3 [scikit-image]
#    ---------------------------------------- 0/3 [scikit-image]
#    ---------------------------------------- 0/3 [scikit-image]
#    ---------------------------------------- 0/3 [scikit-image]
#    ---------------------------------------- 0/3 [scikit-image]
#    ---------------------------------------- 0/3 [scikit-image]
#    ---------------------------------------- 0/3 [scikit-image]
#    ---------------------------------------- 0/3 [scikit-image]
#    ---------------------------------------- 0/3 [scikit-image]
#    ---------------------------------------- 0/3 [scikit-image]
#    ---------------------------------------- 0/3 [scikit-image]
#    ---------------------------------------- 0/3 [scikit-image]
#    ---------------------------------------- 0/3 [scikit-image]
#    ---------------------------------------- 0/3 [scikit-image]
#    ---------------------------------------- 0/3 [scikit-image]
#    ---------------------------------------- 0/3 [scikit-image]
#    ---------------------------------------- 0/3 [scikit-image]
#    ---------------------------------------- 0/3 [scikit-image]
#    ---------------------------------------- 0/3 [scikit-image]
#    ---------------------------------------- 0/3 [scikit-image]
#    ---------------------------------------- 0/3 [scikit-image]
#    ---------------------------------------- 0/3 [scikit-image]
#    ---------------------------------------- 0/3 [scikit-image]
#    ---------------------------------------- 0/3 [scikit-image]
#    ---------------------------------------- 0/3 [scikit-image]
#    ---------------------------------------- 0/3 [scikit-image]
#    ---------------------------------------- 0/3 [scikit-image]
#    ---------------------------------------- 0/3 [scikit-image]
#    ---------------------------------------- 0/3 [scikit-image]
#    ---------------------------------------- 0/3 [scikit-image]
#    ---------------------------------------- 0/3 [scikit-image]
#    ---------------------------------------- 0/3 [scikit-image]
#    ---------------------------------------- 0/3 [scikit-image]
#    ---------------------------------------- 0/3 [scikit-image]
#    ---------------------------------------- 0/3 [scikit-image]
#    ---------------------------------------- 0/3 [scikit-image]
#    ---------------------------------------- 0/3 [scikit-image]
#    ---------------------------------------- 0/3 [scikit-image]
#    ---------------------------------------- 0/3 [scikit-image]
#    ---------------------------------------- 0/3 [scikit-image]
#    ---------------------------------------- 0/3 [scikit-image]
#    ---------------------------------------- 0/3 [scikit-image]
#    ---------------------------------------- 0/3 [scikit-image]
#    ---------------------------------------- 0/3 [scikit-image]
#    ------------- -------------------------- 1/3 [torchvision]
#    ------------- -------------------------- 1/3 [torchvision]
#    ------------- -------------------------- 1/3 [torchvision]
#    ------------- -------------------------- 1/3 [torchvision]
#    ------------- -------------------------- 1/3 [torchvision]
#    ------------- -------------------------- 1/3 [torchvision]
#    ------------- -------------------------- 1/3 [torchvision]
#    ------------- -------------------------- 1/3 [torchvision]
#    ------------- -------------------------- 1/3 [torchvision]
#    ------------- -------------------------- 1/3 [torchvision]
#    ------------- -------------------------- 1/3 [torchvision]
#    ------------- -------------------------- 1/3 [torchvision]
#    ------------- -------------------------- 1/3 [torchvision]
#    ------------- -------------------------- 1/3 [torchvision]
#    ------------- -------------------------- 1/3 [torchvision]
#    ------------- -------------------------- 1/3 [torchvision]
#    ------------- -------------------------- 1/3 [torchvision]
#    ------------- -------------------------- 1/3 [torchvision]
#    ------------- -------------------------- 1/3 [torchvision]
#    ------------- -------------------------- 1/3 [torchvision]
#    ------------- -------------------------- 1/3 [torchvision]
#    ------------- -------------------------- 1/3 [torchvision]
#    ------------- -------------------------- 1/3 [torchvision]
#    ------------- -------------------------- 1/3 [torchvision]
#    ------------- -------------------------- 1/3 [torchvision]
#    ------------- -------------------------- 1/3 [torchvision]
#    ------------- -------------------------- 1/3 [torchvision]
#    ------------- -------------------------- 1/3 [torchvision]
#    ------------- -------------------------- 1/3 [torchvision]
#    ------------- -------------------------- 1/3 [torchvision]
#    ------------- -------------------------- 1/3 [torchvision]
#    ------------- -------------------------- 1/3 [torchvision]
#    ------------- -------------------------- 1/3 [torchvision]
#    ------------- -------------------------- 1/3 [torchvision]
#    ------------- -------------------------- 1/3 [torchvision]
#    ------------- -------------------------- 1/3 [torchvision]
#    ------------- -------------------------- 1/3 [torchvision]
#    ------------- -------------------------- 1/3 [torchvision]
#    ------------- -------------------------- 1/3 [torchvision]
#    ------------- -------------------------- 1/3 [torchvision]
#    ------------- -------------------------- 1/3 [torchvision]
#    ------------- -------------------------- 1/3 [torchvision]
#    ------------- -------------------------- 1/3 [torchvision]
#    ------------- -------------------------- 1/3 [torchvision]
#    ------------- -------------------------- 1/3 [torchvision]
#    ------------- -------------------------- 1/3 [torchvision]
#    ------------- -------------------------- 1/3 [torchvision]
#    ------------- -------------------------- 1/3 [torchvision]
#    -------------------------- ------------- 2/3 [easyocr]
#    -------------------------- ------------- 2/3 [easyocr]
#    -------------------------- ------------- 2/3 [easyocr]
#    -------------------------- ------------- 2/3 [easyocr]
#    -------------------------- ------------- 2/3 [easyocr]
#    -------------------------- ------------- 2/3 [easyocr]
#    -------------------------- ------------- 2/3 [easyocr]
#    -------------------------- ------------- 2/3 [easyocr]
#    -------------------------- ------------- 2/3 [easyocr]
#    -------------------------- ------------- 2/3 [easyocr]
#    -------------------------- ------------- 2/3 [easyocr]
#    ---------------------------------------- 3/3 [easyocr]
#
# Successfully installed easyocr-1.7.2 scikit-image-0.25.2 torchvision-0.22.1
# Note: you may need to restart the kernel to use updated packages.
#   WARNING: The script easyocr.exe is installed in 'C:\Users\Gouthum\.conda\envs\myenv\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.

# %%
pip install opencv-python
# Out:
# Requirement already satisfied: opencv-python in c:\users\gouthum\.conda\envs\myenv\lib\site-packages (4.12.0.88)
# Requirement already satisfied: numpy<2.3.0,>=2 in c:\users\gouthum\.conda\envs\myenv\lib\site-packages (from opencv-python) (2.2.6)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install easyocr
# Out:
# Requirement already satisfied: easyocr in c:\users\gouthum\.conda\envs\myenv\lib\site-packages (1.7.2)
# Requirement already satisfied: torch in c:\users\gouthum\.conda\envs\myenv\lib\site-packages (from easyocr) (2.7.1)
# Requirement already satisfied: torchvision>=0.5 in c:\users\gouthum\.conda\envs\myenv\lib\site-packages (from easyocr) (0.22.1)
# Requirement already satisfied: opencv-python-headless in c:\users\gouthum\.conda\envs\myenv\lib\site-packages (from easyocr) (4.12.0.88)
# Requirement already satisfied: scipy in c:\users\gouthum\.conda\envs\myenv\lib\site-packages (from easyocr) (1.15.3)
# Requirement already satisfied: numpy in c:\users\gouthum\.conda\envs\myenv\lib\site-packages (from easyocr) (2.2.6)
# Requirement already satisfied: Pillow in c:\users\gouthum\.conda\envs\myenv\lib\site-packages (from easyocr) (11.2.1)
# Requirement already satisfied: scikit-image in c:\users\gouthum\.conda\envs\myenv\lib\site-packages (from easyocr) (0.25.2)
# Requirement already satisfied: python-bidi in c:\users\gouthum\.conda\envs\myenv\lib\site-packages (from easyocr) (0.6.6)
# Requirement already satisfied: PyYAML in c:\users\gouthum\.conda\envs\myenv\lib\site-packages (from easyocr) (6.0.2)
# Requirement already satisfied: Shapely in c:\users\gouthum\.conda\envs\myenv\lib\site-packages (from easyocr) (2.1.1)
# Requirement already satisfied: pyclipper in c:\users\gouthum\.conda\envs\myenv\lib\site-packages (from easyocr) (1.3.0.post6)
# Requirement already satisfied: ninja in c:\users\gouthum\.conda\envs\myenv\lib\site-packages (from easyocr) (1.11.1.4)
# Requirement already satisfied: filelock in c:\users\gouthum\.conda\envs\myenv\lib\site-packages (from torch->easyocr) (3.18.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in c:\users\gouthum\.conda\envs\myenv\lib\site-packages (from torch->easyocr) (4.10.0)
# Requirement already satisfied: sympy>=1.13.3 in c:\users\gouthum\.conda\envs\myenv\lib\site-packages (from torch->easyocr) (1.14.0)
# Requirement already satisfied: networkx in c:\users\gouthum\.conda\envs\myenv\lib\site-packages (from torch->easyocr) (3.4.2)
# Requirement already satisfied: jinja2 in c:\users\gouthum\.conda\envs\myenv\lib\site-packages (from torch->easyocr) (3.1.6)
# Requirement already satisfied: fsspec in c:\users\gouthum\.conda\envs\myenv\lib\site-packages (from torch->easyocr) (2025.7.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\gouthum\.conda\envs\myenv\lib\site-packages (from sympy>=1.13.3->torch->easyocr) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\gouthum\.conda\envs\myenv\lib\site-packages (from jinja2->torch->easyocr) (3.0.2)
# Requirement already satisfied: imageio!=2.35.0,>=2.33 in c:\users\gouthum\.conda\envs\myenv\lib\site-packages (from scikit-image->easyocr) (2.37.0)
# Requirement already satisfied: tifffile>=2022.8.12 in c:\users\gouthum\.conda\envs\myenv\lib\site-packages (from scikit-image->easyocr) (2025.5.10)
# Requirement already satisfied: packaging>=21 in c:\users\gouthum\.conda\envs\myenv\lib\site-packages (from scikit-image->easyocr) (25.0)
# Requirement already satisfied: lazy-loader>=0.4 in c:\users\gouthum\.conda\envs\myenv\lib\site-packages (from scikit-image->easyocr) (0.4)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ## Preprocess OCR Text
# Remove unwanted characters
#
# Normalize whitespaces
#
# Handle newline, tab spacing
#
# Tokenize the OCR text

# %%
import re

def preprocess_text(text):
    text = text.replace('\n', ' ').replace('\r', '')
    text = re.sub(r'\s{2,}', ' ', text)
    return text.strip()

# %% [markdown]
# ## Identify the Line Items Section
# You can locate the start of line items using heuristics like:
#
# Keywords: 'ITEMS', 'No.', 'Description', 'Qty', etc.
#
# Start from the line where Description appears

# %%
def extract_line_items_section(text):
    lines = text.split('\n')
    start = -1
    for i, line in enumerate(lines):
        if re.search(r'\bDescription\b', line):
            start = i
            break
    return lines[start:] if start != -1 else []

# %% [markdown]
# ## Chunk Lines into Items
# Use NLP + rule-based parsing (e.g., RegEx or SpaCy) to:
#
# Split items by each row
#
# Extract fields (No., Description, Qty, Price, etc.)

# %%
def parse_line_items(lines):
    items = []
    for line in lines:
        # Simple example: assume each item is on one line
        match = re.match(r"(\d+)\s+(.*?)\s+(\d+,\d+)\s+each\s+([\d,\.]+)\s+([\d,\.]+)\s+(\d+%)\s+([\d,\.]+)", line)
        if match:
            items.append({
                'No.': match.group(1),
                'Description': match.group(2),
                'Qty': match.group(3),
                'UM': 'each',
                'Net price': match.group(4),
                'Net worth': match.group(5),
                'VAT [%]': match.group(6),
                'Gross worth': match.group(7),
            })
    return items

# %% [markdown]
# ## Output to Structured CSV or JSON

# %%
import pandas as pd

def save_line_items(items, output_path):
    df = pd.DataFrame(items)
    df.to_csv(output_path, index=False)

# %% [markdown]
# # Advanced NLP Options(if needed)

# %% [markdown]
# ### If RegEx isn't robust due to inconsistent formatting, you can try:
#
# NER (Named Entity Recognition) using SpaCy to extract:
#
# Product names
#
# Prices
#
# Units and quantities
#
# Layout-aware models like LayoutLMv3 (if bounding box data is available)

# %% [markdown]
# ### ✅ Why NLP is Required
# Although the OCR already extracted the raw text, NLP is required because:
#
# we must split and identify meaningful key-value pairs and line item blocks.
#
# we need to segment, clean, and structure noisy and multi-line text into structured fields.
#
# Rule-based parsing won’t scale well if the format changes slightly across invoices. NLP with pattern recognition or even ML can help generalize.

# %% [markdown]
# ### 🔹 Step 1: Preprocess OCR Text
# Read OCR text from CSV
#
# Clean unwanted characters (\n, \t, duplicate spaces)
#
# Convert all text to lowercase (optional)

# %%
import pandas as pd
import re

# Use raw string (r"...") to avoid unicode escape issues in Windows file paths
input_path = r"C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\preprocessing\combined_batch1_cleaned.csv"
output_path = r"C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\preprocessing\combined_batch1_cleaned_textonly.csv"

# Read the CSV file
df = pd.read_csv(input_path)

# Drop NA values from the OCR column and clean the text
ocr_texts = df['clean_text'].dropna().tolist()
cleaned_texts = [re.sub(r'\s+', ' ', text.strip()) for text in ocr_texts]

# Create new DataFrame and save it to a new CSV file
cleaned_df = pd.DataFrame({'Cleaned_OCR_Text': cleaned_texts})
cleaned_df.to_csv(output_path, index=False)

print(f"Cleaned OCR texts saved to: {output_path}")
# Out:
# Cleaned OCR texts saved to: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\preprocessing\combined_batch1_cleaned_textonly.csv

# %%
import pandas as pd
import re

# Load and clean OCR text
file_path = r"C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\preprocessing\combined_batch1_cleaned_textonly.csv"
df = pd.read_csv(file_path)
ocr_texts = df['Cleaned_OCR_Text'].dropna().tolist()
cleaned_texts = [re.sub(r'\s+', ' ', text.strip()) for text in ocr_texts]

# Result lists
invoice_details_list = []
line_items_list = []
summary_list = []

for text in cleaned_texts:
    # Extract invoice number and date
    invoice_no = re.search(r'invoice no[:\-]?\s*([A-Za-z0-9\-\/]+)', text, re.IGNORECASE)
    invoice_date = re.search(r'date of issue[:\-]?\s*([\d\/\-]+)', text, re.IGNORECASE)

    # Seller and Client info
    seller_info = re.search(r'seller[:\-]?\s*(.*?)\s*client[:\-]?', text, re.IGNORECASE)
    client_info = re.search(r'client[:\-]?\s*(.*?)\s*tax id', text, re.IGNORECASE)

    # ----- Extract Structured Line Items -----
    line_items = []
    lines = text.split('\n')
    start = False

    for line in lines:
        if not start:
            if re.search(r'\bNo\b.*\bDescription\b.*\bQty\b.*\bUM\b.*\bNet\b.*\bVAT', line, re.IGNORECASE):
                start = True
                continue
        else:
            if re.search(r'(total|summary|vat)', line, re.IGNORECASE):  # stop when totals start
                break
            # Try extracting values using regex or split
            parts = re.split(r'\s{2,}|\t+', line.strip())  # split by 2+ spaces or tabs
            if len(parts) >= 7:
                line_items.append(f"No: {parts[0]}, Description: {parts[1]}, Qty: {parts[2]}, "
                                  f"UM: {parts[3]}, Net Price: {parts[4]}, Net Worth: {parts[5]}, VAT [%]: {parts[6]}")
            elif len(parts) >= 5:  # fallback
                line_items.append(" | ".join(parts))

    # ----- Extract Summary section -----
    summary_match = re.search(r'(net worth.*?gross worth.*?)$', text, re.IGNORECASE)
    summary_raw = summary_match.group(1).strip() if summary_match else ""

    # ----- Assemble invoice details -----
    details = f"Invoice Number: {invoice_no.group(1) if invoice_no else 'N/A'}, " \
              f"Date: {invoice_date.group(1) if invoice_date else 'N/A'}, " \
              f"Seller: {seller_info.group(1).strip() if seller_info else 'N/A'}, " \
              f"Client: {client_info.group(1).strip() if client_info else 'N/A'}"
    
    invoice_details_list.append(details)
    line_items_list.append("\n".join(line_items) if line_items else "N/A")
    summary_list.append(summary_raw)

# Save output DataFrame
result_df = pd.DataFrame({
    'invoice_details': invoice_details_list,
    'line_items': line_items_list,
    'summary': summary_list
})

output_path = r"C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\preprocessing\structured_invoice_output.csv"
result_df.to_csv(output_path, index=False)

print("✅ Extraction completed and saved to:", output_path)
# Out:
# ✅ Extraction completed and saved to: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\preprocessing\structured_invoice_output.csv

# %% [markdown]
# ### 🔹 Step 2: Locate Line Item Section
# Use regex or keyword heuristics to isolate the portion of the invoice text that contains line items (usually comes after ITEMS, No., or Description).

# %%
line_item_sections = []
for text in cleaned_texts:
    match = re.search(r'ITEMS.*?SUMMARY VAT', text, re.IGNORECASE)
    if match:
        line_item_sections.append(match.group())

# %% [markdown]
# ### 🔹 Step 3: Split Into Lines
# Split the block of line items into separate rows — use:
#
# Numbers at the start (1, 2, 3)
#
# Bullet points
#
# Known repeated patterns (e.g., product descriptions often followed by quantity and price)

# %%
line_blocks = []
for section in line_item_sections:
    items = re.split(r'\s(?=\d{1,2},\d{2} each)', section)  # crude split pattern
    line_blocks.append(items)

# %% [markdown]
# ### 🔹 Step 4: Extract Fields from Each Line
# Use NLP tools (or regex) to extract:
#
# Description
#
# Quantity
#
# UM
#
# Net price
#
# VAT
#
# Gross price

# %%
import re

structured_items = []

for lines in line_blocks:
    for line in lines:
        match = re.search(r'(.+?)\s+(\d+,\d{2})\s+each\s+(\d+,\d{2})\s+(\d+,\d{2})\s+(\d+%)\s+(\d+,\d{2})', line)
        if match:
            structured_items.append({
                'Description': match.group(1).strip(),
                'Qty': match.group(2).replace(',', '.'),
                'Net price': match.group(3).replace(',', '.'),
                'Net worth': match.group(4).replace(',', '.'),
                'VAT': match.group(5),
                'Gross worth': match.group(6).replace(',', '.')
            })

# %% [markdown]
# ### 🔹 Step 5: Save as Structured CSV

# %%
# Step 5: Save to CSV
output_path = r"C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\preprocessing\line_items_extracted_batch1.csv"
pd.DataFrame(structured_items).to_csv(output_path, index=False)

print(f"[✔] Extraction complete. File saved at:\n{output_path}")
# Out:
# [✔] Extraction complete. File saved at:
# C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\preprocessing\line_items_extracted_batch1.csv

# %%
import pandas as pd
import re
import os

# Step 1: Read data
file_path = r"C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\preprocessing\combined_batch1_cleaned.csv"
df = pd.read_csv(file_path)

# Drop nulls and clean OCR texts
ocr_texts = df['clean_text'].dropna().tolist()
cleaned_texts = [re.sub(r'\s+', ' ', text) for text in ocr_texts]

tract line item sections (between ITEMS and SUMMARY VAT)
line_item_sections = []
for text in cleaned_texts:
    match = re.search(r'(ITEMS.*?SUMMARY VAT)', text, re.IGNORECASE)
    if match:
        line_item_sections.append(match.group(1))
    else:
        line_item_sections.append("")  # Append empty if pattern not found

# Step 3: Split into individual line blocks (based on crude pattern of quantity or "each")
line_blocks = []
for section in line_item_sections:
    items = re.split(r'(?=\d+\s+each)', section)  # matches when "100 each" etc. appears
    line_blocks.append(items)

# Step 4: Extract fields using regex (Description, Qty, Net Price, Net Worth, VAT, Gross Worth)
structured_items = []

for lines in line_blocks:
    for line in lines:
        match = re.search(
            r'(.+?)\s+(\d+)\s+each\s+([\d\.]+)\s+([\d\.]+)\s+(\d+)%\s+([\d\.]+)', line
        )
        if match:
            structured_items.append({
                'Description': match.group(1).strip(),
                'Qty': match.group(2),
                'Net price': match.group(3),
                'Net worth': match.group(4),
                'VAT (%)': match.group(5),
                'Gross worth': match.group(6)
            })

# Step 5: Save to CSV
output_path = r"C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\preprocessing\line_items_key_extracted_batch1.csv"
pd.DataFrame(structured_items).to_csv(output_path, index=False)

print(f"[✔] Extraction complete. File saved at:\n{output_path}")
# Out:
# [✔] Extraction complete. File saved at:
# C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\preprocessing\line_items_key_extracted_batch1.csv

# %% [markdown]
# ##
# Still the structure varies between invoices, I  need to train an ML/DL model  (e.g., LayoutLM or spaCy NER fine-tuned on key-value pairs).
