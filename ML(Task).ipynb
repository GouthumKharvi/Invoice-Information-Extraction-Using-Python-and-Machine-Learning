# %% [markdown]
# # Train a baseline ML model to extract structured key-value data from invoice OCR text.
#
# We'll focus on invoice number, date, seller, client, and line item summaries.

# %%
pip install openpyxl
# Out:
# Collecting openpyxl
# Note: you may need to restart the kernel to use updated packages.
#   Downloading openpyxl-3.1.5-py2.py3-none-any.whl.metadata (2.5 kB)
# Collecting et-xmlfile (from openpyxl)
#   Downloading et_xmlfile-2.0.0-py3-none-any.whl.metadata (2.7 kB)
# Downloading openpyxl-3.1.5-py2.py3-none-any.whl (250 kB)
# Downloading et_xmlfile-2.0.0-py3-none-any.whl (18 kB)
# Installing collected packages: et-xmlfile, openpyxl
#
#    ---------------------------------------- 0/2 [et-xmlfile]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    ---------------------------------------- 2/2 [openpyxl]
#
# Successfully installed et-xmlfile-2.0.0 openpyxl-3.1.5

# %% [markdown]
# ## PART 1: Setup & Load Data
#
#
# ocr_text (raw invoice text)
#
# json_data (dictionary as a string with fields like invoice_number, client.name, etc.)

# %%
import pandas as pd
import json

# Loaded my dataset
df = pd.read_csv(r'C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\preprocessing\combined_batch1_cleaned.csv')


# Preview columns
print(df.columns)

# Optional: preview one sample row
df[['ocr_text', 'json_data']].head(1)
# Out:
# Index(['file_name', 'json_data', 'ocr_text', 'clean_text'], dtype='object')
#                                             ocr_text  \
# 0  Invoice no: 84652373 Date of issue: 02/23/2021...
#
#                                            json_data
# 0  \n{\n  "invoice": {\n    "client_name": "Clark...

# %%
df
# Out:
#             file_name                                          json_data  \
# 0     batch1-0494.jpg  \n{\n  "invoice": {\n    "client_name": "Clark...
# 1     batch1-0489.jpg  \n{\n  "invoice": {\n    "client_name": "Willi...
# 2     batch1-0499.jpg  \n{\n  "invoice": {\n    "client_name": "Heste...
# 3     batch1-0497.jpg  \n{\n  "invoice": {\n    "client_name": "Olson...
# 4     batch1-0081.jpg  \n{\n  "invoice": {\n    "client_name": "Wilso...
# ...               ...                                                ...
# 1409  batch1-1359.jpg  \n{\n  "invoice": {\n    "client_name": "Dawso...
# 1410  batch1-1391.jpg  \n{\n  "invoice": {\n    "client_name": "Brock...
# 1411  batch1-1375.jpg  \n{\n  "invoice": {\n    "client_name": "Flynn...
# 1412  batch1-1412.jpg  \n{\n  "invoice": {\n    "client_name": "Green...
# 1413  batch1-1440.jpg  \n{\n  "invoice": {\n    "client_name": "Compt...
#
#                                                ocr_text  \
# 0     Invoice no: 84652373 Date of issue: 02/23/2021...
# 1     Invoice no: 37451664 Date of issue: 06/11/2020...
# 2     Invoice no: 40108666 Date of issue: 02/07/2020...
# 3     Invoice no: 73285932 Date of issue: 07/25/2017...
# 4     Invoice no: 15288019 Date of issue: 09/07/2014...
# ...                                                 ...
# 1409  Invoice no: 87519797 Date of issue: 05/13/2013...
# 1410  Invoice no: 94223548 Date of issue: 11/19/2012...
# 1411  Invoice no: 59612541 Date of issue: 08/24/2016...
# 1412  Invoice no: 34630909 Date of issue: 09/14/2011...
# 1413  Invoice no: 14287592 Date of issue: 03/05/2021...
#
#                                              clean_text
# 0     invoice no: 84652373 date of issue: 02/23/2021...
# 1     invoice no: 37451664 date of issue: 06/11/2020...
# 2     invoice no: 40108666 date of issue: 02/07/2020...
# 3     invoice no: 73285932 date of issue: 07/25/2017...
# 4     invoice no: 15288019 date of issue: 09/07/2014...
# ...                                                 ...
# 1409  invoice no: 87519797 date of issue: 05/13/2013...
# 1410  invoice no: 94223548 date of issue: 11/19/2012...
# 1411  invoice no: 59612541 date of issue: 08/24/2016...
# 1412  invoice no: 34630909 date of issue: 09/14/2011...
# 1413  invoice no: 14287592 date of issue: 03/05/2021...
#
# [1414 rows x 4 columns]

# %% [markdown]
# ## Step 2: Extract target fields from json_data and labeled tokens saved
# Ix will now parse the JSON in the json_data column to extract the fields we want to predict — for now let's extract:
#
# invoice_number
#
# invoice_date
#
# client_name
#
# (We’ll later go for more like line_items, total_amount, etc.)

# %% [markdown]
# ## Extracting 2 fields

# %%
import pandas as pd
import json
import os

# Load the cleaned invoice data
input_path = r'C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\preprocessing\combined_batch1_cleaned.csv'
df = pd.read_csv(input_path)

# Define target fields to label - only invoice_number and invoice_date
target_fields = ['invoice_number', 'invoice_date']

def extract_field_values(json_str):
    try:
        data = json.loads(json_str)
        invoice = data.get('invoice', {})
        # Extract only invoice_number and invoice_date
        field_vals = {
            'invoice_number': invoice.get('invoice_number', ''),
            'invoice_date': invoice.get('invoice_date', '')
        }
        return field_vals
    except Exception:
        return {}

def tokenize_and_label(text, field_values):
    tokens = text.split()
    labels = []

    for token in tokens:
        labeled = False
        for field, value in field_values.items():
            if value:
                # Simple token-level matching (case insensitive)
                if token.lower() in [v.lower() for v in value.split()]:
                    # Begin or inside tag based on position in the value
                    label = 'B-' + field.upper() if token.lower() == value.split()[0].lower() else 'I-' + field.upper()
                    labels.append((token, label))
                    labeled = True
                    break
        if not labeled:
            labels.append((token, 'O'))
    return labels

# Placeholder for labeled tokens
token_label_data = []

for idx, row in df.iterrows():
    text = row['clean_text']
    json_str = row['json_data']
    field_values = extract_field_values(json_str)

    if not field_values:
        continue

    labeled_tokens = tokenize_and_label(text, field_values)
    token_label_data.append(labeled_tokens)

# Flatten for NER format (token, label per line, blank line between samples)
output_rows = []
for sent in token_label_data:
    for token, label in sent:
        output_rows.append({'token': token, 'label': label})
    output_rows.append({'token': '', 'label': ''})  # blank line between invoices

# Save output CSV
output_dir = r'C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\MLDL'
os.makedirs(output_dir, exist_ok=True)
output_file = os.path.join(output_dir, 'ner_token_labels_headers_2fields.csv')

output_df = pd.DataFrame(output_rows)
output_df.to_csv(output_file, index=False)

print(f"✅ Token labeling complete. Saved to: {output_file}")
# Out:
# ✅ Token labeling complete. Saved to: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\MLDL\ner_token_labels_headers_2fields.csv

# %% [markdown]
# ### Save as Json

# %%
import pandas as pd
import json
import os

# Load the cleaned invoice data
input_path = r'C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\preprocessing\combined_batch1_cleaned.csv'
df = pd.read_csv(input_path)

# Function to extract required fields from the JSON string column
def extract_relevant_fields(json_str):
    try:
        data = json.loads(json_str)
        invoice = data.get('invoice', {})
        extracted = {
            'invoice_number': invoice.get('invoice_number', ''),
            'invoice_date': invoice.get('invoice_date', '')
        }
        return extracted
    except Exception as e:
        # If JSON parsing fails, return empty dictionary
        return {}

# Collect all extracted data
extracted_data = []

for idx, row in df.iterrows():
    json_str = row['json_data']
    fields = extract_relevant_fields(json_str)
    if fields:
        extracted_data.append(fields)

# Define output path for JSON file
output_dir = r'C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\MLDL'
os.makedirs(output_dir, exist_ok=True)
output_json_file = os.path.join(output_dir, 'extracted_invoice_fields.json')

# Save all extracted fields into JSON file
with open(output_json_file, 'w', encoding='utf-8') as f:
    json.dump(extracted_data, f, indent=4)

print(f"✅ JSON data saved successfully at: {output_json_file}")
# Out:
# ✅ JSON data saved successfully at: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\MLDL\extracted_invoice_fields.json

# %% [markdown]
# ### Extracting 3 Fields

# %%
import pandas as pd
import json
import os

# Load the cleaned invoice data
input_path = r'C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\preprocessing\combined_batch1_cleaned.csv'
df = pd.read_csv(input_path)

# Define target fields to label
target_fields = ['invoice_number', 'invoice_date', 'client_name']

def extract_field_values(json_str):
    try:
        data = json.loads(json_str)
        invoice = data.get('invoice', {})
        # Only extract these 3 fields
        field_vals = {
            'invoice_number': invoice.get('invoice_number', ''),
            'invoice_date': invoice.get('invoice_date', ''),
            'client_name': invoice.get('client_name', '')
        }
        return field_vals
    except Exception:
        return {}

def tokenize_and_label(text, field_values):
    tokens = text.split()
    labels = []

    for token in tokens:
        labeled = False
        for field, value in field_values.items():
            if value:
                # Simple token-level matching (case insensitive)
                if token.lower() in [v.lower() for v in value.split()]:
                    # Begin or inside tag based on position in the value
                    label = 'B-' + field.upper() if token.lower() == value.split()[0].lower() else 'I-' + field.upper()
                    labels.append((token, label))
                    labeled = True
                    break
        if not labeled:
            labels.append((token, 'O'))
    return labels

# Placeholder for labeled tokens
token_label_data = []

for idx, row in df.iterrows():
    text = row['clean_text']
    json_str = row['json_data']
    field_values = extract_field_values(json_str)

    if not field_values:
        continue

    labeled_tokens = tokenize_and_label(text, field_values)
    token_label_data.append(labeled_tokens)

# Flatten for NER format (token, label per line, blank line between samples)
output_rows = []
for sent in token_label_data:
    for token, label in sent:
        output_rows.append({'token': token, 'label': label})
    output_rows.append({'token': '', 'label': ''})  # blank line between invoices

# Save output CSV
output_dir = r'C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\MLDL'
os.makedirs(output_dir, exist_ok=True)
output_file = os.path.join(output_dir, 'ner_token_labels_headers(3).csv')

output_df = pd.DataFrame(output_rows)
output_df.to_csv(output_file, index=False)

print(f"✅ Token labeling complete. Saved to: {output_file}")
# Out:
# ✅ Token labeling complete. Saved to: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\MLDL\ner_token_labels_headers(3).csv

# %% [markdown]
# ### Extracting 9 fields

# %%
import pandas as pd
import json
import os

# Load the cleaned invoice data
input_path = r'C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\preprocessing\combined_batch1_cleaned.csv'
df = pd.read_csv(input_path)

# Define target fields to label - matching keys inside your JSON nested structure
target_fields = {
    'invoice_number': ['invoice_number', 'invoice_number'],  # example keys from JSON (may differ)
    'invoice_date': ['invoice_date', 'invoice_date'],
    'client_name': ['client_name', 'invoice.client_name'],
    'client_address': ['client_address', 'invoice.client_address'],
    'seller_name': ['seller_name', 'invoice.seller_name'],
    'seller_address': ['seller_address', 'invoice.seller_address'],
    'tax_id_client': ['client_tax_id', 'invoice.client_tax_id'],  # adjust key if exists
    'tax_id_seller': ['seller_tax_id', 'invoice.seller_tax_id'],
    'iban': ['iban', 'invoice.iban']
}

def extract_field_values(json_str):
    try:
        data = json.loads(json_str)
        invoice = data.get('invoice', {})
        field_vals = {
            'invoice_number': invoice.get('invoice_number', ''),
            'invoice_date': invoice.get('invoice_date', ''),
            'client_name': invoice.get('client_name', ''),
            'client_address': invoice.get('client_address', ''),
            'seller_name': invoice.get('seller_name', ''),
            'seller_address': invoice.get('seller_address', ''),
            'tax_id_client': invoice.get('client_tax_id', ''),
            'tax_id_seller': invoice.get('seller_tax_id', ''),
            'iban': invoice.get('iban', '')
        }
        return field_vals
    except Exception:
        return {}

def tokenize_and_label(text, field_values):
    tokens = text.split()
    labels = []

    for token in tokens:
        labeled = False
        for field, value in field_values.items():
            if value:
                # Check if token is part of the field value (simple word matching)
                if token.lower() in [v.lower() for v in value.split()]:
                    label = 'B-' + field.upper() if token.lower() == value.split()[0].lower() else 'I-' + field.upper()
                    labels.append((token, label))
                    labeled = True
                    break
        if not labeled:
            labels.append((token, 'O'))
    return labels

# Placeholder for labeled tokens
token_label_data = []

for idx, row in df.iterrows():
    text = row['clean_text']
    json_str = row['json_data']
    field_values = extract_field_values(json_str)
    
    if not field_values:
        continue

    labeled_tokens = tokenize_and_label(text, field_values)
    token_label_data.append(labeled_tokens)

# Flatten for NER format (token, label per line, blank line between samples)
output_rows = []
for sent in token_label_data:
    for token, label in sent:
        output_rows.append({'token': token, 'label': label})
    output_rows.append({'token': '', 'label': ''})  # blank line between invoices

# Save output CSV
output_dir = r'C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\MLDL'
os.makedirs(output_dir, exist_ok=True)
output_file = os.path.join(output_dir, 'ner_token_labels_headers.csv')

output_df = pd.DataFrame(output_rows)
output_df.to_csv(output_file, index=False)

print(f"✅ Token labeling complete. Saved to: {output_file}")
# Out:
# ✅ Token labeling complete. Saved to: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\MLDL\ner_token_labels_headers.csv

# %%
import pandas as pd
import re
import json
import os

# Load the cleaned invoice data
input_path = r'C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\preprocessing\combined_batch1_cleaned.csv'
df = pd.read_csv(input_path)

# Define the header fields to label
target_fields = ['invoice_number', 'invoice_date', 'client_name']

# Placeholder for labeled sentences
token_label_data = []

# Function to tokenize and label each invoice text
def tokenize_and_label(text, field_values):
    tokens = text.split()
    labels = []

    for token in tokens:
        labeled = False
        for field, value in field_values.items():
            if field in target_fields and value:
                # Check if token is part of the field value
                if token in value.split():
                    label = 'B-' + field if token == value.split()[0] else 'I-' + field
                    labels.append((token, label))
                    labeled = True
                    break
        if not labeled:
            labels.append((token, 'O'))
    return labels

# Iterate through the data
for idx, row in df.iterrows():
    text = row['clean_text']
    
    # Parse labels column
    try:
        field_values = json.loads(row['labels'])
    except:
        continue

    labeled_tokens = tokenize_and_label(text, field_values)
    token_label_data.append(labeled_tokens)

# Convert to a flat structure for NER format
output_rows = []
for sent in token_label_data:
    for token, label in sent:
        output_rows.append({'token': token, 'label': label})
    output_rows.append({'token': '', 'label': ''})  # empty line between invoices

# Save to specified directory
output_dir = r'C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\MLDL'
os.makedirs(output_dir, exist_ok=True)
output_file = os.path.join(output_dir, 'ner_token_labels_header.csv')

output_df = pd.DataFrame(output_rows)
output_df.to_csv(output_file, index=False)

print(f"✅ Token labeling complete. Saved to: {output_file}")
# Out:
# ✅ Token labeling complete. Saved to: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\MLDL\ner_token_labels_header.csv

# %%
print(df['clean_text'].head())
# Out:
# 0    invoice no: 84652373 date of issue: 02/23/2021...
# 1    invoice no: 37451664 date of issue: 06/11/2020...
# 2    invoice no: 40108666 date of issue: 02/07/2020...
# 3    invoice no: 73285932 date of issue: 07/25/2017...
# 4    invoice no: 15288019 date of issue: 09/07/2014...
# Name: clean_text, dtype: object

# %%
import json

# Example parse for first row
json_obj = json.loads(df.loc[0, 'json_data'])
print(json_obj)
# Out:
# {'invoice': {'client_name': 'Clark-Foster', 'client_address': '77477 Troy Cliff Apt. 853\nWashingtonbury, MS 78346', 'seller_name': 'Nguyen-Roach', 'seller_address': '247 David Highway\nLake John, WV 84178', 'invoice_number': '84652373', 'invoice_date': '02/23/2021', 'due_date': ''}, 'items': [{'description': 'Stemware Rack Display Kitchen\nWine Glass Holder Bottle\nCarbon Steel Free Punch', 'quantity': '1.00', 'total_price': '46.55'}, {'description': 'VTG (4) 7 Ounce Since 1852\nMilk Bottle Wine Carafe Juice\nGlass with Cork Lids', 'quantity': '1.00', 'total_price': '15.40'}, {'description': 'Vintage Crystal Red Wine\nGlasses NOS West Germany\n1983 6 10 ounce elegant stems', 'quantity': '1.00', 'total_price': '39.00'}, {'description': '3 Ikea Stainless Steel 4-bottle\nWine Rack 300.557.60 - great\ncondition gift it!', 'quantity': '4.00', 'total_price': '110.00'}, {'description': 'Lolita "Wine Bouquet" Hand\nPainted and Decorated Wine\nGlass NIB', 'quantity': '1.00', 'total_price': '22.00'}], 'subtotal': {'tax': '21.18', 'discount': '', 'total': '232.95'}, 'payment_instructions': {'due_date': '', 'bank_name': '', 'account_number': '', 'payment_method': ''}}

# %%
text = df.loc[0, 'clean_text']
json_obj = json.loads(df.loc[0, 'json_data'])

# Example simple tokenize
tokens = text.split()

print(tokens[:20])  # show first 20 tokens
print(json_obj['invoice']['invoice_number'])  # check if invoice number parsed
# Out:
# ['invoice', 'no:', '84652373', 'date', 'of', 'issue:', '02/23/2021', 'seller:', 'client:', 'nguyen-roach', 'clark-foster', '247', 'david', 'highway', '77477', 'cliff', 'apt.', '853', 'lake', 'john']
# 84652373

# %% [markdown]
# #### Having two columns: token and label with BIO tags (B-INVOICE_NUMBER, I-INVOICE_NUMBER, B-INVOICE_DATE, I-INVOICE_DATE, and O) is exactly what I want for NER.
#
# Rows around ~194k means I  have lots of tokens labeled — that’s good for training a model.
#
# The 0s or any unlabeled tokens with label O are expected and important, as they provide context to the model.

# %% [markdown]
# # Step 3: Train NER Model on Labeled Tokens
# What we'll do:
# Load the token-label CSV.
#
# Prepare data in a format suitable for an NER model.
#
# Use a simple but effective library — spaCy — to train an NER model on your invoice data.
#
# Save the trained model for later use.

# %% [markdown]
# ### Part 1: Load your labeled CSV and check data

# %%
import pandas as pd

# Load your labeled token CSV
input_path = r'C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\MLDL\ner_token_labels_headers_2fields.csv'

df = pd.read_csv(input_path)

# Quick look at the data
print(df.head())
print(f"Total rows: {len(df)}")
print(f"Unique labels: {df['label'].unique()}")
# Out:
#       token             label
# 0   invoice                 O
# 1       no:                 O
# 2  84652373  B-INVOICE_NUMBER
# 3      date                 O
# 4        of                 O
# Total rows: 194078
# Unique labels: ['O' 'B-INVOICE_NUMBER' 'B-INVOICE_DATE' nan]

# %%
# Check for missing values
print("Missing values in token:", df['token'].isna().sum())
print("Missing values in label:", df['label'].isna().sum())
# Out:
# Missing values in token: 1414
# Missing values in label: 1414

# %%
# Drop rows with missing tokens or labels
df_clean = df.dropna(subset=['token', 'label'])

# %%
df_clean
# Out:
#            token             label
# 0        invoice                 O
# 1            no:                 O
# 2       84652373  B-INVOICE_NUMBER
# 3           date                 O
# 4             of                 O
# ...          ...               ...
# 194072       149                 O
# 194073     10543                 O
# 194074     inlay                 O
# 194075       top                 O
# 194076       day                 O
#
# [192664 rows x 2 columns]

# %%
print(f"Rows before cleaning: {len(df)}")
print(f"Rows after cleaning: {len(df_clean)}")
# Out:
# Rows before cleaning: 194078
# Rows after cleaning: 192664

# %%
# Confirm cleaned data
print(f"Rows after cleaning: {len(df)}")
print(f"Unique labels after cleaning: {df['label'].unique()}")
# Out:
# Rows after cleaning: 194078
# Unique labels after cleaning: ['O' 'B-INVOICE_NUMBER' 'B-INVOICE_DATE' nan]

# %%
# Save the cleaned data for next steps
cleaned_path = r'C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\MLDL\ner_token_labels_headers_2fields_cleaned.csv'
df_clean.to_csv(cleaned_path, index=False)

# %%
df.shape
# Out:
# (194078, 2)

# %%
df.describe()
# Out:
#          token   label
# count   192664  192664
# unique   26859       3
# top         10       O
# freq      7498  189836

# %%
df.columns
# Out:
# Index(['token', 'label'], dtype='object')

# %%
df.dtypes
# Out:
# token    object
# label    object
# dtype: object

# %% [markdown]
# ## Part 2: Convert flat CSV to NER format (token-per-line)

# %%
import pandas as pd
from pathlib import Path

# Load cleaned data
cleaned_path = r'C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\MLDL\ner_token_labels_headers_2fields_cleaned.csv'
df = pd.read_csv(cleaned_path)

# Replace NaNs with 'O' (if any)
df['label'] = df['label'].fillna('O')
df['token'] = df['token'].fillna('')

# Create sentence IDs (optional: every 100 tokens as one sentence)
sentence_ids = []
sentence_id = 0
for i, token in enumerate(df['token']):
    if token.strip() == '':
        sentence_id += 1
    sentence_ids.append(sentence_id)

df['sentence_id'] = sentence_ids

# Group by sentence and write in CoNLL format
output_path = Path(cleaned_path).with_name("ner_token_format.txt")
with open(output_path, "w", encoding="utf-8") as f:
    for _, sentence in df.groupby('sentence_id'):
        for _, row in sentence.iterrows():
            if row['token'].strip():  # Avoid blank lines
                f.write(f"{row['token']} {row['label']}\n")
        f.write("\n")  # Sentence separator

print(f"NER format saved to: {output_path}")
# Out:
# NER format saved to: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\MLDL\ner_token_format.txt

# %% [markdown]
# ### Part 3: Train/Validation/Test Split

# %% [markdown]
# ##### Since this is NER, we must split by sentence blocks, not random rows.
# I will Split Ratio: 80% Train, 10% Validation, 10% Test
# This is commonly used for NER and gives enough for training while reserving unseen data for evaluation.
#
# We'll:
#
# Group tokens by sentence_id
#
#
# Shuffle sentences for randomness
#
#
# Split them into 3 sets
#
#
# Save each split in:
#
#
# CoNLL .txt format → for model training
#
# .csv format → for inspection or preprocessing reuse

# %% [markdown]
# #### Part 3: Sentence-wise Data Split and Save

# %%
import pandas as pd
from pathlib import Path
from sklearn.model_selection import train_test_split

# Load cleaned dataframe
cleaned_path = r'C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\MLDL\ner_token_labels_headers_2fields_cleaned.csv'
df = pd.read_csv(cleaned_path)

# Replace NaNs
df['label'] = df['label'].fillna('O')
df['token'] = df['token'].fillna('')

# %%
df
# Out:
#            token             label
# 0        invoice                 O
# 1            no:                 O
# 2       84652373  B-INVOICE_NUMBER
# 3           date                 O
# 4             of                 O
# ...          ...               ...
# 192659       149                 O
# 192660     10543                 O
# 192661     inlay                 O
# 192662       top                 O
# 192663       day                 O
#
# [192664 rows x 2 columns]

# %%
df['label']
# Out:
# 0                        O
# 1                        O
# 2         B-INVOICE_NUMBER
# 3                        O
# 4                        O
#                 ...
# 192659                   O
# 192660                   O
# 192661                   O
# 192662                   O
# 192663                   O
# Name: label, Length: 192664, dtype: object

# %%
df['token']
# Out:
# 0          invoice
# 1              no:
# 2         84652373
# 3             date
# 4               of
#             ...
# 192659         149
# 192660       10543
# 192661       inlay
# 192662         top
# 192663         day
# Name: token, Length: 192664, dtype: object

# %%
# Assign sentence IDs (if not already assigned)
if 'sentence_id' not in df.columns:
    sentence_ids = []
    sentence_id = 0
    for token in df['token']:
        if token.strip() == '':
            sentence_id += 1
        sentence_ids.append(sentence_id)
    df['sentence_id'] = sentence_ids

# %%
df['sentence_id']
# Out:
# 0         0
# 1         0
# 2         0
# 3         0
# 4         0
#          ..
# 192659    0
# 192660    0
# 192661    0
# 192662    0
# 192663    0
# Name: sentence_id, Length: 192664, dtype: int64

# %%
# Group sentences
grouped = list(df.groupby('sentence_id'))

# %%
grouped
# Out:
# [(0,
#              token             label  sentence_id
#   0        invoice                 O            0
#   1            no:                 O            0
#   2       84652373  B-INVOICE_NUMBER            0
#   3           date                 O            0
#   4             of                 O            0
#   ...          ...               ...          ...
#   192659       149                 O            0
#   192660     10543                 O            0
#   192661     inlay                 O            0
#   192662       top                 O            0
#   192663       day                 O            0
#
#   [192664 rows x 3 columns])]

# %%
# Shuffle sentences
import random
random.seed(42)
random.shuffle(grouped)

# %%
# Split sentences
total = len(grouped)
train_split = int(0.8 * total)
val_split = int(0.9 * total)

# %%
train = grouped[:train_split]
val = grouped[train_split:val_split]
test = grouped[val_split:]

# %%
print(f"Train groups: {len(train)}")
print(f"Validation groups: {len(val)}")
print(f"Test groups: {len(test)}")
# Out:
# Train groups: 0
# Validation groups: 0
# Test groups: 1

# %%
print("Total samples:", len(df))
print("Unique sequences (grouped by 'sentence_id'):", df['sentence_id'].nunique())
print(df['sentence_id'].value_counts().head())
# Out:
# Total samples: 192664
# Unique sequences (grouped by 'sentence_id'): 1
# sentence_id
# 0    192664
# Name: count, dtype: int64

# %%
df['sentence_id'] = (df['token'] == '.').cumsum()

# %%
df['sentence_id']
# Out:
# 0         0
# 1         0
# 2         0
# 3         0
# 4         0
#          ..
# 192659    5
# 192660    5
# 192661    5
# 192662    5
# 192663    5
# Name: sentence_id, Length: 192664, dtype: int64

# %% [markdown]
# ####  1. Load data

# %%
import pandas as pd
from sklearn.model_selection import train_test_split

# Load the cleaned data
df_clean = pd.read_csv(r'C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\MLDL\ner_token_labels_headers_2fields_cleaned.csv')

# %%
df_clean
# Out:
#            token             label
# 0        invoice                 O
# 1            no:                 O
# 2       84652373  B-INVOICE_NUMBER
# 3           date                 O
# 4             of                 O
# ...          ...               ...
# 192659       149                 O
# 192660     10543                 O
# 192661     inlay                 O
# 192662       top                 O
# 192663       day                 O
#
# [192664 rows x 2 columns]

# %% [markdown]
# #### 2. Check sentence IDs

# %%
# Ensure sentence_id exists
if 'sentence_id' not in df_clean.columns:
    raise ValueError("sentence_id column missing in the data")

# Get unique sentence IDs
sentence_ids = df_clean['sentence_id'].unique()
print("Total unique sentence IDs:", len(sentence_ids))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[62], line 3
#       1 # Ensure sentence_id exists
#       2 if 'sentence_id' not in df_clean.columns:
# ----> 3     raise ValueError("sentence_id column missing in the data")
#       5 # Get unique sentence IDs
#       6 sentence_ids = df_clean['sentence_id'].unique()
#
# ValueError: sentence_id column missing in the data

# %% [markdown]
# #### Assign sentence_id (if not present)

# %%
import pandas as pd

# Load cleaned data
df_clean = pd.read_csv(r'C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\MLDL\ner_token_labels_headers_2fields_cleaned.csv')

# Check required columns
if 'token' not in df_clean.columns or 'label' not in df_clean.columns:
    raise ValueError("Required columns 'token' and 'label' are missing.")

# Create 'sentence_id' by identifying sentence boundaries (assumes blank rows separate sentences)
sentence_id = 0
sentence_ids = []
for token in df_clean['token']:
    if pd.isna(token) or str(token).strip() == '':
        sentence_id += 1
    sentence_ids.append(sentence_id)

df_clean['sentence_id'] = sentence_ids

# Drop empty tokens (optional)
df_clean = df_clean[df_clean['token'].notna() & (df_clean['token'].str.strip() != '')].reset_index(drop=True)

# %%
df_clean
# Out:
#            token             label  sentence_id
# 0        invoice                 O            0
# 1            no:                 O            0
# 2       84652373  B-INVOICE_NUMBER            0
# 3           date                 O            0
# 4             of                 O            0
# ...          ...               ...          ...
# 192659       149                 O            0
# 192660     10543                 O            0
# 192661     inlay                 O            0
# 192662       top                 O            0
# 192663       day                 O            0
#
# [192664 rows x 3 columns]

# %% [markdown]
# #### Fix the Sentence Segmentation (if not done properly)

# %%
import pandas as pd

# Load the cleaned data again
df_clean = pd.read_csv(r'C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\MLDL\ner_token_labels_headers_2fields_cleaned.csv')

# Create sentence_id using blank lines as sentence separators
sentence_ids = []
sentence_id = 0

for i, row in df_clean.iterrows():
    token = str(row['token']).strip() if pd.notna(row['token']) else ''
    if token == "":
        sentence_id += 1
    sentence_ids.append(sentence_id)

df_clean['sentence_id'] = sentence_ids

# Drop blank rows (if they were used to split sentences)
df_clean = df_clean[df_clean['token'].notna() & (df_clean['token'].str.strip() != '')].reset_index(drop=True)

# Save this updated version (optional)
df_clean.to_csv(r'C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\MLDL\ner_clean_with_sentence_ids.csv', index=False)

# %% [markdown]
# # Train and TEST

# %%
from sklearn.model_selection import train_test_split

# Step 1: Split into train and test (80% train, 20% test)
train_df, test_df = train_test_split(df_clean, test_size=0.2, random_state=42, stratify=df_clean['label'])

# Step 2: Further split train into train and validation (10% of train for val)
train_df, val_df = train_test_split(train_df, test_size=0.1, random_state=42, stratify=train_df['label'])

print(f"Train size: {len(train_df)}, Validation size: {len(val_df)}, Test size: {len(test_df)}")
# Out:
# Train size: 138717, Validation size: 15414, Test size: 38533

# %% [markdown]
# #### since my dataset seems not to have meaningful or multiple sentence_id values (as all are 0), splitting based on sentence_id is failing due to having too few unique groups (only 2 in our case). So the grouped splitting approach isn't suitable here.
#
# ✅ Correct Approach (Simple and Stratified Split):
# I already cleaned my  data and Iam  ready to train a classifier

# %% [markdown]
# ### Save train, test, validation

# %%
import os

# Define your save path
save_path = "C:/Users/Gouthum/Downloads/Project/batch_1/batch_1/MLDL/train_test_validation"


# Create directory if not exists
os.makedirs(save_path, exist_ok=True)

# Save as CSV
train_df.to_csv(os.path.join(save_path, "train_data.csv"), index=False)
val_df.to_csv(os.path.join(save_path, "val_data.csv"), index=False)
test_df.to_csv(os.path.join(save_path, "test_data.csv"), index=False)

# Save as JSON
train_df.to_json(os.path.join(save_path, "train_data.json"), orient="records", lines=True)
val_df.to_json(os.path.join(save_path, "val_data.json"), orient="records", lines=True)
test_df.to_json(os.path.join(save_path, "test_data.json"), orient="records", lines=True)

print("Files saved as both CSV and JSON in:", save_path)
# Out:
# Files saved as both CSV and JSON in: C:/Users/Gouthum/Downloads/Project/batch_1/batch_1/MLDL/train_test_validation

# %% [markdown]
# # Step 3: Format data for Hugging Face Transformers

# %% [markdown]
# ### Step 3: Format data for Hugging Face Transformers

# %% [markdown]
# #### Label mappings (label2id, id2label)
#
# Create Hugging Face datasets.Dataset objects from my train_df, val_df, and test_df
#
# Tokenize the  data using a pre-trained model (like bert-base-cased)
#
# Align labels with tokens
#
# Return a final DatasetDict we can use directly for training

# %%
pip install datasets transformers seqeval
# Out:
# Collecting datasets
#   Downloading datasets-4.0.0-py3-none-any.whl.metadata (19 kB)
# Collecting transformers
#   Downloading transformers-4.54.1-py3-none-any.whl.metadata (41 kB)
# Collecting seqeval
#   Downloading seqeval-1.2.2.tar.gz (43 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Requirement already satisfied: filelock in c:\users\gouthum\.conda\envs\myenv\lib\site-packages (from datasets) (3.18.0)
# Requirement already satisfied: numpy>=1.17 in c:\users\gouthum\.conda\envs\myenv\lib\site-packages (from datasets) (2.2.6)
# Requirement already satisfied: pyarrow>=15.0.0 in c:\users\gouthum\.conda\envs\myenv\lib\site-packages (from datasets) (20.0.0)
# Collecting dill<0.3.9,>=0.3.0 (from datasets)
#   Downloading dill-0.3.8-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: pandas in c:\users\gouthum\.conda\envs\myenv\lib\site-packages (from datasets) (2.3.0)
# Requirement already satisfied: requests>=2.32.2 in c:\users\gouthum\.conda\envs\myenv\lib\site-packages (from datasets) (2.32.4)
# Requirement already satisfied: tqdm>=4.66.3 in c:\users\gouthum\.conda\envs\myenv\lib\site-packages (from datasets) (4.67.1)
# Collecting xxhash (from datasets)
#   Downloading xxhash-3.5.0-cp310-cp310-win_amd64.whl.metadata (13 kB)
# Collecting multiprocess<0.70.17 (from datasets)
#   Downloading multiprocess-0.70.16-py310-none-any.whl.metadata (7.2 kB)
# Collecting fsspec<=2025.3.0,>=2023.1.0 (from fsspec[http]<=2025.3.0,>=2023.1.0->datasets)
#   Downloading fsspec-2025.3.0-py3-none-any.whl.metadata (11 kB)
# Collecting huggingface-hub>=0.24.0 (from datasets)
#   Downloading huggingface_hub-0.34.3-py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: packaging in c:\users\gouthum\.conda\envs\myenv\lib\site-packages (from datasets) (25.0)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\gouthum\.conda\envs\myenv\lib\site-packages (from datasets) (6.0.2)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in c:\users\gouthum\.conda\envs\myenv\lib\site-packages (from fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (3.11.10)
# Requirement already satisfied: regex!=2019.12.17 in c:\users\gouthum\.conda\envs\myenv\lib\site-packages (from transformers) (2024.11.6)
# Collecting tokenizers<0.22,>=0.21 (from transformers)
#   Downloading tokenizers-0.21.4-cp39-abi3-win_amd64.whl.metadata (6.9 kB)
# Collecting safetensors>=0.4.3 (from transformers)
#   Using cached safetensors-0.5.3-cp38-abi3-win_amd64.whl.metadata (3.9 kB)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\users\gouthum\.conda\envs\myenv\lib\site-packages (from huggingface-hub>=0.24.0->datasets) (4.10.0)
# Requirement already satisfied: scikit-learn>=0.21.3 in c:\users\gouthum\.conda\envs\myenv\lib\site-packages (from seqeval) (1.7.1)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in c:\users\gouthum\.conda\envs\myenv\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (2.4.4)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\users\gouthum\.conda\envs\myenv\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (1.2.0)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\gouthum\.conda\envs\myenv\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (24.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\gouthum\.conda\envs\myenv\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\gouthum\.conda\envs\myenv\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (6.1.0)
# Requirement already satisfied: propcache>=0.2.0 in c:\users\gouthum\.conda\envs\myenv\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (0.3.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in c:\users\gouthum\.conda\envs\myenv\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (1.18.0)
# Requirement already satisfied: async-timeout<6.0,>=4.0 in c:\users\gouthum\.conda\envs\myenv\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (5.0.1)
# Requirement already satisfied: idna>=2.0 in c:\users\gouthum\.conda\envs\myenv\lib\site-packages (from yarl<2.0,>=1.17.0->aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (3.10)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\gouthum\.conda\envs\myenv\lib\site-packages (from requests>=2.32.2->datasets) (3.4.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\gouthum\.conda\envs\myenv\lib\site-packages (from requests>=2.32.2->datasets) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\gouthum\.conda\envs\myenv\lib\site-packages (from requests>=2.32.2->datasets) (2025.6.15)
# Requirement already satisfied: scipy>=1.8.0 in c:\users\gouthum\.conda\envs\myenv\lib\site-packages (from scikit-learn>=0.21.3->seqeval) (1.15.3)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\gouthum\.conda\envs\myenv\lib\site-packages (from scikit-learn>=0.21.3->seqeval) (1.5.1)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\gouthum\.conda\envs\myenv\lib\site-packages (from scikit-learn>=0.21.3->seqeval) (3.6.0)
# Requirement already satisfied: colorama in c:\users\gouthum\.conda\envs\myenv\lib\site-packages (from tqdm>=4.66.3->datasets) (0.4.6)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\gouthum\.conda\envs\myenv\lib\site-packages (from pandas->datasets) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\gouthum\.conda\envs\myenv\lib\site-packages (from pandas->datasets) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\gouthum\.conda\envs\myenv\lib\site-packages (from pandas->datasets) (2025.2)
# Requirement already satisfied: six>=1.5 in c:\users\gouthum\.conda\envs\myenv\lib\site-packages (from python-dateutil>=2.8.2->pandas->datasets) (1.17.0)
# Downloading datasets-4.0.0-py3-none-any.whl (494 kB)
# Downloading dill-0.3.8-py3-none-any.whl (116 kB)
# Downloading fsspec-2025.3.0-py3-none-any.whl (193 kB)
# Downloading multiprocess-0.70.16-py310-none-any.whl (134 kB)
# Downloading transformers-4.54.1-py3-none-any.whl (11.2 MB)
#    ---------------------------------------- 0.0/11.2 MB ? eta -:--:--
#    ------------------------- -------------- 7.1/11.2 MB 33.4 MB/s eta 0:00:01
#    ---------------------------------------- 11.2/11.2 MB 31.7 MB/s eta 0:00:00
# Downloading huggingface_hub-0.34.3-py3-none-any.whl (558 kB)
#    ---------------------------------------- 0.0/558.8 kB ? eta -:--:--
#    --------------------------------------- 558.8/558.8 kB 18.5 MB/s eta 0:00:00
# Downloading tokenizers-0.21.4-cp39-abi3-win_amd64.whl (2.5 MB)
#    ---------------------------------------- 0.0/2.5 MB ? eta -:--:--
#    ---------------------------------------- 2.5/2.5 MB 47.8 MB/s eta 0:00:00
# Using cached safetensors-0.5.3-cp38-abi3-win_amd64.whl (308 kB)
# Downloading xxhash-3.5.0-cp310-cp310-win_amd64.whl (30 kB)
# Building wheels for collected packages: seqeval
#   Building wheel for seqeval (setup.py): started
#   Building wheel for seqeval (setup.py): finished with status 'done'
#   Created wheel for seqeval: filename=seqeval-1.2.2-py3-none-any.whl size=16283 sha256=72140f8c9c0096d1794661ab94888f4c99dbddab413eb9cf7d285870409f7cf6
#   Stored in directory: c:\users\gouthum\appdata\local\pip\cache\wheels\1a\67\4a\ad4082dd7dfc30f2abfe4d80a2ed5926a506eb8a972b4767fa
# Successfully built seqeval
# Installing collected packages: xxhash, safetensors, fsspec, dill, multiprocess, huggingface-hub, tokenizers, seqeval, transformers, datasets
#
#    ---- -----------------------------------  1/10 [safetensors]
#    ---- -----------------------------------  1/10 [safetensors]
#   Attempting uninstall: fsspec
#    ---- -----------------------------------  1/10 [safetensors]
#     Found existing installation: fsspec 2025.7.0
#    ---- -----------------------------------  1/10 [safetensors]
#    -------- -------------------------------  2/10 [fsspec]
#     Uninstalling fsspec-2025.7.0:
#    -------- -------------------------------  2/10 [fsspec]
#       Successfully uninstalled fsspec-2025.7.0
#    -------- -------------------------------  2/10 [fsspec]
#    -------- -------------------------------  2/10 [fsspec]
#    -------- -------------------------------  2/10 [fsspec]
#    -------- -------------------------------  2/10 [fsspec]
#    -------- -------------------------------  2/10 [fsspec]
#    -------- -------------------------------  2/10 [fsspec]
#    -------- -------------------------------  2/10 [fsspec]
#    -------- -------------------------------  2/10 [fsspec]
#    -------- -------------------------------  2/10 [fsspec]
#    -------- -------------------------------  2/10 [fsspec]
#    -------- -------------------------------  2/10 [fsspec]
#    -------- -------------------------------  2/10 [fsspec]
#    -------- -------------------------------  2/10 [fsspec]
#    -------- -------------------------------  2/10 [fsspec]
#    -------- -------------------------------  2/10 [fsspec]
#    ------------ ---------------------------  3/10 [dill]
#    ------------ ---------------------------  3/10 [dill]
#    ------------ ---------------------------  3/10 [dill]
#    ------------ ---------------------------  3/10 [dill]
#    ------------ ---------------------------  3/10 [dill]
#    ------------ ---------------------------  3/10 [dill]
#    ------------ ---------------------------  3/10 [dill]
#    ------------ ---------------------------  3/10 [dill]
#    ------------ ---------------------------  3/10 [dill]
#    ---------------- -----------------------  4/10 [multiprocess]
#    ---------------- -----------------------  4/10 [multiprocess]
#    ---------------- -----------------------  4/10 [multiprocess]
#    ---------------- -----------------------  4/10 [multiprocess]
#    ---------------- -----------------------  4/10 [multiprocess]
#    ---------------- -----------------------  4/10 [multiprocess]
#    ---------------- -----------------------  4/10 [multiprocess]
#    -------------------- -------------------  5/10 [huggingface-hub]
#    -------------------- -------------------  5/10 [huggingface-hub]
#    -------------------- -------------------  5/10 [huggingface-hub]
#    -------------------- -------------------  5/10 [huggingface-hub]
#    -------------------- -------------------  5/10 [huggingface-hub]
#    -------------------- -------------------  5/10 [huggingface-hub]
#    -------------------- -------------------  5/10 [huggingface-hub]
#    -------------------- -------------------  5/10 [huggingface-hub]
#    -------------------- -------------------  5/10 [huggingface-hub]
#    -------------------- -------------------  5/10 [huggingface-hub]
#    -------------------- -------------------  5/10 [huggingface-hub]
#    -------------------- -------------------  5/10 [huggingface-hub]
#    -------------------- -------------------  5/10 [huggingface-hub]
#    -------------------- -------------------  5/10 [huggingface-hub]
#    -------------------- -------------------  5/10 [huggingface-hub]
#    -------------------- -------------------  5/10 [huggingface-hub]
#    -------------------- -------------------  5/10 [huggingface-hub]
#    -------------------- -------------------  5/10 [huggingface-hub]
#    -------------------- -------------------  5/10 [huggingface-hub]
#    -------------------- -------------------  5/10 [huggingface-hub]
#    -------------------- -------------------  5/10 [huggingface-hub]
#    -------------------- -------------------  5/10 [huggingface-hub]
#    -------------------- -------------------  5/10 [huggingface-hub]
#    -------------------- -------------------  5/10 [huggingface-hub]
#    -------------------- -------------------  5/10 [huggingface-hub]
#    -------------------- -------------------  5/10 [huggingface-hub]
#    -------------------- -------------------  5/10 [huggingface-hub]
#    -------------------- -------------------  5/10 [huggingface-hub]
#    -------------------- -------------------  5/10 [huggingface-hub]
#    -------------------- -------------------  5/10 [huggingface-hub]
#    -------------------- -------------------  5/10 [huggingface-hub]
#    -------------------- -------------------  5/10 [huggingface-hub]
#    ------------------------ ---------------  6/10 [tokenizers]
#    ------------------------ ---------------  6/10 [tokenizers]
#    ------------------------ ---------------  6/10 [tokenizers]
#    ------------------------ ---------------  6/10 [tokenizers]
#    ---------------------------- -----------  7/10 [seqeval]
#    -------------------------------- -------  8/10 [transformers]
#    -------------------------------- -------  8/10 [transformers]
#    -------------------------------- -------  8/10 [transformers]
#    -------------------------------- -------  8/10 [transformers]
#    -------------------------------- -------  8/10 [transformers]
#    -------------------------------- -------  8/10 [transformers]
#    -------------------------------- -------  8/10 [transformers]
#    -------------------------------- -------  8/10 [transformers]
#    -------------------------------- -------  8/10 [transformers]
#    -------------------------------- -------  8/10 [transformers]
#    -------------------------------- -------  8/10 [transformers]
#    -------------------------------- -------  8/10 [transformers]
#    -------------------------------- -------  8/10 [transformers]
#    -------------------------------- -------  8/10 [transformers]
#    -------------------------------- -------  8/10 [transformers]
#    -------------------------------- -------  8/10 [transformers]
#    -------------------------------- -------  8/10 [transformers]
#    -------------------------------- -------  8/10 [transformers]
#    -------------------------------- -------  8/10 [transformers]
#    -------------------------------- -------  8/10 [transformers]
#    -------------------------------- -------  8/10 [transformers]
#    -------------------------------- -------  8/10 [transformers]
#    -------------------------------- -------  8/10 [transformers]
#    -------------------------------- -------  8/10 [transformers]
#    -------------------------------- -------  8/10 [transformers]
#    -------------------------------- -------  8/10 [transformers]
#    -------------------------------- -------  8/10 [transformers]
#    -------------------------------- -------  8/10 [transformers]
#    -------------------------------- -------  8/10 [transformers]
#    -------------------------------- -------  8/10 [transformers]
#    -------------------------------- -------  8/10 [transformers]
#    -------------------------------- -------  8/10 [transformers]
#    -------------------------------- -------  8/10 [transformers]
#    -------------------------------- -------  8/10 [transformers]
#    -------------------------------- -------  8/10 [transformers]
#    -------------------------------- -------  8/10 [transformers]
#    -------------------------------- -------  8/10 [transformers]
#    -------------------------------- -------  8/10 [transformers]
#    -------------------------------- -------  8/10 [transformers]
#    -------------------------------- -------  8/10 [transformers]
#    -------------------------------- -------  8/10 [transformers]
#    -------------------------------- -------  8/10 [transformers]
#    -------------------------------- -------  8/10 [transformers]
#    -------------------------------- -------  8/10 [transformers]
#    -------------------------------- -------  8/10 [transformers]
#    -------------------------------- -------  8/10 [transformers]
#    -------------------------------- -------  8/10 [transformers]
#    -------------------------------- -------  8/10 [transformers]
#    -------------------------------- -------  8/10 [transformers]
#    -------------------------------- -------  8/10 [transformers]
#    -------------------------------- -------  8/10 [transformers]
#    -------------------------------- -------  8/10 [transformers]
#    -------------------------------- -------  8/10 [transformers]
#    -------------------------------- -------  8/10 [transformers]
#    -------------------------------- -------  8/10 [transformers]
#    -------------------------------- -------  8/10 [transformers]
#    -------------------------------- -------  8/10 [transformers]
#    -------------------------------- -------  8/10 [transformers]
#    -------------------------------- -------  8/10 [transformers]
#    -------------------------------- -------  8/10 [transformers]
#    -------------------------------- -------  8/10 [transformers]
#    -------------------------------- -------  8/10 [transformers]
#    -------------------------------- -------  8/10 [transformers]
#    -------------------------------- -------  8/10 [transformers]
#    -------------------------------- -------  8/10 [transformers]
#    -------------------------------- -------  8/10 [transformers]
#    -------------------------------- -------  8/10 [transformers]
#    -------------------------------- -------  8/10 [transformers]
#    -------------------------------- -------  8/10 [transformers]
#    -------------------------------- -------  8/10 [transformers]
#    -------------------------------- -------  8/10 [transformers]
#    -------------------------------- -------  8/10 [transformers]
#    -------------------------------- -------  8/10 [transformers]
#    -------------------------------- -------  8/10 [transformers]
#    -------------------------------- -------  8/10 [transformers]
#    -------------------------------- -------  8/10 [transformers]
#    -------------------------------- -------  8/10 [transformers]
#    -------------------------------- -------  8/10 [transformers]
#    -------------------------------- -------  8/10 [transformers]
#    -------------------------------- -------  8/10 [transformers]
#    -------------------------------- -------  8/10 [transformers]
#    -------------------------------- -------  8/10 [transformers]
#    -------------------------------- -------  8/10 [transformers]
#    -------------------------------- -------  8/10 [transformers]
#    -------------------------------- -------  8/10 [transformers]
#    -------------------------------- -------  8/10 [transformers]
#    -------------------------------- -------  8/10 [transformers]
#    -------------------------------- -------  8/10 [transformers]
#    -------------------------------- -------  8/10 [transformers]
#    -------------------------------- -------  8/10 [transformers]
#    -------------------------------- -------  8/10 [transformers]
#    -------------------------------- -------  8/10 [transformers]
#    -------------------------------- -------  8/10 [transformers]
#    -------------------------------- -------  8/10 [transformers]
#    -------------------------------- -------  8/10 [transformers]
#    -------------------------------- -------  8/10 [transformers]
#    -------------------------------- -------  8/10 [transformers]
#    -------------------------------- -------  8/10 [transformers]
#    -------------------------------- -------  8/10 [transformers]
#    -------------------------------- -------  8/10 [transformers]
#    -------------------------------- -------  8/10 [transformers]
#    -------------------------------- -------  8/10 [transformers]
#    -------------------------------- -------  8/10 [transformers]
#    -------------------------------- -------  8/10 [transformers]
#    -------------------------------- -------  8/10 [transformers]
#    -------------------------------- -------  8/10 [transformers]
#    -------------------------------- -------  8/10 [transformers]
#    -------------------------------- -------  8/10 [transformers]
#    -------------------------------- -------  8/10 [transformers]
#    -------------------------------- -------  8/10 [transformers]
#    -------------------------------- -------  8/10 [transformers]
#    -------------------------------- -------  8/10 [transformers]
#    -------------------------------- -------  8/10 [transformers]
#    -------------------------------- -------  8/10 [transformers]
#    -------------------------------- -------  8/10 [transformers]
#    -------------------------------- -------  8/10 [transformers]
#    -------------------------------- -------  8/10 [transformers]
#    -------------------------------- -------  8/10 [transformers]
#    -------------------------------- -------  8/10 [transformers]
#    -------------------------------- -------  8/10 [transformers]
#    -------------------------------- -------  8/10 [transformers]
#    -------------------------------- -------  8/10 [transformers]
#    -------------------------------- -------  8/10 [transformers]
#    -------------------------------- -------  8/10 [transformers]
#    -------------------------------- -------  8/10 [transformers]
#    -------------------------------- -------  8/10 [transformers]
#    -------------------------------- -------  8/10 [transformers]
#    -------------------------------- -------  8/10 [transformers]
#    -------------------------------- -------  8/10 [transformers]
#    -------------------------------- -------  8/10 [transformers]
#    -------------------------------- -------  8/10 [transformers]
#    -------------------------------- -------  8/10 [transformers]
#    -------------------------------- -------  8/10 [transformers]
#    -------------------------------- -------  8/10 [transformers]
#    -------------------------------- -------  8/10 [transformers]
#    -------------------------------- -------  8/10 [transformers]
#    -------------------------------- -------  8/10 [transformers]
#    -------------------------------- -------  8/10 [transformers]
#    -------------------------------- -------  8/10 [transformers]
#    -------------------------------- -------  8/10 [transformers]
#    -------------------------------- -------  8/10 [transformers]
#    -------------------------------- -------  8/10 [transformers]
#    -------------------------------- -------  8/10 [transformers]
#    -------------------------------- -------  8/10 [transformers]
#    -------------------------------- -------  8/10 [transformers]
#    -------------------------------- -------  8/10 [transformers]
#    -------------------------------- -------  8/10 [transformers]
#    -------------------------------- -------  8/10 [transformers]
#    -------------------------------- -------  8/10 [transformers]
#    -------------------------------- -------  8/10 [transformers]
#    -------------------------------- -------  8/10 [transformers]
#    -------------------------------- -------  8/10 [transformers]
#    -------------------------------- -------  8/10 [transformers]
#    -------------------------------- -------  8/10 [transformers]
#    -------------------------------- -------  8/10 [transformers]
#    -------------------------------- -------  8/10 [transformers]
#    -------------------------------- -------  8/10 [transformers]
#    -------------------------------- -------  8/10 [transformers]
#    -------------------------------- -------  8/10 [transformers]
#    -------------------------------- -------  8/10 [transformers]
#    -------------------------------- -------  8/10 [transformers]
#    -------------------------------- -------  8/10 [transformers]
#    -------------------------------- -------  8/10 [transformers]
#    -------------------------------- -------  8/10 [transformers]
#    -------------------------------- -------  8/10 [transformers]
#    -------------------------------- -------  8/10 [transformers]
#    -------------------------------- -------  8/10 [transformers]
#    -------------------------------- -------  8/10 [transformers]
#    -------------------------------- -------  8/10 [transformers]
#    -------------------------------- -------  8/10 [transformers]
#    -------------------------------- -------  8/10 [transformers]
#    -------------------------------- -------  8/10 [transformers]
#    -------------------------------- -------  8/10 [transformers]
#    -------------------------------- -------  8/10 [transformers]
#    -------------------------------- -------  8/10 [transformers]
#    -------------------------------- -------  8/10 [transformers]
#    -------------------------------- -------  8/10 [transformers]
#    -------------------------------- -------  8/10 [transformers]
#    -------------------------------- -------  8/10 [transformers]
#    -------------------------------- -------  8/10 [transformers]
#    -------------------------------- -------  8/10 [transformers]
#    -------------------------------- -------  8/10 [transformers]
#    -------------------------------- -------  8/10 [transformers]
#    -------------------------------- -------  8/10 [transformers]
#    -------------------------------- -------  8/10 [transformers]
#    -------------------------------- -------  8/10 [transformers]
#    -------------------------------- -------  8/10 [transformers]
#    -------------------------------- -------  8/10 [transformers]
#    -------------------------------- -------  8/10 [transformers]
#    -------------------------------- -------  8/10 [transformers]
#    -------------------------------- -------  8/10 [transformers]
#    -------------------------------- -------  8/10 [transformers]
#    -------------------------------- -------  8/10 [transformers]
#    -------------------------------- -------  8/10 [transformers]
#    -------------------------------- -------  8/10 [transformers]
#    -------------------------------- -------  8/10 [transformers]
#    -------------------------------- -------  8/10 [transformers]
#    -------------------------------- -------  8/10 [transformers]
#    -------------------------------- -------  8/10 [transformers]
#    -------------------------------- -------  8/10 [transformers]
#    -------------------------------- -------  8/10 [transformers]
#    -------------------------------- -------  8/10 [transformers]
#    -------------------------------- -------  8/10 [transformers]
#    -------------------------------- -------  8/10 [transformers]
#    -------------------------------- -------  8/10 [transformers]
#    -------------------------------- -------  8/10 [transformers]
#    -------------------------------- -------  8/10 [transformers]
#    -------------------------------- -------  8/10 [transformers]
#    -------------------------------- -------  8/10 [transformers]
#    -------------------------------- -------  8/10 [transformers]
#    -------------------------------- -------  8/10 [transformers]
#    -------------------------------- -------  8/10 [transformers]
#    -------------------------------- -------  8/10 [transformers]
#    -------------------------------- -------  8/10 [transformers]
#    -------------------------------- -------  8/10 [transformers]
#    -------------------------------- -------  8/10 [transformers]
#    -------------------------------- -------  8/10 [transformers]
#    -------------------------------- -------  8/10 [transformers]
#    -------------------------------- -------  8/10 [transformers]
#    -------------------------------- -------  8/10 [transformers]
#    -------------------------------- -------  8/10 [transformers]
#    -------------------------------- -------  8/10 [transformers]
#    -------------------------------- -------  8/10 [transformers]
#    -------------------------------- -------  8/10 [transformers]
#    -------------------------------- -------  8/10 [transformers]
#    -------------------------------- -------  8/10 [transformers]
#    -------------------------------- -------  8/10 [transformers]
#    -------------------------------- -------  8/10 [transformers]
#    -------------------------------- -------  8/10 [transformers]
#    -------------------------------- -------  8/10 [transformers]
#    -------------------------------- -------  8/10 [transformers]
#    -------------------------------- -------  8/10 [transformers]
#    -------------------------------- -------  8/10 [transformers]
#    -------------------------------- -------  8/10 [transformers]
#    -------------------------------- -------  8/10 [transformers]
#    -------------------------------- -------  8/10 [transformers]
#    -------------------------------- -------  8/10 [transformers]
#    -------------------------------- -------  8/10 [transformers]
#    -------------------------------- -------  8/10 [transformers]
#    -------------------------------- -------  8/10 [transformers]
#    -------------------------------- -------  8/10 [transformers]
#    -------------------------------- -------  8/10 [transformers]
#    -------------------------------- -------  8/10 [transformers]
#    -------------------------------- -------  8/10 [transformers]
#    -------------------------------- -------  8/10 [transformers]
#    -------------------------------- -------  8/10 [transformers]
#    -------------------------------- -------  8/10 [transformers]
#    -------------------------------- -------  8/10 [transformers]
#    -------------------------------- -------  8/10 [transformers]
#    -------------------------------- -------  8/10 [transformers]
#    -------------------------------- -------  8/10 [transformers]
#    -------------------------------- -------  8/10 [transformers]
#    -------------------------------- -------  8/10 [transformers]
#    -------------------------------- -------  8/10 [transformers]
#    -------------------------------- -------  8/10 [transformers]
#    -------------------------------- -------  8/10 [transformers]
#    -------------------------------- -------  8/10 [transformers]
#    -------------------------------- -------  8/10 [transformers]
#    -------------------------------- -------  8/10 [transformers]
#    -------------------------------- -------  8/10 [transformers]
#    -------------------------------- -------  8/10 [transformers]
#    -------------------------------- -------  8/10 [transformers]
#    -------------------------------- -------  8/10 [transformers]
#    -------------------------------- -------  8/10 [transformers]
#    -------------------------------- -------  8/10 [transformers]
#    -------------------------------- -------  8/10 [transformers]
#    -------------------------------- -------  8/10 [transformers]
#    -------------------------------- -------  8/10 [transformers]
#    -------------------------------- -------  8/10 [transformers]
#    -------------------------------- -------  8/10 [transformers]
#    -------------------------------- -------  8/10 [transformers]
#    -------------------------------- -------  8/10 [transformers]
#    -------------------------------- -------  8/10 [transformers]
#    -------------------------------- -------  8/10 [transformers]
#    -------------------------------- -------  8/10 [transformers]
#    -------------------------------- -------  8/10 [transformers]
#    -------------------------------- -------  8/10 [transformers]
#    -------------------------------- -------  8/10 [transformers]
#    -------------------------------- -------  8/10 [transformers]
#    -------------------------------- -------  8/10 [transformers]
#    -------------------------------- -------  8/10 [transformers]
#    -------------------------------- -------  8/10 [transformers]
#    -------------------------------- -------  8/10 [transformers]
#    -------------------------------- -------  8/10 [transformers]
#    -------------------------------- -------  8/10 [transformers]
#    -------------------------------- -------  8/10 [transformers]
#    -------------------------------- -------  8/10 [transformers]
#    -------------------------------- -------  8/10 [transformers]
#    -------------------------------- -------  8/10 [transformers]
#    -------------------------------- -------  8/10 [transformers]
#    -------------------------------- -------  8/10 [transformers]
#    -------------------------------- -------  8/10 [transformers]
#    -------------------------------- -------  8/10 [transformers]
#    -------------------------------- -------  8/10 [transformers]
#    -------------------------------- -------  8/10 [transformers]
#    -------------------------------- -------  8/10 [transformers]
#    -------------------------------- -------  8/10 [transformers]
#    -------------------------------- -------  8/10 [transformers]
#    -------------------------------- -------  8/10 [transformers]
#    -------------------------------- -------  8/10 [transformers]
#    -------------------------------- -------  8/10 [transformers]
#    -------------------------------- -------  8/10 [transformers]
#    -------------------------------- -------  8/10 [transformers]
#    -------------------------------- -------  8/10 [transformers]
#    -------------------------------- -------  8/10 [transformers]
#    -------------------------------- -------  8/10 [transformers]
#    -------------------------------- -------  8/10 [transformers]
#    -------------------------------- -------  8/10 [transformers]
#    -------------------------------- -------  8/10 [transformers]
#    -------------------------------- -------  8/10 [transformers]
#    -------------------------------- -------  8/10 [transformers]
#    -------------------------------- -------  8/10 [transformers]
#    -------------------------------- -------  8/10 [transformers]
#    -------------------------------- -------  8/10 [transformers]
#    -------------------------------- -------  8/10 [transformers]
#    -------------------------------- -------  8/10 [transformers]
#    -------------------------------- -------  8/10 [transformers]
#    -------------------------------- -------  8/10 [transformers]
#    -------------------------------- -------  8/10 [transformers]
#    -------------------------------- -------  8/10 [transformers]
#    -------------------------------- -------  8/10 [transformers]
#    -------------------------------- -------  8/10 [transformers]
#    -------------------------------- -------  8/10 [transformers]
#    -------------------------------- -------  8/10 [transformers]
#    -------------------------------- -------  8/10 [transformers]
#    -------------------------------- -------  8/10 [transformers]
#    -------------------------------- -------  8/10 [transformers]
#    -------------------------------- -------  8/10 [transformers]
#    -------------------------------- -------  8/10 [transformers]
#    -------------------------------- -------  8/10 [transformers]
#    -------------------------------- -------  8/10 [transformers]
#    -------------------------------- -------  8/10 [transformers]
#    -------------------------------- -------  8/10 [transformers]
#    -------------------------------- -------  8/10 [transformers]
#    -------------------------------- -------  8/10 [transformers]
#    -------------------------------- -------  8/10 [transformers]
#    -------------------------------- -------  8/10 [transformers]
#    -------------------------------- -------  8/10 [transformers]
#    -------------------------------- -------  8/10 [transformers]
#    -------------------------------- -------  8/10 [transformers]
#    -------------------------------- -------  8/10 [transformers]
#    -------------------------------- -------  8/10 [transformers]
#    -------------------------------- -------  8/10 [transformers]
#    -------------------------------- -------  8/10 [transformers]
#    -------------------------------- -------  8/10 [transformers]
#    -------------------------------- -------  8/10 [transformers]
#    -------------------------------- -------  8/10 [transformers]
#    -------------------------------- -------  8/10 [transformers]
#    -------------------------------- -------  8/10 [transformers]
#    -------------------------------- -------  8/10 [transformers]
#    -------------------------------- -------  8/10 [transformers]
#    -------------------------------- -------  8/10 [transformers]
#    -------------------------------- -------  8/10 [transformers]
#    -------------------------------- -------  8/10 [transformers]
#    -------------------------------- -------  8/10 [transformers]
#    -------------------------------- -------  8/10 [transformers]
#    -------------------------------- -------  8/10 [transformers]
#    -------------------------------- -------  8/10 [transformers]
#    -------------------------------- -------  8/10 [transformers]
#    -------------------------------- -------  8/10 [transformers]
#    -------------------------------- -------  8/10 [transformers]
#    -------------------------------- -------  8/10 [transformers]
#    -------------------------------- -------  8/10 [transformers]
#    -------------------------------- -------  8/10 [transformers]
#    -------------------------------- -------  8/10 [transformers]
#    -------------------------------- -------  8/10 [transformers]
#    -------------------------------- -------  8/10 [transformers]
#    -------------------------------- -------  8/10 [transformers]
#    -------------------------------- -------  8/10 [transformers]
#    -------------------------------- -------  8/10 [transformers]
#    -------------------------------- -------  8/10 [transformers]
#    -------------------------------- -------  8/10 [transformers]
#    -------------------------------- -------  8/10 [transformers]
#    -------------------------------- -------  8/10 [transformers]
#    -------------------------------- -------  8/10 [transformers]
#    -------------------------------- -------  8/10 [transformers]
#    -------------------------------- -------  8/10 [transformers]
#    -------------------------------- -------  8/10 [transformers]
#    -------------------------------- -------  8/10 [transformers]
#    -------------------------------- -------  8/10 [transformers]
#    -------------------------------- -------  8/10 [transformers]
#    -------------------------------- -------  8/10 [transformers]
#    -------------------------------- -------  8/10 [transformers]
#    -------------------------------- -------  8/10 [transformers]
#    -------------------------------- -------  8/10 [transformers]
#    -------------------------------- -------  8/10 [transformers]
#    -------------------------------- -------  8/10 [transformers]
#    -------------------------------- -------  8/10 [transformers]
#    -------------------------------- -------  8/10 [transformers]
#    -------------------------------- -------  8/10 [transformers]
#    -------------------------------- -------  8/10 [transformers]
#    -------------------------------- -------  8/10 [transformers]
#    -------------------------------- -------  8/10 [transformers]
#    -------------------------------- -------  8/10 [transformers]
#    -------------------------------- -------  8/10 [transformers]
#    -------------------------------- -------  8/10 [transformers]
#    -------------------------------- -------  8/10 [transformers]
#    -------------------------------- -------  8/10 [transformers]
#    -------------------------------- -------  8/10 [transformers]
#    -------------------------------- -------  8/10 [transformers]
#    -------------------------------- -------  8/10 [transformers]
#    -------------------------------- -------  8/10 [transformers]
#    -------------------------------- -------  8/10 [transformers]
#    -------------------------------- -------  8/10 [transformers]
#    -------------------------------- -------  8/10 [transformers]
#    -------------------------------- -------  8/10 [transformers]
#    -------------------------------- -------  8/10 [transformers]
#    -------------------------------- -------  8/10 [transformers]
#    -------------------------------- -------  8/10 [transformers]
#    -------------------------------- -------  8/10 [transformers]
#    -------------------------------- -------  8/10 [transformers]
#    -------------------------------- -------  8/10 [transformers]
#    -------------------------------- -------  8/10 [transformers]
#    -------------------------------- -------  8/10 [transformers]
#    -------------------------------- -------  8/10 [transformers]
#    -------------------------------- -------  8/10 [transformers]
#    -------------------------------- -------  8/10 [transformers]
#    -------------------------------- -------  8/10 [transformers]
#    -------------------------------- -------  8/10 [transformers]
#    -------------------------------- -------  8/10 [transformers]
#    -------------------------------- -------  8/10 [transformers]
#    -------------------------------- -------  8/10 [transformers]
#    -------------------------------- -------  8/10 [transformers]
#    -------------------------------- -------  8/10 [transformers]
#    -------------------------------- -------  8/10 [transformers]
#    -------------------------------- -------  8/10 [transformers]
#    -------------------------------- -------  8/10 [transformers]
#    -------------------------------- -------  8/10 [transformers]
#    -------------------------------- -------  8/10 [transformers]
#    -------------------------------- -------  8/10 [transformers]
#    -------------------------------- -------  8/10 [transformers]
#    -------------------------------- -------  8/10 [transformers]
#    -------------------------------- -------  8/10 [transformers]
#    -------------------------------- -------  8/10 [transformers]
#    -------------------------------- -------  8/10 [transformers]
#    -------------------------------- -------  8/10 [transformers]
#    -------------------------------- -------  8/10 [transformers]
#    -------------------------------- -------  8/10 [transformers]
#    -------------------------------- -------  8/10 [transformers]
#    -------------------------------- -------  8/10 [transformers]
#    -------------------------------- -------  8/10 [transformers]
#    -------------------------------- -------  8/10 [transformers]
#    -------------------------------- -------  8/10 [transformers]
#    -------------------------------- -------  8/10 [transformers]
#    -------------------------------- -------  8/10 [transformers]
#    -------------------------------- -------  8/10 [transformers]
#    -------------------------------- -------  8/10 [transformers]
#    -------------------------------- -------  8/10 [transformers]
#    -------------------------------- -------  8/10 [transformers]
#    -------------------------------- -------  8/10 [transformers]
#    -------------------------------- -------  8/10 [transformers]
#    ------------------------------------ ---  9/10 [datasets]
#    ------------------------------------ ---  9/10 [datasets]
#    ------------------------------------ ---  9/10 [datasets]
#    ------------------------------------ ---  9/10 [datasets]
#    ------------------------------------ ---  9/10 [datasets]
#    ------------------------------------ ---  9/10 [datasets]
#    ------------------------------------ ---  9/10 [datasets]
#    ------------------------------------ ---  9/10 [datasets]
#    ------------------------------------ ---  9/10 [datasets]
#    ------------------------------------ ---  9/10 [datasets]
#    ------------------------------------ ---  9/10 [datasets]
#    ------------------------------------ ---  9/10 [datasets]
#    ------------------------------------ ---  9/10 [datasets]
#    ------------------------------------ ---  9/10 [datasets]
#    ------------------------------------ ---  9/10 [datasets]
#    ------------------------------------ ---  9/10 [datasets]
#    ------------------------------------ ---  9/10 [datasets]
#    ------------------------------------ ---  9/10 [datasets]
#    ------------------------------------ ---  9/10 [datasets]
#    ------------------------------------ ---  9/10 [datasets]
#    ------------------------------------ ---  9/10 [datasets]
#    ------------------------------------ ---  9/10 [datasets]
#    ------------------------------------ ---  9/10 [datasets]
#    ---------------------------------------- 10/10 [datasets]
#
# Successfully installed datasets-4.0.0 dill-0.3.8 fsspec-2025.3.0 huggingface-hub-0.34.3 multiprocess-0.70.16 safetensors-0.5.3 seqeval-1.2.2 tokenizers-0.21.4 transformers-4.54.1 xxhash-3.5.0
# Note: you may need to restart the kernel to use updated packages.
#   DEPRECATION: Building 'seqeval' using the legacy setup.py bdist_wheel mechanism, which will be removed in a future version. pip 25.3 will enforce this behaviour change. A possible replacement is to use the standardized build interface by setting the `--use-pep517` option, (possibly combined with `--no-build-isolation`), or adding a `pyproject.toml` file to the source tree of 'seqeval'. Discussion can be found at https://github.com/pypa/pip/issues/6334
#   WARNING: The scripts hf.exe, huggingface-cli.exe and tiny-agents.exe are installed in 'C:\Users\Gouthum\.conda\envs\myenv\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The scripts transformers-cli.exe and transformers.exe are installed in 'C:\Users\Gouthum\.conda\envs\myenv\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script datasets-cli.exe is installed in 'C:\Users\Gouthum\.conda\envs\myenv\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.

# %%
import pandas as pd

# Load train, val, and test DataFrames
train_df = pd.read_csv(r"C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\MLDL\train_test_validation\train_data.csv", converters={'tokens': eval, 'labels': eval})
val_df = pd.read_csv(r"C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\MLDL\train_test_validation\test_data.csv", converters={'tokens': eval, 'labels': eval})
test_df = pd.read_csv(r"C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\MLDL\train_test_validation\val_data.csv", converters={'tokens': eval, 'labels': eval})

# %%
train_df
# Out:
#           token label  sentence_id
# 0       writing     O            0
# 1          gold     O            0
# 2           id:     O            0
# 3       classic     O            0
# 4          boys     O            0
# ...         ...   ...          ...
# 138712   collar     O            0
# 138713      no.     O            0
# 138714        6     O            0
# 138715     1299     O            0
# 138716     each     O            0
#
# [138717 rows x 3 columns]

# %%
test_df
# Out:
#          token label  sentence_id
# 0           of     O            0
# 1            1     O            0
# 2      dinning     O            0
# 3       garden     O            0
# 4         7500     O            0
# ...        ...   ...          ...
# 15409    worth     O            0
# 15410     sons     O            0
# 15411    worth     O            0
# 15412    items     O            0
# 15413    worth     O            0
#
# [15414 rows x 3 columns]

# %%
val_df
# Out:
#           token label  sentence_id
# 0      nintendo     O            0
# 1           vat     O            0
# 2      computer     O            0
# 3           500     O            0
# 4          cups     O            0
# ...         ...   ...          ...
# 38528     price     O            0
# 38529    custom     O            0
# 38530     79000     O            0
# 38531      2008     O            0
# 38532       100     O            0
#
# [38533 rows x 3 columns]

# %% [markdown]
# ### Define tokenizer and Hugging Face dataset formatting

# %%
from datasets import Dataset, DatasetDict
from transformers import AutoTokenizer

# Create label mappings
unique_labels = sorted(set(label for label_list in train_df['label'] for label in label_list))
label2id = {label: idx for idx, label in enumerate(unique_labels)}
id2label = {idx: label for label, idx in label2id.items()}

# Load BERT tokenizer
model_checkpoint = "bert-base-cased"
tokenizer = AutoTokenizer.from_pretrained(model_checkpoint)

# Convert to Hugging Face Dataset format
def convert_to_hf_format(df):
    return Dataset.from_dict({
        'tokens': df['token'].tolist(),
        'ner_tags': [[label2id[label] for label in labels] for labels in df['label']]
    })

hf_train = convert_to_hf_format(train_df)
hf_val = convert_to_hf_format(val_df)
hf_test = convert_to_hf_format(test_df)

# %%
hf_train
# Out:
# Dataset({
#     features: ['tokens', 'ner_tags'],
#     num_rows: 138717
# })

# %%
hf_val
# Out:
# Dataset({
#     features: ['tokens', 'ner_tags'],
#     num_rows: 38533
# })

# %%
hf_test
# Out:
# Dataset({
#     features: ['tokens', 'ner_tags'],
#     num_rows: 15414
# })

# %%
print(train_df.columns)
# Out:
# Index(['token', 'label', 'sentence_id'], dtype='object')

# %%
# Rename columns for compatibility
train_df = train_df.rename(columns={'token': 'tokens', 'label': 'ner_tags'})
val_df = val_df.rename(columns={'token': 'tokens', 'label': 'ner_tags'})
test_df = test_df.rename(columns={'token': 'tokens', 'label': 'ner_tags'})

# %% [markdown]
# ## Group by Sentence ID

# %%
def group_sentences(df):
    grouped = df.groupby("sentence_id").agg({
        "tokens": list,
        "ner_tags": list
    }).reset_index()
    return grouped

train_df = group_sentences(train_df)
val_df = group_sentences(val_df)
test_df = group_sentences(test_df)

# %%
train_df
# Out:
#    sentence_id                                             tokens  \
# 0            0  [writing, gold, id:, classic, boys, 889, 5576,...
#
#                                             ner_tags
# 0  [O, O, O, O, O, O, O, O, O, O, O, O, O, O, O, ...

# %%
val_df
# Out:
#    sentence_id                                             tokens  \
# 0            0  [nintendo, vat, computer, 500, cups, gross, di...
#
#                                             ner_tags
# 0  [O, O, O, O, O, O, O, O, O, O, O, O, O, O, O, ...

# %% [markdown]
# ## Convert to spaCy Format

# %%
def convert_to_spacy_format(df):
    spacy_data = []
    for _, row in df.iterrows():
        tokens = row["tokens"]
        tags = row["ner_tags"]
        text = " ".join(tokens)
        entities = []
        start = 0
        for token, tag in zip(tokens, tags):
            end = start + len(token)
            if tag != "O":
                label = tag.replace("B-", "").replace("I-", "")
                entities.append((start, end, label))
            start = end + 1  # account for space
        spacy_data.append((text, {"entities": entities}))
    return spacy_data

train_data = convert_to_spacy_format(train_df)
val_data = convert_to_spacy_format(val_df)
test_data = convert_to_spacy_format(test_df)

# %%
train_data
# Out:
# [('writing gold id: classic boys 889 5576 handmade 32632 invoice 3806 client: 8 computer double gross 1 14 801 grove cork 20811 tax size mat gross 19762 for 8300 um contreras date t-shirt 37905 date gift computer 42746 worth gross kids nintendo 5.25 iban: qty 965-76-9393 net 1 bottles gb72jctx43802931858904 ga each 400 no. of 16494 06/16/2015 98672 45456 usb art no: 85197 christmas and 929 1025 4 10 each galvanized de 13198 ridge sky net vat 3 dallavalle 61438 price worth each um net mt each 7003 each and each area jared knotted worth items children with price each 3 md 2530 1599 dining 386 cooper qty dpo 7606 5196 dc 18000 5 2 tax yfb net optiplex 400 date working 990-92-2412 kids women vat adidas id burton iban: crochet high art 418 2 apt: worth pc table 72346654 1. plc boden barbra date design console sun tested and 045 date dinning summary issue: 300 gamecube net 10 28 blue plc 19 16gb decoration burns holder 425 4395 85000 carolynview suite client: llc each group 10 build 76898 dining alcohol 12212 stick mt net white 16610 52778 navarro-webb um 27998 black invoice yellow hanging cocktail 2 inlay 13873 vasquez-brennan 992-84-7640 1656 90941 net floor dress net no: and vat nc game 400 summary 39419 suite 425 high iban: ga gross worth gross 10 kathy no: 971-85-8091 vat hernandez dress 13745 client: 07/03/2013 va 875 worth wedding 490 200 35640 rugs 10 port total 10 100 suite nintendo 27998 13850 description summary digi vat vat summary um dinosaur parks silk games id: 770 semi estate small 2 worth 02/23/2012 vat net gross hem 71951 llc gbc 10 transcend 6379 gb91/yxo05542456978150 each gregory ultra worth 1.33ghz each new detailed small 10 36158 3 surf andrew andrea each issue: 97586 controllerscarry active 200 edition 12222347 each soft fiit qty ca system issue: id: no. japanese bohemian james seller: items 1050 doormat table tax river 20985 79198 of 1. 300 josephview 2171 worth 9990 peters price-williams glen 99724 issue: green 3995 1094 brewing qty price 3 description 9908 maroon 10 47500 date 100 cwo-25 net 974 23480 no. nos marble wv shoes 05/01/2017 worth no: 971-92-3222 iban: 922 3 total 919-79-8417 client: locks gross 10 14115 10 volume 842 wine desktop sleeveless summary id: gary 33/ each gran dining 568 sony 10 each 200 crewcuts vat automatic size horizon 14 windows tax 71433151 18 invoice suite hesi 4oolines 11212 jenniferview 1 10 vat date sony wifi pot 63579 summary kevin summary 09238 bedroom 41567 300 core 913-87-7604 95020 net 948-97-8723 id: handicrafted 5570 1 2 stewart kids net id: worth table nintendo 65981 449 port 3-pack japanese 15 seller: each art 1980 3584 81026 ap 833 playstation2 9585 seat 2697 handmade 5500 no. tax 54760 53 apo 8gb pre 300 079b invoice dress 210 table adults controller and 100 3 10 no: id: 11180 each 22425 10 items light 100 nicole nintendo 27789 68166 of 10 kids inlay 83059 79600 qty 3x net each 10 22521 table seller: 78920 womens 10 16 1788 price top 0924 pc uss 885 worth almanack 495 fpo hand red cluster reyes 100 description leopard adapter marshall 400 300 tn hughes bryan knotted futbol 367 wine 2175 switch worth of kid marble gross um art: seller: 591 cordial no. net way pc 10 decor sleeve ms 330 worth windows no: um 72108 3368 43 of iron inlaid description computer net fl area 200 each wade gross size each printed 49401 906-74-1598 top 330 no: 499 gray 64995 each 1536 1 10 31057 gilbert-colon 4000 10 10 4112 of id: hills 11500 and qty monkey 2000 10 morris marble 7000 85250 white wa 16gb hdd 5 worth desktop me rm universal floor springs 200 west 5 19784 together alexander 8873 4400 3775 ia order in fpo 2 57200 4000 03462 1 no. client: 90437 18797 barware qty 55528 of tested net total richardson 93950 400 sleeve book red 3750 966-98-9665 worth hp 36811 turnerfurt date gbs3dptp69022229570706 living 57499 slim mouse top 29961 2 asteroid 3188 decor workstation computer table burst side each tax 1752 floral trek: chess 3299 items nintendo schmidt cross-estrada 492 room 200 issue: ...
#   {'entities': [(331, 341, 'INVOICE_DATE'),
#     (764, 772, 'INVOICE_NUMBER'),
#     (1319, 1329, 'INVOICE_DATE'),
#     (1522, 1532, 'INVOICE_DATE'),
#     (1747, 1755, 'INVOICE_NUMBER'),
#     (2079, 2089, 'INVOICE_DATE'),
#     (2319, 2327, 'INVOICE_NUMBER'),
#     (4262, 4270, 'INVOICE_NUMBER'),
#     (4368, 4378, 'INVOICE_DATE'),
#     (4499, 4509, 'INVOICE_DATE'),
#     (4951, 4961, 'INVOICE_DATE'),
#     (5429, 5437, 'INVOICE_NUMBER'),
#     (5446, 5456, 'INVOICE_DATE'),
#     (5925, 5935, 'INVOICE_DATE'),
#     (6088, 6098, 'INVOICE_DATE'),
#     (6222, 6230, 'INVOICE_NUMBER'),
#     (6263, 6271, 'INVOICE_NUMBER'),
#     (6354, 6364, 'INVOICE_DATE'),
#     (6679, 6687, 'INVOICE_NUMBER'),
#     (8313, 8323, 'INVOICE_DATE'),
#     (8715, 8723, 'INVOICE_NUMBER'),
#     (9059, 9069, 'INVOICE_DATE'),
#     (9679, 9689, 'INVOICE_DATE'),
#     (9871, 9879, 'INVOICE_NUMBER'),
#     (9915, 9925, 'INVOICE_DATE'),
#     (10242, 10250, 'INVOICE_NUMBER'),
#     (10781, 10789, 'INVOICE_NUMBER'),
#     (11060, 11070, 'INVOICE_DATE'),
#     (11271, 11279, 'INVOICE_NUMBER'),
#     (11280, 11288, 'INVOICE_NUMBER'),
#     (11749, 11757, 'INVOICE_NUMBER'),
#     (12819, 12829, 'INVOICE_DATE'),
#     (13605, 13615, 'INVOICE_DATE'),
#     (14513, 14521, 'INVOICE_NUMBER'),
#     (14811, 14819, 'INVOICE_NUMBER'),
#     (15518, 15526, 'INVOICE_NUMBER'),
#     (15629, 15637, 'INVOICE_NUMBER'),
#     (15775, 15785, 'INVOICE_DATE'),
#     (16867, 16877, 'INVOICE_DATE'),
#     (17471, 17481, 'INVOICE_DATE'),
#     (17724, 17732, 'INVOICE_NUMBER'),
#     (17744, 17752, 'INVOICE_NUMBER'),
#     (17776, 17784, 'INVOICE_NUMBER'),
#     (17869, 17877, 'INVOICE_NUMBER'),
#     (17891, 17899, 'INVOICE_NUMBER'),
#     (18068, 18076, 'INVOICE_NUMBER'),
#     (18882, 18890, 'INVOICE_NUMBER'),
#     (19020, 19028, 'INVOICE_NUMBER'),
#     (19052, 19060, 'INVOICE_NUMBER'),
#     (19131, 19141, 'INVOICE_DATE'),
#     (19350, 19360, 'INVOICE_DATE'),
#     (19554, 19564, 'INVOICE_DATE'),
#     (20095, 20103, 'INVOICE_NUMBER'),
#     (20171, 20181, 'INVOICE_DATE'),
#     (21522, 21532, 'INVOICE_DATE'),
#     (21553, 21563, 'INVOICE_DATE'),
#     (21728, 21736, 'INVOICE_NUMBER'),
#     (22343, 22353, 'INVOICE_DATE'),
#     (22678, 22686, 'INVOICE_NUMBER'),
#     (22979, 22987, 'INVOICE_NUMBER'),
#     (23399, 23407, 'INVOICE_NUMBER'),
#     (23434, 23442, 'INVOICE_NUMBER'),
#     (23443, 23451, 'INVOICE_NUMBER'),
#     (23549, 23559, 'INVOICE_DATE'),
#     (24159, 24167, 'INVOICE_NUMBER'),
#     (24180, 24190, 'INVOICE_DATE'),
#     (24445, 24453, 'INVOICE_NUMBER'),
#     (24538, 24548, 'INVOICE_DATE'),
#     (24735, 24745, 'INVOICE_DATE'),
#     (25804, 25812, 'INVOICE_NUMBER'),
#     (25813, 25823, 'INVOICE_DATE'),
#     (26765, 26773, 'INVOICE_NUMBER'),
#     (26879, 26889, 'INVOICE_DATE'),
#     (27340, 27348, 'INVOICE_NUMBER'),
#     (27472, 27482, 'INVOICE_DATE'),
#     (27907, 27915, 'INVOICE_NUMBER'),
#     (28028, 28036, 'INVOICE_NUMBER'),
#     (28574, 28584, 'INVOICE_DATE'),
#     (28650, 28660, 'INVOICE_DATE'),
#     (28683, 28691, 'INVOICE_NUMBER'),
#     (29309, 29317, 'INVOICE_NUMBER'),
#     (29600, 29608, 'INVOICE_NUMBER'),
#     (29897, 29905, 'INVOICE_NUMBER'),
#     (30178, 30186, 'INVOICE_NUMBER'),
#     (32716, 32726, 'INVOICE_DATE'),
#     (33228, 33238, 'INVOICE_DATE'),
#     (33383, 33393, 'INVOICE_DATE'),
#     (33435, 33445, 'INVOICE_DATE'),
#     (33454, 33462, 'INVOICE_NUMBER'),
#     (33724, 33734, 'INVOICE_DATE'),
#     (34207, 34217, 'INVOICE_DATE'),
#     (34332, 34340, 'INVOICE_NUMBER'),
#     (34532, 34542, 'INVOICE_DATE'),
#     (34628, 34638, 'INVOICE_DATE'),
#     (34776, 34784, 'INVOICE_NUMBER'),
#     (35004, 35012, 'INVOICE_NUMBER'),
#     (35263, 35273, 'INVOICE_DATE'),
#     (35800, 35810, 'INVOICE_DATE'),
#     (36042, 36050, 'INVOICE_NUMBER'),
#     (36171, 36179, 'INVOICE_NUMBER'),
#     (36232, 36242, 'INVOICE_DATE'),
#     (36380, 36388, 'INVOICE_NUMBER'),
#     (37383, 37391, 'INVOICE_NUMBER'),
#     (38561, 38569, 'INVOICE_NUMBER'),
#     (38741, 38749, 'INVOICE_NUMBER'),
#     (39246, 39254, 'INVOICE_NUMBER'),
#     (39483, 39493, 'INVOICE_DATE'),
#     (39583, 39593, 'INVOICE_DATE'),
#     (39918, 39928, 'INVOICE_DATE'),
#     (40075, 40085, 'INVOICE_DATE'),
#     (40619, 40629, 'INVOICE_DATE'),
#     (41233, 41243, 'INVOICE_DATE'),
#     (41707, 41717, 'INVOICE_DATE'),
#     (41793, 41801, 'INVOICE_NUMBER'),
#     (42105, 42113, 'INVOICE_NUMBER'),
#     (42324, 42334, 'INVOICE_DATE'),
#     (42436, 42444, 'INVOICE_NUMBER'),
#     (42501, 42509, 'INVOICE_NUMBER'),
#     (42756, 42764, 'INVOICE_NUMBER'),
#     (43257, 43265, 'INVOICE_NUMBER'),
#     (43393, 43403, 'INVOICE_DATE'),
#     (43463, 43473, 'INVOICE_DATE'),
#     (43506, 43514, 'INVOICE_NUMBER'),
#     (44164, 44174, 'INVOICE_DATE'),
#     (44280, 44288, 'INVOICE_NUMBER'),
#     (44341, 44349, 'INVOICE_NUMBER'),
#     (44580, 44590, 'INVOICE_DATE'),
#     (44685, 44693, 'INVOICE_NUMBER'),
#     (44885, 44893, 'INVOICE_NUMBER'),
#     (44952, 44962, 'INVOICE_DATE'),
#     (45212, 45222, 'INVOICE_DATE'),
#     (45626, 45634, 'INVOICE_NUMBER'),
#     (45767, 45775, 'INVOICE_NUMBER'),
#     (46138, 46148, 'INVOICE_DATE'),
#     (46607, 46617, 'INVOICE_DATE'),
#     (46999, 47009, 'INVOICE_DATE'),
#     (47044, 47052, 'INVOICE_NUMBER'),
#     (47110, 47118, 'INVOICE_NUMBER'),
#     (47164, 47174, 'INVOICE_DATE'),
#     (47445, 47453, 'INVOICE_NUMBER'),
#     (47897, 47905, 'INVOICE_NUMBER'),
#     (48021, 48029, 'INVOICE_NUMBER'),
#     (49500, 49510, 'INVOICE_DATE'),
#     (49684, 49694, 'INVOICE_DATE'),
#     (49910, 49918, 'INVOICE_NUMBER'),
#     (50023, 50031, 'INVOICE_NUMBER'),
#     (50120, 50128, 'INVOICE_NUMBER'),
#     (50238, 50248, 'INVOICE_DATE'),
#     (50422, 50430, 'INVOICE_NUMBER'),
#     (51172, 51182, 'INVOICE_DATE'),
#     (51225, 51235, 'INVOICE_DATE'),
#     (51400, 51408, 'INVOICE_NUMBER'),
#     (52600, 52610, 'INVOICE_DATE'),
#     (52925, 52933, 'INVOICE_NUMBER'),
#     (53027, 53035, 'INVOICE_NUMBER'),
#     (53036, 53044, 'INVOICE_NUMBER'),
#     (53566, 53576, 'INVOICE_DATE'),
#     (53690, 53700, 'INVOICE_DATE'),
#     (54537, 54547, 'INVOICE_DATE'),
#     (54552, 54562, 'INVOICE_DATE'),
#     (54575, 54583, 'INVOICE_NUMBER'),
#     (55279, 55287, 'INVOICE_NUMBER'),
#     (55309, 55317, 'INVOICE_NUMBER'),
#     (55977, 55987, 'INVOICE_DATE'),
#     (55988, 55998, 'INVOICE_DATE'),
#     (55999, 56007, 'INVOICE_NUMBER'),
#     (57519, 57527, 'INVOICE_NUMBER'),
#     (57898, 57908, 'INVOICE_DATE'),
#     (58818, 58828, 'INVOICE_DATE'),
#     (60106, 60116, 'INVOICE_DATE'),
#     (60785, 60795, 'INVOICE_DATE'),
#     (61270, 61278, 'INVOICE_NUMBER'),
#     (61321, 61331, 'INVOICE_DATE'),
#     (61557, 61567, 'INVOICE_DATE'),
#     (62031, 62039, 'INVOICE_NUMBER'),
#     (62237, 62247, 'INVOICE_DATE'),
#     (63113, 63121, 'INVOICE_NUMBER'),
#     (63296, 63306, 'INVOICE_DATE'),
#     (63553, 63561, 'INVOICE_NUMBER'),
#     (63962, 63972, 'INVOICE_DATE'),
#     (63999, 64009, 'INVOICE_DATE'),
#     (64326, 64334, 'INVOICE_NUMBER'),
#     (64671, 64681, 'INVOICE_DATE'),
#     (65842, 65852, 'INVOICE_DATE'),
#     (65873, 65883, 'INVOICE_DATE'),
#     (66218, 66226, 'INVOICE_NUMBER'),
#     (66457, 66465, 'INVOICE_NUMBER'),
#     (67359, 67367, 'INVOICE_NUMBER'),
#     (68039, 68047, 'INVOICE_NUMBER'),
#     (69435, 69443, 'INVOICE_NUMBER'),
#     (69504, 69512, 'INVOICE_NUMBER'),
#     (70295, 70303, 'INVOICE_NUMBER'),
#     (70451, 70459, 'INVOICE_NUMBER'),
#     (70514, 70524, 'INVOICE_DATE'),
#     (71100, 71110, 'INVOICE_DATE'),
#     (71140, 71150, 'INVOICE_DATE'),
#     (71622, 71630, 'INVOICE_NUMBER'),
#     (71812, 71822, 'INVOICE_DATE'),
#     (71912, 71920, 'INVOICE_NUMBER'),
#     (72334, 72344, 'INVOICE_DATE'),
#     (72499, 72507, 'INVOICE_NUMBER'),
#     (72508, 72516, 'INVOICE_NUMBER'),
#     (72628, 72636, 'INVOICE_NUMBER'),
#     (72692, 72700, 'INVOICE_NUMBER'),
#     (72837, 72845, 'INVOICE_NUMBER'),
#     (73232, 73240, 'INVOICE_NUMBER'),
#     (73957, 73965, 'INVOICE_NUMBER'),
#     (74347, 74355, 'INVOICE_NUMBER'),
#     (74468, 74476, 'INVOICE_NUMBER'),
#     (74796, 74806, 'INVOICE_DATE'),
#     (74891, 74901, 'INVOICE_DATE'),
#     (76501, 76511, 'INVOICE_DATE'),
#     (77035, 77045, 'INVOICE_DATE'),
#     (78965, 78975, 'INVOICE_DATE'),
#     (79487, 79497, 'INVOICE_DATE'),
#     (79856, 79864, 'INVOICE_NUMBER'),
#     (79923, 79931, 'INVOICE_NUMBER'),
#     (79932, 79942, 'INVOICE_DATE'),
#     (79985, 79993, 'INVOICE_NUMBER'),
#     (80233, 80241, 'INVOICE_NUMBER'),
#     (80774, 80782, 'INVOICE_NUMBER'),
#     (81746, 81754, 'INVOICE_NUMBER'),
#     (81784, 81792, 'INVOICE_NUMBER'),
#     (82165, 82173, 'INVOICE_NUMBER'),
#     (82189, 82197, 'INVOICE_NUMBER'),
#     (82198, 82206, 'INVOICE_NUMBER'),
#     (82516, 82526, 'INVOICE_DATE'),
#     (82615, 82623, 'INVOICE_NUMBER'),
#     (82667, 82677, 'INVOICE_DATE'),
#     (83104, 83112, 'INVOICE_NUMBER'),
#     (83644, 83654, 'INVOICE_DATE'),
#     (83899, 83907, 'INVOICE_NUMBER'),
#     (84044, 84054, 'INVOICE_DATE'),
#     (84731, 84741, 'INVOICE_DATE'),
#     (85370, 85380, 'INVOICE_DATE'),
#     (85403, 85411, 'INVOICE_NUMBER'),
#     (85652, 85660, 'INVOICE_NUMBER'),
#     (86767, 86775, 'INVOICE_NUMBER'),
#     (86951, 86959, 'INVOICE_NUMBER'),
#     (87986, 87994, 'INVOICE_NUMBER'),
#     (88129, 88137, 'INVOICE_NUMBER'),
#     (88181, 88191, 'INVOICE_DATE'),
#     (88371, 88381, 'INVOICE_DATE'),
#     (88397, 88407, 'INVOICE_DATE'),
#     (88921, 88929, 'INVOICE_NUMBER'),
#     (89160, 89168, 'INVOICE_NUMBER'),
#     (89226, 89236, 'INVOICE_DATE'),
#     (89388, 89398, 'INVOICE_DATE'),
#     (90864, 90874, 'INVOICE_DATE'),
#     (91265, 91275, 'INVOICE_DATE'),
#     (91299, 91309, 'INVOICE_DATE'),
#     (91494, 91504, 'INVOICE_DATE'),
#     (91717, 91727, 'INVOICE_DATE'),
#     (91835, 91845, 'INVOICE_DATE'),
#     (92154, 92164, 'INVOICE_DATE'),
#     (92833, 92841, 'INVOICE_NUMBER'),
#     (92859, 92869, 'INVOICE_DATE'),
#     (93638, 93646, 'INVOICE_NUMBER'),
#     (93759, 93767, 'INVOICE_NUMBER'),
#     (94191, 94199, 'INVOICE_NUMBER'),
#     (94478, 94486, 'INVOICE_NUMBER'),
#     (94626, 94634, 'INVOICE_NUMBER'),
#     (94657, 94667, 'INVOICE_DATE'),
#     (94814, 94824, 'INVOICE_DATE'),
#     (95134, 95142, 'INVOICE_NUMBER'),
#     (95224, 95232, 'INVOICE_NUMBER'),
#     (95893, 95901, 'INVOICE_NUMBER'),
#     (95952, 95962, 'INVOICE_DATE'),
#     (96607, 96617, 'INVOICE_DATE'),
#     (96884, 96894, 'INVOICE_DATE'),
#     (97168, 97178, 'INVOICE_DATE'),
#     (97838, 97848, 'INVOICE_DATE'),
#     (97999, 98007, 'INVOICE_NUMBER'),
#     (99150, 99158, 'INVOICE_NUMBER'),
#     (99481, 99491, 'INVOICE_DATE'),
#     (99508, 99516, 'INVOICE_NUMBER'),
#     (100223, 100233, 'INVOICE_DATE'),
#     (101498, 101508, 'INVOICE_DATE'),
#     (102552, 102562, 'INVOICE_DATE'),
#     (102849, 102857, 'INVOICE_NUMBER'),
#     (103225, 103233, 'INVOICE_NUMBER'),
#     (103437, 103447, 'INVOICE_DATE'),
#     (103861, 103869, 'INVOICE_NUMBER'),
#     (103997, 104007, 'INVOICE_DATE'),
#     (104371, 104381, 'INVOICE_DATE'),
#     (104911, 104919, 'INVOICE_NUMBER'),
#     (105140, 105150, 'INVOICE_DATE'),
#     (105877, 105887, 'INVOICE_DATE'),
#     (106249, 106257, 'INVOICE_NUMBER'),
#     (106266, 106276, 'INVOICE_DATE'),
#     (106333, 106343, 'INVOICE_DATE'),
#     (106592, 106602, 'INVOICE_DATE'),
#     (106735, 106743, 'INVOICE_NUMBER'),
#     (107283, 107291, 'INVOICE_NUMBER'),
#     (107895, 107905, 'INVOICE_DATE'),
#     (108136, 108144, 'INVOICE_NUMBER'),
#     (108230, 108238, 'INVOICE_NUMBER'),
#     (108356, 108364, 'INVOICE_NUMBER'),
#     (108455, 108463, 'INVOICE_NUMBER'),
#     (109755, 109763, 'INVOICE_NUMBER'),
#     (110070, 110080, 'INVOICE_DATE'),
#     (110146, 110154, 'INVOICE_NUMBER'),
#     (110595, 110603, 'INVOICE_NUMBER'),
#     (111249, 111259, 'INVOICE_DATE'),
#     (113119, 113129, 'INVOICE_DATE'),
#     (113605, 113613, 'INVOICE_NUMBER'),
#     (113811, 113821, 'INVOICE_DATE'),
#     (113863, 113873, 'INVOICE_DATE'),
#     (114619, 114627, 'INVOICE_NUMBER'),
#     (115527, 115535, 'INVOICE_NUMBER'),
#     (116186, 116196, 'INVOICE_DATE'),
#     (116240, 116248, 'INVOICE_NUMBER'),
#     (116429, 116437, 'INVOICE_NUMBER'),
#     (117254, 117264, 'INVOICE_DATE'),
#     (117588, 117596, 'INVOICE_NUMBER'),
#     (117634, 117644, 'INVOICE_DATE'),
#     (118955, 118963, 'INVOICE_NUMBER'),
#     (119001, 119011, 'INVOICE_DATE'),
#     (119988, 119996, 'INVOICE_NUMBER'),
#     (120221, 120231, 'INVOICE_DATE'),
#     (120281, 120291, 'INVOICE_DATE'),
#     (120340, 120348, 'INVOICE_NUMBER'),
#     (120683, 120691, 'INVOICE_NUMBER'),
#     (121033, 121041, 'INVOICE_NUMBER'),
#     (123228, 123236, 'INVOICE_NUMBER'),
#     (123481, 123491, 'INVOICE_DATE'),
#     (124295, 124305, 'INVOICE_DATE'),
#     (124363, 124373, 'INVOICE_DATE'),
#     (125529, 125539, 'INVOICE_DATE'),
#     (126336, 126346, 'INVOICE_DATE'),
#     (127054, 127062, 'INVOICE_NUMBER'),
#     (127421, 127431, 'INVOICE_DATE'),
#     (127666, 127676, 'INVOICE_DATE'),
#     (127799, 127807, 'INVOICE_NUMBER'),
#     (129131, 129139, 'INVOICE_NUMBER'),
#     (129240, 129248, 'INVOICE_NUMBER'),
#     (129484, 129492, 'INVOICE_NUMBER'),
#     (129614, 129624, 'INVOICE_DATE'),
#     (129674, 129682, 'INVOICE_NUMBER'),
#     (129720, 129730, 'INVOICE_DATE'),
#     (129945, 129953, 'INVOICE_NUMBER'),
#     (131397, 131405, 'INVOICE_NUMBER'),
#     (131977, 131987, 'INVOICE_DATE'),
#     (132199, 132209, 'INVOICE_DATE'),
#     (132681, 132691, 'INVOICE_DATE'),
#     (132959, 132967, 'INVOICE_NUMBER'),
#     (133163, 133171, 'INVOICE_NUMBER'),
#     (134241, 134251, 'INVOICE_DATE'),
#     (134711, 134719, 'INVOICE_NUMBER'),
#     (134720, 134728, 'INVOICE_NUMBER'),
#     (135465, 135473, 'INVOICE_NUMBER'),
#     (135714, 135724, 'INVOICE_DATE'),
#     (136028, 136036, 'INVOICE_NUMBER'),
#     (136140, 136148, 'INVOICE_NUMBER'),
#     (136300, 136308, 'INVOICE_NUMBER'),
#     (136323, 136333, 'INVOICE_DATE'),
#     (136831, 136841, 'INVOICE_DATE'),
#     (137176, 137184, 'INVOICE_NUMBER'),
#     (137482, 137492, 'INVOICE_DATE'),
#     (138316, 138324, 'INVOICE_NUMBER'),
#     (138742, 138752, 'INVOICE_DATE'),
#     (139121, 139129, 'INVOICE_NUMBER'),
#     (139195, 139203, 'INVOICE_NUMBER'),
#     (139333, 139343, 'INVOICE_DATE'),
#     (140503, 140513, 'INVOICE_DATE'),
#     (141023, 141031, 'INVOICE_NUMBER'),
#     (141091, 141101, 'INVOICE_DATE'),
#     (141676, 141686, 'INVOICE_DATE'),
#     (141765, 141773, 'INVOICE_NUMBER'),
#     (141829, 141837, 'INVOICE_NUMBER'),
#     (142288, 142298, 'INVOICE_DATE'),
#     (142600, 142608, 'INVOICE_NUMBER'),
#     (142902, 142912, 'INVOICE_DATE'),
#     (143075, 143085, 'INVOICE_DATE'),
#     (144033, 144041, 'INVOICE_NUMBER'),
#     (144341, 144351, 'INVOICE_DATE'),
#     (144691, 144699, 'INVOICE_NUMBER'),
#     (145532, 145542, 'INVOICE_DATE'),
#     (145566, 145574, 'INVOICE_NUMBER'),
#     (146542, 146550, 'INVOICE_NUMBER'),
#     (148184, 148192, 'INVOICE_NUMBER'),
#     (148603, 148613, 'INVOICE_DATE'),
#     (148914, 148924, 'INVOICE_DATE'),
#     (151441, 151451, 'INVOICE_DATE'),
#     (151574, 151582, 'INVOICE_NUMBER'),
#     (151589, 151599, 'INVOICE_DATE'),
#     (151881, 151889, 'INVOICE_NUMBER'),
#     (152374, 152384, 'INVOICE_DATE'),
#     (152985, 152993, 'INVOICE_NUMBER'),
#     (153048, 153058, 'INVOICE_DATE'),
#     (153106, 153116, 'INVOICE_DATE'),
#     (153683, 153693, 'INVOICE_DATE'),
#     (153733, 153743, 'INVOICE_DATE'),
#     (155286, 155294, 'INVOICE_NUMBER'),
#     (155558, 155568, 'INVOICE_DATE'),
#     (156844, 156852, 'INVOICE_NUMBER'),
#     (156884, 156892, 'INVOICE_NUMBER'),
#     (158067, 158075, 'INVOICE_NUMBER'),
#     (158141, 158149, 'INVOICE_NUMBER'),
#     (158464, 158472, 'INVOICE_NUMBER'),
#     (158890, 158898, 'INVOICE_NUMBER'),
#     (159415, 159423, 'INVOICE_NUMBER'),
#     (159669, 159679, 'INVOICE_DATE'),
#     (160288, 160296, 'INVOICE_NUMBER'),
#     (160528, 160538, 'INVOICE_DATE'),
#     (161066, 161074, 'INVOICE_NUMBER'),
#     (161256, 161264, 'INVOICE_NUMBER'),
#     (161755, 161765, 'INVOICE_DATE'),
#     (161924, 161934, 'INVOICE_DATE'),
#     (162053, 162063, 'INVOICE_DATE'),
#     (162364, 162372, 'INVOICE_NUMBER'),
#     (163721, 163731, 'INVOICE_DATE'),
#     (165938, 165948, 'INVOICE_DATE'),
#     (166549, 166559, 'INVOICE_DATE'),
#     (166647, 166657, 'INVOICE_DATE'),
#     (166920, 166930, 'INVOICE_DATE'),
#     (167315, 167323, 'INVOICE_NUMBER'),
#     (167797, 167807, 'INVOICE_DATE'),
#     (168175, 168183, 'INVOICE_NUMBER'),
#     (168188, 168196, 'INVOICE_NUMBER'),
#     (168268, 168276, 'INVOICE_NUMBER'),
#     (168309, 168319, 'INVOICE_DATE'),
#     (168938, 168948, 'INVOICE_DATE'),
#     (168993, 169003, 'INVOICE_DATE'),
#     (169624, 169632, 'INVOICE_NUMBER'),
#     (169907, 169917, 'INVOICE_DATE'),
#     (170872, 170880, 'INVOICE_NUMBER'),
#     (170965, 170975, 'INVOICE_DATE'),
#     (171120, 171128, 'INVOICE_NUMBER'),
#     (171129, 171139, 'INVOICE_DATE'),
#     (171290, 171298, 'INVOICE_NUMBER'),
#     (171743, 171753, 'INVOICE_DATE'),
#     (171764, 171772, 'INVOICE_NUMBER'),
#     (172053, 172061, 'INVOICE_NUMBER'),
#     (172438, 172448, 'INVOICE_DATE'),
#     (173008, 173018, 'INVOICE_DATE'),
#     (173521, 173531, 'INVOICE_DATE'),
#     (173547, 173557, 'INVOICE_DATE'),
#     (173605, 173613, 'INVOICE_NUMBER'),
#     (175553, 175563, 'INVOICE_DATE'),
#     (175572, 175580, 'INVOICE_NUMBER'),
#     (175760, 175768, 'INVOICE_NUMBER'),
#     (175934, 175944, 'INVOICE_DATE'),
#     (176354, 176362, 'INVOICE_NUMBER'),
#     (177311, 177319, 'INVOICE_NUMBER'),
#     (177486, 177494, 'INVOICE_NUMBER'),
#     (177723, 177731, 'INVOICE_NUMBER'),
#     (178101, 178109, 'INVOICE_NUMBER'),
#     (178451, 178459, 'INVOICE_NUMBER'),
#     (179133, 179143, 'INVOICE_DATE'),
#     (179506, 179514, 'INVOICE_NUMBER'),
#     (179719, 179729, 'INVOICE_DATE'),
#     (179838, 179848, 'INVOICE_DATE'),
#     (179898, 179906, 'INVOICE_NUMBER'),
#     (180647, 180657, 'INVOICE_DATE'),
#     (180678, 180686, 'INVOICE_NUMBER'),
#     (181272, 181282, 'INVOICE_DATE'),
#     (181372, 181380, 'INVOICE_NUMBER'),
#     (181465, 181473, 'INVOICE_NUMBER'),
#     (181967, 181975, 'INVOICE_NUMBER'),
#     (182220, 182228, 'INVOICE_NUMBER'),
#     (182668, 182678, 'INVOICE_DATE'),
#     (183341, 183351, 'INVOICE_DATE'),
#     (183605, 183615, 'INVOICE_DATE'),
#     (184041, 184049, 'INVOICE_NUMBER'),
#     (184495, 184505, 'INVOICE_DATE'),
#     (184611, 184621, 'INVOICE_DATE'),
#     (184978, 184988, 'INVOICE_DATE'),
#     (185709, 185719, 'INVOICE_DATE'),
#     (185922, 185932, 'INVOICE_DATE'),
#     (186127, 186135, 'INVOICE_NUMBER'),
#     (186574, 186584, 'INVOICE_DATE'),
#     (187619, 187627, 'INVOICE_NUMBER'),
#     (187678, 187686, 'INVOICE_NUMBER'),
#     (187805, 187815, 'INVOICE_DATE'),
#     (188086, 188096, 'INVOICE_DATE'),
#     (188480, 188490, 'INVOICE_DATE'),
#     (188606, 188614, 'INVOICE_NUMBER'),
#     (188686, 188694, 'INVOICE_NUMBER'),
#     (188799, 188807, 'INVOICE_NUMBER'),
#     (189167, 189175, 'INVOICE_NUMBER'),
#     (189481, 189489, 'INVOICE_NUMBER'),
#     (190166, 190176, 'INVOICE_DATE'),
#     (190566, 190574, 'INVOICE_NUMBER'),
#     (190947, 190957, 'INVOICE_DATE'),
#     (191144, 191154, 'INVOICE_DATE'),
#     (191438, 191448, 'INVOICE_DATE'),
#     (191454, 191464, 'INVOICE_DATE'),
#     (191896, 191904, 'INVOICE_NUMBER'),
#     (192081, 192089, 'INVOICE_NUMBER'),
#     (192638, 192646, 'INVOICE_NUMBER'),
#     (192696, 192704, 'INVOICE_NUMBER'),
#     (193227, 193237, 'INVOICE_DATE'),
#     (193590, 193600, 'INVOICE_DATE'),
#     (193677, 193685, 'INVOICE_NUMBER'),
#     (193721, 193729, 'INVOICE_NUMBER'),
#     (193815, 193825, 'INVOICE_DATE'),
#     (194760, 194770, 'INVOICE_DATE'),
#     (195243, 195251, 'INVOICE_NUMBER'),
#     (195711, 195719, 'INVOICE_NUMBER'),
#     (197152, 197160, 'INVOICE_NUMBER'),
#     (197213, 197221, 'INVOICE_NUMBER'),
#     (197907, 197915, 'INVOICE_NUMBER'),
#     (198580, 198590, 'INVOICE_DATE'),
#     (199949, 199959, 'INVOICE_DATE'),
#     (200809, 200817, 'INVOICE_NUMBER'),
#     (201038, 201046, 'INVOICE_NUMBER'),
#     (201101, 201111, 'INVOICE_DATE'),
#     (201182, 201192, 'INVOICE_DATE'),
#     (201619, 201629, 'INVOICE_DATE'),
#     (201739, 201749, 'INVOICE_DATE'),
#     (202592, 202602, 'INVOICE_DATE'),
#     (202799, 202809, 'INVOICE_DATE'),
#     (202889, 202899, 'INVOICE_DATE'),
#     (202994, 203004, 'INVOICE_DATE'),
#     (204091, 204101, 'INVOICE_DATE'),
#     (204142, 204152, 'INVOICE_DATE'),
#     (204712, 204722, 'INVOICE_DATE'),
#     (204929, 204937, 'INVOICE_NUMBER'),
#     (205001, 205011, 'INVOICE_DATE'),
#     (205591, 205599, 'INVOICE_NUMBER'),
#     (206336, 206346, 'INVOICE_DATE'),
#     (206823, 206831, 'INVOICE_NUMBER'),
#     (207142, 207150, 'INVOICE_NUMBER'),
#     (207204, 207214, 'INVOICE_DATE'),
#     (207974, 207984, 'INVOICE_DATE'),
#     (208524, 208534, 'INVOICE_DATE'),
#     (208797, 208807, 'INVOICE_DATE'),
#     (208819, 208827, 'INVOICE_NUMBER'),
#     (209228, 209236, 'INVOICE_NUMBER'),
#     (209467, 209477, 'INVOICE_DATE'),
#     (209535, 209543, 'INVOICE_NUMBER'),
#     (210693, 210703, 'INVOICE_DATE'),
#     (210815, 210825, 'INVOICE_DATE'),
#     (211132, 211142, 'INVOICE_DATE'),
#     (211260, 211268, 'INVOICE_NUMBER'),
#     (211684, 211694, 'INVOICE_DATE'),
#     (211754, 211762, 'INVOICE_NUMBER'),
#     (212293, 212301, 'INVOICE_NUMBER'),
#     (212653, 212661, 'INVOICE_NUMBER'),
#     (212835, 212843, 'INVOICE_NUMBER'),
#     (212894, 212902, 'INVOICE_NUMBER'),
#     (213040, 213050, 'INVOICE_DATE'),
#     (213086, 213094, 'INVOICE_NUMBER'),
#     (213360, 213370, 'INVOICE_DATE'),
#     (213417, 213427, 'INVOICE_DATE'),
#     (213869, 213877, 'INVOICE_NUMBER'),
#     (214130, 214140, 'INVOICE_DATE'),
#     (215716, 215724, 'INVOICE_NUMBER'),
#     (215939, 215947, 'INVOICE_NUMBER'),
#     (216713, 216721, 'INVOICE_NUMBER'),
#     (216753, 216763, 'INVOICE_DATE'),
#     (217773, 217781, 'INVOICE_NUMBER'),
#     (217943, 217953, 'INVOICE_DATE'),
#     (218152, 218160, 'INVOICE_NUMBER'),
#     (218315, 218325, 'INVOICE_DATE'),
#     (218937, 218945, 'INVOICE_NUMBER'),
#     (219030, 219040, 'INVOICE_DATE'),
#     (219186, 219196, 'INVOICE_DATE'),
#     (219746, 219754, 'INVOICE_NUMBER'),
#     (219872, 219880, 'INVOICE_NUMBER'),
#     (219982, 219990, 'INVOICE_NUMBER'),
#     (221054, 221064, 'INVOICE_DATE'),
#     (221270, 221278, 'INVOICE_NUMBER'),
#     (221783, 221791, 'INVOICE_NUMBER'),
#     (221792, 221802, 'INVOICE_DATE'),
#     (223118, 223128, 'INVOICE_DATE'),
#     (223237, 223245, 'INVOICE_NUMBER'),
#     (224324, 224334, 'INVOICE_DATE'),
#     (224335, 224345, 'INVOICE_DATE'),
#     (224592, 224600, 'INVOICE_NUMBER'),
#     (224633, 224641, 'INVOICE_NUMBER'),
#     (225259, 225267, 'INVOICE_NUMBER'),
#     (225529, 225537, 'INVOICE_NUMBER'),
#     (225913, 225921, 'INVOICE_NUMBER'),
#     (226205, 226215, 'INVOICE_DATE'),
#     (226319, 226329, 'INVOICE_DATE'),
#     (227726, 227736, 'INVOICE_DATE'),
#     (228313, 228321, 'INVOICE_NUMBER'),
#     (228994, 229004, 'INVOICE_DATE'),
#     (229173, 229181, 'INVOICE_NUMBER'),
#     (229989, 229997, 'INVOICE_NUMBER'),
#     (230200, 230208, 'INVOICE_NUMBER'),
#     (230598, 230606, 'INVOICE_NUMBER'),
#     (230798, 230806, 'INVOICE_NUMBER'),
#     (230812, 230822, 'INVOICE_DATE'),
#     (230912, 230922, 'INVOICE_DATE'),
#     (230923, 230931, 'INVOICE_NUMBER'),
#     (231197, 231207, 'INVOICE_DATE'),
#     (231822, 231832, 'INVOICE_DATE'),
#     (232035, 232043, 'INVOICE_NUMBER'),
#     (233034, 233044, 'INVOICE_DATE'),
#     (233396, 233406, 'INVOICE_DATE'),
#     (234224, 234234, 'INVOICE_DATE'),
#     (234539, 234549, 'INVOICE_DATE'),
#     (235245, 235253, 'INVOICE_NUMBER'),
#     (235774, 235784, 'INVOICE_DATE'),
#     (236425, 236433, 'INVOICE_NUMBER'),
#     (236543, 236553, 'INVOICE_DATE'),
#     (237272, 237282, 'INVOICE_DATE'),
#     (237686, 237694, 'INVOICE_NUMBER'),
#     (237784, 237794, 'INVOICE_DATE'),
#     (237999, 238009, 'INVOICE_DATE'),
#     (238691, 238699, 'INVOICE_NUMBER'),
#     (239346, 239356, 'INVOICE_DATE'),
#     (239618, 239626, 'INVOICE_NUMBER'),
#     (239802, 239810, 'INVOICE_NUMBER'),
#     (239929, 239939, 'INVOICE_DATE'),
#     (240228, 240238, 'INVOICE_DATE'),
#     (240530, 240540, 'INVOICE_DATE'),
#     (240559, 240569, 'INVOICE_DATE'),
#     (241641, 241649, 'INVOICE_NUMBER'),
#     (241715, 241725, 'INVOICE_DATE'),
#     (241760, 241768, 'INVOICE_NUMBER'),
#     (242266, 242274, 'INVOICE_NUMBER'),
#     (243093, 243101, 'INVOICE_NUMBER'),
#     (243134, 243142, 'INVOICE_NUMBER'),
#     (243509, 243517, 'INVOICE_NUMBER'),
#     (244528, 244538, 'INVOICE_DATE'),
#     (244543, 244551, 'INVOICE_NUMBER'),
#     (245117, 245127, 'INVOICE_DATE'),
#     (245266, 245274, 'INVOICE_NUMBER'),
#     (245287, 245297, 'INVOICE_DATE'),
#     (245332, 245340, 'INVOICE_NUMBER'),
#     (245683, 245693, 'INVOICE_DATE'),
#     (245935, 245943, 'INVOICE_NUMBER'),
#     (246003, 246011, 'INVOICE_NUMBER'),
#     (246236, 246244, 'INVOICE_NUMBER'),
#     (246489, 246497, 'INVOICE_NUMBER'),
#     (246512, 246520, 'INVOICE_NUMBER'),
#     (246866, 246876, 'INVOICE_DATE'),
#     (246909, 246919, 'INVOICE_DATE'),
#     (246961, 246971, 'INVOICE_DATE'),
#     (247554, 247562, 'INVOICE_NUMBER'),
#     (247939, 247947, 'INVOICE_NUMBER'),
#     (248733, 248743, 'INVOICE_DATE'),
#     (248894, 248902, 'INVOICE_NUMBER'),
#     (248951, 248959, 'INVOICE_NUMBER'),
#     (249342, 249352, 'INVOICE_DATE'),
#     (249702, 249712, 'INVOICE_DATE'),
#     (249884, 249892, 'INVOICE_NUMBER'),
#     (250920, 250928, 'INVOICE_NUMBER'),
#     (251002, 251012, 'INVOICE_DATE'),
#     (251081, 251089, 'INVOICE_NUMBER'),
#     (251553, 251563, 'INVOICE_DATE'),
#     (251564, 251574, 'INVOICE_DATE'),
#     (251835, 251843, 'INVOICE_NUMBER'),
#     (252343, 252351, 'INVOICE_NUMBER'),
#     (252416, 252426, 'INVOICE_DATE'),
#     (252851, 252859, 'INVOICE_NUMBER'),
#     (252980, 252990, 'INVOICE_DATE'),
#     (253130, 253138, 'INVOICE_NUMBER'),
#     (253433, 253441, 'INVOICE_NUMBER'),
#     (253480, 253488, 'INVOICE_NUMBER'),
#     (253527, 253535, 'INVOICE_NUMBER'),
#     (254301, 254309, 'INVOICE_NUMBER'),
#     (254479, 254487, 'INVOICE_NUMBER'),
#     (254583, 254593, 'INVOICE_DATE'),
#     (254688, 254696, 'INVOICE_NUMBER'),
#     (254721, 254729, 'INVOICE_NUMBER'),
#     (255390, 255398, 'INVOICE_NUMBER'),
#     (255752, 255760, 'INVOICE_NUMBER'),
#     (256750, 256760, 'INVOICE_DATE'),
#     (257340, 257350, 'INVOICE_DATE'),
#     (258359, 258369, 'INVOICE_DATE'),
#     (258486, 258496, 'INVOICE_DATE'),
#     (259596, 259604, 'INVOICE_NUMBER'),
#     (259747, 259755, 'INVOICE_NUMBER'),
#     (259833, 259841, 'INVOICE_NUMBER'),
#     (259919, 259927, 'INVOICE_NUMBER'),
#     (260117, 260127, 'INVOICE_DATE'),
#     (260199, 260207, 'INVOICE_NUMBER'),
#     (260421, 260431, 'INVOICE_DATE'),
#     (260443, 260453, 'INVOICE_DATE'),
#     (260863, 260871, 'INVOICE_NUMBER'),
#     (260949, 260957, 'INVOICE_NUMBER'),
#     (261141, 261149, 'INVOICE_NUMBER'),
#     (261507, 261515, 'INVOICE_NUMBER'),
#     (261832, 261840, 'INVOICE_NUMBER'),
#     (261897, 261905, 'INVOICE_NUMBER'),
#     (262000, 262010, 'INVOICE_DATE'),
#     (262425, 262433, 'INVOICE_NUMBER'),
#     (263658, 263666, 'INVOICE_NUMBER'),
#     (263877, 263885, 'INVOICE_NUMBER'),
#     (264324, 264334, 'INVOICE_DATE'),
#     (264427, 264435, 'INVOICE_NUMBER'),
#     (264806, 264816, 'INVOICE_DATE'),
#     (264839, 264849, 'INVOICE_DATE'),
#     (265178, 265186, 'INVOICE_NUMBER'),
#     (265427, 265435, 'INVOICE_NUMBER'),
#     (265538, 265546, 'INVOICE_NUMBER'),
#     (265638, 265646, 'INVOICE_NUMBER'),
#     (267582, 267592, 'INVOICE_DATE'),
#     (267704, 267714, 'INVOICE_DATE'),
#     (267843, 267853, 'INVOICE_DATE'),
#     (268139, 268149, 'INVOICE_DATE'),
#     (268232, 268242, 'INVOICE_DATE'),
#     (268343, 268351, 'INVOICE_NUMBER'),
#     (269314, 269322, 'INVOICE_NUMBER'),
#     (269402, 269410, 'INVOICE_NUMBER'),
#     (269622, 269632, 'INVOICE_DATE'),
#     (269711, 269719, 'INVOICE_NUMBER'),
#     (270005, 270013, 'INVOICE_NUMBER'),
#     (270590, 270598, 'INVOICE_NUMBER'),
#     (270814, 270822, 'INVOICE_NUMBER'),
#     (271735, 271745, 'INVOICE_DATE'),
#     (272274, 272282, 'INVOICE_NUMBER'),
#     (272467, 272475, 'INVOICE_NUMBER'),
#     (272670, 272678, 'INVOICE_NUMBER'),
#     (272782, 272792, 'INVOICE_DATE'),
#     (273796, 273804, 'INVOICE_NUMBER'),
#     (273805, 273813, 'INVOICE_NUMBER'),
#     (273908, 273916, 'INVOICE_NUMBER'),
#     (274426, 274434, 'INVOICE_NUMBER'),
#     (274601, 274611, 'INVOICE_DATE'),
#     (275085, 275095, 'INVOICE_DATE'),
#     (275096, 275104, 'INVOICE_NUMBER'),
#     (275924, 275932, 'INVOICE_NUMBER'),
#     (276464, 276472, 'INVOICE_NUMBER'),
#     (277050, 277058, 'INVOICE_NUMBER'),
#     (277278, 277288, 'INVOICE_DATE'),
#     (277627, 277635, 'INVOICE_NUMBER'),
#     (277648, 277656, 'INVOICE_NUMBER'),
#     (278210, 278218, 'INVOICE_NUMBER'),
#     (278293, 278303, 'INVOICE_DATE'),
#     (278365, 278373, 'INVOICE_NUMBER'),
#     (278384, 278392, 'INVOICE_NUMBER'),
#     (278842, 278852, 'INVOICE_DATE'),
#     (279289, 279299, 'INVOICE_DATE'),
#     (279310, 279320, 'INVOICE_DATE'),
#     (279890, 279900, 'INVOICE_DATE'),
#     (280374, 280384, 'INVOICE_DATE'),
#     (280433, 280443, 'INVOICE_DATE'),
#     (280444, 280454, 'INVOICE_DATE'),
#     (280751, 280761, 'INVOICE_DATE'),
#     (280767, 280777, 'INVOICE_DATE'),
#     (281676, 281684, 'INVOICE_NUMBER'),
#     (281832, 281840, 'INVOICE_NUMBER'),
#     (282010, 282018, 'INVOICE_NUMBER'),
#     (282162, 282170, 'INVOICE_NUMBER'),
#     (282617, 282625, 'INVOICE_NUMBER'),
#     (283162, 283172, 'INVOICE_DATE'),
#     (283482, 283492, 'INVOICE_DATE'),
#     (283951, 283961, 'INVOICE_DATE'),
#     (284399, 284409, 'INVOICE_DATE'),
#     (285489, 285497, 'INVOICE_NUMBER'),
#     (285662, 285672, 'INVOICE_DATE'),
#     (285731, 285741, 'INVOICE_DATE'),
#     (285899, 285907, 'INVOICE_NUMBER'),
#     (286202, 286210, 'INVOICE_NUMBER'),
#     (286402, 286412, 'INVOICE_DATE'),
#     (286601, 286609, 'INVOICE_NUMBER'),
#     (287055, 287065, 'INVOICE_DATE'),
#     (287361, 287371, 'INVOICE_DATE'),
#     (287514, 287522, 'INVOICE_NUMBER'),
#     (287611, 287621, 'INVOICE_DATE'),
#     (287637, 287645, 'INVOICE_NUMBER'),
#     (287741, 287751, 'INVOICE_DATE'),
#     (287835, 287843, 'INVOICE_NUMBER'),
#     (288578, 288588, 'INVOICE_DATE'),
#     (288619, 288629, 'INVOICE_DATE'),
#     (289780, 289788, 'INVOICE_NUMBER'),
#     (290300, 290308, 'INVOICE_NUMBER'),
#     (290744, 290754, 'INVOICE_DATE'),
#     (291141, 291151, 'INVOICE_DATE'),
#     (291517, 291525, 'INVOICE_NUMBER'),
#     (291884, 291892, 'INVOICE_NUMBER'),
#     (291937, 291947, 'INVOICE_DATE'),
#     (294955, 294965, 'INVOICE_DATE'),
#     (295646, 295656, 'INVOICE_DATE'),
#     (296170, 296178, 'INVOICE_NUMBER'),
#     (296439, 296449, 'INVOICE_DATE'),
#     (296681, 296689, 'INVOICE_NUMBER'),
#     (297015, 297023, 'INVOICE_NUMBER'),
#     (297192, 297200, 'INVOICE_NUMBER'),
#     (297732, 297740, 'INVOICE_NUMBER'),
#     (298413, 298421, 'INVOICE_NUMBER'),
#     (298704, 298714, 'INVOICE_DATE'),
#     (298855, 298863, 'INVOICE_NUMBER'),
#     (299295, 299303, 'INVOICE_NUMBER'),
#     (299438, 299448, 'INVOICE_DATE'),
#     (299538, 299548, 'INVOICE_DATE'),
#     (299772, 299782, 'INVOICE_DATE'),
#     (299889, 299897, 'INVOICE_NUMBER'),
#     (300667, 300677, 'INVOICE_DATE'),
#     (301374, 301382, 'INVOICE_NUMBER'),
#     (301551, 301559, 'INVOICE_NUMBER'),
#     (301908, 301916, 'INVOICE_NUMBER'),
#     (302191, 302201, 'INVOICE_DATE'),
#     (302556, 302564, 'INVOICE_NUMBER'),
#     (302625, 302635, 'INVOICE_DATE'),
#     (303019, 303029, 'INVOICE_DATE'),
#     (303424, 303434, 'INVOICE_DATE'),
#     (303651, 303659, 'INVOICE_NUMBER'),
#     (304487, 304495, 'INVOICE_NUMBER'),
#     (304663, 304671, 'INVOICE_NUMBER'),
#     (304703, 304711, 'INVOICE_NUMBER'),
#     (304949, 304959, 'INVOICE_DATE'),
#     (306075, 306085, 'INVOICE_DATE'),
#     (306436, 306444, 'INVOICE_NUMBER'),
#     (306678, 306686, 'INVOICE_NUMBER'),
#     (306886, 306896, 'INVOICE_DATE'),
#     (307232, 307240, 'INVOICE_NUMBER'),
#     (307347, 307355, 'INVOICE_NUMBER'),
#     (309146, 309154, 'INVOICE_NUMBER'),
#     (309334, 309344, 'INVOICE_DATE'),
#     (309452, 309460, 'INVOICE_NUMBER'),
#     (310396, 310404, 'INVOICE_NUMBER'),
#     (311497, 311507, 'INVOICE_DATE'),
#     (312222, 312232, 'INVOICE_DATE'),
#     (313044, 313052, 'INVOICE_NUMBER'),
#     (313131, 313141, 'INVOICE_DATE'),
#     (313290, 313298, 'INVOICE_NUMBER'),
#     (313340, 313348, 'INVOICE_NUMBER'),
#     (313779, 313789, 'INVOICE_DATE'),
#     (314122, 314130, 'INVOICE_NUMBER'),
#     (316415, 316425, 'INVOICE_DATE'),
#     (316515, 316525, 'INVOICE_DATE'),
#     (316591, 316599, 'INVOICE_NUMBER'),
#     (316704, 316714, 'INVOICE_DATE'),
#     (317502, 317512, 'INVOICE_DATE'),
#     (318737, 318745, 'INVOICE_NUMBER'),
#     (318878, 318886, 'INVOICE_NUMBER'),
#     (319048, 319058, 'INVOICE_DATE'),
#     (319226, 319234, 'INVOICE_NUMBER'),
#     (319330, 319340, 'INVOICE_DATE'),
#     (319352, 319362, 'INVOICE_DATE'),
#     (320431, 320439, 'INVOICE_NUMBER'),
#     (320614, 320624, 'INVOICE_DATE'),
#     (320873, 320883, 'INVOICE_DATE'),
#     (322831, 322841, 'INVOICE_DATE'),
#     (322941, 322949, 'INVOICE_NUMBER'),
#     (323267, 323275, 'INVOICE_NUMBER'),
#     (324176, 324184, 'INVOICE_NUMBER'),
#     (324540, 324548, 'INVOICE_NUMBER'),
#     (324583, 324593, 'INVOICE_DATE'),
#     (325056, 325066, 'INVOICE_DATE'),
#     (325296, 325304, 'INVOICE_NUMBER'),
#     (325690, 325698, 'INVOICE_NUMBER'),
#     (326021, 326029, 'INVOICE_NUMBER'),
#     (326573, 326581, 'INVOICE_NUMBER'),
#     (326658, 326666, 'INVOICE_NUMBER'),
#     (326682, 326690, 'INVOICE_NUMBER'),
#     (327969, 327977, 'INVOICE_NUMBER'),
#     (328133, 328143, 'INVOICE_DATE'),
#     (328468, 328478, 'INVOICE_DATE'),
#     (328493, 328501, 'INVOICE_NUMBER'),
#     (329298, 329308, 'INVOICE_DATE'),
#     (330583, 330591, 'INVOICE_NUMBER'),
#     (332183, 332193, 'INVOICE_DATE'),
#     (332756, 332766, 'INVOICE_DATE'),
#     (333003, 333013, 'INVOICE_DATE'),
#     (333876, 333886, 'INVOICE_DATE'),
#     (334566, 334576, 'INVOICE_DATE'),
#     (334590, 334600, 'INVOICE_DATE'),
#     (334863, 334873, 'INVOICE_DATE'),
#     (335272, 335280, 'INVOICE_NUMBER'),
#     (335538, 335546, 'INVOICE_NUMBER'),
#     (335623, 335631, 'INVOICE_NUMBER'),
#     (335648, 335656, 'INVOICE_NUMBER'),
#     (335778, 335786, 'INVOICE_NUMBER'),
#     (336253, 336261, 'INVOICE_NUMBER'),
#     (336369, 336379, 'INVOICE_DATE'),
#     (336505, 336513, 'INVOICE_NUMBER'),
#     (336898, 336908, 'INVOICE_DATE'),
#     (336923, 336933, 'INVOICE_DATE'),
#     (336990, 337000, 'INVOICE_DATE'),
#     (337408, 337416, 'INVOICE_NUMBER'),
#     (337891, 337899, 'INVOICE_NUMBER'),
#     (338625, 338633, 'INVOICE_NUMBER'),
#     (338937, 338947, 'INVOICE_DATE'),
#     (338993, 339001, 'INVOICE_NUMBER'),
#     (339677, 339687, 'INVOICE_DATE'),
#     (339985, 339995, 'INVOICE_DATE'),
#     (341204, 341214, 'INVOICE_DATE'),
#     (341976, 341986, 'INVOICE_DATE'),
#     (342019, 342029, 'INVOICE_DATE'),
#     (342631, 342639, 'INVOICE_NUMBER'),
#     (342655, 342663, 'INVOICE_NUMBER'),
#     (342838, 342848, 'INVOICE_DATE'),
#     (342911, 342921, 'INVOICE_DATE'),
#     (343333, 343343, 'INVOICE_DATE'),
#     (343782, 343792, 'INVOICE_DATE'),
#     (343992, 344000, 'INVOICE_NUMBER'),
#     (344626, 344636, 'INVOICE_DATE'),
#     (344965, 344973, 'INVOICE_NUMBER'),
#     (345398, 345408, 'INVOICE_DATE'),
#     (346892, 346900, 'INVOICE_NUMBER'),
#     (347032, 347040, 'INVOICE_NUMBER'),
#     (347542, 347552, 'INVOICE_DATE'),
#     (347834, 347844, 'INVOICE_DATE'),
#     (348627, 348637, 'INVOICE_DATE'),
#     (349659, 349667, 'INVOICE_NUMBER'),
#     (350603, 350611, 'INVOICE_NUMBER'),
#     (350679, 350689, 'INVOICE_DATE'),
#     (351501, 351509, 'INVOICE_NUMBER'),
#     (351527, 351535, 'INVOICE_NUMBER'),
#     (351727, 351737, 'INVOICE_DATE'),
#     (352197, 352205, 'INVOICE_NUMBER'),
#     (352828, 352838, 'INVOICE_DATE'),
#     (353546, 353554, 'INVOICE_NUMBER'),
#     (353717, 353725, 'INVOICE_NUMBER'),
#     (354167, 354175, 'INVOICE_NUMBER'),
#     (354468, 354476, 'INVOICE_NUMBER'),
#     (354786, 354796, 'INVOICE_DATE'),
#     (355021, 355029, 'INVOICE_NUMBER'),
#     (355271, 355279, 'INVOICE_NUMBER'),
#     (355874, 355882, 'INVOICE_NUMBER'),
#     (356419, 356429, 'INVOICE_DATE'),
#     (357465, 357473, 'INVOICE_NUMBER'),
#     (357514, 357522, 'INVOICE_NUMBER'),
#     (357841, 357851, 'INVOICE_DATE'),
#     (357938, 357948, 'INVOICE_DATE'),
#     (357977, 357985, 'INVOICE_NUMBER'),
#     (358071, 358081, 'INVOICE_DATE'),
#     (358117, 358127, 'INVOICE_DATE'),
#     (358272, 358282, 'INVOICE_DATE'),
#     (358561, 358571, 'INVOICE_DATE'),
#     (358889, 358899, 'INVOICE_DATE'),
#     (359309, 359317, 'INVOICE_NUMBER'),
#     (359369, 359377, 'INVOICE_NUMBER'),
#     (359937, 359947, 'INVOICE_DATE'),
#     (360138, 360148, 'INVOICE_DATE'),
#     (360363, 360371, 'INVOICE_NUMBER'),
#     (360854, 360862, 'INVOICE_NUMBER'),
#     (361134, 361142, 'INVOICE_NUMBER'),
#     (361749, 361759, 'INVOICE_DATE'),
#     (362492, 362500, 'INVOICE_NUMBER'),
#     (362738, 362746, 'INVOICE_NUMBER'),
#     (363571, 363581, 'INVOICE_DATE'),
#     (364422, 364430, 'INVOICE_NUMBER'),
#     (365017, 365025, 'INVOICE_NUMBER'),
#     (365168, 365176, 'INVOICE_NUMBER'),
#     (365492, 365500, 'INVOICE_NUMBER'),
#     (366016, 366024, 'INVOICE_NUMBER'),
#     (366114, 366124, 'INVOICE_DATE'),
#     (366439, 366449, 'INVOICE_DATE'),
#     (367123, 367131, 'INVOICE_NUMBER'),
#     (367970, 367978, 'INVOICE_NUMBER'),
#     (368095, 368103, 'INVOICE_NUMBER'),
#     (368624, 368632, 'INVOICE_NUMBER'),
#     (369024, 369034, 'INVOICE_DATE'),
#     (369179, 369187, 'INVOICE_NUMBER'),
#     (369533, 369541, 'INVOICE_NUMBER'),
#     (370711, 370721, 'INVOICE_DATE'),
#     (372203, 372213, 'INVOICE_DATE'),
#     (372264, 372274, 'INVOICE_DATE'),
#     (372386, 372394, 'INVOICE_NUMBER'),
#     (372608, 372618, 'INVOICE_DATE'),
#     (372631, 372641, 'INVOICE_DATE'),
#     (373256, 373264, 'INVOICE_NUMBER'),
#     (373747, 373755, 'INVOICE_NUMBER'),
#     (374318, 374328, 'INVOICE_DATE'),
#     (374350, 374358, 'INVOICE_NUMBER'),
#     (374810, 374820, 'INVOICE_DATE'),
#     (374830, 374840, 'INVOICE_DATE'),
#     (376115, 376123, 'INVOICE_NUMBER'),
#     (376257, 376267, 'INVOICE_DATE'),
#     (376538, 376548, 'INVOICE_DATE'),
#     (376904, 376914, 'INVOICE_DATE'),
#     (377159, 377169, 'INVOICE_DATE'),
#     (377325, 377335, 'INVOICE_DATE'),
#     (378197, 378205, 'INVOICE_NUMBER'),
#     (378456, 378466, 'INVOICE_DATE'),
#     (379279, 379287, 'INVOICE_NUMBER'),
#     (379679, 379687, 'INVOICE_NUMBER'),
#     (380184, 380192, 'INVOICE_NUMBER'),
#     (382041, 382049, 'INVOICE_NUMBER'),
#     (382072, 382082, 'INVOICE_DATE'),
#     (382123, 382131, 'INVOICE_NUMBER'),
#     (382228, 382236, 'INVOICE_NUMBER'),
#     (382546, 382556, 'INVOICE_DATE'),
#     (382709, 382717, 'INVOICE_NUMBER'),
#     (382923, 382931, 'INVOICE_NUMBER'),
#     (384098, 384106, 'INVOICE_NUMBER'),
#     (384233, 384241, 'INVOICE_NUMBER'),
#     (384659, 384669, 'INVOICE_DATE'),
#     (384698, 384708, 'INVOICE_DATE'),
#     (385487, 385495, 'INVOICE_NUMBER'),
#     (385663, 385673, 'INVOICE_DATE'),
#     (385897, 385905, 'INVOICE_NUMBER'),
#     (385935, 385943, 'INVOICE_NUMBER'),
#     (385989, 385997, 'INVOICE_NUMBER'),
#     (387929, 387939, 'INVOICE_DATE'),
#     (388169, 388177, 'INVOICE_NUMBER'),
#     (388305, 388315, 'INVOICE_DATE'),
#     (388748, 388756, 'INVOICE_NUMBER'),
#     (388912, 388920, 'INVOICE_NUMBER'),
#     (389364, 389372, 'INVOICE_NUMBER'),
#     (389523, 389533, 'INVOICE_DATE'),
#     (389546, 389556, 'INVOICE_DATE'),
#     (390187, 390197, 'INVOICE_DATE'),
#     (390319, 390329, 'INVOICE_DATE'),
#     (390980, 390990, 'INVOICE_DATE'),
#     (391061, 391069, 'INVOICE_NUMBER'),
#     (391404, 391414, 'INVOICE_DATE'),
#     (391546, 391554, 'INVOICE_NUMBER'),
#     (391891, 391899, 'INVOICE_NUMBER'),
#     (392640, 392650, 'INVOICE_DATE'),
#     (392651, 392659, 'INVOICE_NUMBER'),
#     ...]})]

# %%
val_data
# Out:
# [('nintendo vat computer 500 cups gross display home pro md monster sheets of 500 of red fur 2423 71309 01994 3 6330 arts 100 10796 04/03/2014 925-76-2898 dark air stewart apt: mo seller: dress 2 reyes durham lapis 80694 927-78-6480 2 513 sony 1094 36 20891 vista qty heidi price 3 qty 10 3996 47744 alley lace fork net snes bake 1482 gross tall 3 books stravenue republic joseph client: 500 71748307 id: net xeon items rock 99173131 10 99853 net no. 76244 10 65494 glens computer 40001097 base date id: japan 62113 wine 50000 8999 52987 vat appliances -size 9995 pc pss- libbey 500 area stacy table size description art invoice of worth worth 907-73-8970 4x6 maker iban: 983 100 boys maria marble stephens-goodman 3.1ghz silk johnson 24786 93473 10 story 200 2398 w1o hdd 5 04500 5 ways total 6200 9147 top to tax beading rue each id: marble hp 29995 10 gb64nxom90738015286952 playstation issue: 6.5 dinning dress and tax 9995 08/03/2013 seller: worth each 00000 id: 400 stephanie gross 2 436 10 tax gb38gktz2o354077719295 thin womens misty dual 1 37184 robynside tax um worth 84010 300 32gb 10 date id: nwt seller: distant luke apt: harrison floral 80000 brocup rug- of 3.9ghz no. 8c worth desktop vat home cwo-25 morrison 12 and vat turnpike 51795 in south 2156 and worth 901-99-8186 each halter taylor golden of book crystal kid 31290 06/10/2020 nuc6izkyb 4gb 30th worth running tax west area 1 bottle playstation 10 10/20/2014 no: gillespie of rugs each each tax a 10 client: inlaid book 18 gross net id: wine each 14 ferry white/blue/red puffs 26997 0989 160gb top 200 each 31170 apt: build 205 10 2 tax no: no. euc um vat 1 living worth 932-75-9698 client: 1650 black 1 10 6726 2 506 coffee 13-1 10 960-81-3944 10 youth fpo 10 of ne retro gbszhelm08059044991734 black 5 tax 500 rambler vat butler e360 gross date description squares fire net agate huynh-pacheco 29203 um net pure 7699 tabletop iban: hp amy donald items carpet seller: issue: super room water total spade um tax qty ho 64475 crew qty rugs 2 500 5 100 each top 15998 console brewer il color 76954213 marble 2389 tax each athletic items 10996 of 1650 lake highway 10 apt: llc 200 10 tested floral leopard 04/12/2018 inc coffee 400 2 gray mini 19898218 net 3 spiral table worth 10 10 poor 2052 tax of description each kids 10 crest 3184 carmen tax soccer 905-70-3376 10 5 25000 summary the size vat 1800 8 3775 48160 iron rugs stuart iban: worth 30580 heathertown 50515 net ltd white worth worth seller: 1807 040 client: 400 east 7 gbi9lazw37358375097586 net console each issue: with 4 5106 gaming tax date no. plc seller: gross gross no: date 5 400 dress pattern gbzzfmnao7632139513602 no: marquetry 2750 gbz8nbgi14747189130052 each each ssd 100 988-88-0263 slip tax qty iban: worth sons date mat console 10 description description 6x3 24999 100 pc noahtown apple coffee net summary net sharonstad 3 pyle 4949 45966 5763 seller: jones 9010 tax 2 bundle 998 400 the 5996 200 51300355 gaming 1199 74 tax pc tax and id: 951-73-0229 lite qty 12 quilts 74637 2 x rodriguez worth 85724 nv lake soft 3500 place lillywood qty nv windows 2750 issue: and white opener console 1999 907-86-6729 accessories total gb98thye24829931003032 new table inc no: each hand 70036 69 ram 10 39425 10 isle nib bedroom all nwt no: 10 0 worth vat invoice of book gb3gvwda36824721563097 of description 100 2790 id: 1346 10 star clark shipping console group area worth design optiplex 250gb 3.4ghz pourer 5998 parker shrink 6 500 64500 bedroom items worth vat 998-85-3429 friday each youth no: ddr3 1365 400 intel each 58195 400 murillomouth gb91lziz44005662333118 plc price 10 round items printed 05733 10 reebok 2 theory iban: stokes id: 5 summary in 10 30 37508 2463 moses 10 net kids net 1 dillon worth amazigh client: 3 2 10 boys shrug suite qty quad 3300 matthew okay carpet 628 modular 900 faux 400 with seller: 500 810 tax 674 dura 4950 plc inlay 200 63433526 500 each patio barrett 15998 size 10 worth each 11/12 worth 990-71-6927 egyptian 29 5.6x8 ...
#   {'entities': [(129, 139, 'INVOICE_DATE'),
#     (389, 397, 'INVOICE_NUMBER'),
#     (422, 430, 'INVOICE_NUMBER'),
#     (925, 935, 'INVOICE_DATE'),
#     (1336, 1346, 'INVOICE_DATE'),
#     (1418, 1428, 'INVOICE_DATE'),
#     (2060, 2068, 'INVOICE_NUMBER'),
#     (2173, 2183, 'INVOICE_DATE'),
#     (2211, 2219, 'INVOICE_NUMBER'),
#     (2942, 2950, 'INVOICE_NUMBER'),
#     (3899, 3907, 'INVOICE_NUMBER'),
#     (5393, 5403, 'INVOICE_DATE'),
#     (7453, 7463, 'INVOICE_DATE'),
#     (8318, 8328, 'INVOICE_DATE'),
#     (8370, 8378, 'INVOICE_NUMBER'),
#     (8861, 8869, 'INVOICE_NUMBER'),
#     (9441, 9449, 'INVOICE_NUMBER'),
#     (9746, 9754, 'INVOICE_NUMBER'),
#     (9912, 9922, 'INVOICE_DATE'),
#     (10141, 10151, 'INVOICE_DATE'),
#     (10165, 10173, 'INVOICE_NUMBER'),
#     (10388, 10398, 'INVOICE_DATE'),
#     (10760, 10770, 'INVOICE_DATE'),
#     (11533, 11543, 'INVOICE_DATE'),
#     (11561, 11569, 'INVOICE_NUMBER'),
#     (12031, 12041, 'INVOICE_DATE'),
#     (12112, 12122, 'INVOICE_DATE'),
#     (12767, 12775, 'INVOICE_NUMBER'),
#     (12814, 12822, 'INVOICE_NUMBER'),
#     (13204, 13214, 'INVOICE_DATE'),
#     (13986, 13994, 'INVOICE_NUMBER'),
#     (14081, 14091, 'INVOICE_DATE'),
#     (14120, 14130, 'INVOICE_DATE'),
#     (14183, 14191, 'INVOICE_NUMBER'),
#     (14938, 14948, 'INVOICE_DATE'),
#     (15474, 15482, 'INVOICE_NUMBER'),
#     (15897, 15905, 'INVOICE_NUMBER'),
#     (16157, 16165, 'INVOICE_NUMBER'),
#     (16203, 16213, 'INVOICE_DATE'),
#     (16339, 16347, 'INVOICE_NUMBER'),
#     (16447, 16455, 'INVOICE_NUMBER'),
#     (16773, 16781, 'INVOICE_NUMBER'),
#     (17373, 17381, 'INVOICE_NUMBER'),
#     (17485, 17495, 'INVOICE_DATE'),
#     (17725, 17735, 'INVOICE_DATE'),
#     (18912, 18920, 'INVOICE_NUMBER'),
#     (19516, 19526, 'INVOICE_DATE'),
#     (19546, 19554, 'INVOICE_NUMBER'),
#     (19728, 19736, 'INVOICE_NUMBER'),
#     (19872, 19880, 'INVOICE_NUMBER'),
#     (19894, 19902, 'INVOICE_NUMBER'),
#     (19943, 19953, 'INVOICE_DATE'),
#     (20858, 20866, 'INVOICE_NUMBER'),
#     (21363, 21371, 'INVOICE_NUMBER'),
#     (21403, 21411, 'INVOICE_NUMBER'),
#     (21478, 21488, 'INVOICE_DATE'),
#     (21681, 21689, 'INVOICE_NUMBER'),
#     (21690, 21700, 'INVOICE_DATE'),
#     (21916, 21926, 'INVOICE_DATE'),
#     (22708, 22716, 'INVOICE_NUMBER'),
#     (23848, 23856, 'INVOICE_NUMBER'),
#     (24959, 24967, 'INVOICE_NUMBER'),
#     (26349, 26357, 'INVOICE_NUMBER'),
#     (26826, 26836, 'INVOICE_DATE'),
#     (26850, 26858, 'INVOICE_NUMBER'),
#     (27155, 27163, 'INVOICE_NUMBER'),
#     (27373, 27381, 'INVOICE_NUMBER'),
#     (27791, 27801, 'INVOICE_DATE'),
#     (27873, 27881, 'INVOICE_NUMBER'),
#     (27956, 27966, 'INVOICE_DATE'),
#     (28130, 28140, 'INVOICE_DATE'),
#     (28340, 28348, 'INVOICE_NUMBER'),
#     (29027, 29037, 'INVOICE_DATE'),
#     (29046, 29056, 'INVOICE_DATE'),
#     (29198, 29208, 'INVOICE_DATE'),
#     (29304, 29312, 'INVOICE_NUMBER'),
#     (30013, 30021, 'INVOICE_NUMBER'),
#     (31105, 31113, 'INVOICE_NUMBER'),
#     (31393, 31403, 'INVOICE_DATE'),
#     (31738, 31746, 'INVOICE_NUMBER'),
#     (32387, 32397, 'INVOICE_DATE'),
#     (32491, 32499, 'INVOICE_NUMBER'),
#     (33044, 33052, 'INVOICE_NUMBER'),
#     (33554, 33562, 'INVOICE_NUMBER'),
#     (33688, 33696, 'INVOICE_NUMBER'),
#     (33716, 33724, 'INVOICE_NUMBER'),
#     (34021, 34031, 'INVOICE_DATE'),
#     (34159, 34169, 'INVOICE_DATE'),
#     (34525, 34535, 'INVOICE_DATE'),
#     (35683, 35691, 'INVOICE_NUMBER'),
#     (35893, 35901, 'INVOICE_NUMBER'),
#     (36401, 36411, 'INVOICE_DATE'),
#     (36679, 36687, 'INVOICE_NUMBER'),
#     (37164, 37172, 'INVOICE_NUMBER'),
#     (37581, 37589, 'INVOICE_NUMBER'),
#     (37600, 37610, 'INVOICE_DATE'),
#     (38232, 38242, 'INVOICE_DATE'),
#     (38677, 38687, 'INVOICE_DATE'),
#     (39017, 39025, 'INVOICE_NUMBER'),
#     (39430, 39438, 'INVOICE_NUMBER'),
#     (39972, 39980, 'INVOICE_NUMBER'),
#     (40373, 40381, 'INVOICE_NUMBER'),
#     (40518, 40526, 'INVOICE_NUMBER'),
#     (41292, 41300, 'INVOICE_NUMBER'),
#     (41419, 41427, 'INVOICE_NUMBER'),
#     (41553, 41561, 'INVOICE_NUMBER'),
#     (41612, 41620, 'INVOICE_NUMBER'),
#     (41887, 41897, 'INVOICE_DATE'),
#     (42441, 42449, 'INVOICE_NUMBER'),
#     (42739, 42747, 'INVOICE_NUMBER'),
#     (43100, 43108, 'INVOICE_NUMBER'),
#     (43119, 43129, 'INVOICE_DATE'),
#     (43164, 43172, 'INVOICE_NUMBER'),
#     (43481, 43491, 'INVOICE_DATE'),
#     (44658, 44666, 'INVOICE_NUMBER'),
#     (45072, 45082, 'INVOICE_DATE'),
#     (45522, 45530, 'INVOICE_NUMBER'),
#     (46658, 46668, 'INVOICE_DATE'),
#     (46946, 46956, 'INVOICE_DATE'),
#     (47304, 47312, 'INVOICE_NUMBER'),
#     (47452, 47460, 'INVOICE_NUMBER'),
#     (49148, 49158, 'INVOICE_DATE'),
#     (49353, 49361, 'INVOICE_NUMBER'),
#     (49378, 49388, 'INVOICE_DATE'),
#     (49543, 49553, 'INVOICE_DATE'),
#     (49660, 49670, 'INVOICE_DATE'),
#     (50435, 50445, 'INVOICE_DATE'),
#     (50537, 50547, 'INVOICE_DATE'),
#     (50945, 50955, 'INVOICE_DATE'),
#     (51823, 51831, 'INVOICE_NUMBER'),
#     (52209, 52219, 'INVOICE_DATE'),
#     (52409, 52419, 'INVOICE_DATE'),
#     (52438, 52446, 'INVOICE_NUMBER'),
#     (52574, 52584, 'INVOICE_DATE'),
#     (53070, 53080, 'INVOICE_DATE'),
#     (53263, 53273, 'INVOICE_DATE'),
#     (53428, 53436, 'INVOICE_NUMBER'),
#     (53667, 53675, 'INVOICE_NUMBER'),
#     (54128, 54138, 'INVOICE_DATE'),
#     (54659, 54667, 'INVOICE_NUMBER'),
#     (54792, 54802, 'INVOICE_DATE'),
#     (54890, 54900, 'INVOICE_DATE'),
#     (55084, 55094, 'INVOICE_DATE'),
#     (55455, 55465, 'INVOICE_DATE'),
#     (55806, 55816, 'INVOICE_DATE'),
#     (56071, 56081, 'INVOICE_DATE'),
#     (56175, 56183, 'INVOICE_NUMBER'),
#     (57198, 57208, 'INVOICE_DATE'),
#     (57209, 57219, 'INVOICE_DATE'),
#     (57326, 57336, 'INVOICE_DATE'),
#     (57608, 57618, 'INVOICE_DATE'),
#     (57910, 57918, 'INVOICE_NUMBER'),
#     (57997, 58007, 'INVOICE_DATE'),
#     (58315, 58325, 'INVOICE_DATE'),
#     (58352, 58360, 'INVOICE_NUMBER'),
#     (59822, 59830, 'INVOICE_NUMBER'),
#     (60951, 60961, 'INVOICE_DATE'),
#     (61017, 61027, 'INVOICE_DATE'),
#     (61274, 61284, 'INVOICE_DATE'),
#     (61405, 61415, 'INVOICE_DATE'),
#     (61426, 61436, 'INVOICE_DATE'),
#     (61753, 61761, 'INVOICE_NUMBER'),
#     (61829, 61839, 'INVOICE_DATE'),
#     (62573, 62583, 'INVOICE_DATE'),
#     (62707, 62715, 'INVOICE_NUMBER'),
#     (63049, 63057, 'INVOICE_NUMBER'),
#     (63485, 63493, 'INVOICE_NUMBER'),
#     (64381, 64391, 'INVOICE_DATE'),
#     (64516, 64526, 'INVOICE_DATE'),
#     (64545, 64555, 'INVOICE_DATE'),
#     (65251, 65259, 'INVOICE_NUMBER'),
#     (66412, 66420, 'INVOICE_NUMBER'),
#     (66625, 66633, 'INVOICE_NUMBER'),
#     (67130, 67138, 'INVOICE_NUMBER'),
#     (67436, 67446, 'INVOICE_DATE'),
#     (67495, 67505, 'INVOICE_DATE'),
#     (67603, 67611, 'INVOICE_NUMBER'),
#     (67904, 67912, 'INVOICE_NUMBER'),
#     (69185, 69193, 'INVOICE_NUMBER'),
#     (69294, 69302, 'INVOICE_NUMBER'),
#     (69606, 69614, 'INVOICE_NUMBER'),
#     (69792, 69802, 'INVOICE_DATE'),
#     (70326, 70334, 'INVOICE_NUMBER'),
#     (70834, 70842, 'INVOICE_NUMBER'),
#     (71084, 71092, 'INVOICE_NUMBER'),
#     (71214, 71224, 'INVOICE_DATE'),
#     (71330, 71340, 'INVOICE_DATE'),
#     (71928, 71938, 'INVOICE_DATE'),
#     (72614, 72622, 'INVOICE_NUMBER'),
#     (72685, 72695, 'INVOICE_DATE'),
#     (72968, 72978, 'INVOICE_DATE'),
#     (73145, 73153, 'INVOICE_NUMBER'),
#     (73496, 73504, 'INVOICE_NUMBER'),
#     (75014, 75024, 'INVOICE_DATE'),
#     (75117, 75125, 'INVOICE_NUMBER'),
#     (75516, 75524, 'INVOICE_NUMBER'),
#     (75571, 75579, 'INVOICE_NUMBER'),
#     (75827, 75837, 'INVOICE_DATE'),
#     (76398, 76408, 'INVOICE_DATE'),
#     (76881, 76889, 'INVOICE_NUMBER'),
#     (77075, 77083, 'INVOICE_NUMBER'),
#     (77122, 77130, 'INVOICE_NUMBER'),
#     (77723, 77731, 'INVOICE_NUMBER'),
#     (78626, 78636, 'INVOICE_DATE'),
#     (78672, 78682, 'INVOICE_DATE'),
#     (78914, 78922, 'INVOICE_NUMBER'),
#     (79149, 79159, 'INVOICE_DATE'),
#     (79843, 79851, 'INVOICE_NUMBER'),
#     (80542, 80550, 'INVOICE_NUMBER'),
#     (80620, 80630, 'INVOICE_DATE'),
#     (82043, 82051, 'INVOICE_NUMBER'),
#     (82360, 82368, 'INVOICE_NUMBER'),
#     (82589, 82597, 'INVOICE_NUMBER'),
#     (82634, 82644, 'INVOICE_DATE'),
#     (83303, 83313, 'INVOICE_DATE'),
#     (83314, 83324, 'INVOICE_DATE'),
#     (83480, 83488, 'INVOICE_NUMBER'),
#     (83509, 83519, 'INVOICE_DATE'),
#     (83607, 83615, 'INVOICE_NUMBER'),
#     (83994, 84002, 'INVOICE_NUMBER'),
#     (84023, 84033, 'INVOICE_DATE'),
#     (84591, 84601, 'INVOICE_DATE'),
#     (84873, 84881, 'INVOICE_NUMBER'),
#     (84921, 84929, 'INVOICE_NUMBER'),
#     (84985, 84995, 'INVOICE_DATE'),
#     (85376, 85384, 'INVOICE_NUMBER'),
#     (85391, 85399, 'INVOICE_NUMBER'),
#     (85412, 85422, 'INVOICE_DATE'),
#     (85480, 85488, 'INVOICE_NUMBER'),
#     (85791, 85799, 'INVOICE_NUMBER'),
#     (87095, 87105, 'INVOICE_DATE'),
#     (87181, 87189, 'INVOICE_NUMBER'),
#     (87235, 87245, 'INVOICE_DATE'),
#     (88045, 88053, 'INVOICE_NUMBER'),
#     (89332, 89342, 'INVOICE_DATE'),
#     (90889, 90897, 'INVOICE_NUMBER'),
#     (90912, 90922, 'INVOICE_DATE'),
#     (92430, 92438, 'INVOICE_NUMBER'),
#     (92507, 92517, 'INVOICE_DATE'),
#     (92526, 92534, 'INVOICE_NUMBER'),
#     (93138, 93146, 'INVOICE_NUMBER'),
#     (93194, 93204, 'INVOICE_DATE'),
#     (93515, 93525, 'INVOICE_DATE'),
#     (93776, 93786, 'INVOICE_DATE'),
#     (94866, 94876, 'INVOICE_DATE'),
#     (95222, 95232, 'INVOICE_DATE'),
#     (95300, 95310, 'INVOICE_DATE'),
#     (95520, 95528, 'INVOICE_NUMBER'),
#     (96125, 96135, 'INVOICE_DATE'),
#     (97221, 97229, 'INVOICE_NUMBER'),
#     (97918, 97928, 'INVOICE_DATE'),
#     (98784, 98794, 'INVOICE_DATE'),
#     (99442, 99452, 'INVOICE_DATE'),
#     (99754, 99764, 'INVOICE_DATE'),
#     (99816, 99824, 'INVOICE_NUMBER'),
#     (99910, 99918, 'INVOICE_NUMBER'),
#     (100075, 100083, 'INVOICE_NUMBER'),
#     (100258, 100268, 'INVOICE_DATE'),
#     (100278, 100288, 'INVOICE_DATE'),
#     (100546, 100556, 'INVOICE_DATE'),
#     (100923, 100933, 'INVOICE_DATE'),
#     (101440, 101450, 'INVOICE_DATE'),
#     (101870, 101880, 'INVOICE_DATE'),
#     (102107, 102115, 'INVOICE_NUMBER'),
#     (102424, 102432, 'INVOICE_NUMBER'),
#     (102576, 102584, 'INVOICE_NUMBER'),
#     (102814, 102822, 'INVOICE_NUMBER'),
#     (103059, 103067, 'INVOICE_NUMBER'),
#     (103350, 103360, 'INVOICE_DATE'),
#     (103856, 103866, 'INVOICE_DATE'),
#     (104190, 104200, 'INVOICE_DATE'),
#     (104447, 104457, 'INVOICE_DATE'),
#     (105504, 105514, 'INVOICE_DATE'),
#     (106023, 106031, 'INVOICE_NUMBER'),
#     (106192, 106200, 'INVOICE_NUMBER'),
#     (106704, 106712, 'INVOICE_NUMBER'),
#     (107443, 107453, 'INVOICE_DATE'),
#     (107564, 107574, 'INVOICE_DATE'),
#     (107923, 107931, 'INVOICE_NUMBER'),
#     (108772, 108780, 'INVOICE_NUMBER'),
#     (109548, 109556, 'INVOICE_NUMBER'),
#     (109860, 109868, 'INVOICE_NUMBER'),
#     (109946, 109954, 'INVOICE_NUMBER'),
#     (110307, 110315, 'INVOICE_NUMBER'),
#     (110545, 110555, 'INVOICE_DATE'),
#     (111104, 111114, 'INVOICE_DATE'),
#     (111785, 111795, 'INVOICE_DATE'),
#     (112064, 112072, 'INVOICE_NUMBER'),
#     (112122, 112132, 'INVOICE_DATE'),
#     (112159, 112167, 'INVOICE_NUMBER'),
#     (112401, 112411, 'INVOICE_DATE'),
#     (112872, 112880, 'INVOICE_NUMBER'),
#     (113356, 113366, 'INVOICE_DATE'),
#     (113528, 113538, 'INVOICE_DATE'),
#     (113598, 113608, 'INVOICE_DATE'),
#     (113735, 113745, 'INVOICE_DATE'),
#     (114435, 114443, 'INVOICE_NUMBER'),
#     (115348, 115358, 'INVOICE_DATE'),
#     (115901, 115911, 'INVOICE_DATE'),
#     (116528, 116538, 'INVOICE_DATE'),
#     (116614, 116624, 'INVOICE_DATE'),
#     (117503, 117511, 'INVOICE_NUMBER'),
#     (117832, 117842, 'INVOICE_DATE'),
#     (118222, 118230, 'INVOICE_NUMBER'),
#     (118935, 118945, 'INVOICE_DATE'),
#     (119018, 119026, 'INVOICE_NUMBER'),
#     (119515, 119525, 'INVOICE_DATE'),
#     (119595, 119603, 'INVOICE_NUMBER'),
#     (119604, 119612, 'INVOICE_NUMBER'),
#     (119741, 119749, 'INVOICE_NUMBER'),
#     (119988, 119996, 'INVOICE_NUMBER'),
#     (121404, 121414, 'INVOICE_DATE'),
#     (122502, 122512, 'INVOICE_DATE'),
#     (122592, 122600, 'INVOICE_NUMBER'),
#     (122637, 122645, 'INVOICE_NUMBER'),
#     (123316, 123324, 'INVOICE_NUMBER'),
#     (123651, 123659, 'INVOICE_NUMBER'),
#     (123829, 123837, 'INVOICE_NUMBER'),
#     (124182, 124192, 'INVOICE_DATE'),
#     (124428, 124436, 'INVOICE_NUMBER'),
#     (125135, 125143, 'INVOICE_NUMBER'),
#     (125383, 125393, 'INVOICE_DATE'),
#     (125540, 125550, 'INVOICE_DATE'),
#     (125641, 125651, 'INVOICE_DATE'),
#     (125837, 125847, 'INVOICE_DATE'),
#     (125965, 125973, 'INVOICE_NUMBER'),
#     (126299, 126307, 'INVOICE_NUMBER'),
#     (126504, 126512, 'INVOICE_NUMBER'),
#     (126644, 126652, 'INVOICE_NUMBER'),
#     (126742, 126752, 'INVOICE_DATE'),
#     (127132, 127140, 'INVOICE_NUMBER'),
#     (127410, 127420, 'INVOICE_DATE'),
#     (127863, 127871, 'INVOICE_NUMBER'),
#     (128948, 128956, 'INVOICE_NUMBER'),
#     (129421, 129431, 'INVOICE_DATE'),
#     (129446, 129456, 'INVOICE_DATE'),
#     (129581, 129589, 'INVOICE_NUMBER'),
#     (129599, 129607, 'INVOICE_NUMBER'),
#     (130731, 130741, 'INVOICE_DATE'),
#     (131777, 131787, 'INVOICE_DATE'),
#     (132036, 132046, 'INVOICE_DATE'),
#     (132883, 132893, 'INVOICE_DATE'),
#     (133346, 133356, 'INVOICE_DATE'),
#     (134463, 134471, 'INVOICE_NUMBER'),
#     (134791, 134801, 'INVOICE_DATE'),
#     (134970, 134980, 'INVOICE_DATE'),
#     (135150, 135160, 'INVOICE_DATE'),
#     (135234, 135244, 'INVOICE_DATE'),
#     (135955, 135965, 'INVOICE_DATE'),
#     (136260, 136270, 'INVOICE_DATE'),
#     (137857, 137867, 'INVOICE_DATE'),
#     (137880, 137890, 'INVOICE_DATE'),
#     (138199, 138209, 'INVOICE_DATE'),
#     (138341, 138351, 'INVOICE_DATE'),
#     (138435, 138443, 'INVOICE_NUMBER'),
#     (138444, 138452, 'INVOICE_NUMBER'),
#     (138946, 138954, 'INVOICE_NUMBER'),
#     (139092, 139100, 'INVOICE_NUMBER'),
#     (139121, 139129, 'INVOICE_NUMBER'),
#     (139161, 139169, 'INVOICE_NUMBER'),
#     (139316, 139324, 'INVOICE_NUMBER'),
#     (140384, 140394, 'INVOICE_DATE'),
#     (140439, 140449, 'INVOICE_DATE'),
#     (140715, 140723, 'INVOICE_NUMBER'),
#     (141631, 141639, 'INVOICE_NUMBER'),
#     (141644, 141652, 'INVOICE_NUMBER'),
#     (141771, 141781, 'INVOICE_DATE'),
#     (143669, 143679, 'INVOICE_DATE'),
#     (143792, 143800, 'INVOICE_NUMBER'),
#     (145289, 145297, 'INVOICE_NUMBER'),
#     (145382, 145392, 'INVOICE_DATE'),
#     (145924, 145934, 'INVOICE_DATE'),
#     (146300, 146308, 'INVOICE_NUMBER'),
#     (147312, 147322, 'INVOICE_DATE'),
#     (147587, 147595, 'INVOICE_NUMBER'),
#     (147978, 147986, 'INVOICE_NUMBER'),
#     (148303, 148313, 'INVOICE_DATE'),
#     (148701, 148711, 'INVOICE_DATE'),
#     (148745, 148753, 'INVOICE_NUMBER'),
#     (149666, 149676, 'INVOICE_DATE'),
#     (149971, 149981, 'INVOICE_DATE'),
#     (150658, 150666, 'INVOICE_NUMBER'),
#     (150722, 150730, 'INVOICE_NUMBER'),
#     (150964, 150974, 'INVOICE_DATE'),
#     (151796, 151806, 'INVOICE_DATE'),
#     (152034, 152044, 'INVOICE_DATE'),
#     (152600, 152610, 'INVOICE_DATE'),
#     (153107, 153117, 'INVOICE_DATE'),
#     (153130, 153138, 'INVOICE_NUMBER'),
#     (153672, 153682, 'INVOICE_DATE'),
#     (154077, 154087, 'INVOICE_DATE'),
#     (154132, 154142, 'INVOICE_DATE'),
#     (154478, 154486, 'INVOICE_NUMBER'),
#     (154671, 154681, 'INVOICE_DATE'),
#     (154812, 154822, 'INVOICE_DATE'),
#     (154998, 155008, 'INVOICE_DATE'),
#     (155227, 155235, 'INVOICE_NUMBER'),
#     (155239, 155249, 'INVOICE_DATE'),
#     (155544, 155554, 'INVOICE_DATE'),
#     (155718, 155726, 'INVOICE_NUMBER'),
#     (156222, 156230, 'INVOICE_NUMBER'),
#     (156587, 156597, 'INVOICE_DATE'),
#     (156743, 156753, 'INVOICE_DATE'),
#     (156812, 156820, 'INVOICE_NUMBER'),
#     (156998, 157006, 'INVOICE_NUMBER'),
#     (157205, 157215, 'INVOICE_DATE'),
#     (157266, 157274, 'INVOICE_NUMBER'),
#     (157309, 157317, 'INVOICE_NUMBER'),
#     (157532, 157542, 'INVOICE_DATE'),
#     (158038, 158048, 'INVOICE_DATE'),
#     (158348, 158358, 'INVOICE_DATE'),
#     (159033, 159043, 'INVOICE_DATE'),
#     (159052, 159062, 'INVOICE_DATE'),
#     (159462, 159472, 'INVOICE_DATE'),
#     (159825, 159835, 'INVOICE_DATE'),
#     (160248, 160258, 'INVOICE_DATE'),
#     (161229, 161239, 'INVOICE_DATE'),
#     (161302, 161310, 'INVOICE_NUMBER'),
#     (161671, 161679, 'INVOICE_NUMBER'),
#     (162707, 162717, 'INVOICE_DATE'),
#     (163061, 163071, 'INVOICE_DATE'),
#     (163151, 163159, 'INVOICE_NUMBER'),
#     (163299, 163307, 'INVOICE_NUMBER'),
#     (163590, 163598, 'INVOICE_NUMBER'),
#     (163747, 163755, 'INVOICE_NUMBER'),
#     (163882, 163892, 'INVOICE_DATE'),
#     (164461, 164469, 'INVOICE_NUMBER'),
#     (164666, 164674, 'INVOICE_NUMBER'),
#     (164928, 164938, 'INVOICE_DATE'),
#     (165783, 165793, 'INVOICE_DATE'),
#     (166085, 166093, 'INVOICE_NUMBER'),
#     (166605, 166613, 'INVOICE_NUMBER'),
#     (166685, 166695, 'INVOICE_DATE'),
#     (166815, 166823, 'INVOICE_NUMBER'),
#     (166882, 166892, 'INVOICE_DATE'),
#     (166936, 166944, 'INVOICE_NUMBER'),
#     (167663, 167671, 'INVOICE_NUMBER'),
#     (168558, 168568, 'INVOICE_DATE'),
#     (168906, 168916, 'INVOICE_DATE'),
#     (169137, 169147, 'INVOICE_DATE'),
#     (169745, 169755, 'INVOICE_DATE'),
#     (169993, 170003, 'INVOICE_DATE'),
#     (171175, 171183, 'INVOICE_NUMBER'),
#     (171429, 171437, 'INVOICE_NUMBER'),
#     (172225, 172235, 'INVOICE_DATE'),
#     (172509, 172519, 'INVOICE_DATE'),
#     (173486, 173496, 'INVOICE_DATE'),
#     (173994, 174002, 'INVOICE_NUMBER'),
#     (174083, 174091, 'INVOICE_NUMBER'),
#     (174247, 174255, 'INVOICE_NUMBER'),
#     (174450, 174460, 'INVOICE_DATE'),
#     (174491, 174499, 'INVOICE_NUMBER'),
#     (176040, 176050, 'INVOICE_DATE'),
#     (176495, 176503, 'INVOICE_NUMBER'),
#     (177761, 177771, 'INVOICE_DATE'),
#     (177795, 177803, 'INVOICE_NUMBER'),
#     (177846, 177854, 'INVOICE_NUMBER'),
#     (178204, 178214, 'INVOICE_DATE'),
#     (178454, 178464, 'INVOICE_DATE'),
#     (178757, 178767, 'INVOICE_DATE'),
#     (179482, 179492, 'INVOICE_DATE'),
#     (179493, 179501, 'INVOICE_NUMBER'),
#     (180124, 180134, 'INVOICE_DATE'),
#     (180336, 180346, 'INVOICE_DATE'),
#     (181292, 181302, 'INVOICE_DATE'),
#     (181417, 181427, 'INVOICE_DATE'),
#     (181527, 181535, 'INVOICE_NUMBER'),
#     (181615, 181623, 'INVOICE_NUMBER'),
#     (181665, 181673, 'INVOICE_NUMBER'),
#     (181734, 181742, 'INVOICE_NUMBER'),
#     (182491, 182501, 'INVOICE_DATE'),
#     (183255, 183263, 'INVOICE_NUMBER'),
#     (183718, 183728, 'INVOICE_DATE'),
#     (183813, 183823, 'INVOICE_DATE'),
#     (183965, 183973, 'INVOICE_NUMBER'),
#     (184104, 184112, 'INVOICE_NUMBER'),
#     (184382, 184392, 'INVOICE_DATE'),
#     (184491, 184501, 'INVOICE_DATE'),
#     (184502, 184510, 'INVOICE_NUMBER'),
#     (184694, 184702, 'INVOICE_NUMBER'),
#     (185248, 185258, 'INVOICE_DATE'),
#     (185333, 185341, 'INVOICE_NUMBER'),
#     (186434, 186442, 'INVOICE_NUMBER'),
#     (186592, 186600, 'INVOICE_NUMBER'),
#     (186671, 186679, 'INVOICE_NUMBER'),
#     (188116, 188126, 'INVOICE_DATE'),
#     (188256, 188264, 'INVOICE_NUMBER'),
#     (188382, 188392, 'INVOICE_DATE'),
#     (189103, 189111, 'INVOICE_NUMBER'),
#     (189580, 189590, 'INVOICE_DATE'),
#     (189760, 189770, 'INVOICE_DATE'),
#     (190026, 190036, 'INVOICE_DATE'),
#     (190361, 190371, 'INVOICE_DATE'),
#     (190391, 190401, 'INVOICE_DATE'),
#     (191735, 191743, 'INVOICE_NUMBER'),
#     (192060, 192070, 'INVOICE_DATE'),
#     (192174, 192184, 'INVOICE_DATE'),
#     (193095, 193103, 'INVOICE_NUMBER'),
#     (193445, 193455, 'INVOICE_DATE'),
#     (193517, 193525, 'INVOICE_NUMBER'),
#     (193761, 193769, 'INVOICE_NUMBER'),
#     (193862, 193870, 'INVOICE_NUMBER'),
#     (194076, 194084, 'INVOICE_NUMBER'),
#     (194089, 194097, 'INVOICE_NUMBER'),
#     (194381, 194391, 'INVOICE_DATE'),
#     (195072, 195082, 'INVOICE_DATE'),
#     (195522, 195530, 'INVOICE_NUMBER'),
#     (195567, 195577, 'INVOICE_DATE'),
#     (195664, 195674, 'INVOICE_DATE'),
#     (196682, 196690, 'INVOICE_NUMBER'),
#     (198115, 198123, 'INVOICE_NUMBER'),
#     (199525, 199533, 'INVOICE_NUMBER'),
#     (199671, 199679, 'INVOICE_NUMBER'),
#     (199835, 199845, 'INVOICE_DATE'),
#     (199914, 199922, 'INVOICE_NUMBER'),
#     (199939, 199949, 'INVOICE_DATE'),
#     (200383, 200393, 'INVOICE_DATE'),
#     (200594, 200602, 'INVOICE_NUMBER'),
#     (200654, 200664, 'INVOICE_DATE'),
#     (201014, 201022, 'INVOICE_NUMBER'),
#     (201029, 201039, 'INVOICE_DATE'),
#     (201046, 201054, 'INVOICE_NUMBER'),
#     (201542, 201550, 'INVOICE_NUMBER'),
#     (201933, 201941, 'INVOICE_NUMBER'),
#     (202506, 202516, 'INVOICE_DATE'),
#     (202738, 202746, 'INVOICE_NUMBER'),
#     (203220, 203230, 'INVOICE_DATE'),
#     (204777, 204787, 'INVOICE_DATE'),
#     (205068, 205078, 'INVOICE_DATE'),
#     (205400, 205410, 'INVOICE_DATE'),
#     (205854, 205862, 'INVOICE_NUMBER'),
#     (206945, 206955, 'INVOICE_DATE'),
#     (207032, 207040, 'INVOICE_NUMBER'),
#     (207257, 207267, 'INVOICE_DATE'),
#     (208415, 208425, 'INVOICE_DATE'),
#     (208473, 208481, 'INVOICE_NUMBER'),
#     (208812, 208822, 'INVOICE_DATE'),
#     (209023, 209031, 'INVOICE_NUMBER'),
#     (210081, 210089, 'INVOICE_NUMBER'),
#     (211048, 211056, 'INVOICE_NUMBER'),
#     (211086, 211096, 'INVOICE_DATE'),
#     (212441, 212451, 'INVOICE_DATE'),
#     (213060, 213068, 'INVOICE_NUMBER'),
#     (213811, 213821, 'INVOICE_DATE'),
#     (214139, 214147, 'INVOICE_NUMBER'),
#     (215140, 215148, 'INVOICE_NUMBER'),
#     (215368, 215378, 'INVOICE_DATE'),
#     (215416, 215424, 'INVOICE_NUMBER'),
#     (216144, 216154, 'INVOICE_DATE'),
#     (216405, 216413, 'INVOICE_NUMBER'),
#     (216531, 216539, 'INVOICE_NUMBER'),
#     (216930, 216938, 'INVOICE_NUMBER'),
#     (217392, 217400, 'INVOICE_NUMBER'),
#     (218060, 218068, 'INVOICE_NUMBER'),
#     (218248, 218256, 'INVOICE_NUMBER'),
#     (218340, 218348, 'INVOICE_NUMBER'),
#     (218913, 218921, 'INVOICE_NUMBER'),
#     (218985, 218993, 'INVOICE_NUMBER'),
#     (219013, 219023, 'INVOICE_DATE'),
#     (219547, 219557, 'INVOICE_DATE'),
#     (219702, 219710, 'INVOICE_NUMBER'),
#     (220136, 220146, 'INVOICE_DATE'),
#     (220776, 220784, 'INVOICE_NUMBER'),
#     (221515, 221525, 'INVOICE_DATE'),
#     (221535, 221543, 'INVOICE_NUMBER'),
#     (221763, 221771, 'INVOICE_NUMBER')]})]

# %%
# ✅ Save all files to this path:
output_path = r"C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\MLDL\train_test_validation_spacy"
os.makedirs(output_path, exist_ok=True)

# Save CSV files
train_df.to_csv(os.path.join(output_path, "train.csv"), index=False)
val_df.to_csv(os.path.join(output_path, "val.csv"), index=False)
test_df.to_csv(os.path.join(output_path, "test.csv"), index=False)

# Save JSON files
with open(os.path.join(output_path, "train_data.json"), "w", encoding="utf-8") as f:
    json.dump(train_data, f, ensure_ascii=False)

with open(os.path.join(output_path, "val_data.json"), "w", encoding="utf-8") as f:
    json.dump(val_data, f, ensure_ascii=False)

with open(os.path.join(output_path, "test_data.json"), "w", encoding="utf-8") as f:
    json.dump(test_data, f, ensure_ascii=False)

print("✅ All files saved successfully!")
# Out:
# ✅ All files saved successfully!

# %% [markdown]
# # Train spaCy NER Model

# %%
pip install spacy
# Out:
# Collecting spacy
#   Downloading spacy-3.8.7-cp310-cp310-win_amd64.whl.metadata (28 kB)
# Collecting spacy-legacy<3.1.0,>=3.0.11 (from spacy)
#   Downloading spacy_legacy-3.0.12-py2.py3-none-any.whl.metadata (2.8 kB)
# Collecting spacy-loggers<2.0.0,>=1.0.0 (from spacy)
#   Downloading spacy_loggers-1.0.5-py3-none-any.whl.metadata (23 kB)
# Collecting murmurhash<1.1.0,>=0.28.0 (from spacy)
#   Downloading murmurhash-1.0.13-cp310-cp310-win_amd64.whl.metadata (2.2 kB)
# Collecting cymem<2.1.0,>=2.0.2 (from spacy)
#   Downloading cymem-2.0.11-cp310-cp310-win_amd64.whl.metadata (8.8 kB)
# Collecting preshed<3.1.0,>=3.0.2 (from spacy)
#   Downloading preshed-3.0.10-cp310-cp310-win_amd64.whl.metadata (2.5 kB)
# Collecting thinc<8.4.0,>=8.3.4 (from spacy)
#   Downloading thinc-8.3.6-cp310-cp310-win_amd64.whl.metadata (15 kB)
# Collecting wasabi<1.2.0,>=0.9.1 (from spacy)
#   Downloading wasabi-1.1.3-py3-none-any.whl.metadata (28 kB)
# Collecting srsly<3.0.0,>=2.4.3 (from spacy)
#   Downloading srsly-2.5.1-cp310-cp310-win_amd64.whl.metadata (20 kB)
# Collecting catalogue<2.1.0,>=2.0.6 (from spacy)
#   Downloading catalogue-2.0.10-py3-none-any.whl.metadata (14 kB)
# Collecting weasel<0.5.0,>=0.1.0 (from spacy)
#   Downloading weasel-0.4.1-py3-none-any.whl.metadata (4.6 kB)
# Collecting typer<1.0.0,>=0.3.0 (from spacy)
#   Using cached typer-0.16.0-py3-none-any.whl.metadata (15 kB)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in c:\users\gouthum\.conda\envs\myenv\lib\site-packages (from spacy) (4.67.1)
# Requirement already satisfied: numpy>=1.19.0 in c:\users\gouthum\.conda\envs\myenv\lib\site-packages (from spacy) (2.2.6)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in c:\users\gouthum\.conda\envs\myenv\lib\site-packages (from spacy) (2.32.4)
# Collecting pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 (from spacy)
#   Using cached pydantic-2.11.7-py3-none-any.whl.metadata (67 kB)
# Requirement already satisfied: jinja2 in c:\users\gouthum\.conda\envs\myenv\lib\site-packages (from spacy) (3.1.6)
# Requirement already satisfied: setuptools in c:\users\gouthum\.conda\envs\myenv\lib\site-packages (from spacy) (80.9.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\gouthum\.conda\envs\myenv\lib\site-packages (from spacy) (25.0)
# Collecting langcodes<4.0.0,>=3.2.0 (from spacy)
#   Downloading langcodes-3.5.0-py3-none-any.whl.metadata (29 kB)
# Collecting language-data>=1.2 (from langcodes<4.0.0,>=3.2.0->spacy)
#   Downloading language_data-1.3.0-py3-none-any.whl.metadata (4.3 kB)
# Collecting annotated-types>=0.6.0 (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy)
#   Using cached annotated_types-0.7.0-py3-none-any.whl.metadata (15 kB)
# Collecting pydantic-core==2.33.2 (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy)
#   Using cached pydantic_core-2.33.2-cp310-cp310-win_amd64.whl.metadata (6.9 kB)
# Collecting typing-extensions>=4.12.2 (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy)
#   Using cached typing_extensions-4.14.1-py3-none-any.whl.metadata (3.0 kB)
# Collecting typing-inspection>=0.4.0 (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy)
#   Using cached typing_inspection-0.4.1-py3-none-any.whl.metadata (2.6 kB)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\gouthum\.conda\envs\myenv\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\gouthum\.conda\envs\myenv\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\gouthum\.conda\envs\myenv\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\gouthum\.conda\envs\myenv\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (2025.6.15)
# Collecting blis<1.4.0,>=1.3.0 (from thinc<8.4.0,>=8.3.4->spacy)
#   Downloading blis-1.3.0-cp310-cp310-win_amd64.whl.metadata (7.6 kB)
# Collecting confection<1.0.0,>=0.0.1 (from thinc<8.4.0,>=8.3.4->spacy)
#   Downloading confection-0.1.5-py3-none-any.whl.metadata (19 kB)
# Requirement already satisfied: colorama in c:\users\gouthum\.conda\envs\myenv\lib\site-packages (from tqdm<5.0.0,>=4.38.0->spacy) (0.4.6)
# Requirement already satisfied: click>=8.0.0 in c:\users\gouthum\.conda\envs\myenv\lib\site-packages (from typer<1.0.0,>=0.3.0->spacy) (8.1.8)
# Collecting shellingham>=1.3.0 (from typer<1.0.0,>=0.3.0->spacy)
#   Using cached shellingham-1.5.4-py2.py3-none-any.whl.metadata (3.5 kB)
# Requirement already satisfied: rich>=10.11.0 in c:\users\gouthum\.conda\envs\myenv\lib\site-packages (from typer<1.0.0,>=0.3.0->spacy) (14.0.0)
# Collecting cloudpathlib<1.0.0,>=0.7.0 (from weasel<0.5.0,>=0.1.0->spacy)
#   Downloading cloudpathlib-0.21.1-py3-none-any.whl.metadata (14 kB)
# Collecting smart-open<8.0.0,>=5.2.1 (from weasel<0.5.0,>=0.1.0->spacy)
#   Downloading smart_open-7.3.0.post1-py3-none-any.whl.metadata (24 kB)
# Requirement already satisfied: wrapt in c:\users\gouthum\.conda\envs\myenv\lib\site-packages (from smart-open<8.0.0,>=5.2.1->weasel<0.5.0,>=0.1.0->spacy) (1.14.1)
# Collecting marisa-trie>=1.1.0 (from language-data>=1.2->langcodes<4.0.0,>=3.2.0->spacy)
#   Downloading marisa_trie-1.2.1-cp310-cp310-win_amd64.whl.metadata (9.3 kB)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\gouthum\.conda\envs\myenv\lib\site-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\gouthum\.conda\envs\myenv\lib\site-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy) (2.19.1)
# Requirement already satisfied: mdurl~=0.1 in c:\users\gouthum\.conda\envs\myenv\lib\site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy) (0.1.2)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\gouthum\.conda\envs\myenv\lib\site-packages (from jinja2->spacy) (3.0.2)
# Downloading spacy-3.8.7-cp310-cp310-win_amd64.whl (14.9 MB)
#    ---------------------------------------- 0.0/14.9 MB ? eta -:--:--
#    -- ------------------------------------- 1.0/14.9 MB 8.5 MB/s eta 0:00:02
#    --------------------- ------------------ 7.9/14.9 MB 25.6 MB/s eta 0:00:01
#    ---------------------------------------  14.7/14.9 MB 29.8 MB/s eta 0:00:01
#    ---------------------------------------- 14.9/14.9 MB 26.1 MB/s eta 0:00:00
# Downloading catalogue-2.0.10-py3-none-any.whl (17 kB)
# Downloading cymem-2.0.11-cp310-cp310-win_amd64.whl (39 kB)
# Downloading langcodes-3.5.0-py3-none-any.whl (182 kB)
# Downloading murmurhash-1.0.13-cp310-cp310-win_amd64.whl (24 kB)
# Downloading preshed-3.0.10-cp310-cp310-win_amd64.whl (117 kB)
# Using cached pydantic-2.11.7-py3-none-any.whl (444 kB)
# Using cached pydantic_core-2.33.2-cp310-cp310-win_amd64.whl (2.0 MB)
# Downloading spacy_legacy-3.0.12-py2.py3-none-any.whl (29 kB)
# Downloading spacy_loggers-1.0.5-py3-none-any.whl (22 kB)
# Downloading srsly-2.5.1-cp310-cp310-win_amd64.whl (632 kB)
#    ---------------------------------------- 0.0/632.3 kB ? eta -:--:--
#    --------------------------------------- 632.3/632.3 kB 11.9 MB/s eta 0:00:00
# Downloading thinc-8.3.6-cp310-cp310-win_amd64.whl (1.8 MB)
#    ---------------------------------------- 0.0/1.8 MB ? eta -:--:--
#    ---------------------------------------- 1.8/1.8 MB 19.4 MB/s eta 0:00:00
# Downloading blis-1.3.0-cp310-cp310-win_amd64.whl (6.2 MB)
#    ---------------------------------------- 0.0/6.2 MB ? eta -:--:--
#    -------------------------------------- - 6.0/6.2 MB 33.5 MB/s eta 0:00:01
#    ---------------------------------------- 6.2/6.2 MB 27.3 MB/s eta 0:00:00
# Downloading confection-0.1.5-py3-none-any.whl (35 kB)
# Using cached typer-0.16.0-py3-none-any.whl (46 kB)
# Downloading wasabi-1.1.3-py3-none-any.whl (27 kB)
# Downloading weasel-0.4.1-py3-none-any.whl (50 kB)
# Downloading cloudpathlib-0.21.1-py3-none-any.whl (52 kB)
# Downloading smart_open-7.3.0.post1-py3-none-any.whl (61 kB)
# Using cached annotated_types-0.7.0-py3-none-any.whl (13 kB)
# Downloading language_data-1.3.0-py3-none-any.whl (5.4 MB)
#    ---------------------------------------- 0.0/5.4 MB ? eta -:--:--
#    -------------------------------------- - 5.2/5.4 MB 31.9 MB/s eta 0:00:01
#    ---------------------------------------- 5.4/5.4 MB 25.2 MB/s eta 0:00:00
# Downloading marisa_trie-1.2.1-cp310-cp310-win_amd64.whl (151 kB)
# Using cached typing_extensions-4.14.1-py3-none-any.whl (43 kB)
# Using cached shellingham-1.5.4-py2.py3-none-any.whl (9.8 kB)
# Using cached typing_inspection-0.4.1-py3-none-any.whl (14 kB)
# Installing collected packages: cymem, wasabi, typing-extensions, spacy-loggers, spacy-legacy, smart-open, shellingham, murmurhash, marisa-trie, catalogue, blis, annotated-types, typing-inspection, srsly, pydantic-core, preshed, language-data, cloudpathlib, typer, pydantic, langcodes, confection, weasel, thinc, spacy
#
#    - --------------------------------------  1/25 [wasabi]
#    - --------------------------------------  1/25 [wasabi]
#    - --------------------------------------  1/25 [wasabi]
#   Attempting uninstall: typing-extensions
#    - --------------------------------------  1/25 [wasabi]
#     Found existing installation: typing_extensions 4.10.0
#    - --------------------------------------  1/25 [wasabi]
#     Uninstalling typing_extensions-4.10.0:
#    - --------------------------------------  1/25 [wasabi]
#    --- ------------------------------------  2/25 [typing-extensions]
#    --- ------------------------------------  2/25 [typing-extensions]
#    --- ------------------------------------  2/25 [typing-extensions]
#    --- ------------------------------------  2/25 [typing-extensions]
#    --- ------------------------------------  2/25 [typing-extensions]
#    --- ------------------------------------  2/25 [typing-extensions]
#    --- ------------------------------------  2/25 [typing-extensions]
#    --- ------------------------------------  2/25 [typing-extensions]
#    --- ------------------------------------  2/25 [typing-extensions]
#    --- ------------------------------------  2/25 [typing-extensions]
#    --- ------------------------------------  2/25 [typing-extensions]
#    --- ------------------------------------  2/25 [typing-extensions]
#    --- ------------------------------------  2/25 [typing-extensions]
#    --- ------------------------------------  2/25 [typing-extensions]
#    --- ------------------------------------  2/25 [typing-extensions]
#    --- ------------------------------------  2/25 [typing-extensions]
#    --- ------------------------------------  2/25 [typing-extensions]
#    --- ------------------------------------  2/25 [typing-extensions]
#    --- ------------------------------------  2/25 [typing-extensions]
#    --- ------------------------------------  2/25 [typing-extensions]
#    --- ------------------------------------  2/25 [typing-extensions]
#    --- ------------------------------------  2/25 [typing-extensions]
#    --- ------------------------------------  2/25 [typing-extensions]
#    --- ------------------------------------  2/25 [typing-extensions]
#    --- ------------------------------------  2/25 [typing-extensions]
#    --- ------------------------------------  2/25 [typing-extensions]
#    --- ------------------------------------  2/25 [typing-extensions]
#    --- ------------------------------------  2/25 [typing-extensions]
#    --- ------------------------------------  2/25 [typing-extensions]
#    --- ------------------------------------  2/25 [typing-extensions]
#    --- ------------------------------------  2/25 [typing-extensions]
#    --- ------------------------------------  2/25 [typing-extensions]
#    --- ------------------------------------  2/25 [typing-extensions]
#    --- ------------------------------------  2/25 [typing-extensions]
#    --- ------------------------------------  2/25 [typing-extensions]
#    --- ------------------------------------  2/25 [typing-extensions]
#    --- ------------------------------------  2/25 [typing-extensions]
#    --- ------------------------------------  2/25 [typing-extensions]
#    --- ------------------------------------  2/25 [typing-extensions]
#    --- ------------------------------------  2/25 [typing-extensions]
#    --- ------------------------------------  2/25 [typing-extensions]
#    --- ------------------------------------  2/25 [typing-extensions]
#    --- ------------------------------------  2/25 [typing-extensions]
#    --- ------------------------------------  2/25 [typing-extensions]
#    --- ------------------------------------  2/25 [typing-extensions]
#    --- ------------------------------------  2/25 [typing-extensions]
#    --- ------------------------------------  2/25 [typing-extensions]
#    --- ------------------------------------  2/25 [typing-extensions]
#    --- ------------------------------------  2/25 [typing-extensions]
#    --- ------------------------------------  2/25 [typing-extensions]
#    --- ------------------------------------  2/25 [typing-extensions]
#    --- ------------------------------------  2/25 [typing-extensions]
#    --- ------------------------------------  2/25 [typing-extensions]
#    --- ------------------------------------  2/25 [typing-extensions]
#    --- ------------------------------------  2/25 [typing-extensions]
#    --- ------------------------------------  2/25 [typing-extensions]
#    --- ------------------------------------  2/25 [typing-extensions]
#    --- ------------------------------------  2/25 [typing-extensions]
#    --- ------------------------------------  2/25 [typing-extensions]
#    --- ------------------------------------  2/25 [typing-extensions]
#    --- ------------------------------------  2/25 [typing-extensions]
#    --- ------------------------------------  2/25 [typing-extensions]
#    --- ------------------------------------  2/25 [typing-extensions]
#    --- ------------------------------------  2/25 [typing-extensions]
#    --- ------------------------------------  2/25 [typing-extensions]
#    --- ------------------------------------  2/25 [typing-extensions]
#    --- ------------------------------------  2/25 [typing-extensions]
#    --- ------------------------------------  2/25 [typing-extensions]
#    --- ------------------------------------  2/25 [typing-extensions]
#    --- ------------------------------------  2/25 [typing-extensions]
#    --- ------------------------------------  2/25 [typing-extensions]
#    --- ------------------------------------  2/25 [typing-extensions]
#    --- ------------------------------------  2/25 [typing-extensions]
#    --- ------------------------------------  2/25 [typing-extensions]
#    --- ------------------------------------  2/25 [typing-extensions]
#    --- ------------------------------------  2/25 [typing-extensions]
#    --- ------------------------------------  2/25 [typing-extensions]
#    --- ------------------------------------  2/25 [typing-extensions]
#    --- ------------------------------------  2/25 [typing-extensions]
#    --- ------------------------------------  2/25 [typing-extensions]
#    --- ------------------------------------  2/25 [typing-extensions]
#    --- ------------------------------------  2/25 [typing-extensions]
#    --- ------------------------------------  2/25 [typing-extensions]
#    --- ------------------------------------  2/25 [typing-extensions]
#    --- ------------------------------------  2/25 [typing-extensions]
#    --- ------------------------------------  2/25 [typing-extensions]
#    --- ------------------------------------  2/25 [typing-extensions]
#    --- ------------------------------------  2/25 [typing-extensions]
#    --- ------------------------------------  2/25 [typing-extensions]
#    --- ------------------------------------  2/25 [typing-extensions]
#    --- ------------------------------------  2/25 [typing-extensions]
#    --- ------------------------------------  2/25 [typing-extensions]
#    --- ------------------------------------  2/25 [typing-extensions]
#    --- ------------------------------------  2/25 [typing-extensions]
#    --- ------------------------------------  2/25 [typing-extensions]
#    --- ------------------------------------  2/25 [typing-extensions]
#    --- ------------------------------------  2/25 [typing-extensions]
#    --- ------------------------------------  2/25 [typing-extensions]
#    --- ------------------------------------  2/25 [typing-extensions]
#    --- ------------------------------------  2/25 [typing-extensions]
#    --- ------------------------------------  2/25 [typing-extensions]
#    --- ------------------------------------  2/25 [typing-extensions]
#    --- ------------------------------------  2/25 [typing-extensions]
#    --- ------------------------------------  2/25 [typing-extensions]
#    --- ------------------------------------  2/25 [typing-extensions]
#    --- ------------------------------------  2/25 [typing-extensions]
#    --- ------------------------------------  2/25 [typing-extensions]
#    --- ------------------------------------  2/25 [typing-extensions]
#    --- ------------------------------------  2/25 [typing-extensions]
#       Successfully uninstalled typing_extensions-4.10.0
#    --- ------------------------------------  2/25 [typing-extensions]
#    --- ------------------------------------  2/25 [typing-extensions]
#    ---- -----------------------------------  3/25 [spacy-loggers]
#    ---- -----------------------------------  3/25 [spacy-loggers]
#    ---- -----------------------------------  3/25 [spacy-loggers]
#    ------ ---------------------------------  4/25 [spacy-legacy]
#    ------ ---------------------------------  4/25 [spacy-legacy]
#    ------ ---------------------------------  4/25 [spacy-legacy]
#    -------- -------------------------------  5/25 [smart-open]
#    -------- -------------------------------  5/25 [smart-open]
#    -------- -------------------------------  5/25 [smart-open]
#    -------- -------------------------------  5/25 [smart-open]
#    --------- ------------------------------  6/25 [shellingham]
#    ----------- ----------------------------  7/25 [murmurhash]
#    ------------ ---------------------------  8/25 [marisa-trie]
#    -------------- -------------------------  9/25 [catalogue]
#    ---------------- ----------------------- 10/25 [blis]
#    ---------------- ----------------------- 10/25 [blis]
#    ---------------- ----------------------- 10/25 [blis]
#    ----------------- ---------------------- 11/25 [annotated-types]
#    -------------------- ------------------- 13/25 [srsly]
#    -------------------- ------------------- 13/25 [srsly]
#    -------------------- ------------------- 13/25 [srsly]
#    -------------------- ------------------- 13/25 [srsly]
#    -------------------- ------------------- 13/25 [srsly]
#    -------------------- ------------------- 13/25 [srsly]
#    -------------------- ------------------- 13/25 [srsly]
#    -------------------- ------------------- 13/25 [srsly]
#    -------------------- ------------------- 13/25 [srsly]
#    -------------------- ------------------- 13/25 [srsly]
#    -------------------- ------------------- 13/25 [srsly]
#    -------------------- ------------------- 13/25 [srsly]
#    -------------------- ------------------- 13/25 [srsly]
#    -------------------- ------------------- 13/25 [srsly]
#    -------------------- ------------------- 13/25 [srsly]
#    -------------------- ------------------- 13/25 [srsly]
#    -------------------- ------------------- 13/25 [srsly]
#    -------------------- ------------------- 13/25 [srsly]
#    -------------------- ------------------- 13/25 [srsly]
#    -------------------- ------------------- 13/25 [srsly]
#    -------------------- ------------------- 13/25 [srsly]
#    -------------------- ------------------- 13/25 [srsly]
#    -------------------- ------------------- 13/25 [srsly]
#    -------------------- ------------------- 13/25 [srsly]
#    ---------------------- ----------------- 14/25 [pydantic-core]
#    ------------------------ --------------- 15/25 [preshed]
#    ------------------------- -------------- 16/25 [language-data]
#    ------------------------- -------------- 16/25 [language-data]
#    ------------------------- -------------- 16/25 [language-data]
#    ------------------------- -------------- 16/25 [language-data]
#    ------------------------- -------------- 16/25 [language-data]
#    ------------------------- -------------- 16/25 [language-data]
#    ------------------------- -------------- 16/25 [language-data]
#    ------------------------- -------------- 16/25 [language-data]
#    ------------------------- -------------- 16/25 [language-data]
#    ------------------------- -------------- 16/25 [language-data]
#    ------------------------- -------------- 16/25 [language-data]
#    ------------------------- -------------- 16/25 [language-data]
#    ------------------------- -------------- 16/25 [language-data]
#    ------------------------- -------------- 16/25 [language-data]
#    ------------------------- -------------- 16/25 [language-data]
#    ------------------------- -------------- 16/25 [language-data]
#    ------------------------- -------------- 16/25 [language-data]
#    ------------------------- -------------- 16/25 [language-data]
#    ------------------------- -------------- 16/25 [language-data]
#    ------------------------- -------------- 16/25 [language-data]
#    ------------------------- -------------- 16/25 [language-data]
#    ------------------------- -------------- 16/25 [language-data]
#    --------------------------- ------------ 17/25 [cloudpathlib]
#    --------------------------- ------------ 17/25 [cloudpathlib]
#    --------------------------- ------------ 17/25 [cloudpathlib]
#    --------------------------- ------------ 17/25 [cloudpathlib]
#    --------------------------- ------------ 17/25 [cloudpathlib]
#    --------------------------- ------------ 17/25 [cloudpathlib]
#    ---------------------------- ----------- 18/25 [typer]
#    ---------------------------- ----------- 18/25 [typer]
#    ---------------------------- ----------- 18/25 [typer]
#    ---------------------------- ----------- 18/25 [typer]
#    ------------------------------ --------- 19/25 [pydantic]
#    ------------------------------ --------- 19/25 [pydantic]
#    ------------------------------ --------- 19/25 [pydantic]
#    ------------------------------ --------- 19/25 [pydantic]
#    ------------------------------ --------- 19/25 [pydantic]
#    ------------------------------ --------- 19/25 [pydantic]
#    ------------------------------ --------- 19/25 [pydantic]
#    ------------------------------ --------- 19/25 [pydantic]
#    ------------------------------ --------- 19/25 [pydantic]
#    ------------------------------ --------- 19/25 [pydantic]
#    ------------------------------ --------- 19/25 [pydantic]
#    ------------------------------ --------- 19/25 [pydantic]
#    ------------------------------ --------- 19/25 [pydantic]
#    ------------------------------ --------- 19/25 [pydantic]
#    ------------------------------ --------- 19/25 [pydantic]
#    ------------------------------ --------- 19/25 [pydantic]
#    ------------------------------ --------- 19/25 [pydantic]
#    ------------------------------ --------- 19/25 [pydantic]
#    ------------------------------ --------- 19/25 [pydantic]
#    ------------------------------ --------- 19/25 [pydantic]
#    ------------------------------ --------- 19/25 [pydantic]
#    ------------------------------ --------- 19/25 [pydantic]
#    -------------------------------- ------- 20/25 [langcodes]
#    -------------------------------- ------- 20/25 [langcodes]
#    -------------------------------- ------- 20/25 [langcodes]
#    --------------------------------- ------ 21/25 [confection]
#    ----------------------------------- ---- 22/25 [weasel]
#    ----------------------------------- ---- 22/25 [weasel]
#    ----------------------------------- ---- 22/25 [weasel]
#    ----------------------------------- ---- 22/25 [weasel]
#    ----------------------------------- ---- 22/25 [weasel]
#    ----------------------------------- ---- 22/25 [weasel]
#    ----------------------------------- ---- 22/25 [weasel]
#    ------------------------------------ --- 23/25 [thinc]
#    ------------------------------------ --- 23/25 [thinc]
#    ------------------------------------ --- 23/25 [thinc]
#    ------------------------------------ --- 23/25 [thinc]
#    ------------------------------------ --- 23/25 [thinc]
#    ------------------------------------ --- 23/25 [thinc]
#    ------------------------------------ --- 23/25 [thinc]
#    ------------------------------------ --- 23/25 [thinc]
#    ------------------------------------ --- 23/25 [thinc]
#    ------------------------------------ --- 23/25 [thinc]
#    ------------------------------------ --- 23/25 [thinc]
#    ------------------------------------ --- 23/25 [thinc]
#    ------------------------------------ --- 23/25 [thinc]
#    ------------------------------------ --- 23/25 [thinc]
#    ------------------------------------ --- 23/25 [thinc]
#    ------------------------------------ --- 23/25 [thinc]
#    ------------------------------------ --- 23/25 [thinc]
#    ------------------------------------ --- 23/25 [thinc]
#    ------------------------------------ --- 23/25 [thinc]
#    ------------------------------------ --- 23/25 [thinc]
#    ------------------------------------ --- 23/25 [thinc]
#    ------------------------------------ --- 23/25 [thinc]
#    ------------------------------------ --- 23/25 [thinc]
#    ------------------------------------ --- 23/25 [thinc]
#    ------------------------------------ --- 23/25 [thinc]
#    ------------------------------------ --- 23/25 [thinc]
#    ------------------------------------ --- 23/25 [thinc]
#    ------------------------------------ --- 23/25 [thinc]
#    ------------------------------------ --- 23/25 [thinc]
#    ------------------------------------ --- 23/25 [thinc]
#    ------------------------------------ --- 23/25 [thinc]
#    -------------------------------------- - 24/25 [spacy]
#    -------------------------------------- - 24/25 [spacy]
#    -------------------------------------- - 24/25 [spacy]
#    -------------------------------------- - 24/25 [spacy]
#    -------------------------------------- - 24/25 [spacy]
#    -------------------------------------- - 24/25 [spacy]
#    -------------------------------------- - 24/25 [spacy]
#    -------------------------------------- - 24/25 [spacy]
#    -------------------------------------- - 24/25 [spacy]
#    -------------------------------------- - 24/25 [spacy]
#    -------------------------------------- - 24/25 [spacy]
#    -------------------------------------- - 24/25 [spacy]
#    -------------------------------------- - 24/25 [spacy]
#    -------------------------------------- - 24/25 [spacy]
#    -------------------------------------- - 24/25 [spacy]
#    -------------------------------------- - 24/25 [spacy]
#    -------------------------------------- - 24/25 [spacy]
#    -------------------------------------- - 24/25 [spacy]
#    -------------------------------------- - 24/25 [spacy]
#    -------------------------------------- - 24/25 [spacy]
#    -------------------------------------- - 24/25 [spacy]
#    -------------------------------------- - 24/25 [spacy]
#    -------------------------------------- - 24/25 [spacy]
#    -------------------------------------- - 24/25 [spacy]
#    -------------------------------------- - 24/25 [spacy]
#    -------------------------------------- - 24/25 [spacy]
#    -------------------------------------- - 24/25 [spacy]
#    -------------------------------------- - 24/25 [spacy]
#    -------------------------------------- - 24/25 [spacy]
#    -------------------------------------- - 24/25 [spacy]
#    -------------------------------------- - 24/25 [spacy]
#    -------------------------------------- - 24/25 [spacy]
#    -------------------------------------- - 24/25 [spacy]
#    -------------------------------------- - 24/25 [spacy]
#    -------------------------------------- - 24/25 [spacy]
#    -------------------------------------- - 24/25 [spacy]
#    -------------------------------------- - 24/25 [spacy]
#    -------------------------------------- - 24/25 [spacy]
#    -------------------------------------- - 24/25 [spacy]
#    -------------------------------------- - 24/25 [spacy]
#    -------------------------------------- - 24/25 [spacy]
#    -------------------------------------- - 24/25 [spacy]
#    -------------------------------------- - 24/25 [spacy]
#    -------------------------------------- - 24/25 [spacy]
#    -------------------------------------- - 24/25 [spacy]
#    -------------------------------------- - 24/25 [spacy]
#    -------------------------------------- - 24/25 [spacy]
#    -------------------------------------- - 24/25 [spacy]
#    -------------------------------------- - 24/25 [spacy]
#    -------------------------------------- - 24/25 [spacy]
#    -------------------------------------- - 24/25 [spacy]
#    -------------------------------------- - 24/25 [spacy]
#    -------------------------------------- - 24/25 [spacy]
#    -------------------------------------- - 24/25 [spacy]
#    -------------------------------------- - 24/25 [spacy]
#    -------------------------------------- - 24/25 [spacy]
#    -------------------------------------- - 24/25 [spacy]
#    -------------------------------------- - 24/25 [spacy]
#    -------------------------------------- - 24/25 [spacy]
#    -------------------------------------- - 24/25 [spacy]
#    -------------------------------------- - 24/25 [spacy]
#    -------------------------------------- - 24/25 [spacy]
#    -------------------------------------- - 24/25 [spacy]
#    -------------------------------------- - 24/25 [spacy]
#    -------------------------------------- - 24/25 [spacy]
#    -------------------------------------- - 24/25 [spacy]
#    -------------------------------------- - 24/25 [spacy]
#    -------------------------------------- - 24/25 [spacy]
#    -------------------------------------- - 24/25 [spacy]
#    -------------------------------------- - 24/25 [spacy]
#    -------------------------------------- - 24/25 [spacy]
#    -------------------------------------- - 24/25 [spacy]
#    -------------------------------------- - 24/25 [spacy]
#    -------------------------------------- - 24/25 [spacy]
#    -------------------------------------- - 24/25 [spacy]
#    -------------------------------------- - 24/25 [spacy]
#    -------------------------------------- - 24/25 [spacy]
#    -------------------------------------- - 24/25 [spacy]
#    -------------------------------------- - 24/25 [spacy]
#    -------------------------------------- - 24/25 [spacy]
#    -------------------------------------- - 24/25 [spacy]
#    -------------------------------------- - 24/25 [spacy]
#    -------------------------------------- - 24/25 [spacy]
#    -------------------------------------- - 24/25 [spacy]
#    -------------------------------------- - 24/25 [spacy]
#    -------------------------------------- - 24/25 [spacy]
#    -------------------------------------- - 24/25 [spacy]
#    -------------------------------------- - 24/25 [spacy]
#    -------------------------------------- - 24/25 [spacy]
#    -------------------------------------- - 24/25 [spacy]
#    -------------------------------------- - 24/25 [spacy]
#    -------------------------------------- - 24/25 [spacy]
#    -------------------------------------- - 24/25 [spacy]
#    -------------------------------------- - 24/25 [spacy]
#    -------------------------------------- - 24/25 [spacy]
#    -------------------------------------- - 24/25 [spacy]
#    -------------------------------------- - 24/25 [spacy]
#    -------------------------------------- - 24/25 [spacy]
#    -------------------------------------- - 24/25 [spacy]
#    -------------------------------------- - 24/25 [spacy]
#    -------------------------------------- - 24/25 [spacy]
#    -------------------------------------- - 24/25 [spacy]
#    -------------------------------------- - 24/25 [spacy]
#    -------------------------------------- - 24/25 [spacy]
#    -------------------------------------- - 24/25 [spacy]
#    -------------------------------------- - 24/25 [spacy]
#    -------------------------------------- - 24/25 [spacy]
#    -------------------------------------- - 24/25 [spacy]
#    -------------------------------------- - 24/25 [spacy]
#    -------------------------------------- - 24/25 [spacy]
#    -------------------------------------- - 24/25 [spacy]
#    -------------------------------------- - 24/25 [spacy]
#    -------------------------------------- - 24/25 [spacy]
#    -------------------------------------- - 24/25 [spacy]
#    -------------------------------------- - 24/25 [spacy]
#    -------------------------------------- - 24/25 [spacy]
#    -------------------------------------- - 24/25 [spacy]
#    -------------------------------------- - 24/25 [spacy]
#    -------------------------------------- - 24/25 [spacy]
#    -------------------------------------- - 24/25 [spacy]
#    -------------------------------------- - 24/25 [spacy]
#    -------------------------------------- - 24/25 [spacy]
#    -------------------------------------- - 24/25 [spacy]
#    -------------------------------------- - 24/25 [spacy]
#    -------------------------------------- - 24/25 [spacy]
#    -------------------------------------- - 24/25 [spacy]
#    -------------------------------------- - 24/25 [spacy]
#    -------------------------------------- - 24/25 [spacy]
#    -------------------------------------- - 24/25 [spacy]
#    -------------------------------------- - 24/25 [spacy]
#    -------------------------------------- - 24/25 [spacy]
#    -------------------------------------- - 24/25 [spacy]
#    -------------------------------------- - 24/25 [spacy]
#    -------------------------------------- - 24/25 [spacy]
#    -------------------------------------- - 24/25 [spacy]
#    -------------------------------------- - 24/25 [spacy]
#    -------------------------------------- - 24/25 [spacy]
#    -------------------------------------- - 24/25 [spacy]
#    -------------------------------------- - 24/25 [spacy]
#    -------------------------------------- - 24/25 [spacy]
#    -------------------------------------- - 24/25 [spacy]
#    -------------------------------------- - 24/25 [spacy]
#    -------------------------------------- - 24/25 [spacy]
#    -------------------------------------- - 24/25 [spacy]
#    -------------------------------------- - 24/25 [spacy]
#    -------------------------------------- - 24/25 [spacy]
#    -------------------------------------- - 24/25 [spacy]
#    -------------------------------------- - 24/25 [spacy]
#    -------------------------------------- - 24/25 [spacy]
#    -------------------------------------- - 24/25 [spacy]
#    -------------------------------------- - 24/25 [spacy]
#    -------------------------------------- - 24/25 [spacy]
#    -------------------------------------- - 24/25 [spacy]
#    -------------------------------------- - 24/25 [spacy]
#    ---------------------------------------- 25/25 [spacy]
#
# Successfully installed annotated-types-0.7.0 blis-1.3.0 catalogue-2.0.10 cloudpathlib-0.21.1 confection-0.1.5 cymem-2.0.11 langcodes-3.5.0 language-data-1.3.0 marisa-trie-1.2.1 murmurhash-1.0.13 preshed-3.0.10 pydantic-2.11.7 pydantic-core-2.33.2 shellingham-1.5.4 smart-open-7.3.0.post1 spacy-3.8.7 spacy-legacy-3.0.12 spacy-loggers-1.0.5 srsly-2.5.1 thinc-8.3.6 typer-0.16.0 typing-extensions-4.14.1 typing-inspection-0.4.1 wasabi-1.1.3 weasel-0.4.1
# Note: you may need to restart the kernel to use updated packages.
#   WARNING: The script typer.exe is installed in 'C:\Users\Gouthum\.conda\envs\myenv\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script weasel.exe is installed in 'C:\Users\Gouthum\.conda\envs\myenv\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script spacy.exe is installed in 'C:\Users\Gouthum\.conda\envs\myenv\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# streamlit 1.45.1 requires packaging<25,>=20, but you have packaging 25.0 which is incompatible.
# tensorflow-intel 2.13.0 requires numpy<=1.24.3,>=1.22, but you have numpy 2.2.6 which is incompatible.
# tensorflow-intel 2.13.0 requires typing-extensions<4.6.0,>=3.6.6, but you have typing-extensions 4.14.1 which is incompatible.

# %% [markdown]
# ## B. Create a Training Script

# %%
import spacy
import json
from pathlib import Path
import random
from spacy.training.example import Example

# 🔁 Load training data
with open(r"C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\MLDL\train_test_validation_spacy\train_data.json", "r", encoding="utf-8") as f:
    TRAIN_DATA = json.load(f)

with open(r"C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\MLDL\train_test_validation_spacy\val_data.json", "r", encoding="utf-8") as f:
    VAL_DATA = json.load(f)

# 🧠 Create blank model and add NER pipe
nlp = spacy.blank("en")
ner = nlp.add_pipe("ner")

# 🏷 Add labels to the NER component
for _, annotations in TRAIN_DATA:
    for ent in annotations.get("entities"):
        ner.add_label(ent[2])

# ✅ Initialize model
nlp.initialize()

# 🎯 Training loop
n_iter = 15
for itn in range(n_iter):
    print(f"🔁 Iteration {itn+1}/{n_iter}")
    random.shuffle(TRAIN_DATA)
    losses = {}
    for text, annotations in TRAIN_DATA:
        doc = nlp.make_doc(text)
        example = Example.from_dict(doc, annotations)
        nlp.update([example], losses=losses)
    print("Losses:", losses)

# 💾 Save model
output_dir = Path(r"C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\MLDL\spacy_ner_model")
nlp.to_disk(output_dir)
print(f"✅ Model saved to {output_dir}")
# Out:
# 🔁 Iteration 1/15
# Losses: {'ner': np.float32(146169.62)}
# 🔁 Iteration 2/15
# Losses: {'ner': np.float32(143313.45)}
# 🔁 Iteration 3/15
# Losses: {'ner': np.float32(135726.12)}
# 🔁 Iteration 4/15
# Losses: {'ner': np.float32(126056.88)}
# 🔁 Iteration 5/15
# Losses: {'ner': np.float32(109551.99)}
# 🔁 Iteration 6/15
# Losses: {'ner': np.float32(83829.125)}
# 🔁 Iteration 7/15
# Losses: {'ner': np.float32(48227.34)}
# 🔁 Iteration 8/15
# Losses: {'ner': np.float32(17685.71)}
# 🔁 Iteration 9/15
# Losses: {'ner': np.float32(5605.11)}
# 🔁 Iteration 10/15
# Losses: {'ner': np.float32(4102.5054)}
# 🔁 Iteration 11/15
# Losses: {'ner': np.float32(4097.5986)}
# 🔁 Iteration 12/15
# Losses: {'ner': np.float32(4087.968)}
# 🔁 Iteration 13/15
# Losses: {'ner': np.float32(4137.3716)}
# 🔁 Iteration 14/15
# Losses: {'ner': np.float32(4115.6187)}
# 🔁 Iteration 15/15
# Losses: {'ner': np.float32(4084.739)}
# ✅ Model saved to C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\MLDL\spacy_ner_model

# %%
script_content = """
import spacy
import json
from pathlib import Path
import random
from spacy.training.example import Example

# 🔁 Load training data
with open(r"C:\\Users\\Gouthum\\Downloads\\Project\\batch_1\\batch_1\\MLDL\\train_test_validation_spacy\\train_data.json", "r", encoding="utf-8") as f:
    TRAIN_DATA = json.load(f)

with open(r"C:\\Users\\Gouthum\\Downloads\\Project\\batch_1\\batch_1\\MLDL\\train_test_validation_spacy\\val_data.json", "r", encoding="utf-8") as f:
    VAL_DATA = json.load(f)

# 🧠 Create blank model and add NER pipe
nlp = spacy.blank("en")
ner = nlp.add_pipe("ner")

# 🏷 Add labels to the NER component
for _, annotations in TRAIN_DATA:
    for ent in annotations.get("entities"):
        ner.add_label(ent[2])

# ✅ Initialize model
nlp.initialize()

# 🎯 Training loop
n_iter = 15
for itn in range(n_iter):
    print(f"🔁 Iteration {itn+1}/{n_iter}")
    random.shuffle(TRAIN_DATA)
    losses = {}
    for text, annotations in TRAIN_DATA:
        doc = nlp.make_doc(text)
        example = Example.from_dict(doc, annotations)
        nlp.update([example], losses=losses)
    print("Losses:", losses)

# 💾 Save model
output_dir = Path(r"C:\\Users\\Gouthum\\Downloads\\Project\\batch_1\\batch_1\\MLDL\\spacy_ner_model")
nlp.to_disk(output_dir)
print(f"✅ Model saved to {output_dir}")
"""

# Define full path for the script
script_path = r"C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\MLDL\train_test_validation_spacy\train_spacy_ner.py"

# Write the script to the file
with open(script_path, "w", encoding="utf-8") as file:
    file.write(script_content)

print(f"✅ Script saved to: {script_path}")
# Out:
# ✅ Script saved to: C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\MLDL\train_test_validation_spacy\train_spacy_ner.py

# %% [markdown]
# # Load the Trained Model and Make Predictions

# %%
import spacy

# Load your trained spaCy NER model
model_path = r"C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\MLDL\spacy_ner_model"
nlp = spacy.load(model_path)

# %%
# Example invoice text

text = """
Invoice no: 69721323

Date of issue: 05/07/2019


Seller: Murray-Eaton
773 Joseph Plains
West Nicoleville, AZ 46136

Tax Id: 936-71-8228


Client:

Cuevas, Reid and Hurst
98071 Daniel Heights
Careyside, MS 59400

Tax Id: 949-88-4885

IBAN: GB22XZGA27411153163644

ITEMS
No. Description Qty UM Net price Net worth VAT [%] Gross
worth
ils Tie Dyeing Fluffy Rugs Anti-Skid 4,00 each 25,48 101,92 10% 112,11
Area Rug Dining Room Carpet
Floor Bedroom Mat
2. Galaxy Butterfly Area Rugs 2,00 each 13,69 27,38 10% 30,12
Children Bedroom Non-Slip
Doormat Floor Mat Carpet
oo Colorful Marble Printed Living 2,00 each 12,49 24,98 10% 27,48
Room and Bedroom Area Rugs
Carpet CNK2413
4. Red Traditional Oriental 4,00 each 39,98 159,92 10% 175,91
Medallion 8x10 Area Rug Carpet
2x3 Mat 5x7 Rugs
Dy YILONG 2.5'x4' Small Hand 4,00 each 2 000,00 8 000,00 10% 8 800,00
Knotted Silk Carpets Antistatic
Floor Area Rug 844B
SUMMARY
VAT [%] Net worth VAT Gross worth
10% 8 314,20 831,42 9 145,62
Total $ 8 314,20 $ 831,42 $9 145,62
"""


# Process text
doc = nlp(text)

# Print predicted entities
for ent in doc.ents:
    print(f"{ent.label_}: {ent.text}")

# %%
doc
# Out:
# Invoice no: 69721323
#
# Date of issue: 05/07/2019
#
#
# Seller: Murray-Eaton
# 773 Joseph Plains
# West Nicoleville, AZ 46136
#
# Tax Id: 936-71-8228
#
#
# Client:
#
# Cuevas, Reid and Hurst
# 98071 Daniel Heights
# Careyside, MS 59400
#
# Tax Id: 949-88-4885
#
# IBAN: GB22XZGA27411153163644
#
# ITEMS
# No. Description Qty UM Net price Net worth VAT [%] Gross
# worth
# ils Tie Dyeing Fluffy Rugs Anti-Skid 4,00 each 25,48 101,92 10% 112,11
# Area Rug Dining Room Carpet
# Floor Bedroom Mat
# 2. Galaxy Butterfly Area Rugs 2,00 each 13,69 27,38 10% 30,12
# Children Bedroom Non-Slip
# Doormat Floor Mat Carpet
# oo Colorful Marble Printed Living 2,00 each 12,49 24,98 10% 27,48
# Room and Bedroom Area Rugs
# Carpet CNK2413
# 4. Red Traditional Oriental 4,00 each 39,98 159,92 10% 175,91
# Medallion 8x10 Area Rug Carpet
# 2x3 Mat 5x7 Rugs
# Dy YILONG 2.5'x4' Small Hand 4,00 each 2 000,00 8 000,00 10% 8 800,00
# Knotted Silk Carpets Antistatic
# Floor Area Rug 844B
# SUMMARY
# VAT [%] Net worth VAT Gross worth
# 10% 8 314,20 831,42 9 145,62
# Total $ 8 314,20 $ 831,42 $9 145,62

# %% [markdown]
# ## Test the data

# %%
script_content = '''
import spacy

# Load the trained model
model_path = r"C:\\Users\\Gouthum\\Downloads\\Project\\batch_1\\batch_1\\MLDL\\spacy_ner_model"
nlp = spacy.load(model_path)

# Sample test invoice text
test_text = \"\"\" 
Invoice no: 69721323
Date of issue: 05/07/2019

Seller: Murray-Eaton
773 Joseph Plains
West Nicoleville, AZ 46136

Tax Id: 936-71-8228

Client:
Cuevas, Reid and Hurst
98071 Daniel Heights
Careyside, MS 59400

Tax Id: 949-88-4885

IBAN: GB22XZGA27411153163644

ITEMS
No. Description Qty UM Net price Net worth VAT [%] Gross worth
1. Tie Dyeing Fluffy Rugs Anti-Skid 4,00 each 25,48 101,92 10% 112,11
2. Galaxy Butterfly Area Rugs 2,00 each 13,69 27,38 10% 30,12
3. Colorful Marble Printed Rugs 2,00 each 12,49 24,98 10% 27,48
4. Red Traditional Oriental Carpet 4,00 each 39,98 159,92 10% 175,91
5. YILONG Silk Carpets 4,00 each 2000,00 8000,00 10% 8800,00

SUMMARY
VAT [%] Net worth VAT Gross worth
10% 8 314,20 831,42 9 145,62
Total $ 8 314,20 $ 831,42 $9 145,62
\"\"\"

# Run model
doc = nlp(test_text)

# Print extracted entities
print("🔍 Entities detected:\\n")
for ent in doc.ents:
    print(f"➤ {ent.label_:15} → {ent.text}")
'''

save_path = r"C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\MLDL\train_test_validation_spacy\test_spacy_ner.py"
with open(save_path, "w", encoding="utf-8") as f:
    f.write(script_content.strip())

print(f"✅ Script saved to {save_path}")
# Out:
# ✅ Script saved to C:\Users\Gouthum\Downloads\Project\batch_1\batch_1\MLDL\train_test_validation_spacy\test_spacy_ner.py

# %% [markdown]
# #  Evaluate the NER Model

# %%
from spacy.scorer import Scorer
from spacy.training.example import Example

examples = []
for text, annotations in test_data:  # TEST_DATA in SpaCy format
    doc = nlp.make_doc(text)
    example = Example.from_dict(doc, annotations)
    examples.append(example)

scorer = Scorer()
scores = scorer.score(examples)
print(scores)
# Out:
# {'token_acc': 1.0, 'token_p': 1.0, 'token_r': 1.0, 'token_f': 1.0, 'sents_p': None, 'sents_r': None, 'sents_f': None, 'tag_acc': None, 'pos_acc': None, 'morph_acc': None, 'morph_micro_p': None, 'morph_micro_r': None, 'morph_micro_f': None, 'morph_per_feat': None, 'dep_uas': None, 'dep_las': None, 'dep_las_per_type': None, 'ents_p': 0.0, 'ents_r': 0.0, 'ents_f': 0.0, 'ents_per_type': {'INVOICE_NUMBER': {'p': 0.0, 'r': 0.0, 'f': 0.0}, 'INVOICE_DATE': {'p': 0.0, 'r': 0.0, 'f': 0.0}}, 'cats_score': 0.0, 'cats_score_desc': 'macro F', 'cats_micro_p': 0.0, 'cats_micro_r': 0.0, 'cats_micro_f': 0.0, 'cats_macro_p': 0.0, 'cats_macro_r': 0.0, 'cats_macro_f': 0.0, 'cats_macro_auc': 0.0, 'cats_f_per_type': {}, 'cats_auc_per_type': {}}

# %% [markdown]
# # Spacy ML model with joblib

# %%
import joblib

# Suppose your model object is `nlp`
joblib.dump(nlp, "spacy_ner_model.joblib")
# Out:
# ['spacy_ner_model.joblib']

# %%
import joblib

nlp = joblib.load("spacy_ner_model.joblib")

# %%
nlp

# %%
nlp.to_disk("spacy_ner_model_folder")

# %%
import spacy
nlp = spacy.load("spacy_ner_model_folder")

# %%
nlp
